# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from astropy.io import fits

# %%
plt.imshow(fits.getdata('delve_dr1_sim_code/sim/backgrounds/g.fits')[625])

# %%
# Load the data
lenses = np.load('delve_dr1_lens_training_data/training_data/training_lens.npy')

# %%
lenses.shape
# Out:
# (39999, 45, 45, 4)

# %%
metadata_lens = pd.read_csv('delve_dr1_lens_training_data/training_data/metadata_lens.csv')

# %%
    # cols = ['PLANE_1-NUMBER_OF_OBJECTS',
    #         'PLANE_1-OBJECT_1-NAME',
    #         'PLANE_1-OBJECT_1-NUMBER_OF_LIGHT_PROFILES',
    #         'PLANE_1-OBJECT_1-NUMBER_OF_SHEAR_PROFILES',
    #         'PLANE_1-OBJECT_1-NUMBER_OF_MASS_PROFILES',
    #         'PLANE_1-OBJECT_1-HOST',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-NAME',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-magnitude',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_x',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_y',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e1',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e2',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-R_sersic',
    #         'PLANE_1-OBJECT_1-LIGHT_PROFILE_1-n_sersic',
    #         ]

# %%
def model_metadata(band):
    cols = [i for i in metadata_lens.columns if ('PLANE' in i) and ('-' + band in i)]
    return metadata_lens[cols]

# %%
plt.hist(model_metadata('r')[['PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma2-r',]], bins  = 100)
plt.title("$\\gamma$ Distribution | $\\gamma$ ~ $\\log$N(0.05, 0.2)")
plt.xlabel("$\\gamma$")
plt.ylabel("Number of Images")
# Out:
# Text(0, 0.5, 'Number of Images')

# %%
model_metadata('z').loc[374]
# Out:
# NUMBER_OF_PLANES-z                                           2
# PLANE_1-NUMBER_OF_OBJECTS-z                                  1
# PLANE_1-OBJECT_1-NAME-z                               DARKLENS
# PLANE_2-NUMBER_OF_OBJECTS-z                                  1
# PLANE_2-OBJECT_1-NAME-z                                 SOURCE
# PLANE_1-OBJECT_1-REDSHIFT-z                           0.166842
# PLANE_1-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-z                  1
# PLANE_1-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-z                  1
# PLANE_1-OBJECT_1-NUMBER_OF_MASS_PROFILES-z                   1
# PLANE_1-OBJECT_1-HOST-z                                   None
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-NAME-z         SERSIC_ELLIPSE
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-magnitude-z              1000
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_x-z                0.0
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_y-z                0.0
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-R_sersic-z                6.0
# ...

# %%
plt.imshow(lenses[0, :, :, 0])
plt.colorbar()

# %%
l = [1, 2, 3, 3]

# %%
l[2::-1]
# Out:
# [3, 2, 1]
