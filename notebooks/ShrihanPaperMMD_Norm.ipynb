# %%
# Imports we will use
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
#from torchsummary import summary
from sklearn.metrics import r2_score

# For matplotlib
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# Set Seed
torch.manual_seed(22)

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Load data function
def create_dataloader(img_path, metadata_path, batch_size):
    '''
    Creates dataloader for training, reserving the last 1000 images for validation/testing
    '''
    data = np.load(img_path).squeeze()
    length = len(data)
    data_train = torch.tensor(data[:int(.7*length)])
    data_test = torch.tensor(data[int(.7*length):int(.9*length)])
    data_val = torch.tensor(data[int(.9*length):])

    metadata = pd.read_csv(metadata_path)
    labels = metadata['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()
    labels_train = torch.tensor(labels[:int(.7*length)])
    labels_test = torch.tensor(labels[int(.7*length):int(.9*length)])
    labels_val = torch.tensor(labels[int(.9*length):])

    data_train.cuda()
    data_test.cuda()
    data_val.cuda()
    labels_train.cuda()
    labels_test.cuda()
    labels_val.cuda()

    train_dataset = TensorDataset(data_train, labels_train)
    test_dataset = TensorDataset(data_test, labels_test)
    val_dataset = TensorDataset(data_val, labels_val)

    train_dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_dataloader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=True)

    return train_dataloader, test_dataloader, val_dataloader, data

# %%
#mount to drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Load in data
source_img_path = '/content/gdrive/MyDrive/deepskies/paxnorm_source.npy'
target_img_path = '/content/gdrive/MyDrive/deepskies/paxnorm_target.npy'
source_meta = '/content/gdrive/MyDrive/deepskies/pax_source_metadata.csv'
target_meta = '/content/gdrive/MyDrive/deepskies/pax_target_metadata.csv'
batch_size = 32
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path,
                                                                                                        source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path,
                                                                                                        target_meta, batch_size)

# %%
# Define data visualization function
def visualize_data(data):
    '''
    visualizes 16 random images from dataset
    '''
    #get random indices
    x = np.empty(1)
    i = 1

    while i < 16:
        example_num = int(random.randrange(0, len(data[0:])))
        if example_num != x[i-1]:
            x = np.append(x, [example_num])
            i += 1

    #plot the examples for source
    fig1=plt.figure(figsize=(8,8))

    for i in range(16):
        plt.subplot(4, 4, i + 1)
        plt.axis("off")

        example_indices = int(x[i])

        example_image = np.squeeze(data[example_indices:(example_indices + 1)]) #change band by switching 0:1 to 1:2 or 2:3

        plt.imshow(example_image, aspect='auto', cmap='viridis')

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %%
# Define and initialize model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.feature = nn.Sequential()
        self.feature.add_module('f_conv1', nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_bn1', nn.BatchNorm2d(8))
        self.feature.add_module('f_pool1', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv2', nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_bn2', nn.BatchNorm2d(16))
        self.feature.add_module('f_pool2', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv3', nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        self.feature.add_module('f_bn3', nn.BatchNorm2d(32))
        self.feature.add_module('f_pool3', nn.MaxPool2d(kernel_size=2, stride=2))

        self.regressor = nn.Sequential()
        self.regressor.add_module('r_fc1', nn.Linear(in_features=32*5*5, out_features=128))
        self.regressor.add_module('r_relu1', nn.ReLU(True))
        #self.regressor.add_module('r_fc2', nn.Linear(in_features=128, out_features=64))
        #self.regressor.add_module('r_relu2', nn.ReLU(True))
        self.regressor.add_module('r_fc3', nn.Linear(in_features=128, out_features=1))

    def forward(self, x):
        x = x.view(-1, 1, 40, 40)

        features = self.feature(x)
        features = features.view(-1, 32*5*5)
        estimate = self.regressor(features)
        estimate = F.relu(estimate)
        estimate = estimate.view(-1)

        return estimate, features

# %%
# code from https://github.com/ZongxianLee/MMD_Loss.Pytorch

class MMD_loss(nn.Module):
    def __init__(self, kernel_mul = 2.0, kernel_num = 5):
        super(MMD_loss, self).__init__()
        self.kernel_num = kernel_num
        self.kernel_mul = kernel_mul
        self.fix_sigma = None
        return
    def guassian_kernel(self, source, target, kernel_mul=2.0, kernel_num=5, fix_sigma=None):
        n_samples = int(source.size()[0])+int(target.size()[0])
        total = torch.cat([source, target], dim=0)

        total0 = total.unsqueeze(0).expand(int(total.size(0)), int(total.size(0)), int(total.size(1)))
        total1 = total.unsqueeze(1).expand(int(total.size(0)), int(total.size(0)), int(total.size(1)))
        L2_distance = ((total0-total1)**2).sum(2)
        if fix_sigma:
            bandwidth = fix_sigma
        else:
            bandwidth = torch.sum(L2_distance.data) / (n_samples**2-n_samples)
        bandwidth /= kernel_mul ** (kernel_num // 2)
        bandwidth_list = [bandwidth * (kernel_mul**i) for i in range(kernel_num)]
        kernel_val = [torch.exp(-L2_distance / bandwidth_temp) for bandwidth_temp in bandwidth_list]
        return sum(kernel_val)

    def forward(self, source, target):
        batch_size = int(source.size()[0])
        kernels = self.guassian_kernel(source, target, kernel_mul=self.kernel_mul, kernel_num=self.kernel_num, fix_sigma=self.fix_sigma)
        XX = kernels[:batch_size, :batch_size]
        YY = kernels[batch_size:, batch_size:]
        XY = kernels[:batch_size, batch_size:]
        YX = kernels[batch_size:, :batch_size]
        loss = torch.mean(XX + YY - XY -YX)
        return loss

# %%
# Define training loop
def train_loop(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, optimizer, n_epoch, epoch):

    domain_error = 0
    domain_classifier_accuracy = 0
    estimator_error = 0
    score_list = np.array([])

    len_dataloader = min(len(source_dataloader), len(target_dataloader))
    data_source_iter = iter(source_dataloader)
    data_target_iter = iter(target_dataloader)

    i = 0
    while i < len_dataloader:

        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # Source Training

        data_source = next(data_source_iter)
        X, y = data_source
        X = X.float()
        X = X.cuda()
        y = y.cuda()

        model.zero_grad()
        batch_size = len(y)

        domain_label = torch.zeros(batch_size)
        domain_label = domain_label.long()
        domain_label = domain_label.cuda()

        estimate_output, domain_output_source = model(X)

        estimate_loss = regressor_loss_fn(estimate_output, y)

        # Target Training

        data_target = next(data_target_iter)
        X_target, _ = data_target
        X_target = X_target.float()
        X_target = X_target.cuda()

        batch_size = len(X_target)

        _, domain_output_target = model(X_target)
        domain_loss = da_loss(domain_output_source, domain_output_target)

        loss = estimate_loss + domain_loss*1.4
        loss.backward()
        optimizer.step()

        # Update values

        domain_error += domain_loss.item()
        #domain_classifier_accuracy +=
        estimator_error += estimate_loss.item()
        score = r2_score(y.cpu().detach().numpy(), estimate_output.cpu().detach().numpy())
        score_list = np.append(score_list, score)

        i += 1

    score = np.mean(score_list)
    domain_error = domain_error / (len_dataloader)
    estimator_error /= len_dataloader

    return [domain_error, estimator_error, score]

# %%
# Define testing loop

def test_loop(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, n_epoch, epoch):

    with torch.no_grad():

        len_dataloader = min(len(source_dataloader), len(target_dataloader))
        data_source_iter = iter(source_dataloader)
        data_target_iter = iter(target_dataloader)

        domain_classifier_error = 0
        domain_classifier_accuracy = 0
        estimator_error = 0
        estimator_error_target = 0
        score_list = np.array([])
        score_list_target = np.array([])

        i = 0
        while i < len_dataloader:

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # Source Testing

            data_source = next(data_source_iter)
            X, y = data_source
            X = X.float()
            X = X.cuda()
            y = y.cuda()

            batch_size = len(y)

            #domain_label = torch.zeros(batch_size)
            #domain_label = domain_label.long()
            #domain_label = domain_label.cuda()

            estimate_output, domain_output = model(X)

            estimate_loss = regressor_loss_fn(estimate_output, y)
            #domain_loss_source = classifier_loss_fn(domain_output, domain_label)

            # Target Testing

            data_target = next(data_target_iter)
            X_target, y_target = data_target
            X_target = X_target.float()
            X_target = X_target.cuda()
            y_target = y_target.cuda()

            batch_size = len(X_target)

            #domain_label = torch.ones(batch_size)
            #domain_label = domain_label.long()
            #domain_label = domain_label.cuda()

            estimate_output_target, domain_output = model(X_target)

            estimate_loss_target = regressor_loss_fn(estimate_output_target, y_target)
            #domain_loss_target = classifier_loss_fn(domain_output, domain_label)

            # Update values

           # domain_classifier_error += domain_loss_source.item()
            #domain_classifier_error += domain_loss_target.item()
            #domain_classifier_accuracy +=
            estimator_error += estimate_loss.item()
            estimator_error_target += estimate_loss_target.item()
            score = r2_score(y.cpu(), estimate_output.cpu())
            score_list = np.append(score_list, score)
            score_target = r2_score(y_target.cpu(), estimate_output_target.cpu())
            score_list_target = np.append(score_list_target, score_target)

            i += 1

        score = np.mean(score_list)
        score_target = np.mean(score_list_target)
        #classifier_error = domain_classifier_error / (len_dataloader * 2)
        estimator_error /= len_dataloader
        estimator_error_target /= len_dataloader
    classifier_error = 1
    return [classifier_error, estimator_error, estimator_error_target, score, score_target]

# %%
# Initialize dictionary for training stats
import time
model = NeuralNetwork().cuda()
# Hyper parameter presets
learning_rate = 6e-5
epochs = 30
# Define loss functions and optimizer
regressor_loss_fn = nn.MSELoss().cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
da_loss = MMD_loss()

stats = {'train_domain_classifier_error':[],
             'train_estimator_error':[],
             'train_score':[],
             'val_domain_classifier_error':[],
             'val_estimator_error':[],
             'val_estimator_error_target':[],
             'val_score':[],
             'val_score_target':[]}

# Train
for i in range(epochs):
        start_time = time.time()
        print(f"Epoch {i+1}\n-------------------------------")
        vals = train_loop(source_train_dataloader, target_train_dataloader, model,
                   regressor_loss_fn, da_loss, optimizer, epochs, i)

        vals_validate = test_loop(source_val_dataloader, target_val_dataloader,
                         model, regressor_loss_fn, da_loss, epochs, i)
        print(time.time() - start_time)
        to_print = (
            f'Train Estimator Error = {vals[1]}\n'
            f'Train Estimator R2 Score = {vals[2]:.4f}\n'
            f'Train Domain Classifier Error = {vals[0]}\n'
            f'Validation Source Estimator Error = {vals_validate[1]}\n'
            f'Validation Source R2 Score = {vals_validate[3]:.4f}\n'
            f'Validation Target Estimator Error = {vals_validate[2]}\n'
            f'Validation Target R2 Score = {vals_validate[4]:.4f}\n'
            f'Validation Domain Classifier Error = {vals_validate[0]}\n'
        )

        print(to_print)
# Out:
# Epoch 1
# -------------------------------
# 13.581112623214722
# Train Estimator Error = 0.09199322644072896
# Train Estimator R2 Score = 0.8157
# Train Domain Classifier Error = 0.2670615230579699
# Validation Source Estimator Error = 0.03646218794498854
# Validation Source R2 Score = 0.9251
# Validation Target Estimator Error = 0.2777657509799216
# Validation Target R2 Score = 0.4482
# Validation Domain Classifier Error = 1
#
# Epoch 2
# -------------------------------
# 10.377604246139526
# Train Estimator Error = 0.023997597736042587
# Train Estimator R2 Score = 0.9512
# Train Domain Classifier Error = 0.1560812352371608
# Validation Source Estimator Error = 0.021160885608594887
# Validation Source R2 Score = 0.9561
# Validation Target Estimator Error = 0.2441540381805912
# Validation Target R2 Score = 0.5169
# Validation Domain Classifier Error = 1
#
# Epoch 3
# -------------------------------
# 9.853866338729858
# Train Estimator Error = 0.018986416839733993
# Train Estimator R2 Score = 0.9613
# Train Domain Classifier Error = 0.12684479085439085
# Validation Source Estimator Error = 0.0188018555758865
# Validation Source R2 Score = 0.9610
# Validation Target Estimator Error = 0.2243359449088194
# Validation Target R2 Score = 0.5637
# Validation Domain Classifier Error = 1
#
# Epoch 4
# -------------------------------
# 9.862557411193848
# Train Estimator Error = 0.016686171725293592
# Train Estimator R2 Score = 0.9660
# Train Domain Classifier Error = 0.10639657654290444
# Validation Source Estimator Error = 0.014433606201486223
# Validation Source R2 Score = 0.9705
# Validation Target Estimator Error = 0.19040933047320432
# Validation Target R2 Score = 0.6224
# Validation Domain Classifier Error = 1
#
# Epoch 5
# -------------------------------
# 11.282002449035645
# Train Estimator Error = 0.014782161311411607
# Train Estimator R2 Score = 0.9700
# Train Domain Classifier Error = 0.09711363937848774
# Validation Source Estimator Error = 0.013902857089949072
# Validation Source R2 Score = 0.9709
# Validation Target Estimator Error = 0.17992561082741257
# Validation Target R2 Score = 0.6395
# Validation Domain Classifier Error = 1
#
# Epoch 6
# -------------------------------
# 11.177637815475464
# Train Estimator Error = 0.013926084319357735
# Train Estimator R2 Score = 0.9716
# Train Domain Classifier Error = 0.09024614101817229
# Validation Source Estimator Error = 0.013192928081769853
# Validation Source R2 Score = 0.9721
# Validation Target Estimator Error = 0.18601261591835386
# Validation Target R2 Score = 0.6389
# Validation Domain Classifier Error = 1
#
# Epoch 7
# -------------------------------
# 11.3385329246521
# Train Estimator Error = 0.012580905173917111
# Train Estimator R2 Score = 0.9743
# Train Domain Classifier Error = 0.08457219048694348
# Validation Source Estimator Error = 0.013591168377145081
# Validation Source R2 Score = 0.9714
# Validation Target Estimator Error = 0.163277925057396
# Validation Target R2 Score = 0.6816
# Validation Domain Classifier Error = 1
#
# Epoch 8
# -------------------------------
# 9.412630081176758
# Train Estimator Error = 0.012310691208491813
# Train Estimator R2 Score = 0.9750
# Train Domain Classifier Error = 0.0827114367057353
# Validation Source Estimator Error = 0.011099833912055964
# Validation Source R2 Score = 0.9771
# Validation Target Estimator Error = 0.15860066971011982
# Validation Target R2 Score = 0.6875
# Validation Domain Classifier Error = 1
#
# Epoch 9
# -------------------------------
# 10.317763805389404
# Train Estimator Error = 0.01134519436046774
# Train Estimator R2 Score = 0.9769
# Train Domain Classifier Error = 0.07978843465120526
# Validation Source Estimator Error = 0.010512172836205287
# Validation Source R2 Score = 0.9783
# Validation Target Estimator Error = 0.17654029934839077
# Validation Target R2 Score = 0.6521
# Validation Domain Classifier Error = 1
#
# Epoch 10
# -------------------------------
# 10.309382915496826
# Train Estimator Error = 0.010800870143939524
# Train Estimator R2 Score = 0.9781
# Train Domain Classifier Error = 0.07782429059664336
# Validation Source Estimator Error = 0.009727731305560108
# Validation Source R2 Score = 0.9800
# Validation Target Estimator Error = 0.1668673993628116
# Validation Target R2 Score = 0.6741
# Validation Domain Classifier Error = 1
#
# Epoch 11
# -------------------------------
# 9.793317079544067
# Train Estimator Error = 0.010452489983894857
# Train Estimator R2 Score = 0.9787
# Train Domain Classifier Error = 0.07639904363826598
# Validation Source Estimator Error = 0.009681407658822217
# Validation Source R2 Score = 0.9797
# Validation Target Estimator Error = 0.15697582474180088
# Validation Target R2 Score = 0.6949
# Validation Domain Classifier Error = 1
#
# Epoch 12
# -------------------------------
# 9.87688946723938
# Train Estimator Error = 0.009743996442106622
# Train Estimator R2 Score = 0.9801
# Train Domain Classifier Error = 0.07539513770838216
# Validation Source Estimator Error = 0.00889408345197796
# Validation Source R2 Score = 0.9815
# Validation Target Estimator Error = 0.15544565978228667
# Validation Target R2 Score = 0.6966
# Validation Domain Classifier Error = 1
#
# Epoch 13
# -------------------------------
# 10.417881727218628
# Train Estimator Error = 0.009569445237605893
# Train Estimator R2 Score = 0.9805
# Train Domain Classifier Error = 0.07334916813425052
# Validation Source Estimator Error = 0.009633569625224088
# Validation Source R2 Score = 0.9799
# Validation Target Estimator Error = 0.14803784862635241
# Validation Target R2 Score = 0.7078
# Validation Domain Classifier Error = 1
#
# Epoch 14
# -------------------------------
# 10.335829257965088
# Train Estimator Error = 0.009174344441649152
# Train Estimator R2 Score = 0.9814
# Train Domain Classifier Error = 0.07219227442562144
# Validation Source Estimator Error = 0.009470508772001904
# Validation Source R2 Score = 0.9806
# Validation Target Estimator Error = 0.15910812545638936
# Validation Target R2 Score = 0.6872
# Validation Domain Classifier Error = 1
#
# Epoch 15
# -------------------------------
# 9.256653547286987
# Train Estimator Error = 0.009000444036893124
# Train Estimator R2 Score = 0.9818
# Train Domain Classifier Error = 0.07118474883819084
# Validation Source Estimator Error = 0.00956014986001667
# Validation Source R2 Score = 0.9803
# Validation Target Estimator Error = 0.16705236109388863
# Validation Target R2 Score = 0.6747
# Validation Domain Classifier Error = 1
#
# Epoch 16
# -------------------------------
# 10.327528953552246
# Train Estimator Error = 0.00896486739216839
# Train Estimator R2 Score = 0.9818
# Train Domain Classifier Error = 0.07042521125444601
# Validation Source Estimator Error = 0.007881428806146808
# Validation Source R2 Score = 0.9839
# Validation Target Estimator Error = 0.1554679355708657
# Validation Target R2 Score = 0.6945
# Validation Domain Classifier Error = 1
#
# Epoch 17
# -------------------------------
# 10.346488952636719
# Train Estimator Error = 0.008602441103160177
# Train Estimator R2 Score = 0.9825
# Train Domain Classifier Error = 0.07057200246056375
# Validation Source Estimator Error = 0.009423192009139972
# Validation Source R2 Score = 0.9808
# Validation Target Estimator Error = 0.17477289347606859
# Validation Target R2 Score = 0.6625
# Validation Domain Classifier Error = 1
#
# Epoch 18
# -------------------------------
# 9.778363943099976
# Train Estimator Error = 0.00826381700550984
# Train Estimator R2 Score = 0.9832
# Train Domain Classifier Error = 0.06878443808895851
# Validation Source Estimator Error = 0.00893218778548347
# Validation Source R2 Score = 0.9812
# Validation Target Estimator Error = 0.13490204109697584
# Validation Target R2 Score = 0.7348
# Validation Domain Classifier Error = 1
#
# Epoch 19
# -------------------------------
# 9.720883846282959
# Train Estimator Error = 0.008250556516518962
# Train Estimator R2 Score = 0.9833
# Train Domain Classifier Error = 0.06888323923031471
# Validation Source Estimator Error = 0.008449520534616272
# Validation Source R2 Score = 0.9815
# Validation Target Estimator Error = 0.15966157235537365
# Validation Target R2 Score = 0.6864
# Validation Domain Classifier Error = 1
#
# Epoch 20
# -------------------------------
# 10.345067501068115
# Train Estimator Error = 0.007859433107069562
# Train Estimator R2 Score = 0.9840
# Train Domain Classifier Error = 0.06647057709891956
# Validation Source Estimator Error = 0.007750319953189249
# Validation Source R2 Score = 0.9841
# Validation Target Estimator Error = 0.15207763512138348
# Validation Target R2 Score = 0.7018
# Validation Domain Classifier Error = 1
#
# Epoch 21
# -------------------------------
# 10.285476922988892
# Train Estimator Error = 0.007782782959603659
# Train Estimator R2 Score = 0.9842
# Train Domain Classifier Error = 0.0682988055016321
# Validation Source Estimator Error = 0.007373429235711599
# Validation Source R2 Score = 0.9848
# Validation Target Estimator Error = 0.14463488064753782
# Validation Target R2 Score = 0.7164
# Validation Domain Classifier Error = 1
#
# Epoch 22
# -------------------------------
# 9.379778861999512
# Train Estimator Error = 0.007571954974799095
# Train Estimator R2 Score = 0.9847
# Train Domain Classifier Error = 0.07007339639994409
# Validation Source Estimator Error = 0.008793221561202578
# Validation Source R2 Score = 0.9815
# Validation Target Estimator Error = 0.15348689191660303
# Validation Target R2 Score = 0.6991
# Validation Domain Classifier Error = 1
#
# Epoch 23
# -------------------------------
# 10.151494026184082
# Train Estimator Error = 0.007522204311111673
# Train Estimator R2 Score = 0.9848
# Train Domain Classifier Error = 0.0712604425418475
# Validation Source Estimator Error = 0.008116969666710704
# Validation Source R2 Score = 0.9831
# Validation Target Estimator Error = 0.14922603599394962
# Validation Target R2 Score = 0.7100
# Validation Domain Classifier Error = 1
#
# Epoch 24
# -------------------------------
# 10.181642293930054
# Train Estimator Error = 0.007620940325437778
# Train Estimator R2 Score = 0.9846
# Train Domain Classifier Error = 0.07326627641548514
# Validation Source Estimator Error = 0.008922996822519192
# Validation Source R2 Score = 0.9816
# Validation Target Estimator Error = 0.15953743690328234
# Validation Target R2 Score = 0.6879
# Validation Domain Classifier Error = 1
#
# Epoch 25
# -------------------------------
# 9.977151155471802
# Train Estimator Error = 0.007755387558259574
# Train Estimator R2 Score = 0.9844
# Train Domain Classifier Error = 0.07503341019521356
# Validation Source Estimator Error = 0.010000287620410038
# Validation Source R2 Score = 0.9792
# Validation Target Estimator Error = 0.1477454317982789
# Validation Target R2 Score = 0.7107
# Validation Domain Classifier Error = 1
#
# Epoch 26
# -------------------------------
# 9.45276427268982
# Train Estimator Error = 0.007866691429358677
# Train Estimator R2 Score = 0.9840
# Train Domain Classifier Error = 0.07562775674941771
# Validation Source Estimator Error = 0.008206529652545596
# Validation Source R2 Score = 0.9831
# Validation Target Estimator Error = 0.15062352110910568
# Validation Target R2 Score = 0.7060
# Validation Domain Classifier Error = 1
#
# Epoch 27
# -------------------------------
# 10.217795372009277
# Train Estimator Error = 0.008083716728486175
# Train Estimator R2 Score = 0.9836
# Train Domain Classifier Error = 0.07821438019887512
# Validation Source Estimator Error = 0.008323276419916256
# Validation Source R2 Score = 0.9830
# Validation Target Estimator Error = 0.1566467028419683
# Validation Target R2 Score = 0.6940
# Validation Domain Classifier Error = 1
#
# Epoch 28
# -------------------------------
# 10.252973318099976
# Train Estimator Error = 0.008435450297000545
# Train Estimator R2 Score = 0.9830
# Train Domain Classifier Error = 0.07786504538828538
# Validation Source Estimator Error = 0.00837835176865671
# Validation Source R2 Score = 0.9825
# Validation Target Estimator Error = 0.14729658656629027
# Validation Target R2 Score = 0.7121
# Validation Domain Classifier Error = 1
#
# Epoch 29
# -------------------------------
# 9.541378259658813
# Train Estimator Error = 0.009130423851106895
# Train Estimator R2 Score = 0.9816
# Train Domain Classifier Error = 0.08177040810858528
# Validation Source Estimator Error = 0.009654444482201223
# Validation Source R2 Score = 0.9798
# Validation Target Estimator Error = 0.14051444624449796
# Validation Target R2 Score = 0.7242
# Validation Domain Classifier Error = 1
#
# Epoch 30
# -------------------------------
# 11.456701755523682
# Train Estimator Error = 0.010755455194609801
# Train Estimator R2 Score = 0.9783
# Train Domain Classifier Error = 0.09022517310254534
# Validation Source Estimator Error = 0.012100349186332363
# Validation Source R2 Score = 0.9752
# Validation Target Estimator Error = 0.14828931355172661
# Validation Target R2 Score = 0.7114
# Validation Domain Classifier Error = 1

# %%
# Test Source
preds = np.array([])
true = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds = np.append(preds, pred.cpu())
        true = np.append(true, y.cpu())
        score = r2_score(y.cpu(), pred.cpu())
        score_list = np.append(score_list, score)

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true, preds,  color='black')
line = np.linspace(0, 4, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD - Source')
# Out:
# Source R2 Score is 0.9753
# Text(0.5, 1.0, 'MMD - Source')

# %%
# Test target
preds = np.array([])
true = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds = np.append(preds, pred.cpu())
        true = np.append(true, y.cpu())
        score = r2_score(y.cpu(), pred.cpu())
        score_list = np.append(score_list, score)

score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true, preds,  color='black')
line = np.linspace(0, 4, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD - Target')
# Out:
# Target R2 Score is 0.7081
# Text(0.5, 1.0, 'MMD - Target')
