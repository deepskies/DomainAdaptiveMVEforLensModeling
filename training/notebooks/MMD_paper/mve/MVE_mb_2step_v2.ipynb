# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# Set Seed
torch.manual_seed(22)

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Load in data
head = Path.cwd().parents[3]
source_img_path = head / 'data/mb_lenscolor_source/mb_lenscolor_source.npy'
target_img_path = head / 'data/mb_lenscolor_target/mb_lenscolor_target.npy'
source_meta = head / 'data/mb_lenscolor_source/mb_lenscolor_source_metadata.csv'
target_meta = head / 'data/mb_lenscolor_target/mb_lenscolor_target_metadata.csv'
batch_size = 32
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %%
# Define and initialize model
class NeuralNetwork(nn.Module):
    def __init__(self, npix):
        super(NeuralNetwork, self).__init__()
        self.feature = nn.Sequential()
        self.feature.add_module('f_conv1', nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_bn1', nn.BatchNorm2d(8))
        self.feature.add_module('f_pool1', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv2', nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_bn2', nn.BatchNorm2d(16))
        self.feature.add_module('f_pool2', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv3', nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        self.feature.add_module('f_bn3', nn.BatchNorm2d(32))
        self.feature.add_module('f_pool3', nn.MaxPool2d(kernel_size=2, stride=2))

        self.regressor = nn.Sequential()
        self.regressor.add_module('r_fc1', nn.Linear(in_features=32*5*5, out_features=128))
        self.regressor.add_module('r_relu1', nn.ReLU(True))
        self.regressor.add_module('r_fc3', nn.Linear(in_features=128, out_features=2))

        self.npix = npix

    def forward(self, x):
        x = x.view(-1, 3, self.npix, self.npix)

        features = self.feature(x)
        features = features.view(-1, 32*5*5)
        estimate = self.regressor(features)
        estimate = F.relu(estimate)
        estimate = estimate.view(-1, 2)

        return estimate, features


    def get_feature(self, x):
        x = x.view(-1, 3, self.npix, self.npix)
        features = self.feature(x)
        features = features.view(-1, 32*5*5)
        return features

# %%
def loss_bnll(mean, variance, truth, beta, epsilon = 1e-7):  # beta=0.5):
    """Compute beta-NLL loss

    :param mean: Predicted mean of shape B x D
    :param variance: Predicted variance of shape B x D
    :param truth: truth of shape B x D
    :param beta: Parameter from range [0, 1] controlling relative
        weighting between data points, where `0` corresponds to
        high weight on low error points and `1` to an equal weighting.
    :returns: Loss per batch element of shape B
    """
    variance = variance + epsilon
    loss = 0.5 * ((truth - mean) ** 2 / variance + variance.log())
    if beta > 0:
        loss = loss * (variance.detach() ** beta)
    return loss.sum(axis=-1) / len(mean)

# %%
# Define training loop
def train_loop(source_dataloader, 
               target_dataloader, 
               model, 
               regressor_loss_fn,
               da_loss,
               optimizer,
               n_epoch,
               epoch,
               init_wt_da,
               final_wt_da,):
               # init_wt_mve,
               # final_wt_mve):
    """
    Trains the Neural Network on Source/Target Domains with the following loss:
        Loss = Source Regression Loss + 1.4 * DA MMD Loss
    
    source_dataloader: DataLoader for the source domain data.
	target_dataloader: DataLoader for the target domain data.
	model: The neural network model to be trained.
	regressor_loss_fn: Loss function for the regression task (e.g., MSELoss).
	da_loss: Loss function for domain adaptation (e.g., MMD loss).
	optimizer: Optimizer for the model parameters.
	n_epoch: Total number of epochs for training.
	epoch: Current epoch number.
    """

    domain_error = 0
    domain_classifier_accuracy = 0
    estimator_error = 0
    mve_error = 0
    score_list = np.array([])

    # Iteration length is shorter of the two datasets
    len_dataloader = min(len(source_dataloader), len(target_dataloader))
    data_source_iter = iter(source_dataloader)
    data_target_iter = iter(target_dataloader)

    # Iterate over the two datasets
    i = 0
    while i < len_dataloader:

        # Time-varying hyperparameter, p 0 -> infty, alpha 0 -> 1
        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader # UNUSED
        alpha = 2. / (1. + np.exp(-10 * p)) - 1 # UNUSED

        # Source Training

        # Load a batch of source data, move to GPU
        data_source = next(data_source_iter)
        X, y = data_source
        X = X.float()
        X = X.cuda()
        y = y.cuda()

        # Zero model gradients and labels
        model.zero_grad()
        batch_size = len(y)

        domain_label = torch.zeros(batch_size)
        domain_label = domain_label.long()
        domain_label = domain_label.cuda()

        # Apply data to model and get predictions, embeddings, apply gradients
        estimate_output, domain_output_source = model(X)
        mean = estimate_output[:, 0]
        variance = estimate_output[:, 1]

        # print(y.shape)
        # print(mean.shape)
        # Calculate source regression loss based on predictions
        estimate_loss = regressor_loss_fn(mean, y)

        
        # Target Training

        data_target = next(data_target_iter)
        X_target, _ = data_target
        X_target = X_target.float()
        X_target = X_target.cuda()

        batch_size = len(X_target)

        _, domain_output_target = model(X_target)

        # Calculate the DA Loss between source and target, MMD loss
        domain_loss = da_loss(domain_output_source, domain_output_target)
        mve_loss = loss_bnll(mean.flatten(), variance.flatten(), y, beta = 0.5)
        
        # Hyperparameter of da_weight set to weight domain loss vs source loss
        # Perhaps this is where alpha was initially used
        da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
        # mve_weight_power = (init_wt_mve - ((init_wt_mve - final_wt_mve) * (epoch / n_epoch)))
        # mve_weight = 10 ** (-mve_weight_power)

        # Calculate the R2 score of the predictions vs. labels
        score = r2_score(y.cpu().detach().numpy(), mean.cpu().detach().numpy())

        
        if (epoch) > 15:
            loss = mve_loss + domain_loss * da_weight 
        else:
            loss = estimate_loss + domain_loss * da_weight 

        
        
        # Backpropagation, update optimizer lr
        loss.backward()
        optimizer.step()

        # Update values
        
        # Domain loss is the DA loss or MMD loss between embedding outputs
        domain_error += domain_loss.item()

        # Estimator loss is the source data loss on regression
        estimator_error += estimate_loss.item()

        mve_error += mve_loss.item()

        score_list = np.append(score_list, score)

        i += 1

    # Calculate average scores/errors of batches for this epoch
    score = np.mean(score_list)
    domain_error = domain_error / (len_dataloader)
    estimator_error /= len_dataloader
    mve_error /= len_dataloader

    return [domain_error, estimator_error, mve_error, score]

# %%
def test_loop(source_dataloader, 
              target_dataloader, 
              model, 
              regressor_loss_fn, 
              da_loss, 
              n_epoch, 
              epoch):
    """
    Tests the model accuracy.
    
    source_dataloader: DataLoader for the source domain data.
	target_dataloader: DataLoader for the target domain data.
	model: The neural network model to be trained.
	regressor_loss_fn: Loss function for the regression task (e.g., MSELoss).
	da_loss: Loss function for domain adaptation (e.g., MMD loss). UNUSED
	n_epoch: Total number of epochs for training.
	epoch: Current epoch number.
    """

    
    # Evaluating without gradient computation in bg for validation
    with torch.no_grad():
        
        len_dataloader = min(len(source_dataloader), len(target_dataloader))
        data_source_iter = iter(source_dataloader)
        data_target_iter = iter(target_dataloader)

        
        domain_classifier_error = 0
        domain_classifier_accuracy = 0
        estimator_error = 0
        estimator_error_target = 0
        mve_error = 0
        mve_error_target = 0
        score_list = np.array([])
        score_list_target = np.array([])

        i = 0
        while i < len_dataloader:

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # Source Testing

            data_source = next(data_source_iter)
            X, y = data_source
            X = X.float()
            X = X.cuda()
            y = y.cuda()

            batch_size = len(y)

            estimate_output, domain_output = model(X)
            source_mean = estimate_output[:, 0]
            source_variance = estimate_output[:, 1]
            
            estimate_loss = regressor_loss_fn(source_mean, y)
            mve_loss = loss_bnll(source_mean.flatten(), source_variance.flatten(), y, beta = 0.5)

            # Target Testing

            data_target = next(data_target_iter)
            X_target, y_target = data_target
            X_target = X_target.float()
            X_target = X_target.cuda()
            y_target = y_target.cuda()

            batch_size = len(X_target)

            estimate_output_target, domain_output = model(X_target)
            target_mean = estimate_output_target[:, 0]
            target_variance = estimate_output_target[:, 1]
            
            estimate_loss_target = regressor_loss_fn(target_mean, y_target)
            mve_loss_target = loss_bnll(target_mean.flatten(), target_variance.flatten(), y_target, beta = 0.5)
            
            # Update values

            # Regression loss on validation testing
            estimator_error += estimate_loss.item()
            estimator_error_target += estimate_loss_target.item()

            # MVE loss on validation testing
            mve_error += mve_loss.item()
            mve_error_target += mve_loss_target.item()

            # R2 Scores on validation testing
            score = r2_score(y.cpu(), source_mean.cpu())
            score_list = np.append(score_list, score)
            score_target = r2_score(y_target.cpu(), target_mean.cpu())
            score_list_target = np.append(score_list_target, score_target)

            i += 1

        score = np.mean(score_list)
        score_target = np.mean(score_list_target)
        estimator_error /= len_dataloader
        estimator_error_target /= len_dataloader
        mve_error /= len_dataloader
        mve_error_target /= len_dataloader
        
    classifier_error = 1 # UNUSED, legacy
    return [classifier_error, estimator_error, estimator_error_target, score, score_target, mve_error, mve_error_target]

# %%
model = NeuralNetwork(npix=40).cuda()
learning_rate = 2e-5
epochs = 100
# Define loss functions and optimizer
regressor_loss_fn = nn.MSELoss().cuda()

# Try to adjust momentum -> see if that helps
# Try SGD, Adadelta, see if that helps
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
da_loss = MMD_loss()

source_labels = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
target_labels = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
mod_name = None#"models/mb_lenscolor_jul25_1700" #
stats = {'train_DA_loss':[],
             'train_regression_loss':[],
             'train_mve_loss':[],
             'train_r2_score':[],
             'val_source_regression_loss':[],
             'val_target_regression_loss':[],
             'val_source_r2_score':[],
             'val_target_r2_score':[],
             'val_source_mve_loss': [],
             'val_target_mve_loss': [],
            'epoch_no': 0}
if mod_name is not None:
    state = torch.load(mod_name)
    model.load_state_dict(state['state_dict'])
    optimizer.load_state_dict(state['optimizer'])
    
    stat_file = Path(mod_name+'.json')
    if stat_file.is_file():
        stats = json.load(open(mod_name+'.json', 'r'))

# %%
print("Beginning Training...")
mod_name = "models/mb_mve2step_aug1_2100"
# Train
best_target_R2 = -1.0
for i in range(stats['epoch_no'], stats['epoch_no'] + epochs):
        # if (i % 5 == 0):
        #     print("Generating Isomap...")
        #     source_iso, target_iso, trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
        #     show_isomaps(source_iso, target_iso, trained_source_iso, trained_target_iso, source_labels, target_labels, mod_name, stats["epoch_no"], 15000, 50, save = True)
        if (len(stats['val_target_r2_score']) > 0) and (stats['val_target_r2_score'][-1] > best_target_R2):
            print("Saving Model...", end = ' ')
            state = {
                    'epoch': stats['epoch_no'],
                    'state_dict': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    }
            torch.save(state, mod_name)
            best_target_R2 = stats['val_target_r2_score'][-1]
            print("Done.")
            
        start_time = time.time()
        vals = train_loop(source_train_dataloader, target_train_dataloader, model,
                   regressor_loss_fn, da_loss, optimizer, epochs, i, init_wt_da = 1.4, final_wt_da = 2.0)
#                         init_wt_mve = 6, final_wt_mve = 2)

        vals_validate = test_loop(source_val_dataloader, target_val_dataloader,
                         model, regressor_loss_fn, da_loss, epochs, i)

        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])
        stats['val_source_regression_loss'].append(vals_validate[1])
        stats['val_target_regression_loss'].append(vals_validate[2])
        stats['val_source_r2_score'].append(vals_validate[3])
        stats['val_target_r2_score'].append(vals_validate[4])
        stats['val_source_mve_loss'].append(vals_validate[5])
        stats['val_target_mve_loss'].append(vals_validate[6])
        stats['epoch_no'] += 1

        
        print_epoch_scores(stats, i, time.time() - start_time)
# Out:
# Beginning Training...
#
# Epoch 0: 19.84s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2836
# 	Train Regression Loss: : 0.2769
# 	Train Mve Loss: : 310.5679
# 	Train R2 Score: : 0.1286
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0517
# 	Val Target Regression Loss: : 0.0723
# 	Val Source R2 Score: : 0.8387
# 	Val Target R2 Score: : 0.7705
# 	Val Source Mve Loss: : 34.3223
# 	Val Target Mve Loss: : 48.2114
# Saving Model... Done.
#
# Epoch 1: 14.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1678
# 	Train Regression Loss: : 0.0401
# 	Train Mve Loss: : 21.6411
# 	Train R2 Score: : 0.8738
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0346
# 	Val Target Regression Loss: : 0.0469
# 	Val Source R2 Score: : 0.8896
# 	Val Target R2 Score: : 0.8514
# 	Val Source Mve Loss: : 13.0007
# 	Val Target Mve Loss: : 16.8877
# Saving Model... Done.
#
# Epoch 2: 12.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1525
# 	Train Regression Loss: : 0.0289
# 	Train Mve Loss: : 11.6135
# 	Train R2 Score: : 0.9091
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0298
# 	Val Target Regression Loss: : 0.0333
# 	Val Source R2 Score: : 0.9063
# 	Val Target R2 Score: : 0.8956
# 	Val Source Mve Loss: : 12.4044
# 	Val Target Mve Loss: : 11.8249
# Saving Model... Done.
#
# Epoch 3: 12.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1460
# 	Train Regression Loss: : 0.0237
# 	Train Mve Loss: : 9.1999
# 	Train R2 Score: : 0.9257
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0239
# 	Val Target Regression Loss: : 0.0300
# 	Val Source R2 Score: : 0.9253
# 	Val Target R2 Score: : 0.9043
# 	Val Source Mve Loss: : 9.6130
# 	Val Target Mve Loss: : 12.5770
# Saving Model... Done.
#
# Epoch 4: 13.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1434
# 	Train Regression Loss: : 0.0214
# 	Train Mve Loss: : 9.5514
# 	Train R2 Score: : 0.9329
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0216
# 	Val Target Regression Loss: : 0.0256
# 	Val Source R2 Score: : 0.9318
# 	Val Target R2 Score: : 0.9183
# 	Val Source Mve Loss: : 11.1237
# 	Val Target Mve Loss: : 14.1743
# Saving Model... Done.
#
# Epoch 5: 11.96s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1411
# 	Train Regression Loss: : 0.0197
# 	Train Mve Loss: : 9.9798
# 	Train R2 Score: : 0.9384
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0210
# 	Val Target Regression Loss: : 0.0257
# 	Val Source R2 Score: : 0.9349
# 	Val Target R2 Score: : 0.9193
# 	Val Source Mve Loss: : 10.3917
# 	Val Target Mve Loss: : 14.4733
# Saving Model... Done.
#
# Epoch 6: 11.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1389
# 	Train Regression Loss: : 0.0190
# 	Train Mve Loss: : 11.2859
# 	Train R2 Score: : 0.9404
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0193
# 	Val Target Regression Loss: : 0.0243
# 	Val Source R2 Score: : 0.9388
# 	Val Target R2 Score: : 0.9228
# 	Val Source Mve Loss: : 12.4191
# 	Val Target Mve Loss: : 17.1788
# Saving Model... Done.
#
# Epoch 7: 11.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1407
# 	Train Regression Loss: : 0.0177
# 	Train Mve Loss: : 13.6742
# 	Train R2 Score: : 0.9441
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0182
# 	Val Target Regression Loss: : 0.0226
# 	Val Source R2 Score: : 0.9428
# 	Val Target R2 Score: : 0.9279
# 	Val Source Mve Loss: : 17.2284
# 	Val Target Mve Loss: : 22.8156
# Saving Model... Done.
#
# Epoch 8: 14.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1406
# 	Train Regression Loss: : 0.0168
# 	Train Mve Loss: : 16.2139
# 	Train R2 Score: : 0.9474
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0166
# 	Val Target Regression Loss: : 0.0199
# 	Val Source R2 Score: : 0.9479
# 	Val Target R2 Score: : 0.9373
# 	Val Source Mve Loss: : 17.0854
# 	Val Target Mve Loss: : 21.9424
# Saving Model... Done.
#
# Epoch 9: 14.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1367
# 	Train Regression Loss: : 0.0162
# 	Train Mve Loss: : 17.7309
# 	Train R2 Score: : 0.9489
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0172
# 	Val Target Regression Loss: : 0.0202
# 	Val Source R2 Score: : 0.9464
# 	Val Target R2 Score: : 0.9360
# 	Val Source Mve Loss: : 19.3236
# 	Val Target Mve Loss: : 23.9789
#
# Epoch 10: 13.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1405
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : 19.4493
# 	Train R2 Score: : 0.9491
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0237
# 	Val Target Regression Loss: : 0.0265
# 	Val Source R2 Score: : 0.9263
# 	Val Target R2 Score: : 0.9150
# 	Val Source Mve Loss: : 29.5538
# 	Val Target Mve Loss: : 34.1003
#
# Epoch 11: 15.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1400
# 	Train Regression Loss: : 0.0160
# 	Train Mve Loss: : 20.6299
# 	Train R2 Score: : 0.9495
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0168
# 	Val Target Regression Loss: : 0.0196
# 	Val Source R2 Score: : 0.9469
# 	Val Target R2 Score: : 0.9382
# 	Val Source Mve Loss: : 22.5308
# 	Val Target Mve Loss: : 27.0954
# Saving Model... Done.
#
# Epoch 12: 13.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1392
# 	Train Regression Loss: : 0.0159
# 	Train Mve Loss: : 21.5124
# 	Train R2 Score: : 0.9500
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0170
# 	Val Target Regression Loss: : 0.0191
# 	Val Source R2 Score: : 0.9410
# 	Val Target R2 Score: : 0.9394
# 	Val Source Mve Loss: : 22.1800
# 	Val Target Mve Loss: : 26.1964
# Saving Model... Done.
#
# Epoch 13: 14.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1398
# 	Train Regression Loss: : 0.0158
# 	Train Mve Loss: : 21.8190
# 	Train R2 Score: : 0.9501
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0167
# 	Val Target Regression Loss: : 0.0195
# 	Val Source R2 Score: : 0.9477
# 	Val Target R2 Score: : 0.9376
# 	Val Source Mve Loss: : 23.0627
# 	Val Target Mve Loss: : 28.2202
#
# Epoch 14: 11.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1430
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : 22.2692
# 	Train R2 Score: : 0.9493
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0172
# 	Val Target Regression Loss: : 0.0202
# 	Val Source R2 Score: : 0.9457
# 	Val Target R2 Score: : 0.9361
# 	Val Source Mve Loss: : 23.6458
# 	Val Target Mve Loss: : 28.4140
#
# Epoch 15: 12.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1447
# 	Train Regression Loss: : 0.0164
# 	Train Mve Loss: : 22.6890
# 	Train R2 Score: : 0.9484
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0176
# 	Val Target Regression Loss: : 0.0202
# 	Val Source R2 Score: : 0.9435
# 	Val Target R2 Score: : 0.9358
# 	Val Source Mve Loss: : 25.0425
# 	Val Target Mve Loss: : 28.9433
#
# Epoch 16: 12.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1443
# 	Train Regression Loss: : 0.0436
# 	Train Mve Loss: : 0.2846
# 	Train R2 Score: : 0.8630
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0301
# 	Val Target Regression Loss: : 0.0350
# 	Val Source R2 Score: : 0.9074
# 	Val Target R2 Score: : 0.8903
# 	Val Source Mve Loss: : -0.2229
# 	Val Target Mve Loss: : -0.1590
#
# Epoch 17: 13.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1402
# 	Train Regression Loss: : 0.0285
# 	Train Mve Loss: : -0.0800
# 	Train R2 Score: : 0.9106
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0227
# 	Val Target Regression Loss: : 0.0261
# 	Val Source R2 Score: : 0.9300
# 	Val Target R2 Score: : 0.9178
# 	Val Source Mve Loss: : -0.3014
# 	Val Target Mve Loss: : -0.3269
#
# Epoch 18: 13.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1412
# 	Train Regression Loss: : 0.0214
# 	Train Mve Loss: : -0.1075
# 	Train R2 Score: : 0.9325
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0200
# 	Val Target Regression Loss: : 0.0232
# 	Val Source R2 Score: : 0.9369
# 	Val Target R2 Score: : 0.9272
# 	Val Source Mve Loss: : -0.2063
# 	Val Target Mve Loss: : -0.2590
#
# Epoch 19: 12.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1404
# 	Train Regression Loss: : 0.0286
# 	Train Mve Loss: : 0.0443
# 	Train R2 Score: : 0.9099
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0221
# 	Val Target Regression Loss: : 0.0248
# 	Val Source R2 Score: : 0.9309
# 	Val Target R2 Score: : 0.9214
# 	Val Source Mve Loss: : 1.3717
# 	Val Target Mve Loss: : 2.0360
#
# Epoch 20: 13.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1421
# 	Train Regression Loss: : 0.0214
# 	Train Mve Loss: : 0.1145
# 	Train R2 Score: : 0.9325
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0319
# 	Val Target Regression Loss: : 0.0344
# 	Val Source R2 Score: : 0.9001
# 	Val Target R2 Score: : 0.8907
# 	Val Source Mve Loss: : -0.1524
# 	Val Target Mve Loss: : -0.1179
#
# Epoch 21: 11.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1417
# 	Train Regression Loss: : 0.0236
# 	Train Mve Loss: : -0.1159
# 	Train R2 Score: : 0.9256
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0227
# 	Val Target Regression Loss: : 0.0248
# 	Val Source R2 Score: : 0.9292
# 	Val Target R2 Score: : 0.9216
# 	Val Source Mve Loss: : 1.4073
# 	Val Target Mve Loss: : 1.5435
#
# Epoch 22: 12.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1398
# 	Train Regression Loss: : 0.0240
# 	Train Mve Loss: : -0.0843
# 	Train R2 Score: : 0.9246
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0334
# 	Val Target Regression Loss: : 0.0359
# 	Val Source R2 Score: : 0.8939
# 	Val Target R2 Score: : 0.8851
# 	Val Source Mve Loss: : 0.8784
# 	Val Target Mve Loss: : 0.9645
#
# Epoch 23: 13.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1411
# 	Train Regression Loss: : 0.0232
# 	Train Mve Loss: : -0.0400
# 	Train R2 Score: : 0.9271
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0231
# 	Val Target Regression Loss: : 0.0260
# 	Val Source R2 Score: : 0.9288
# 	Val Target R2 Score: : 0.9163
# 	Val Source Mve Loss: : -0.1172
# 	Val Target Mve Loss: : -0.1170
#
# Epoch 24: 13.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1406
# 	Train Regression Loss: : 0.0229
# 	Train Mve Loss: : -0.0628
# 	Train R2 Score: : 0.9283
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0248
# 	Val Target Regression Loss: : 0.0274
# 	Val Source R2 Score: : 0.9212
# 	Val Target R2 Score: : 0.9141
# 	Val Source Mve Loss: : 0.1190
# 	Val Target Mve Loss: : 0.2546
#
# Epoch 25: 13.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1378
# 	Train Regression Loss: : 0.0269
# 	Train Mve Loss: : -0.1336
# 	Train R2 Score: : 0.9157
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0224
# 	Val Target Regression Loss: : 0.0250
# 	Val Source R2 Score: : 0.9304
# 	Val Target R2 Score: : 0.9211
# 	Val Source Mve Loss: : -0.0836
# 	Val Target Mve Loss: : -0.0198
#
# Epoch 26: 12.00s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1404
# 	Train Regression Loss: : 0.0267
# 	Train Mve Loss: : 0.0408
# 	Train R2 Score: : 0.9161
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0255
# 	Val Target Regression Loss: : 0.0276
# 	Val Source R2 Score: : 0.9188
# 	Val Target R2 Score: : 0.9124
# 	Val Source Mve Loss: : -0.2294
# 	Val Target Mve Loss: : -0.2282
#
# Epoch 27: 12.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1441
# 	Train Regression Loss: : 0.0215
# 	Train Mve Loss: : -0.0491
# 	Train R2 Score: : 0.9322
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0216
# 	Val Target Regression Loss: : 0.0228
# 	Val Source R2 Score: : 0.9321
# 	Val Target R2 Score: : 0.9277
# 	Val Source Mve Loss: : -0.1854
# 	Val Target Mve Loss: : -0.1864
#
# Epoch 28: 13.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1429
# 	Train Regression Loss: : 0.0243
# 	Train Mve Loss: : -0.1477
# 	Train R2 Score: : 0.9238
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0239
# 	Val Target Regression Loss: : 0.0258
# 	Val Source R2 Score: : 0.9243
# 	Val Target R2 Score: : 0.9181
# 	Val Source Mve Loss: : -0.0888
# 	Val Target Mve Loss: : -0.1255
#
# Epoch 29: 12.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1412
# 	Train Regression Loss: : 0.0248
# 	Train Mve Loss: : -0.1045
# 	Train R2 Score: : 0.9228
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0312
# 	Val Target Regression Loss: : 0.0342
# 	Val Source R2 Score: : 0.9041
# 	Val Target R2 Score: : 0.8934
# 	Val Source Mve Loss: : -0.3227
# 	Val Target Mve Loss: : -0.3193
#
# Epoch 30: 13.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1404
# 	Train Regression Loss: : 0.0310
# 	Train Mve Loss: : 0.0081
# 	Train R2 Score: : 0.9027
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0269
# 	Val Target Regression Loss: : 0.0291
# 	Val Source R2 Score: : 0.9167
# 	Val Target R2 Score: : 0.9076
# 	Val Source Mve Loss: : -0.0135
# 	Val Target Mve Loss: : -0.0142
#
# Epoch 31: 14.73s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1386
# 	Train Regression Loss: : 0.0254
# 	Train Mve Loss: : -0.1542
# 	Train R2 Score: : 0.9207
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0274
# 	Val Target Regression Loss: : 0.0290
# 	Val Source R2 Score: : 0.9137
# 	Val Target R2 Score: : 0.9079
# 	Val Source Mve Loss: : -0.1949
# 	Val Target Mve Loss: : 0.0106
#
# Epoch 32: 15.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1427
# 	Train Regression Loss: : 0.0269
# 	Train Mve Loss: : -0.0897
# 	Train R2 Score: : 0.9163
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0277
# 	Val Target Regression Loss: : 0.0291
# 	Val Source R2 Score: : 0.9133
# 	Val Target R2 Score: : 0.9080
# 	Val Source Mve Loss: : 0.0175
# 	Val Target Mve Loss: : 0.0167
#
# Epoch 33: 12.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1412
# 	Train Regression Loss: : 0.0277
# 	Train Mve Loss: : 0.3491
# 	Train R2 Score: : 0.9130
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0274
# 	Val Target Regression Loss: : 0.0290
# 	Val Source R2 Score: : 0.9150
# 	Val Target R2 Score: : 0.9084
# 	Val Source Mve Loss: : -0.2547
# 	Val Target Mve Loss: : -0.2864
#
# Epoch 34: 12.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1402
# 	Train Regression Loss: : 0.0224
# 	Train Mve Loss: : -0.1366
# 	Train R2 Score: : 0.9299
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0225
# 	Val Target Regression Loss: : 0.0248
# 	Val Source R2 Score: : 0.9300
# 	Val Target R2 Score: : 0.9215
# 	Val Source Mve Loss: : -0.3209
# 	Val Target Mve Loss: : -0.3296
#
# Epoch 35: 13.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1406
# 	Train Regression Loss: : 0.0228
# 	Train Mve Loss: : -0.1386
# 	Train R2 Score: : 0.9286
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0258
# 	Val Target Regression Loss: : 0.0291
# 	Val Source R2 Score: : 0.9194
# 	Val Target R2 Score: : 0.9084
# 	Val Source Mve Loss: : -0.3131
# 	Val Target Mve Loss: : -0.3140
#
# Epoch 36: 14.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1419
# 	Train Regression Loss: : 0.0395
# 	Train Mve Loss: : -0.0040
# 	Train R2 Score: : 0.8750
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0328
# 	Val Target Regression Loss: : 0.0343
# 	Val Source R2 Score: : 0.8954
# 	Val Target R2 Score: : 0.8907
# 	Val Source Mve Loss: : 0.0475
# 	Val Target Mve Loss: : 0.0369
#
# Epoch 37: 13.67s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1422
# 	Train Regression Loss: : 0.0298
# 	Train Mve Loss: : -0.0071
# 	Train R2 Score: : 0.9063
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0301
# 	Val Target Regression Loss: : 0.0335
# 	Val Source R2 Score: : 0.9064
# 	Val Target R2 Score: : 0.8940
# 	Val Source Mve Loss: : -0.2659
# 	Val Target Mve Loss: : -0.2594
#
# Epoch 38: 12.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1433
# 	Train Regression Loss: : 0.0312
# 	Train Mve Loss: : 0.0595
# 	Train R2 Score: : 0.9018
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0307
# 	Val Target Regression Loss: : 0.0336
# 	Val Source R2 Score: : 0.9041
# 	Val Target R2 Score: : 0.8940
# 	Val Source Mve Loss: : -0.0393
# 	Val Target Mve Loss: : -0.0392
#
# Epoch 39: 15.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1424
# 	Train Regression Loss: : 0.0419
# 	Train Mve Loss: : -0.1334
# 	Train R2 Score: : 0.8674
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0388
# 	Val Target Regression Loss: : 0.0418
# 	Val Source R2 Score: : 0.8802
# 	Val Target R2 Score: : 0.8666
# 	Val Source Mve Loss: : -0.1890
# 	Val Target Mve Loss: : -0.1648
#
# Epoch 40: 16.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1425
# 	Train Regression Loss: : 0.0376
# 	Train Mve Loss: : -0.0055
# 	Train R2 Score: : 0.8820
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0629
# 	Val Target Regression Loss: : 0.0651
# 	Val Source R2 Score: : 0.8031
# 	Val Target R2 Score: : 0.7862
# 	Val Source Mve Loss: : -0.0017
# 	Val Target Mve Loss: : -0.0027
#
# Epoch 41: 16.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1398
# 	Train Regression Loss: : 0.0348
# 	Train Mve Loss: : -0.0520
# 	Train R2 Score: : 0.8910
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0344
# 	Val Target Regression Loss: : 0.0355
# 	Val Source R2 Score: : 0.8929
# 	Val Target R2 Score: : 0.8863
# 	Val Source Mve Loss: : 0.0564
# 	Val Target Mve Loss: : 0.1541
#
# Epoch 42: 16.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1409
# 	Train Regression Loss: : 0.0265
# 	Train Mve Loss: : 0.2028
# 	Train R2 Score: : 0.9169
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0437
# 	Val Target Regression Loss: : 0.0446
# 	Val Source R2 Score: : 0.8618
# 	Val Target R2 Score: : 0.8554
# 	Val Source Mve Loss: : 1.1879
# 	Val Target Mve Loss: : 1.8335
#
# Epoch 43: 16.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1420
# 	Train Regression Loss: : 0.0243
# 	Train Mve Loss: : -0.0907
# 	Train R2 Score: : 0.9234
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0406
# 	Val Target Regression Loss: : 0.0423
# 	Val Source R2 Score: : 0.8719
# 	Val Target R2 Score: : 0.8646
# 	Val Source Mve Loss: : -0.2997
# 	Val Target Mve Loss: : -0.2995
#
# Epoch 44: 18.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1436
# 	Train Regression Loss: : 0.0284
# 	Train Mve Loss: : -0.1141
# 	Train R2 Score: : 0.9108
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0242
# 	Val Target Regression Loss: : 0.0263
# 	Val Source R2 Score: : 0.9246
# 	Val Target R2 Score: : 0.9165
# 	Val Source Mve Loss: : 0.7710
# 	Val Target Mve Loss: : 1.2852
#
# Epoch 45: 18.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1417
# 	Train Regression Loss: : 0.0229
# 	Train Mve Loss: : 0.3515
# 	Train R2 Score: : 0.9281
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0257
# 	Val Target Regression Loss: : 0.0281
# 	Val Source R2 Score: : 0.9207
# 	Val Target R2 Score: : 0.9108
# 	Val Source Mve Loss: : -0.2760
# 	Val Target Mve Loss: : -0.2758
#
# Epoch 46: 20.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1405
# 	Train Regression Loss: : 0.0221
# 	Train Mve Loss: : -0.0595
# 	Train R2 Score: : 0.9306
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0269
# 	Val Target Regression Loss: : 0.0309
# 	Val Source R2 Score: : 0.9164
# 	Val Target R2 Score: : 0.9012
# 	Val Source Mve Loss: : -0.3200
# 	Val Target Mve Loss: : -0.3179
#
# Epoch 47: 16.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1410
# 	Train Regression Loss: : 0.0219
# 	Train Mve Loss: : 0.0165
# 	Train R2 Score: : 0.9313
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0212
# 	Val Target Regression Loss: : 0.0237
# 	Val Source R2 Score: : 0.9348
# 	Val Target R2 Score: : 0.9253
# 	Val Source Mve Loss: : -0.1278
# 	Val Target Mve Loss: : -0.1286
#
# Epoch 48: 17.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1403
# 	Train Regression Loss: : 0.0239
# 	Train Mve Loss: : -0.2385
# 	Train R2 Score: : 0.9249
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0301
# 	Val Target Regression Loss: : 0.0340
# 	Val Source R2 Score: : 0.9051
# 	Val Target R2 Score: : 0.8918
# 	Val Source Mve Loss: : -0.2948
# 	Val Target Mve Loss: : -0.2917
#
# Epoch 49: 15.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1425
# 	Train Regression Loss: : 0.0219
# 	Train Mve Loss: : -0.2007
# 	Train R2 Score: : 0.9313
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0299
# 	Val Target Regression Loss: : 0.0320
# 	Val Source R2 Score: : 0.9059
# 	Val Target R2 Score: : 0.8990
# 	Val Source Mve Loss: : 0.7328
# 	Val Target Mve Loss: : 1.4001
#
# Epoch 50: 14.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1417
# 	Train Regression Loss: : 0.0280
# 	Train Mve Loss: : 0.0556
# 	Train R2 Score: : 0.9125
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0284
# 	Val Target Regression Loss: : 0.0307
# 	Val Source R2 Score: : 0.9116
# 	Val Target R2 Score: : 0.9039
# 	Val Source Mve Loss: : 0.1267
# 	Val Target Mve Loss: : 0.1239
#
# Epoch 51: 14.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1418
# 	Train Regression Loss: : 0.0274
# 	Train Mve Loss: : 0.0081
# 	Train R2 Score: : 0.9143
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0270
# 	Val Target Regression Loss: : 0.0313
# 	Val Source R2 Score: : 0.9154
# 	Val Target R2 Score: : 0.9002
# 	Val Source Mve Loss: : -0.3243
# 	Val Target Mve Loss: : -0.3192
#
# Epoch 52: 14.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1432
# 	Train Regression Loss: : 0.0227
# 	Train Mve Loss: : -0.1761
# 	Train R2 Score: : 0.9290
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0240
# 	Val Target Regression Loss: : 0.0273
# 	Val Source R2 Score: : 0.9248
# 	Val Target R2 Score: : 0.9111
# 	Val Source Mve Loss: : 0.2394
# 	Val Target Mve Loss: : 0.2139
#
# Epoch 53: 14.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1409
# 	Train Regression Loss: : 0.0233
# 	Train Mve Loss: : 0.0241
# 	Train R2 Score: : 0.9271
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0249
# 	Val Target Regression Loss: : 0.0285
# 	Val Source R2 Score: : 0.9222
# 	Val Target R2 Score: : 0.9108
# 	Val Source Mve Loss: : 0.0052
# 	Val Target Mve Loss: : 0.1140
#
# Epoch 54: 13.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1423
# 	Train Regression Loss: : 0.0227
# 	Train Mve Loss: : -0.1179
# 	Train R2 Score: : 0.9289
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0248
# 	Val Target Regression Loss: : 0.0275
# 	Val Source R2 Score: : 0.9232
# 	Val Target R2 Score: : 0.9136
# 	Val Source Mve Loss: : 0.0707
# 	Val Target Mve Loss: : 0.1440
#
# Epoch 55: 16.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1417
# 	Train Regression Loss: : 0.0228
# 	Train Mve Loss: : -0.1404
# 	Train R2 Score: : 0.9286
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0231
# 	Val Target Regression Loss: : 0.0259
# 	Val Source R2 Score: : 0.9280
# 	Val Target R2 Score: : 0.9189
# 	Val Source Mve Loss: : -0.2027
# 	Val Target Mve Loss: : -0.2139
#
# Epoch 56: 15.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1412
# 	Train Regression Loss: : 0.0289
# 	Train Mve Loss: : 0.0016
# 	Train R2 Score: : 0.9089
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0362
# 	Val Target Regression Loss: : 0.0374
# 	Val Source R2 Score: : 0.8876
# 	Val Target R2 Score: : 0.8807
# 	Val Source Mve Loss: : 0.2018
# 	Val Target Mve Loss: : 0.2001
#
# Epoch 57: 13.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1415
# 	Train Regression Loss: : 0.0284
# 	Train Mve Loss: : 0.1763
# 	Train R2 Score: : 0.9114
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0262
# 	Val Target Regression Loss: : 0.0283
# 	Val Source R2 Score: : 0.9196
# 	Val Target R2 Score: : 0.9109
# 	Val Source Mve Loss: : 0.1500
# 	Val Target Mve Loss: : 0.1490
#
# Epoch 58: 20.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1418
# 	Train Regression Loss: : 0.0337
# 	Train Mve Loss: : 0.0762
# 	Train R2 Score: : 0.8935
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0866
# 	Val Target Regression Loss: : 0.0874
# 	Val Source R2 Score: : 0.7292
# 	Val Target R2 Score: : 0.7232
# 	Val Source Mve Loss: : -0.1470
# 	Val Target Mve Loss: : -0.0330
#
# Epoch 59: 17.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1423
# 	Train Regression Loss: : 0.0266
# 	Train Mve Loss: : 0.0989
# 	Train R2 Score: : 0.9163
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0228
# 	Val Target Regression Loss: : 0.0247
# 	Val Source R2 Score: : 0.9290
# 	Val Target R2 Score: : 0.9216
# 	Val Source Mve Loss: : -0.3020
# 	Val Target Mve Loss: : -0.2997
#
# Epoch 60: 16.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1409
# 	Train Regression Loss: : 0.0212
# 	Train Mve Loss: : 0.2533
# 	Train R2 Score: : 0.9338
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0230
# 	Val Target Regression Loss: : 0.0239
# 	Val Source R2 Score: : 0.9291
# 	Val Target R2 Score: : 0.9240
# 	Val Source Mve Loss: : 0.6679
# 	Val Target Mve Loss: : 0.9126
#
# Epoch 61: 17.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1420
# 	Train Regression Loss: : 0.0235
# 	Train Mve Loss: : -0.0029
# 	Train R2 Score: : 0.9264
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0264
# 	Val Target Regression Loss: : 0.0274
# 	Val Source R2 Score: : 0.9172
# 	Val Target R2 Score: : 0.9118
# 	Val Source Mve Loss: : -0.0180
# 	Val Target Mve Loss: : -0.0188
#
# Epoch 62: 14.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1408
# 	Train Regression Loss: : 0.0327
# 	Train Mve Loss: : 0.0063
# 	Train R2 Score: : 0.8972
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0283
# 	Val Target Regression Loss: : 0.0304
# 	Val Source R2 Score: : 0.9121
# 	Val Target R2 Score: : 0.9037
# 	Val Source Mve Loss: : -0.1199
# 	Val Target Mve Loss: : -0.1189
#
# Epoch 63: 16.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1397
# 	Train Regression Loss: : 0.0380
# 	Train Mve Loss: : 0.1418
# 	Train R2 Score: : 0.8806
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0576
# 	Val Target Regression Loss: : 0.0591
# 	Val Source R2 Score: : 0.8205
# 	Val Target R2 Score: : 0.8140
# 	Val Source Mve Loss: : 0.1223
# 	Val Target Mve Loss: : 0.1224
#
# Epoch 64: 15.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1410
# 	Train Regression Loss: : 0.0403
# 	Train Mve Loss: : 0.3300
# 	Train R2 Score: : 0.8726
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0280
# 	Val Target Regression Loss: : 0.0303
# 	Val Source R2 Score: : 0.9134
# 	Val Target R2 Score: : 0.9039
# 	Val Source Mve Loss: : 2.6866
# 	Val Target Mve Loss: : 2.9204
#
# Epoch 65: 20.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1412
# 	Train Regression Loss: : 0.0231
# 	Train Mve Loss: : 0.1921
# 	Train R2 Score: : 0.9284
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0235
# 	Val Target Regression Loss: : 0.0249
# 	Val Source R2 Score: : 0.9276
# 	Val Target R2 Score: : 0.9214
# 	Val Source Mve Loss: : 2.3773
# 	Val Target Mve Loss: : 2.3749
#
# Epoch 66: 23.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1425
# 	Train Regression Loss: : 0.0242
# 	Train Mve Loss: : 0.5968
# 	Train R2 Score: : 0.9240
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0302
# 	Val Target Regression Loss: : 0.0331
# 	Val Source R2 Score: : 0.9050
# 	Val Target R2 Score: : 0.8940
# 	Val Source Mve Loss: : -0.2336
# 	Val Target Mve Loss: : -0.2584
#
# Epoch 67: 23.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1432
# 	Train Regression Loss: : 0.0221
# 	Train Mve Loss: : 0.1295
# 	Train R2 Score: : 0.9311
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0215
# 	Val Target Regression Loss: : 0.0236
# 	Val Source R2 Score: : 0.9333
# 	Val Target R2 Score: : 0.9260
# 	Val Source Mve Loss: : 0.4695
# 	Val Target Mve Loss: : 0.6151
#
# Epoch 68: 17.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1413
# 	Train Regression Loss: : 0.0308
# 	Train Mve Loss: : -0.0496
# 	Train R2 Score: : 0.9045
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0295
# 	Val Target Regression Loss: : 0.0311
# 	Val Source R2 Score: : 0.9081
# 	Val Target R2 Score: : 0.8962
# 	Val Source Mve Loss: : -0.1339
# 	Val Target Mve Loss: : -0.1325
#
# Epoch 69: 21.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1403
# 	Train Regression Loss: : 0.0306
# 	Train Mve Loss: : 0.1375
# 	Train R2 Score: : 0.9036
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0279
# 	Val Target Regression Loss: : 0.0301
# 	Val Source R2 Score: : 0.9133
# 	Val Target R2 Score: : 0.9045
# 	Val Source Mve Loss: : 0.1752
# 	Val Target Mve Loss: : 0.1753
#
# Epoch 70: 19.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1409
# 	Train Regression Loss: : 0.0254
# 	Train Mve Loss: : 0.0886
# 	Train R2 Score: : 0.9205
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0246
# 	Val Target Regression Loss: : 0.0263
# 	Val Source R2 Score: : 0.9237
# 	Val Target R2 Score: : 0.9159
# 	Val Source Mve Loss: : 1.5235
# 	Val Target Mve Loss: : 1.4991
#
# Epoch 71: 25.36s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1420
# 	Train Regression Loss: : 0.0231
# 	Train Mve Loss: : 0.1677
# 	Train R2 Score: : 0.9277
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0211
# 	Val Target Regression Loss: : 0.0235
# 	Val Source R2 Score: : 0.9346
# 	Val Target R2 Score: : 0.9258
# 	Val Source Mve Loss: : 0.3777
# 	Val Target Mve Loss: : 0.5709
#
# Epoch 72: 24.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1422
# 	Train Regression Loss: : 0.0231
# 	Train Mve Loss: : 0.0413
# 	Train R2 Score: : 0.9283
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0286
# 	Val Target Regression Loss: : 0.0315
# 	Val Source R2 Score: : 0.9097
# 	Val Target R2 Score: : 0.9004
# 	Val Source Mve Loss: : -0.2857
# 	Val Target Mve Loss: : -0.2986
#
# Epoch 73: 23.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1423
# 	Train Regression Loss: : 0.0253
# 	Train Mve Loss: : 0.2235
# 	Train R2 Score: : 0.9210
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0250
# 	Val Target Regression Loss: : 0.0264
# 	Val Source R2 Score: : 0.9219
# 	Val Target R2 Score: : 0.9158
# 	Val Source Mve Loss: : 0.1686
# 	Val Target Mve Loss: : 0.1690
#
# Epoch 74: 18.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1422
# 	Train Regression Loss: : 0.0218
# 	Train Mve Loss: : 0.0881
# 	Train R2 Score: : 0.9318
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0226
# 	Val Target Regression Loss: : 0.0236
# 	Val Source R2 Score: : 0.9296
# 	Val Target R2 Score: : 0.9249
# 	Val Source Mve Loss: : -0.0175
# 	Val Target Mve Loss: : -0.0163
#
# Epoch 75: 15.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1428
# 	Train Regression Loss: : 0.0246
# 	Train Mve Loss: : 0.1914
# 	Train R2 Score: : 0.9225
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0314
# 	Val Target Regression Loss: : 0.0311
# 	Val Source R2 Score: : 0.9005
# 	Val Target R2 Score: : 0.8990
# 	Val Source Mve Loss: : -0.1298
# 	Val Target Mve Loss: : -0.1200
#
# Epoch 76: 17.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1418
# 	Train Regression Loss: : 0.0307
# 	Train Mve Loss: : 0.1602
# 	Train R2 Score: : 0.9032
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0294
# 	Val Target Regression Loss: : 0.0293
# 	Val Source R2 Score: : 0.8977
# 	Val Target R2 Score: : 0.9060
# 	Val Source Mve Loss: : 0.6231
# 	Val Target Mve Loss: : 0.7856
#
# Epoch 77: 16.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1429
# 	Train Regression Loss: : 0.0322
# 	Train Mve Loss: : 0.0721
# 	Train R2 Score: : 0.8981
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0227
# 	Val Target Regression Loss: : 0.0245
# 	Val Source R2 Score: : 0.9293
# 	Val Target R2 Score: : 0.9218
# 	Val Source Mve Loss: : -0.2731
# 	Val Target Mve Loss: : -0.2508
#
# Epoch 78: 19.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1413
# 	Train Regression Loss: : 0.0248
# 	Train Mve Loss: : 0.0835
# 	Train R2 Score: : 0.9224
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0396
# 	Val Target Regression Loss: : 0.0409
# 	Val Source R2 Score: : 0.8702
# 	Val Target R2 Score: : 0.8698
# 	Val Source Mve Loss: : -0.2273
# 	Val Target Mve Loss: : -0.2261
#
# Epoch 79: 16.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1423
# 	Train Regression Loss: : 0.0263
# 	Train Mve Loss: : -0.1771
# 	Train R2 Score: : 0.9173
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1038
# 	Val Target Regression Loss: : 0.1063
# 	Val Source R2 Score: : 0.6692
# 	Val Target R2 Score: : 0.6584
# 	Val Source Mve Loss: : -0.2274
# 	Val Target Mve Loss: : -0.1984
#
# Epoch 80: 14.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1403
# 	Train Regression Loss: : 0.0313
# 	Train Mve Loss: : -0.1149
# 	Train R2 Score: : 0.9016
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0383
# 	Val Target Regression Loss: : 0.0417
# 	Val Source R2 Score: : 0.8800
# 	Val Target R2 Score: : 0.8678
# 	Val Source Mve Loss: : -0.1403
# 	Val Target Mve Loss: : -0.1394
#
# Epoch 81: 18.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1398
# 	Train Regression Loss: : 0.0337
# 	Train Mve Loss: : 0.0550
# 	Train R2 Score: : 0.8940
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0410
# 	Val Target Regression Loss: : 0.0424
# 	Val Source R2 Score: : 0.8726
# 	Val Target R2 Score: : 0.8658
# 	Val Source Mve Loss: : -0.2713
# 	Val Target Mve Loss: : -0.2858
#
# Epoch 82: 15.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1418
# 	Train Regression Loss: : 0.0214
# 	Train Mve Loss: : 0.0944
# 	Train R2 Score: : 0.9326
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0212
# 	Val Target Regression Loss: : 0.0232
# 	Val Source R2 Score: : 0.9346
# 	Val Target R2 Score: : 0.9267
# 	Val Source Mve Loss: : -0.1939
# 	Val Target Mve Loss: : -0.1940
#
# Epoch 83: 14.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1421
# 	Train Regression Loss: : 0.0210
# 	Train Mve Loss: : 0.2480
# 	Train R2 Score: : 0.9343
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0213
# 	Val Target Regression Loss: : 0.0230
# 	Val Source R2 Score: : 0.9326
# 	Val Target R2 Score: : 0.9273
# 	Val Source Mve Loss: : 0.2431
# 	Val Target Mve Loss: : 0.2426
#
# Epoch 84: 12.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1432
# 	Train Regression Loss: : 0.0235
# 	Train Mve Loss: : 0.2434
# 	Train R2 Score: : 0.9258
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0230
# 	Val Target Regression Loss: : 0.0249
# 	Val Source R2 Score: : 0.9297
# 	Val Target R2 Score: : 0.9208
# 	Val Source Mve Loss: : -0.1712
# 	Val Target Mve Loss: : -0.1704
#
# Epoch 85: 17.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1413
# 	Train Regression Loss: : 0.0248
# 	Train Mve Loss: : -0.0317
# 	Train R2 Score: : 0.9222
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0236
# 	Val Target Regression Loss: : 0.0258
# 	Val Source R2 Score: : 0.9260
# 	Val Target R2 Score: : 0.9174
# 	Val Source Mve Loss: : -0.0629
# 	Val Target Mve Loss: : -0.0631
#
# Epoch 86: 18.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1416
# 	Train Regression Loss: : 0.0212
# 	Train Mve Loss: : -0.1133
# 	Train R2 Score: : 0.9334
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0207
# 	Val Target Regression Loss: : 0.0230
# 	Val Source R2 Score: : 0.9364
# 	Val Target R2 Score: : 0.9273
# 	Val Source Mve Loss: : -0.2833
# 	Val Target Mve Loss: : -0.2815
#
# Epoch 87: 16.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1432
# 	Train Regression Loss: : 0.0233
# 	Train Mve Loss: : 0.1794
# 	Train R2 Score: : 0.9263
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0224
# 	Val Target Regression Loss: : 0.0240
# 	Val Source R2 Score: : 0.9309
# 	Val Target R2 Score: : 0.9240
# 	Val Source Mve Loss: : 0.2951
# 	Val Target Mve Loss: : 0.2949
#
# Epoch 88: 21.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1420
# 	Train Regression Loss: : 0.0352
# 	Train Mve Loss: : 0.1624
# 	Train R2 Score: : 0.8892
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0245
# 	Val Target Regression Loss: : 0.0259
# 	Val Source R2 Score: : 0.9245
# 	Val Target R2 Score: : 0.9180
# 	Val Source Mve Loss: : 2.1101
# 	Val Target Mve Loss: : 2.3972
#
# Epoch 89: 22.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1439
# 	Train Regression Loss: : 0.0222
# 	Train Mve Loss: : 0.3313
# 	Train R2 Score: : 0.9302
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0237
# 	Val Target Regression Loss: : 0.0253
# 	Val Source R2 Score: : 0.9274
# 	Val Target R2 Score: : 0.9202
# 	Val Source Mve Loss: : 0.3768
# 	Val Target Mve Loss: : 0.3765
#
# Epoch 90: 21.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1425
# 	Train Regression Loss: : 0.0218
# 	Train Mve Loss: : 0.3424
# 	Train R2 Score: : 0.9318
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0234
# 	Val Target Regression Loss: : 0.0250
# 	Val Source R2 Score: : 0.9277
# 	Val Target R2 Score: : 0.9200
# 	Val Source Mve Loss: : 0.2818
# 	Val Target Mve Loss: : 0.2822
#
# Epoch 91: 15.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1422
# 	Train Regression Loss: : 0.0312
# 	Train Mve Loss: : 0.1584
# 	Train R2 Score: : 0.9016
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0285
# 	Val Target Regression Loss: : 0.0298
# 	Val Source R2 Score: : 0.9103
# 	Val Target R2 Score: : 0.9046
# 	Val Source Mve Loss: : 0.3000
# 	Val Target Mve Loss: : 0.2992
#
# Epoch 92: 20.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1429
# 	Train Regression Loss: : 0.0287
# 	Train Mve Loss: : 0.2523
# 	Train R2 Score: : 0.9092
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0692
# 	Val Target Regression Loss: : 0.0713
# 	Val Source R2 Score: : 0.7812
# 	Val Target R2 Score: : 0.7687
# 	Val Source Mve Loss: : 0.1011
# 	Val Target Mve Loss: : 0.1014
#
# Epoch 93: 16.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1418
# 	Train Regression Loss: : 0.0296
# 	Train Mve Loss: : 0.6617
# 	Train R2 Score: : 0.9068
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0219
# 	Val Target Regression Loss: : 0.0232
# 	Val Source R2 Score: : 0.9325
# 	Val Target R2 Score: : 0.9266
# 	Val Source Mve Loss: : 0.4815
# 	Val Target Mve Loss: : 0.6793
#
# Epoch 94: 20.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1422
# 	Train Regression Loss: : 0.0225
# 	Train Mve Loss: : 0.1969
# 	Train R2 Score: : 0.9299
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0235
# 	Val Target Regression Loss: : 0.0255
# 	Val Source R2 Score: : 0.9274
# 	Val Target R2 Score: : 0.9191
# 	Val Source Mve Loss: : 1.5658
# 	Val Target Mve Loss: : 2.3416
#
# Epoch 95: 16.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1406
# 	Train Regression Loss: : 0.0257
# 	Train Mve Loss: : 0.1935
# 	Train R2 Score: : 0.9200
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0261
# 	Val Target Regression Loss: : 0.0280
# 	Val Source R2 Score: : 0.9189
# 	Val Target R2 Score: : 0.9119
# 	Val Source Mve Loss: : 0.0370
# 	Val Target Mve Loss: : 0.0372
#
# Epoch 96: 21.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1425
# 	Train Regression Loss: : 0.0278
# 	Train Mve Loss: : -0.0308
# 	Train R2 Score: : 0.9123
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0274
# 	Val Target Regression Loss: : 0.0270
# 	Val Source R2 Score: : 0.9133
# 	Val Target R2 Score: : 0.9140
# 	Val Source Mve Loss: : -0.0300
# 	Val Target Mve Loss: : -0.0301
#
# Epoch 97: 16.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1422
# 	Train Regression Loss: : 0.0281
# 	Train Mve Loss: : -0.0395
# 	Train R2 Score: : 0.9112
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0474
# 	Val Target Regression Loss: : 0.0494
# 	Val Source R2 Score: : 0.8504
# 	Val Target R2 Score: : 0.8438
# 	Val Source Mve Loss: : 0.3953
# 	Val Target Mve Loss: : 0.3946
#
# Epoch 98: 18.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1414
# 	Train Regression Loss: : 0.0287
# 	Train Mve Loss: : 0.3722
# 	Train R2 Score: : 0.9099
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0217
# 	Val Target Regression Loss: : 0.0231
# 	Val Source R2 Score: : 0.9321
# 	Val Target R2 Score: : 0.9277
# 	Val Source Mve Loss: : 0.2752
# 	Val Target Mve Loss: : 0.2752
#
# Epoch 99: 16.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1414
# 	Train Regression Loss: : 0.0208
# 	Train Mve Loss: : 0.0957
# 	Train R2 Score: : 0.9347
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0234
# 	Val Target Regression Loss: : 0.0243
# 	Val Source R2 Score: : 0.9271
# 	Val Target R2 Score: : 0.9229
# 	Val Source Mve Loss: : -0.1615
# 	Val Target Mve Loss: : -0.1605

# %%
state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
mod_name = "models/mb_mve2stepFinal_aug1_1900"
torch.save(state, mod_name)
json.dump(stats, open(mod_name+'.json', 'w'))

# %%
mod_name = "models/mb_mve2step_aug1_2100"
model.load_state_dict(torch.load(mod_name)['state_dict'])
#stats = json.load(open(mod_name+'.json', 'r'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# def generate_isomaps(source_data, target_data, model, n_neighbors = 5, n_components = 2, n_points = 1000):
#     device = "cuda" if torch.cuda.is_available() else "cpu"
#     gc.collect()
#     torch.cuda.empty_cache()
#
#     isomap = Isomap(n_neighbors=n_neighbors, n_components=n_components)
#     train_isomap = Isomap(n_neighbors=n_neighbors, n_components=n_components)
#
#     sdata = source_data.reshape([-1, np.prod(source_data.shape[1:])])[:n_points]
#     tdata = target_data.reshape([-1, np.prod(target_data.shape[1:])])[:n_points]
#     catdata = np.concatenate((sdata, tdata), axis=0)
#     print(catdata.shape)
#     isomap = isomap.fit(catdata)
#
#     with torch.no_grad():
#         source_tensor = torch.FloatTensor(source_data[:n_points]).to(device)
#         target_tensor = torch.FloatTensor(target_data[:n_points]).to(device)
#         sfeat = model.get_feature(source_tensor).cpu().detach().numpy()
#         tfeat = model.get_feature(target_tensor).cpu().detach().numpy()
#         catfeat = np.concatenate((sfeat, tfeat), axis=0)
#
#     train_isomap = train_isomap.fit(catfeat)
#     trained_source_iso = train_isomap.transform(sfeat)
#     trained_target_iso = train_isomap.transform(tfeat)
#
#     del sfeat
#     del tfeat
#
#     source_iso = isomap.transform(sdata)
#     target_iso = isomap.transform(tdata)
#
#     return source_iso, target_iso, trained_source_iso, trained_target_iso

# %%
source_iso, target_iso, trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
# Out:
# (2000, 6075)

# %% [markdown]
# def show_isomaps(source_iso,
#                  target_iso,
#                  trained_source_iso,
#                  trained_target_iso,
#                  source_labels,
#                  target_labels,
#                  mod_name,
#                  epoch_no,
#                  pretrain_lim = 500,
#                  posttrain_lim = 50,
#                  save = False):
#
#     fig0, axes = plt.subplots(1, 2, figsize=(8, 4))
#
#     (ax1, ax2) = axes
#     ax1.scatter(source_iso[:, 0], source_iso[:, 1], s=3, marker='o')
#     ax1.scatter(target_iso[:, 0], target_iso[:, 1], s=3, marker='^')
#     lval1 = pretrain_lim
#     ax1.set_xlim(-lval1, lval1)
#     ax1.set_ylim(-lval1, lval1)
#     ax1.set_title('Source and Target')
#
#     ax2.scatter(trained_source_iso[:, 0], trained_source_iso[:, 1], s=3, marker='o')
#     ax2.scatter(trained_target_iso[:, 0], trained_target_iso[:, 1], s=3, marker='^')
#     lval2 = posttrain_lim
#     ax2.set_xlim(-lval2, lval2)
#     ax2.set_ylim(-lval2, lval2)
#     ax2.set_title('Trained Source and Target')
#
#     ax1.set_xlabel('Component 1')
#     ax1.set_ylabel('Component 2')
#     ax2.set_xlabel('Component 1')
#     ax2.set_ylabel('Component 2')
#
#     if save:
#         plt.savefig(mod_name + "_" + str(epoch_no) + "_compare.png", bbox_inches = 'tight', dpi = 400)
#
#     plt.show()
#
#     fig1, ax = plt.subplots(2, 2, figsize=(14, 10))
#
#     ax1 = ax[0][1]
#     scatter1 = ax1.scatter(trained_source_iso[:, 0], trained_source_iso[:, 1], s=3, marker='o', c = source_labels)
#     lval1 = posttrain_lim
#     ax1.set_xlim(-lval1, lval1)
#     ax1.set_ylim(-lval1, lval1)
#     ax1.set_title('Trained Source')
#
#     ax2 = ax[0][0]
#     ax2.scatter(source_iso[:, 0], source_iso[:, 1], s=3, c = source_labels)
#     lval2 = pretrain_lim
#     ax2.set_xlim(-lval2, lval2)
#     ax2.set_ylim(-lval2, lval2)
#     ax2.set_title('Source')
#
#     ax1 = ax[1][1]
#     ax1.scatter(trained_target_iso[:, 0], trained_target_iso[:, 1], s=3, marker='o', c = target_labels)
#     lval1 = posttrain_lim
#     ax1.set_xlim(-lval1, lval1)
#     ax1.set_ylim(-lval1, lval1)
#     ax1.set_title('Trained Target')
#
#     ax2 = ax[1][0]
#     ax2.scatter(target_iso[:, 0], target_iso[:, 1], s=3, c = target_labels)
#     lval2 = pretrain_lim
#     ax2.set_xlim(-lval2, lval2)
#     ax2.set_ylim(-lval2, lval2)
#     ax2.set_title('Target')
#
#     for i in ax.ravel():
#         i.set_xlabel('Component 1')
#         i.set_ylabel('Component 2')
#
#     cbar = fig.colorbar(scatter1, ax=ax.ravel().tolist(), orientation='vertical')
#     cbar.set_label('$\\theta_E$')
#
#     plt.suptitle("Isomap of Regression Inputs: Before and After", x = 0.44, y = 0.94, fontsize = 20)
#
#     if save:
#         plt.savefig(mod_name + "_" + str(epoch_no) + "_thetaE.png", bbox_inches = 'tight', dpi = 400)
#
#     plt.show()
#
#     return fig0, axes, fig1, ax

# %%
source_labels = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
target_labels = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
show_isomaps(source_iso, target_iso, trained_source_iso, trained_target_iso, source_labels, target_labels, mod_name, stats["epoch_no"], 100000, 50)
# Out:
# (<Figure size 800x400 with 2 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Trained Source and Target'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object),
#  <Figure size 1400x1000 with 5 Axes>,
#  array([[<Axes: title={'center': 'Source'}, xlabel='Component 1', ylabel='Component 2'>,
#          <Axes: title={'center': 'Trained Source'}, xlabel='Component 1', ylabel='Component 2'>],
#         [<Axes: title={'center': 'Target'}, xlabel='Component 1', ylabel='Component 2'>,
#          <Axes: title={'center': 'Trained Target'}, xlabel='Component 1', ylabel='Component 2'>]],
#        dtype=object))

# %%
# Classifier
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# Estimator
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 10)
# Out:
# (-1.0, 10.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Source R2 Score is 0.9488
# Text(0.5, 1.0, 'MMD | Source | R2: 0.949')

# %%
plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | BNLL: 21.231')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Target R2 Score is 0.9197
# Text(0.5, 1.0, 'MMD | Target | R2: 0.920')

# %%
plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.159')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Variance: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Variance")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 n_points = 30
# ----> 2 rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
#       3 residuals = preds_source[rand_idx] - true_source[rand_idx]
#       4 resid_all = preds_target - true_target
#
# NameError: name 'preds_source' is not defined

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Variance: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Variance")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
true.shape
# Out:
# (20000,)

# %%
imgs.shape
# Out:
# (20000, 3, 45, 45)

# %%
idx = (np.abs(true - preds) > 0.7)

# %%
preds
# Out:
# array([1.30214167, 2.98077202, 2.00425458, ..., 0.95970899, 3.07219529,
#        2.18891573])

# %%
true
# Out:
# array([1.69164467, 3.9343679 , 2.13911223, ..., 1.52133608, 2.09088802,
#        2.36884522])

# %%
i = 0
b = 0
plt.imshow(imgs[idx][i, b, :, :])
print(true[idx][0])
print(preds[idx][0])
# Out:
# 3.9343678951263428
# 2.980772018432617

# %%
i = 134
# Create a figure with 3 subplots arranged horizontally
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# First subplot
axs[0].imshow(imgs[idx][i, 0, :, :])
axs[0].set_title('g')

# Second subplot
axs[1].imshow(imgs[idx][i, 1, :, :])
axs[1].set_title('r')

# Third subplot
axs[2].imshow(imgs[idx][i, 2, :, :])
axs[2].set_title('z')

# Adjust layout to prevent overlap
plt.tight_layout()

print(true[idx][i])
print(preds[idx][i])
# Show the plot
plt.show()
# Out:
# 1.154159426689148
# 2.234156370162964

# %%
i = 16
# Create a figure with 3 subplots arranged horizontally
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# First subplot
axs[0].imshow(source_data[i, 0, :, :])
axs[0].set_title('g')

# Second subplot
axs[1].imshow(source_data[i, 1, :, :])
axs[1].set_title('r')

# Third subplot
axs[2].imshow(source_data[i, 2, :, :])
axs[2].set_title('z')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
