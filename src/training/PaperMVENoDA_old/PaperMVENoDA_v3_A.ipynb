# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 11
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    if epoch < evolv_epoch:
        da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    else:
        da_weight = final_wt_da
    return 0

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    if epoch < evolv_epoch:
        beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    else:
        beta_val = beta_final
    return beta_val

# Initialize hyperparameters
learning_rate = 1e-5
n_epoch = 300

evolv_epoch = 250
init_wt_da = 0.0
final_wt_da = 1.0
beta_init = 1.0
beta_final = 0.0

# %%
from torch.optim.lr_scheduler import MultiStepLR
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = MultiStepLR(optimizer, milestones=[100, 200, 250, 275], gamma=0.5)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None #"models/papermve_v1_aug20_1940_A" # "models/start_code_test_2"
stats, model, optimizer, best_target_R2, best_mve_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/papermve_noda_v3_aug22_2300_A"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")

stats['lr'] = []
for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            if ((curr_epoch > 250) and (stats['val_target_r2_score'][-1] > 0.95) and (stats['val_target_mve_loss'][-1] < -1)):
                print("Saving Model Minima...", end = ' ')
                m_name = save_mod_name + f"_{curr_epoch}"
                save_model(m_name, model, optimizer, stats)
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        scheduler.step()

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Epoch 0: 34.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1595
# 	Train Regression Loss: : 1.9477
# 	Train Mve Loss: : 0.8444
# 	Train R2 Score: : -4.9194
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.7303
# 	Val Target Regression Loss: : 0.6086
# 	Val Source R2 Score: : -1.2421
# 	Val Target R2 Score: : -0.8114
# 	Val Source Mve Loss: : 0.2728
# 	Val Target Mve Loss: : 0.2199
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 1: 33.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1862
# 	Train Regression Loss: : 0.3954
# 	Train Mve Loss: : 0.0603
# 	Train R2 Score: : -0.1958
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2411
# 	Val Target Regression Loss: : 0.2233
# 	Val Source R2 Score: : 0.2630
# 	Val Target R2 Score: : 0.3357
# 	Val Source Mve Loss: : -0.0478
# 	Val Target Mve Loss: : -0.0436
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 2: 35.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1874
# 	Train Regression Loss: : 0.1825
# 	Train Mve Loss: : -0.0627
# 	Train R2 Score: : 0.4479
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1326
# 	Val Target Regression Loss: : 0.1217
# 	Val Source R2 Score: : 0.5919
# 	Val Target R2 Score: : 0.6386
# 	Val Source Mve Loss: : -0.0727
# 	Val Target Mve Loss: : -0.0414
# Saving Model... Done.
#
# Epoch 3: 33.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1819
# 	Train Regression Loss: : 0.1032
# 	Train Mve Loss: : -0.0730
# 	Train R2 Score: : 0.6880
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0796
# 	Val Target Regression Loss: : 0.0742
# 	Val Source R2 Score: : 0.7572
# 	Val Target R2 Score: : 0.7797
# 	Val Source Mve Loss: : -0.0642
# 	Val Target Mve Loss: : -0.0266
# Saving Model... Done.
#
# Epoch 4: 33.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1782
# 	Train Regression Loss: : 0.0635
# 	Train Mve Loss: : -0.0728
# 	Train R2 Score: : 0.8081
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0528
# 	Val Target Regression Loss: : 0.0528
# 	Val Source R2 Score: : 0.8380
# 	Val Target R2 Score: : 0.8431
# 	Val Source Mve Loss: : -0.0811
# 	Val Target Mve Loss: : -0.0424
# Saving Model... Done.
#
# Epoch 5: 36.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1723
# 	Train Regression Loss: : 0.0449
# 	Train Mve Loss: : -0.0706
# 	Train R2 Score: : 0.8641
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0399
# 	Val Target Regression Loss: : 0.0429
# 	Val Source R2 Score: : 0.8774
# 	Val Target R2 Score: : 0.8718
# 	Val Source Mve Loss: : -0.0626
# 	Val Target Mve Loss: : -0.0271
# Saving Model... Done.
#
# Epoch 6: 47.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1667
# 	Train Regression Loss: : 0.0356
# 	Train Mve Loss: : -0.0703
# 	Train R2 Score: : 0.8922
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0333
# 	Val Target Regression Loss: : 0.0400
# 	Val Source R2 Score: : 0.8977
# 	Val Target R2 Score: : 0.8812
# 	Val Source Mve Loss: : -0.0520
# 	Val Target Mve Loss: : -0.0194
# Saving Model... Done.
#
# Epoch 7: 44.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1631
# 	Train Regression Loss: : 0.0318
# 	Train Mve Loss: : -0.0743
# 	Train R2 Score: : 0.9037
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0313
# 	Val Target Regression Loss: : 0.0372
# 	Val Source R2 Score: : 0.9041
# 	Val Target R2 Score: : 0.8889
# 	Val Source Mve Loss: : -0.0647
# 	Val Target Mve Loss: : -0.0329
# Saving Model... Done.
#
# Epoch 8: 43.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1626
# 	Train Regression Loss: : 0.0296
# 	Train Mve Loss: : -0.0640
# 	Train R2 Score: : 0.9103
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0295
# 	Val Target Regression Loss: : 0.0353
# 	Val Source R2 Score: : 0.9092
# 	Val Target R2 Score: : 0.8946
# 	Val Source Mve Loss: : -0.0593
# 	Val Target Mve Loss: : -0.0262
# Saving Model... Done.
#
# Epoch 9: 39.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1621
# 	Train Regression Loss: : 0.0282
# 	Train Mve Loss: : -0.0673
# 	Train R2 Score: : 0.9145
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0281
# 	Val Target Regression Loss: : 0.0361
# 	Val Source R2 Score: : 0.9131
# 	Val Target R2 Score: : 0.8930
# 	Val Source Mve Loss: : -0.0550
# 	Val Target Mve Loss: : -0.0235
#
# Epoch 10: 45.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1616
# 	Train Regression Loss: : 0.0269
# 	Train Mve Loss: : -0.0745
# 	Train R2 Score: : 0.9185
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0271
# 	Val Target Regression Loss: : 0.0348
# 	Val Source R2 Score: : 0.9164
# 	Val Target R2 Score: : 0.8971
# 	Val Source Mve Loss: : -0.0904
# 	Val Target Mve Loss: : -0.0623
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 11: 39.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1618
# 	Train Regression Loss: : 0.0261
# 	Train Mve Loss: : -0.0769
# 	Train R2 Score: : 0.9208
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0263
# 	Val Target Regression Loss: : 0.0352
# 	Val Source R2 Score: : 0.9192
# 	Val Target R2 Score: : 0.8946
# 	Val Source Mve Loss: : -0.0926
# 	Val Target Mve Loss: : -0.0587
#
# Epoch 12: 43.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1614
# 	Train Regression Loss: : 0.0256
# 	Train Mve Loss: : -0.0867
# 	Train R2 Score: : 0.9224
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0262
# 	Val Target Regression Loss: : 0.0346
# 	Val Source R2 Score: : 0.9199
# 	Val Target R2 Score: : 0.8973
# 	Val Source Mve Loss: : -0.1018
# 	Val Target Mve Loss: : -0.0693
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 13: 46.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1606
# 	Train Regression Loss: : 0.0252
# 	Train Mve Loss: : -0.0747
# 	Train R2 Score: : 0.9235
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0253
# 	Val Target Regression Loss: : 0.0338
# 	Val Source R2 Score: : 0.9224
# 	Val Target R2 Score: : 0.8993
# 	Val Source Mve Loss: : -0.0646
# 	Val Target Mve Loss: : -0.0270
# Saving Model... Done.
#
# Epoch 14: 45.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1596
# 	Train Regression Loss: : 0.0248
# 	Train Mve Loss: : -0.0650
# 	Train R2 Score: : 0.9249
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0253
# 	Val Target Regression Loss: : 0.0353
# 	Val Source R2 Score: : 0.9217
# 	Val Target R2 Score: : 0.8948
# 	Val Source Mve Loss: : -0.0644
# 	Val Target Mve Loss: : -0.0264
#
# Epoch 15: 42.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1583
# 	Train Regression Loss: : 0.0243
# 	Train Mve Loss: : -0.0665
# 	Train R2 Score: : 0.9261
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0244
# 	Val Target Regression Loss: : 0.0335
# 	Val Source R2 Score: : 0.9253
# 	Val Target R2 Score: : 0.8997
# 	Val Source Mve Loss: : -0.0570
# 	Val Target Mve Loss: : -0.0202
# Saving Model... Done.
#
# Epoch 16: 44.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1559
# 	Train Regression Loss: : 0.0238
# 	Train Mve Loss: : -0.0866
# 	Train R2 Score: : 0.9278
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0240
# 	Val Target Regression Loss: : 0.0333
# 	Val Source R2 Score: : 0.9268
# 	Val Target R2 Score: : 0.9008
# 	Val Source Mve Loss: : -0.1376
# 	Val Target Mve Loss: : -0.1182
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 17: 43.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1564
# 	Train Regression Loss: : 0.0233
# 	Train Mve Loss: : -0.0966
# 	Train R2 Score: : 0.9293
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0234
# 	Val Target Regression Loss: : 0.0332
# 	Val Source R2 Score: : 0.9285
# 	Val Target R2 Score: : 0.9018
# 	Val Source Mve Loss: : -0.0654
# 	Val Target Mve Loss: : -0.0267
# Saving Model... Done.
#
# Epoch 18: 47.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1564
# 	Train Regression Loss: : 0.0229
# 	Train Mve Loss: : -0.0660
# 	Train R2 Score: : 0.9304
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0232
# 	Val Target Regression Loss: : 0.0340
# 	Val Source R2 Score: : 0.9291
# 	Val Target R2 Score: : 0.8982
# 	Val Source Mve Loss: : -0.0605
# 	Val Target Mve Loss: : -0.0192
#
# Epoch 19: 39.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1561
# 	Train Regression Loss: : 0.0228
# 	Train Mve Loss: : -0.0853
# 	Train R2 Score: : 0.9309
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0230
# 	Val Target Regression Loss: : 0.0331
# 	Val Source R2 Score: : 0.9294
# 	Val Target R2 Score: : 0.9009
# 	Val Source Mve Loss: : -0.0688
# 	Val Target Mve Loss: : -0.0295
# Generating Isomap...
# Epoch 20: 42.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1558
# 	Train Regression Loss: : 0.0223
# 	Train Mve Loss: : -0.0660
# 	Train R2 Score: : 0.9323
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0223
# 	Val Target Regression Loss: : 0.0332
# 	Val Source R2 Score: : 0.9318
# 	Val Target R2 Score: : 0.9015
# 	Val Source Mve Loss: : -0.0569
# 	Val Target Mve Loss: : -0.0137
#
# Epoch 21: 47.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1573
# 	Train Regression Loss: : 0.0218
# 	Train Mve Loss: : -0.0770
# 	Train R2 Score: : 0.9341
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0222
# 	Val Target Regression Loss: : 0.0332
# 	Val Source R2 Score: : 0.9321
# 	Val Target R2 Score: : 0.9015
# 	Val Source Mve Loss: : -0.1000
# 	Val Target Mve Loss: : -0.0687
#
# Epoch 22: 40.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1547
# 	Train Regression Loss: : 0.0216
# 	Train Mve Loss: : -0.1021
# 	Train R2 Score: : 0.9346
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0219
# 	Val Target Regression Loss: : 0.0319
# 	Val Source R2 Score: : 0.9315
# 	Val Target R2 Score: : 0.9052
# 	Val Source Mve Loss: : -0.1042
# 	Val Target Mve Loss: : -0.0653
# Saving Model... Done.
#
# Epoch 23: 46.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1530
# 	Train Regression Loss: : 0.0213
# 	Train Mve Loss: : -0.1209
# 	Train R2 Score: : 0.9356
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0214
# 	Val Target Regression Loss: : 0.0323
# 	Val Source R2 Score: : 0.9343
# 	Val Target R2 Score: : 0.9038
# 	Val Source Mve Loss: : -0.1170
# 	Val Target Mve Loss: : -0.0942
#
# Epoch 24: 46.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1512
# 	Train Regression Loss: : 0.0210
# 	Train Mve Loss: : -0.0969
# 	Train R2 Score: : 0.9364
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0212
# 	Val Target Regression Loss: : 0.0323
# 	Val Source R2 Score: : 0.9353
# 	Val Target R2 Score: : 0.9041
# 	Val Source Mve Loss: : -0.0755
# 	Val Target Mve Loss: : -0.0357
#
# Epoch 25: 40.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1529
# 	Train Regression Loss: : 0.0208
# 	Train Mve Loss: : -0.0801
# 	Train R2 Score: : 0.9370
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0214
# 	Val Target Regression Loss: : 0.0335
# 	Val Source R2 Score: : 0.9347
# 	Val Target R2 Score: : 0.9008
# 	Val Source Mve Loss: : -0.0651
# 	Val Target Mve Loss: : -0.0162
#
# Epoch 26: 42.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1513
# 	Train Regression Loss: : 0.0205
# 	Train Mve Loss: : -0.0817
# 	Train R2 Score: : 0.9377
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0209
# 	Val Target Regression Loss: : 0.0324
# 	Val Source R2 Score: : 0.9358
# 	Val Target R2 Score: : 0.9037
# 	Val Source Mve Loss: : -0.1610
# 	Val Target Mve Loss: : -0.1393
# Saving Model MVE... Done.
#
# Epoch 27: 43.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1536
# 	Train Regression Loss: : 0.0203
# 	Train Mve Loss: : -0.1243
# 	Train R2 Score: : 0.9384
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0207
# 	Val Target Regression Loss: : 0.0333
# 	Val Source R2 Score: : 0.9370
# 	Val Target R2 Score: : 0.9016
# 	Val Source Mve Loss: : -0.0954
# 	Val Target Mve Loss: : -0.0445
#
# Epoch 28: 45.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1556
# 	Train Regression Loss: : 0.0204
# 	Train Mve Loss: : -0.1343
# 	Train R2 Score: : 0.9382
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0208
# 	Val Target Regression Loss: : 0.0327
# 	Val Source R2 Score: : 0.9366
# 	Val Target R2 Score: : 0.9018
# 	Val Source Mve Loss: : -0.1152
# 	Val Target Mve Loss: : -0.0753
#
# Epoch 29: 45.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1568
# 	Train Regression Loss: : 0.0203
# 	Train Mve Loss: : -0.0917
# 	Train R2 Score: : 0.9385
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0209
# 	Val Target Regression Loss: : 0.0311
# 	Val Source R2 Score: : 0.9358
# 	Val Target R2 Score: : 0.9071
# 	Val Source Mve Loss: : -0.0784
# 	Val Target Mve Loss: : -0.0259
# Saving Model... Done.
#
# Epoch 30: 43.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1563
# 	Train Regression Loss: : 0.0201
# 	Train Mve Loss: : -0.1035
# 	Train R2 Score: : 0.9391
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0205
# 	Val Target Regression Loss: : 0.0326
# 	Val Source R2 Score: : 0.9373
# 	Val Target R2 Score: : 0.9030
# 	Val Source Mve Loss: : -0.1580
# 	Val Target Mve Loss: : -0.1310
#
# Epoch 31: 42.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1558
# 	Train Regression Loss: : 0.0199
# 	Train Mve Loss: : -0.1221
# 	Train R2 Score: : 0.9397
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0204
# 	Val Target Regression Loss: : 0.0323
# 	Val Source R2 Score: : 0.9376
# 	Val Target R2 Score: : 0.9044
# 	Val Source Mve Loss: : -0.0967
# 	Val Target Mve Loss: : -0.0342
#
# Epoch 32: 39.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1553
# 	Train Regression Loss: : 0.0197
# 	Train Mve Loss: : -0.0922
# 	Train R2 Score: : 0.9402
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0201
# 	Val Target Regression Loss: : 0.0317
# 	Val Source R2 Score: : 0.9384
# 	Val Target R2 Score: : 0.9059
# 	Val Source Mve Loss: : -0.0748
# 	Val Target Mve Loss: : -0.0046
#
# Epoch 33: 37.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1547
# 	Train Regression Loss: : 0.0194
# 	Train Mve Loss: : -0.0833
# 	Train R2 Score: : 0.9412
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0198
# 	Val Target Regression Loss: : 0.0327
# 	Val Source R2 Score: : 0.9391
# 	Val Target R2 Score: : 0.9030
# 	Val Source Mve Loss: : -0.1197
# 	Val Target Mve Loss: : -0.0687
#
# Epoch 34: 42.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1554
# 	Train Regression Loss: : 0.0192
# 	Train Mve Loss: : -0.0907
# 	Train R2 Score: : 0.9419
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0193
# 	Val Target Regression Loss: : 0.0326
# 	Val Source R2 Score: : 0.9410
# 	Val Target R2 Score: : 0.9026
# 	Val Source Mve Loss: : -0.0836
# 	Val Target Mve Loss: : -0.0094
#
# Epoch 35: 47.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1540
# 	Train Regression Loss: : 0.0188
# 	Train Mve Loss: : -0.0808
# 	Train R2 Score: : 0.9429
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0192
# 	Val Target Regression Loss: : 0.0316
# 	Val Source R2 Score: : 0.9412
# 	Val Target R2 Score: : 0.9058
# 	Val Source Mve Loss: : -0.1423
# 	Val Target Mve Loss: : -0.1135
#
# Epoch 36: 41.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1544
# 	Train Regression Loss: : 0.0185
# 	Train Mve Loss: : -0.1001
# 	Train R2 Score: : 0.9439
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0186
# 	Val Target Regression Loss: : 0.0319
# 	Val Source R2 Score: : 0.9427
# 	Val Target R2 Score: : 0.9044
# 	Val Source Mve Loss: : -0.0945
# 	Val Target Mve Loss: : -0.0253
#
# Epoch 37: 40.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1530
# 	Train Regression Loss: : 0.0183
# 	Train Mve Loss: : -0.0903
# 	Train R2 Score: : 0.9446
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0186
# 	Val Target Regression Loss: : 0.0318
# 	Val Source R2 Score: : 0.9425
# 	Val Target R2 Score: : 0.9053
# 	Val Source Mve Loss: : -0.0874
# 	Val Target Mve Loss: : -0.0069
#
# Epoch 38: 41.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1519
# 	Train Regression Loss: : 0.0179
# 	Train Mve Loss: : -0.0939
# 	Train R2 Score: : 0.9457
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0182
# 	Val Target Regression Loss: : 0.0312
# 	Val Source R2 Score: : 0.9437
# 	Val Target R2 Score: : 0.9073
# 	Val Source Mve Loss: : -0.0825
# 	Val Target Mve Loss: : 0.0088
# Saving Model... Done.
#
# Epoch 39: 39.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1520
# 	Train Regression Loss: : 0.0175
# 	Train Mve Loss: : -0.0819
# 	Train R2 Score: : 0.9469
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0178
# 	Val Target Regression Loss: : 0.0304
# 	Val Source R2 Score: : 0.9457
# 	Val Target R2 Score: : 0.9090
# 	Val Source Mve Loss: : -0.0613
# 	Val Target Mve Loss: : 0.0389
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 40: 45.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1503
# 	Train Regression Loss: : 0.0172
# 	Train Mve Loss: : -0.1115
# 	Train R2 Score: : 0.9477
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0173
# 	Val Target Regression Loss: : 0.0316
# 	Val Source R2 Score: : 0.9468
# 	Val Target R2 Score: : 0.9062
# 	Val Source Mve Loss: : -0.0816
# 	Val Target Mve Loss: : -0.0004
#
# Epoch 41: 46.06s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1512
# 	Train Regression Loss: : 0.0169
# 	Train Mve Loss: : -0.0827
# 	Train R2 Score: : 0.9486
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0170
# 	Val Target Regression Loss: : 0.0304
# 	Val Source R2 Score: : 0.9480
# 	Val Target R2 Score: : 0.9098
# 	Val Source Mve Loss: : -0.0612
# 	Val Target Mve Loss: : 0.0446
# Saving Model... Done.
#
# Epoch 42: 45.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1511
# 	Train Regression Loss: : 0.0166
# 	Train Mve Loss: : -0.0860
# 	Train R2 Score: : 0.9497
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0166
# 	Val Target Regression Loss: : 0.0302
# 	Val Source R2 Score: : 0.9488
# 	Val Target R2 Score: : 0.9104
# 	Val Source Mve Loss: : -0.0691
# 	Val Target Mve Loss: : 0.0435
# Saving Model... Done.
#
# Epoch 43: 45.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1518
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.1000
# 	Train R2 Score: : 0.9511
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0167
# 	Val Target Regression Loss: : 0.0310
# 	Val Source R2 Score: : 0.9488
# 	Val Target R2 Score: : 0.9073
# 	Val Source Mve Loss: : -0.0898
# 	Val Target Mve Loss: : 0.0301
#
# Epoch 44: 41.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1512
# 	Train Regression Loss: : 0.0158
# 	Train Mve Loss: : -0.0921
# 	Train R2 Score: : 0.9523
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0161
# 	Val Target Regression Loss: : 0.0305
# 	Val Source R2 Score: : 0.9507
# 	Val Target R2 Score: : 0.9095
# 	Val Source Mve Loss: : -0.1158
# 	Val Target Mve Loss: : -0.0352
#
# Epoch 45: 41.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1484
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.1240
# 	Train R2 Score: : 0.9533
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0159
# 	Val Target Regression Loss: : 0.0294
# 	Val Source R2 Score: : 0.9514
# 	Val Target R2 Score: : 0.9121
# 	Val Source Mve Loss: : -0.1115
# 	Val Target Mve Loss: : -0.0197
# Saving Model... Done.
#
# Epoch 46: 46.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1470
# 	Train Regression Loss: : 0.0152
# 	Train Mve Loss: : -0.1108
# 	Train R2 Score: : 0.9539
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0153
# 	Val Target Regression Loss: : 0.0297
# 	Val Source R2 Score: : 0.9528
# 	Val Target R2 Score: : 0.9116
# 	Val Source Mve Loss: : -0.1385
# 	Val Target Mve Loss: : -0.1038
#
# Epoch 47: 40.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1459
# 	Train Regression Loss: : 0.0149
# 	Train Mve Loss: : -0.1141
# 	Train R2 Score: : 0.9547
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0154
# 	Val Target Regression Loss: : 0.0306
# 	Val Source R2 Score: : 0.9529
# 	Val Target R2 Score: : 0.9095
# 	Val Source Mve Loss: : -0.0910
# 	Val Target Mve Loss: : 0.0352

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = "models/papermve_v3_aug22_1315_A_mve" # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(0, 0.05)
# Out:
# (0.0, 0.05)

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-2, 10)
# Out:
# (-2.0, 10.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9664

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.966')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | BNLL: -0.323')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9598

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.960')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.960')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.316')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
