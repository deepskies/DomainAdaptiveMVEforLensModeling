# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Set Seed
torch.manual_seed(22)

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_lenscolor_source/mb_lenscolor_source.npy'
target_img_path = head / 'data/mb_lenscolor_target/mb_lenscolor_target.npy'
source_meta = head / 'data/mb_lenscolor_source/mb_lenscolor_source_metadata.csv'
target_meta = head / 'data/mb_lenscolor_target/mb_lenscolor_target_metadata.csv'
batch_size = 32
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    return da_weight

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    beta_val = beta_init - (beta_init - beta_final) * (epoch / n_epoch)
    return beta_val

# Initialize hyperparameters
learning_rate = 3e-5
n_epoch = 150
init_wt_da = 1.4
final_wt_da = 1.0
beta_init = 1.0
beta_final = 0.4

# %%
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None # "models/start_code_test_2"
stats, model, optimizer, best_target_R2, best_mve_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/mve_v2_aug4_2000"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")


for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1

        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# Epoch 0: 14.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2988
# 	Train Regression Loss: : 0.8872
# 	Train Mve Loss: : 0.2975
# 	Train R2 Score: : -1.7871
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2336
# 	Val Target Regression Loss: : 0.2482
# 	Val Source R2 Score: : 0.2731
# 	Val Target R2 Score: : 0.2172
# 	Val Source Mve Loss: : -0.0586
# 	Val Target Mve Loss: : -0.0518
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 1: 16.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1749
# 	Train Regression Loss: : 0.1455
# 	Train Mve Loss: : -0.0692
# 	Train R2 Score: : 0.5474
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0826
# 	Val Target Regression Loss: : 0.0887
# 	Val Source R2 Score: : 0.7380
# 	Val Target R2 Score: : 0.7205
# 	Val Source Mve Loss: : -0.0655
# 	Val Target Mve Loss: : -0.0612
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 2: 13.67s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1588
# 	Train Regression Loss: : 0.0563
# 	Train Mve Loss: : -0.0706
# 	Train R2 Score: : 0.8231
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0502
# 	Val Target Regression Loss: : 0.0530
# 	Val Source R2 Score: : 0.8416
# 	Val Target R2 Score: : 0.8336
# 	Val Source Mve Loss: : -0.1058
# 	Val Target Mve Loss: : -0.1027
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 3: 13.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1520
# 	Train Regression Loss: : 0.0423
# 	Train Mve Loss: : -0.0607
# 	Train R2 Score: : 0.8675
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0417
# 	Val Target Regression Loss: : 0.0474
# 	Val Source R2 Score: : 0.8705
# 	Val Target R2 Score: : 0.8468
# 	Val Source Mve Loss: : -0.1070
# 	Val Target Mve Loss: : -0.1044
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 4: 13.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1492
# 	Train Regression Loss: : 0.0386
# 	Train Mve Loss: : -0.0952
# 	Train R2 Score: : 0.8783
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0394
# 	Val Target Regression Loss: : 0.0421
# 	Val Source R2 Score: : 0.8754
# 	Val Target R2 Score: : 0.8649
# 	Val Source Mve Loss: : -0.0588
# 	Val Target Mve Loss: : -0.0562
# Saving Model... Done.
#
# Epoch 5: 13.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1467
# 	Train Regression Loss: : 0.0358
# 	Train Mve Loss: : -0.0582
# 	Train R2 Score: : 0.8874
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0386
# 	Val Target Regression Loss: : 0.0394
# 	Val Source R2 Score: : 0.8800
# 	Val Target R2 Score: : 0.8752
# 	Val Source Mve Loss: : -0.0429
# 	Val Target Mve Loss: : -0.0424
# Saving Model... Done.
#
# Epoch 6: 13.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1429
# 	Train Regression Loss: : 0.0350
# 	Train Mve Loss: : -0.0554
# 	Train R2 Score: : 0.8899
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0365
# 	Val Target Regression Loss: : 0.0369
# 	Val Source R2 Score: : 0.8845
# 	Val Target R2 Score: : 0.8829
# 	Val Source Mve Loss: : -0.0410
# 	Val Target Mve Loss: : -0.0402
# Saving Model... Done.
#
# Epoch 7: 13.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1414
# 	Train Regression Loss: : 0.0342
# 	Train Mve Loss: : -0.0500
# 	Train R2 Score: : 0.8920
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0358
# 	Val Target Regression Loss: : 0.0378
# 	Val Source R2 Score: : 0.8873
# 	Val Target R2 Score: : 0.8796
# 	Val Source Mve Loss: : -0.1647
# 	Val Target Mve Loss: : -0.1637
# Saving Model MVE... Done.
#
# Epoch 8: 13.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1392
# 	Train Regression Loss: : 0.0340
# 	Train Mve Loss: : -0.0642
# 	Train R2 Score: : 0.8932
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0353
# 	Val Target Regression Loss: : 0.0356
# 	Val Source R2 Score: : 0.8889
# 	Val Target R2 Score: : 0.8881
# 	Val Source Mve Loss: : -0.0429
# 	Val Target Mve Loss: : -0.0425
# Saving Model... Done.
#
# Epoch 9: 13.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1342
# 	Train Regression Loss: : 0.0336
# 	Train Mve Loss: : -0.0516
# 	Train R2 Score: : 0.8940
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0352
# 	Val Target Regression Loss: : 0.0366
# 	Val Source R2 Score: : 0.8900
# 	Val Target R2 Score: : 0.8835
# 	Val Source Mve Loss: : -0.0813
# 	Val Target Mve Loss: : -0.0806
#
# Epoch 10: 16.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1377
# 	Train Regression Loss: : 0.0342
# 	Train Mve Loss: : -0.0489
# 	Train R2 Score: : 0.8917
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0354
# 	Val Target Regression Loss: : 0.0365
# 	Val Source R2 Score: : 0.8886
# 	Val Target R2 Score: : 0.8835
# 	Val Source Mve Loss: : -0.0368
# 	Val Target Mve Loss: : -0.0360
#
# Epoch 11: 13.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1370
# 	Train Regression Loss: : 0.0349
# 	Train Mve Loss: : -0.0547
# 	Train R2 Score: : 0.8895
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0373
# 	Val Target Regression Loss: : 0.0374
# 	Val Source R2 Score: : 0.8814
# 	Val Target R2 Score: : 0.8818
# 	Val Source Mve Loss: : -0.0463
# 	Val Target Mve Loss: : -0.0461
#
# Epoch 12: 13.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1372
# 	Train Regression Loss: : 0.0353
# 	Train Mve Loss: : -0.0566
# 	Train R2 Score: : 0.8892
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0374
# 	Val Target Regression Loss: : 0.0373
# 	Val Source R2 Score: : 0.8682
# 	Val Target R2 Score: : 0.8816
# 	Val Source Mve Loss: : -0.0357
# 	Val Target Mve Loss: : -0.0357
#
# Epoch 13: 14.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1382
# 	Train Regression Loss: : 0.0354
# 	Train Mve Loss: : -0.0490
# 	Train R2 Score: : 0.8885
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0376
# 	Val Target Regression Loss: : 0.0388
# 	Val Source R2 Score: : 0.8816
# 	Val Target R2 Score: : 0.8767
# 	Val Source Mve Loss: : -0.0530
# 	Val Target Mve Loss: : -0.0518
#
# Epoch 14: 13.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1411
# 	Train Regression Loss: : 0.0367
# 	Train Mve Loss: : -0.0685
# 	Train R2 Score: : 0.8838
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0381
# 	Val Target Regression Loss: : 0.0394
# 	Val Source R2 Score: : 0.8811
# 	Val Target R2 Score: : 0.8744
# 	Val Source Mve Loss: : -0.0481
# 	Val Target Mve Loss: : -0.0463
#
# Epoch 15: 13.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1434
# 	Train Regression Loss: : 0.0362
# 	Train Mve Loss: : -0.0511
# 	Train R2 Score: : 0.8855
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0382
# 	Val Target Regression Loss: : 0.0390
# 	Val Source R2 Score: : 0.8775
# 	Val Target R2 Score: : 0.8761
# 	Val Source Mve Loss: : -0.0540
# 	Val Target Mve Loss: : -0.0524
#
# Epoch 16: 13.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1442
# 	Train Regression Loss: : 0.0353
# 	Train Mve Loss: : -0.0495
# 	Train R2 Score: : 0.8889
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0367
# 	Val Target Regression Loss: : 0.0396
# 	Val Source R2 Score: : 0.8857
# 	Val Target R2 Score: : 0.8749
# 	Val Source Mve Loss: : -0.0588
# 	Val Target Mve Loss: : -0.0554
#
# Epoch 17: 13.84s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1429
# 	Train Regression Loss: : 0.0348
# 	Train Mve Loss: : -0.0879
# 	Train R2 Score: : 0.8908
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0345
# 	Val Target Regression Loss: : 0.0380
# 	Val Source R2 Score: : 0.8925
# 	Val Target R2 Score: : 0.8800
# 	Val Source Mve Loss: : -0.0551
# 	Val Target Mve Loss: : -0.0525
#
# Epoch 18: 13.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1462
# 	Train Regression Loss: : 0.0338
# 	Train Mve Loss: : -0.0509
# 	Train R2 Score: : 0.8933
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0347
# 	Val Target Regression Loss: : 0.0397
# 	Val Source R2 Score: : 0.8908
# 	Val Target R2 Score: : 0.8749
# 	Val Source Mve Loss: : -0.0561
# 	Val Target Mve Loss: : -0.0521
#
# Epoch 19: 16.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1483
# 	Train Regression Loss: : 0.0366
# 	Train Mve Loss: : -0.0532
# 	Train R2 Score: : 0.8850
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0409
# 	Val Target Regression Loss: : 0.0468
# 	Val Source R2 Score: : 0.8718
# 	Val Target R2 Score: : 0.8519
# 	Val Source Mve Loss: : -0.0473
# 	Val Target Mve Loss: : -0.0427
# Generating Isomap...
# Epoch 20: 13.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1529
# 	Train Regression Loss: : 0.0422
# 	Train Mve Loss: : -0.0556
# 	Train R2 Score: : 0.8673
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0456
# 	Val Target Regression Loss: : 0.0486
# 	Val Source R2 Score: : 0.8570
# 	Val Target R2 Score: : 0.8476
# 	Val Source Mve Loss: : -0.0536
# 	Val Target Mve Loss: : -0.0513
#
# Epoch 21: 13.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1504
# 	Train Regression Loss: : 0.0487
# 	Train Mve Loss: : -0.0614
# 	Train R2 Score: : 0.8477
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0574
# 	Val Target Regression Loss: : 0.0579
# 	Val Source R2 Score: : 0.8218
# 	Val Target R2 Score: : 0.8184
# 	Val Source Mve Loss: : -0.0408
# 	Val Target Mve Loss: : -0.0404
#
# Epoch 22: 13.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1473
# 	Train Regression Loss: : 0.0590
# 	Train Mve Loss: : -0.0738
# 	Train R2 Score: : 0.8158
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0656
# 	Val Target Regression Loss: : 0.0662
# 	Val Source R2 Score: : 0.7970
# 	Val Target R2 Score: : 0.7906
# 	Val Source Mve Loss: : -0.0759
# 	Val Target Mve Loss: : -0.0752
#
# Epoch 23: 13.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1463
# 	Train Regression Loss: : 0.0648
# 	Train Mve Loss: : -0.0714
# 	Train R2 Score: : 0.7977
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0706
# 	Val Target Regression Loss: : 0.0718
# 	Val Source R2 Score: : 0.7814
# 	Val Target R2 Score: : 0.7717
# 	Val Source Mve Loss: : -0.0669
# 	Val Target Mve Loss: : -0.0659
#
# Epoch 24: 13.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1459
# 	Train Regression Loss: : 0.0714
# 	Train Mve Loss: : -0.0743
# 	Train R2 Score: : 0.7779
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0797
# 	Val Target Regression Loss: : 0.0807
# 	Val Source R2 Score: : 0.7508
# 	Val Target R2 Score: : 0.7472
# 	Val Source Mve Loss: : -0.0514
# 	Val Target Mve Loss: : -0.0507
#
# Epoch 25: 13.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1451
# 	Train Regression Loss: : 0.0798
# 	Train Mve Loss: : -0.0774
# 	Train R2 Score: : 0.7514
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0956
# 	Val Target Regression Loss: : 0.0972
# 	Val Source R2 Score: : 0.7054
# 	Val Target R2 Score: : 0.6949
# 	Val Source Mve Loss: : -0.0725
# 	Val Target Mve Loss: : -0.0715
#
# Epoch 26: 13.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1451
# 	Train Regression Loss: : 0.0902
# 	Train Mve Loss: : -0.0807
# 	Train R2 Score: : 0.7189
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0955
# 	Val Target Regression Loss: : 0.0964
# 	Val Source R2 Score: : 0.7029
# 	Val Target R2 Score: : 0.6950
# 	Val Source Mve Loss: : -0.0809
# 	Val Target Mve Loss: : -0.0803
#
# Epoch 27: 13.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1469
# 	Train Regression Loss: : 0.1042
# 	Train Mve Loss: : -0.0836
# 	Train R2 Score: : 0.6752
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1118
# 	Val Target Regression Loss: : 0.1118
# 	Val Source R2 Score: : 0.6542
# 	Val Target R2 Score: : 0.6500
# 	Val Source Mve Loss: : -0.0815
# 	Val Target Mve Loss: : -0.0814
#
# Epoch 28: 16.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1453
# 	Train Regression Loss: : 0.1222
# 	Train Mve Loss: : -0.0848
# 	Train R2 Score: : 0.6203
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1345
# 	Val Target Regression Loss: : 0.1337
# 	Val Source R2 Score: : 0.5806
# 	Val Target R2 Score: : 0.5799
# 	Val Source Mve Loss: : -0.0911
# 	Val Target Mve Loss: : -0.0916
#
# Epoch 29: 13.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1459
# 	Train Regression Loss: : 0.1473
# 	Train Mve Loss: : -0.0841
# 	Train R2 Score: : 0.5427
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1535
# 	Val Target Regression Loss: : 0.1536
# 	Val Source R2 Score: : 0.5311
# 	Val Target R2 Score: : 0.5201
# 	Val Source Mve Loss: : -0.0916
# 	Val Target Mve Loss: : -0.0915
#
# Epoch 30: 14.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1445
# 	Train Regression Loss: : 0.1684
# 	Train Mve Loss: : -0.0814
# 	Train R2 Score: : 0.4774
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1742
# 	Val Target Regression Loss: : 0.1731
# 	Val Source R2 Score: : 0.4687
# 	Val Target R2 Score: : 0.4558
# 	Val Source Mve Loss: : -0.0740
# 	Val Target Mve Loss: : -0.0747
#
# Epoch 31: 13.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1438
# 	Train Regression Loss: : 0.1898
# 	Train Mve Loss: : -0.0770
# 	Train R2 Score: : 0.4119
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2083
# 	Val Target Regression Loss: : 0.2086
# 	Val Source R2 Score: : 0.3497
# 	Val Target R2 Score: : 0.3463
# 	Val Source Mve Loss: : -0.0694
# 	Val Target Mve Loss: : -0.0692
#
# Epoch 32: 13.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1450
# 	Train Regression Loss: : 0.2188
# 	Train Mve Loss: : -0.0688
# 	Train R2 Score: : 0.3236
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2306
# 	Val Target Regression Loss: : 0.2291
# 	Val Source R2 Score: : 0.2889
# 	Val Target R2 Score: : 0.2848
# 	Val Source Mve Loss: : -0.0638
# 	Val Target Mve Loss: : -0.0647
#
# Epoch 33: 13.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1457
# 	Train Regression Loss: : 0.2459
# 	Train Mve Loss: : -0.0594
# 	Train R2 Score: : 0.2375
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2648
# 	Val Target Regression Loss: : 0.2612
# 	Val Source R2 Score: : 0.1830
# 	Val Target R2 Score: : 0.1856
# 	Val Source Mve Loss: : -0.0488
# 	Val Target Mve Loss: : -0.0510
#
# Epoch 34: 14.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1445
# 	Train Regression Loss: : 0.2729
# 	Train Mve Loss: : -0.0484
# 	Train R2 Score: : 0.1546
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2987
# 	Val Target Regression Loss: : 0.2940
# 	Val Source R2 Score: : 0.0796
# 	Val Target R2 Score: : 0.0804
# 	Val Source Mve Loss: : -0.0326
# 	Val Target Mve Loss: : -0.0354
#
# Epoch 35: 13.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1453
# 	Train Regression Loss: : 0.2907
# 	Train Mve Loss: : -0.0405
# 	Train R2 Score: : 0.0989
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2973
# 	Val Target Regression Loss: : 0.2962
# 	Val Source R2 Score: : 0.0820
# 	Val Target R2 Score: : 0.0715
# 	Val Source Mve Loss: : -0.0393
# 	Val Target Mve Loss: : -0.0399
#
# Epoch 36: 14.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1425
# 	Train Regression Loss: : 0.3024
# 	Train Mve Loss: : -0.0351
# 	Train R2 Score: : 0.0630
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3084
# 	Val Target Regression Loss: : 0.3057
# 	Val Source R2 Score: : 0.0481
# 	Val Target R2 Score: : 0.0449
# 	Val Source Mve Loss: : -0.0324
# 	Val Target Mve Loss: : -0.0341
#
# Epoch 37: 15.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1470
# 	Train Regression Loss: : 0.3104
# 	Train Mve Loss: : -0.0312
# 	Train R2 Score: : 0.0373
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3140
# 	Val Target Regression Loss: : 0.3119
# 	Val Source R2 Score: : 0.0340
# 	Val Target R2 Score: : 0.0232
# 	Val Source Mve Loss: : -0.0295
# 	Val Target Mve Loss: : -0.0307
#
# Epoch 38: 13.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1495
# 	Train Regression Loss: : 0.3149
# 	Train Mve Loss: : -0.0289
# 	Train R2 Score: : 0.0228
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3158
# 	Val Target Regression Loss: : 0.3142
# 	Val Source R2 Score: : 0.0287
# 	Val Target R2 Score: : 0.0219
# 	Val Source Mve Loss: : -0.0272
# 	Val Target Mve Loss: : -0.0281
#
# Epoch 39: 13.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1472
# 	Train Regression Loss: : 0.3190
# 	Train Mve Loss: : -0.0270
# 	Train R2 Score: : 0.0111
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3202
# 	Val Target Regression Loss: : 0.3170
# 	Val Source R2 Score: : 0.0176
# 	Val Target R2 Score: : 0.0056
# 	Val Source Mve Loss: : -0.0272
# 	Val Target Mve Loss: : -0.0291
# Generating Isomap...
# Epoch 40: 15.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1433
# 	Train Regression Loss: : 0.3208
# 	Train Mve Loss: : -0.0261
# 	Train R2 Score: : 0.0042
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3213
# 	Val Target Regression Loss: : 0.3171
# 	Val Source R2 Score: : 0.0032
# 	Val Target R2 Score: : 0.0027
# 	Val Source Mve Loss: : -0.0249
# 	Val Target Mve Loss: : -0.0274
#
# Epoch 41: 13.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1439
# 	Train Regression Loss: : 0.3233
# 	Train Mve Loss: : -0.0249
# 	Train R2 Score: : -0.0006
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3259
# 	Val Target Regression Loss: : 0.3239
# 	Val Source R2 Score: : -0.0013
# 	Val Target R2 Score: : -0.0209
# 	Val Source Mve Loss: : -0.0221
# 	Val Target Mve Loss: : -0.0233
#
# Epoch 42: 13.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1445
# 	Train Regression Loss: : 0.3253
# 	Train Mve Loss: : -0.0239
# 	Train R2 Score: : -0.0058
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3269
# 	Val Target Regression Loss: : 0.3229
# 	Val Source R2 Score: : -0.0084
# 	Val Target R2 Score: : -0.0224
# 	Val Source Mve Loss: : -0.0227
# 	Val Target Mve Loss: : -0.0251
#
# Epoch 43: 13.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1450
# 	Train Regression Loss: : 0.3267
# 	Train Mve Loss: : -0.0233
# 	Train R2 Score: : -0.0101
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3284
# 	Val Target Regression Loss: : 0.3268
# 	Val Source R2 Score: : -0.0201
# 	Val Target R2 Score: : -0.0230
# 	Val Source Mve Loss: : -0.0232
# 	Val Target Mve Loss: : -0.0241
#
# Epoch 44: 13.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1477
# 	Train Regression Loss: : 0.3280
# 	Train Mve Loss: : -0.0228
# 	Train R2 Score: : -0.0152
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3285
# 	Val Target Regression Loss: : 0.3250
# 	Val Source R2 Score: : -0.0128
# 	Val Target R2 Score: : -0.0171
# 	Val Source Mve Loss: : -0.0222
# 	Val Target Mve Loss: : -0.0244
#
# Epoch 45: 15.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1456
# 	Train Regression Loss: : 0.3292
# 	Train Mve Loss: : -0.0221
# 	Train R2 Score: : -0.0195
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3336
# 	Val Target Regression Loss: : 0.3264
# 	Val Source R2 Score: : -0.0194
# 	Val Target R2 Score: : -0.0188
# 	Val Source Mve Loss: : -0.0191
# 	Val Target Mve Loss: : -0.0235
#
# Epoch 46: 13.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1447
# 	Train Regression Loss: : 0.3306
# 	Train Mve Loss: : -0.0214
# 	Train R2 Score: : -0.0243
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3320
# 	Val Target Regression Loss: : 0.3259
# 	Val Source R2 Score: : -0.0245
# 	Val Target R2 Score: : -0.0231
# 	Val Source Mve Loss: : -0.0194
# 	Val Target Mve Loss: : -0.0232
#
# Epoch 47: 15.20s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1433
# 	Train Regression Loss: : 0.3316
# 	Train Mve Loss: : -0.0210
# 	Train R2 Score: : -0.0279
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3314
# 	Val Target Regression Loss: : 0.3260
# 	Val Source R2 Score: : -0.0141
# 	Val Target R2 Score: : -0.0207
# 	Val Source Mve Loss: : -0.0203
# 	Val Target Mve Loss: : -0.0236
#
# Epoch 48: 13.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1376
# 	Train Regression Loss: : 0.3312
# 	Train Mve Loss: : -0.0213
# 	Train R2 Score: : -0.0270
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3314
# 	Val Target Regression Loss: : 0.3260
# 	Val Source R2 Score: : -0.0238
# 	Val Target R2 Score: : -0.0217
# 	Val Source Mve Loss: : -0.0214
# 	Val Target Mve Loss: : -0.0247
#
# Epoch 49: 13.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1376
# 	Train Regression Loss: : 0.3320
# 	Train Mve Loss: : -0.0210
# 	Train R2 Score: : -0.0277
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3363
# 	Val Target Regression Loss: : 0.3300
# 	Val Source R2 Score: : -0.0349
# 	Val Target R2 Score: : -0.0326
# 	Val Source Mve Loss: : -0.0191
# 	Val Target Mve Loss: : -0.0230
#
# Epoch 50: 13.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1403
# 	Train Regression Loss: : 0.3325
# 	Train Mve Loss: : -0.0207
# 	Train R2 Score: : -0.0296
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3395
# 	Val Target Regression Loss: : 0.3319
# 	Val Source R2 Score: : -0.0468
# 	Val Target R2 Score: : -0.0340
# 	Val Source Mve Loss: : -0.0163
# 	Val Target Mve Loss: : -0.0211
#
# Epoch 51: 13.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1394
# 	Train Regression Loss: : 0.3333
# 	Train Mve Loss: : -0.0204
# 	Train R2 Score: : -0.0325
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3362
# 	Val Target Regression Loss: : 0.3343
# 	Val Source R2 Score: : -0.0357
# 	Val Target R2 Score: : -0.0455
# 	Val Source Mve Loss: : -0.0192
# 	Val Target Mve Loss: : -0.0203
#
# Epoch 52: 13.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1366
# 	Train Regression Loss: : 0.3337
# 	Train Mve Loss: : -0.0203
# 	Train R2 Score: : -0.0331
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3360
# 	Val Target Regression Loss: : 0.3333
# 	Val Source R2 Score: : -0.0413
# 	Val Target R2 Score: : -0.0596
# 	Val Source Mve Loss: : -0.0185
# 	Val Target Mve Loss: : -0.0202
#
# Epoch 53: 13.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1391
# 	Train Regression Loss: : 0.3338
# 	Train Mve Loss: : -0.0204
# 	Train R2 Score: : -0.0343
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3328
# 	Val Target Regression Loss: : 0.3284
# 	Val Source R2 Score: : -0.0282
# 	Val Target R2 Score: : -0.0217
# 	Val Source Mve Loss: : -0.0216
# 	Val Target Mve Loss: : -0.0244
#
# Epoch 54: 16.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1354
# 	Train Regression Loss: : 0.3342
# 	Train Mve Loss: : -0.0201
# 	Train R2 Score: : -0.0352
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3342
# 	Val Target Regression Loss: : 0.3288
# 	Val Source R2 Score: : -0.0271
# 	Val Target R2 Score: : -0.0247
# 	Val Source Mve Loss: : -0.0206
# 	Val Target Mve Loss: : -0.0241
#
# Epoch 55: 13.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1336
# 	Train Regression Loss: : 0.3338
# 	Train Mve Loss: : -0.0205
# 	Train R2 Score: : -0.0333
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3336
# 	Val Target Regression Loss: : 0.3300
# 	Val Source R2 Score: : -0.0309
# 	Val Target R2 Score: : -0.0321
# 	Val Source Mve Loss: : -0.0211
# 	Val Target Mve Loss: : -0.0234
#
# Epoch 56: 13.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1250
# 	Train Regression Loss: : 0.3343
# 	Train Mve Loss: : -0.0202
# 	Train R2 Score: : -0.0371
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3402
# 	Val Target Regression Loss: : 0.3379
# 	Val Source R2 Score: : -0.0489
# 	Val Target R2 Score: : -0.0609
# 	Val Source Mve Loss: : -0.0170
# 	Val Target Mve Loss: : -0.0185
#
# Epoch 57: 13.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1259
# 	Train Regression Loss: : 0.3341
# 	Train Mve Loss: : -0.0204
# 	Train R2 Score: : -0.0355
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3348
# 	Val Target Regression Loss: : 0.3295
# 	Val Source R2 Score: : -0.0256
# 	Val Target R2 Score: : -0.0254
# 	Val Source Mve Loss: : -0.0195
# 	Val Target Mve Loss: : -0.0229
#
# Epoch 58: 13.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1269
# 	Train Regression Loss: : 0.3344
# 	Train Mve Loss: : -0.0204
# 	Train R2 Score: : -0.0351
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3357
# 	Val Target Regression Loss: : 0.3335
# 	Val Source R2 Score: : -0.0318
# 	Val Target R2 Score: : -0.0375
# 	Val Source Mve Loss: : -0.0203
# 	Val Target Mve Loss: : -0.0217
#
# Epoch 59: 13.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1186
# 	Train Regression Loss: : 0.3345
# 	Train Mve Loss: : -0.0204
# 	Train R2 Score: : -0.0356
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3357
# 	Val Target Regression Loss: : 0.3321
# 	Val Source R2 Score: : -0.0400
# 	Val Target R2 Score: : -0.0404
# 	Val Source Mve Loss: : -0.0204
# 	Val Target Mve Loss: : -0.0227
# Generating Isomap...
# Epoch 60: 13.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1198
# 	Train Regression Loss: : 0.3344
# 	Train Mve Loss: : -0.0205
# 	Train R2 Score: : -0.0363
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3350
# 	Val Target Regression Loss: : 0.3309
# 	Val Source R2 Score: : -0.0299
# 	Val Target R2 Score: : -0.0356
# 	Val Source Mve Loss: : -0.0202
# 	Val Target Mve Loss: : -0.0229
#
# Epoch 61: 13.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1162
# 	Train Regression Loss: : 0.3343
# 	Train Mve Loss: : -0.0207
# 	Train R2 Score: : -0.0376
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3344
# 	Val Target Regression Loss: : 0.3297
# 	Val Source R2 Score: : -0.0304
# 	Val Target R2 Score: : -0.0331
# 	Val Source Mve Loss: : -0.0206
# 	Val Target Mve Loss: : -0.0237
#
# Epoch 62: 13.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1195
# 	Train Regression Loss: : 0.3347
# 	Train Mve Loss: : -0.0205
# 	Train R2 Score: : -0.0369
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3414
# 	Val Target Regression Loss: : 0.3336
# 	Val Source R2 Score: : -0.0509
# 	Val Target R2 Score: : -0.0471
# 	Val Source Mve Loss: : -0.0169
# 	Val Target Mve Loss: : -0.0219
#
# Epoch 63: 15.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1152
# 	Train Regression Loss: : 0.3345
# 	Train Mve Loss: : -0.0208
# 	Train R2 Score: : -0.0366
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3362
# 	Val Target Regression Loss: : 0.3309
# 	Val Source R2 Score: : -0.0391
# 	Val Target R2 Score: : -0.0269
# 	Val Source Mve Loss: : -0.0201
# 	Val Target Mve Loss: : -0.0236
#
# Epoch 64: 13.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1191
# 	Train Regression Loss: : 0.3349
# 	Train Mve Loss: : -0.0206
# 	Train R2 Score: : -0.0398
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3383
# 	Val Target Regression Loss: : 0.3315
# 	Val Source R2 Score: : -0.0391
# 	Val Target R2 Score: : -0.0369
# 	Val Source Mve Loss: : -0.0181
# 	Val Target Mve Loss: : -0.0226
#
# Epoch 65: 13.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1203
# 	Train Regression Loss: : 0.3348
# 	Train Mve Loss: : -0.0208
# 	Train R2 Score: : -0.0357
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3361
# 	Val Target Regression Loss: : 0.3296
# 	Val Source R2 Score: : -0.0385
# 	Val Target R2 Score: : -0.0310
# 	Val Source Mve Loss: : -0.0195
# 	Val Target Mve Loss: : -0.0239
#
# Epoch 66: 13.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1169
# 	Train Regression Loss: : 0.3349
# 	Train Mve Loss: : -0.0208
# 	Train R2 Score: : -0.0413
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3345
# 	Val Target Regression Loss: : 0.3304
# 	Val Source R2 Score: : -0.0305
# 	Val Target R2 Score: : -0.0391
# 	Val Source Mve Loss: : -0.0212
# 	Val Target Mve Loss: : -0.0240
#
# Epoch 67: 13.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1167
# 	Train Regression Loss: : 0.3351
# 	Train Mve Loss: : -0.0208
# 	Train R2 Score: : -0.0405
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3340
# 	Val Target Regression Loss: : 0.3297
# 	Val Source R2 Score: : -0.0339
# 	Val Target R2 Score: : -0.0329
# 	Val Source Mve Loss: : -0.0219
# 	Val Target Mve Loss: : -0.0248
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 43
#      40 da_weight = da_weight_function(curr_epoch)
#      42 # Train, backpropagate
# ---> 43 vals = train_loop_mve(source_train_dataloader,
#      44                       target_train_dataloader,
#      45                       model,
#      46                       regressor_loss_fn,
#      47                       da_loss_fn,
#      48                       optimizer,
#      49                       da_weight,
#      50                       beta)
#      52 # Test, validate metrics
#      53 vals_validate = test_loop_mve(source_val_dataloader,
#      54                               target_val_dataloader,
#      55                               model,
#      56                               regressor_loss_fn,
#      57                               beta)
#
# File ~/work/dauq/src/training/MVE/train_utils.py:447, in train_loop_mve(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, optimizer, da_weight, beta_val)
#     443 loss = mve_loss + domain_loss * da_weight
#     446 # Backpropagation, update optimizer lr
# --> 447 loss.backward()
#     448 optimizer.step()
#     450 # Update values
#     451
#     452 # Domain loss is the DA loss or MMD loss between embedding outputs
#     453 # Estimator loss is the source data loss on regression
#     454 # MVE Error is the mve loss on training
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = final_mod_name # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 0.005)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is -0.0342

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: -0.034')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | BNLL: -0.032')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is -0.0363

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: -0.036')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: -0.036')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.024')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
