# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Set Seed
torch.manual_seed(22)

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_lenscolor_source/mb_lenscolor_source.npy'
target_img_path = head / 'data/mb_lenscolor_target/mb_lenscolor_target.npy'
source_meta = head / 'data/mb_lenscolor_source/mb_lenscolor_source_metadata.csv'
target_meta = head / 'data/mb_lenscolor_target/mb_lenscolor_target_metadata.csv'
batch_size = 64
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    return da_weight

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    beta_val = beta_init - (beta_init - beta_final) * (epoch / n_epoch)
    return beta_val

# Initialize hyperparameters
learning_rate = 3e-5
n_epoch = 250
init_wt_da = 1.4
final_wt_da = 1.0
beta_init = 1.0
beta_final = 0.0

# %%
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None # "models/start_code_test_2"
stats, model, optimizer, best_target_R2, best_mve_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/mve_v7_aug5_0045"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")


for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1

        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# Epoch 0: 12.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.3155
# 	Train Regression Loss: : 1.5881
# 	Train Mve Loss: : 0.6630
# 	Train R2 Score: : -3.8758
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.4044
# 	Val Target Regression Loss: : 0.4190
# 	Val Source R2 Score: : -0.2330
# 	Val Target R2 Score: : -0.2946
# 	Val Source Mve Loss: : 0.0715
# 	Val Target Mve Loss: : 0.0773
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 1: 11.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1512
# 	Train Regression Loss: : 0.2869
# 	Train Mve Loss: : -0.0185
# 	Train R2 Score: : 0.1251
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2338
# 	Val Target Regression Loss: : 0.2526
# 	Val Source R2 Score: : 0.2830
# 	Val Target R2 Score: : 0.2186
# 	Val Source Mve Loss: : -0.0608
# 	Val Target Mve Loss: : -0.0510
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 2: 11.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1092
# 	Train Regression Loss: : 0.1872
# 	Train Mve Loss: : -0.0685
# 	Train R2 Score: : 0.4293
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1462
# 	Val Target Regression Loss: : 0.1584
# 	Val Source R2 Score: : 0.5484
# 	Val Target R2 Score: : 0.5120
# 	Val Source Mve Loss: : -0.0722
# 	Val Target Mve Loss: : -0.0661
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 3: 10.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0957
# 	Train Regression Loss: : 0.1060
# 	Train Mve Loss: : -0.0762
# 	Train R2 Score: : 0.6766
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0804
# 	Val Target Regression Loss: : 0.0894
# 	Val Source R2 Score: : 0.7552
# 	Val Target R2 Score: : 0.7185
# 	Val Source Mve Loss: : -0.0577
# 	Val Target Mve Loss: : -0.0521
# Saving Model... Done.
#
# Epoch 4: 10.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0881
# 	Train Regression Loss: : 0.0597
# 	Train Mve Loss: : -0.0696
# 	Train R2 Score: : 0.8178
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0522
# 	Val Target Regression Loss: : 0.0565
# 	Val Source R2 Score: : 0.8387
# 	Val Target R2 Score: : 0.8235
# 	Val Source Mve Loss: : -0.0737
# 	Val Target Mve Loss: : -0.0712
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 5: 10.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0845
# 	Train Regression Loss: : 0.0431
# 	Train Mve Loss: : -0.0802
# 	Train R2 Score: : 0.8682
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0431
# 	Val Target Regression Loss: : 0.0460
# 	Val Source R2 Score: : 0.8698
# 	Val Target R2 Score: : 0.8574
# 	Val Source Mve Loss: : -0.0612
# 	Val Target Mve Loss: : -0.0569
# Saving Model... Done.
#
# Epoch 6: 10.66s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0804
# 	Train Regression Loss: : 0.0381
# 	Train Mve Loss: : -0.0634
# 	Train R2 Score: : 0.8832
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0398
# 	Val Target Regression Loss: : 0.0430
# 	Val Source R2 Score: : 0.8769
# 	Val Target R2 Score: : 0.8659
# 	Val Source Mve Loss: : -0.0449
# 	Val Target Mve Loss: : -0.0428
# Saving Model... Done.
#
# Epoch 7: 10.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0781
# 	Train Regression Loss: : 0.0354
# 	Train Mve Loss: : -0.0691
# 	Train R2 Score: : 0.8914
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0361
# 	Val Target Regression Loss: : 0.0393
# 	Val Source R2 Score: : 0.8878
# 	Val Target R2 Score: : 0.8779
# 	Val Source Mve Loss: : -0.0680
# 	Val Target Mve Loss: : -0.0649
# Saving Model... Done.
#
# Epoch 8: 11.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0765
# 	Train Regression Loss: : 0.0338
# 	Train Mve Loss: : -0.0644
# 	Train R2 Score: : 0.8965
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0350
# 	Val Target Regression Loss: : 0.0375
# 	Val Source R2 Score: : 0.8930
# 	Val Target R2 Score: : 0.8842
# 	Val Source Mve Loss: : -0.0463
# 	Val Target Mve Loss: : -0.0451
# Saving Model... Done.
#
# Epoch 9: 9.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0744
# 	Train Regression Loss: : 0.0320
# 	Train Mve Loss: : -0.0704
# 	Train R2 Score: : 0.9014
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0331
# 	Val Target Regression Loss: : 0.0359
# 	Val Source R2 Score: : 0.8996
# 	Val Target R2 Score: : 0.8885
# 	Val Source Mve Loss: : -0.1200
# 	Val Target Mve Loss: : -0.1185
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 10: 9.91s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0745
# 	Train Regression Loss: : 0.0308
# 	Train Mve Loss: : -0.0610
# 	Train R2 Score: : 0.9053
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0321
# 	Val Target Regression Loss: : 0.0350
# 	Val Source R2 Score: : 0.9021
# 	Val Target R2 Score: : 0.8918
# 	Val Source Mve Loss: : -0.0463
# 	Val Target Mve Loss: : -0.0444
# Saving Model... Done.
#
# Epoch 11: 10.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0725
# 	Train Regression Loss: : 0.0297
# 	Train Mve Loss: : -0.0677
# 	Train R2 Score: : 0.9087
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0313
# 	Val Target Regression Loss: : 0.0343
# 	Val Source R2 Score: : 0.9042
# 	Val Target R2 Score: : 0.8946
# 	Val Source Mve Loss: : -0.1717
# 	Val Target Mve Loss: : -0.1702
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 12: 10.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0720
# 	Train Regression Loss: : 0.0287
# 	Train Mve Loss: : -0.0732
# 	Train R2 Score: : 0.9122
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0328
# 	Val Target Regression Loss: : 0.0324
# 	Val Source R2 Score: : 0.8805
# 	Val Target R2 Score: : 0.8998
# 	Val Source Mve Loss: : -0.0842
# 	Val Target Mve Loss: : -0.0855
# Saving Model... Done.
#
# Epoch 13: 9.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0722
# 	Train Regression Loss: : 0.0281
# 	Train Mve Loss: : -0.0515
# 	Train R2 Score: : 0.9138
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0301
# 	Val Target Regression Loss: : 0.0313
# 	Val Source R2 Score: : 0.9068
# 	Val Target R2 Score: : 0.9030
# 	Val Source Mve Loss: : -0.0542
# 	Val Target Mve Loss: : -0.0530
# Saving Model... Done.
#
# Epoch 14: 10.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0725
# 	Train Regression Loss: : 0.0276
# 	Train Mve Loss: : -0.0518
# 	Train R2 Score: : 0.9150
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0291
# 	Val Target Regression Loss: : 0.0315
# 	Val Source R2 Score: : 0.9103
# 	Val Target R2 Score: : 0.9024
# 	Val Source Mve Loss: : -0.0466
# 	Val Target Mve Loss: : -0.0441
#
# Epoch 15: 10.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0736
# 	Train Regression Loss: : 0.0267
# 	Train Mve Loss: : -0.0554
# 	Train R2 Score: : 0.9181
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0286
# 	Val Target Regression Loss: : 0.0311
# 	Val Source R2 Score: : 0.9100
# 	Val Target R2 Score: : 0.9032
# 	Val Source Mve Loss: : -0.0471
# 	Val Target Mve Loss: : -0.0448
# Saving Model... Done.
#
# Epoch 16: 9.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0711
# 	Train Regression Loss: : 0.0260
# 	Train Mve Loss: : -0.0563
# 	Train R2 Score: : 0.9204
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0264
# 	Val Target Regression Loss: : 0.0301
# 	Val Source R2 Score: : 0.9199
# 	Val Target R2 Score: : 0.9073
# 	Val Source Mve Loss: : -0.0788
# 	Val Target Mve Loss: : -0.0767
# Saving Model... Done.
#
# Epoch 17: 10.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0710
# 	Train Regression Loss: : 0.0260
# 	Train Mve Loss: : -0.1338
# 	Train R2 Score: : 0.9202
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0273
# 	Val Target Regression Loss: : 0.0299
# 	Val Source R2 Score: : 0.9169
# 	Val Target R2 Score: : 0.9083
# 	Val Source Mve Loss: : -0.1721
# 	Val Target Mve Loss: : -0.1708
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 18: 10.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0707
# 	Train Regression Loss: : 0.0258
# 	Train Mve Loss: : -0.1488
# 	Train R2 Score: : 0.9208
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0267
# 	Val Target Regression Loss: : 0.0290
# 	Val Source R2 Score: : 0.9181
# 	Val Target R2 Score: : 0.9103
# 	Val Source Mve Loss: : -0.1388
# 	Val Target Mve Loss: : -0.1367
# Saving Model... Done.
#
# Epoch 19: 10.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0717
# 	Train Regression Loss: : 0.0251
# 	Train Mve Loss: : -0.0973
# 	Train R2 Score: : 0.9231
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0264
# 	Val Target Regression Loss: : 0.0289
# 	Val Source R2 Score: : 0.9178
# 	Val Target R2 Score: : 0.9106
# 	Val Source Mve Loss: : -0.0756
# 	Val Target Mve Loss: : -0.0724
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 20: 10.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0711
# 	Train Regression Loss: : 0.0244
# 	Train Mve Loss: : -0.0752
# 	Train R2 Score: : 0.9251
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0257
# 	Val Target Regression Loss: : 0.0283
# 	Val Source R2 Score: : 0.9197
# 	Val Target R2 Score: : 0.9126
# 	Val Source Mve Loss: : -0.0676
# 	Val Target Mve Loss: : -0.0647
# Saving Model... Done.
#
# Epoch 21: 10.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0709
# 	Train Regression Loss: : 0.0237
# 	Train Mve Loss: : -0.0713
# 	Train R2 Score: : 0.9271
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0257
# 	Val Target Regression Loss: : 0.0286
# 	Val Source R2 Score: : 0.9221
# 	Val Target R2 Score: : 0.9115
# 	Val Source Mve Loss: : -0.0707
# 	Val Target Mve Loss: : -0.0679
#
# Epoch 22: 10.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0699
# 	Train Regression Loss: : 0.0233
# 	Train Mve Loss: : -0.0636
# 	Train R2 Score: : 0.9285
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0246
# 	Val Target Regression Loss: : 0.0275
# 	Val Source R2 Score: : 0.9247
# 	Val Target R2 Score: : 0.9146
# 	Val Source Mve Loss: : -0.0625
# 	Val Target Mve Loss: : -0.0592
# Saving Model... Done.
#
# Epoch 23: 10.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0711
# 	Train Regression Loss: : 0.0228
# 	Train Mve Loss: : -0.0942
# 	Train R2 Score: : 0.9299
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0238
# 	Val Target Regression Loss: : 0.0272
# 	Val Source R2 Score: : 0.9281
# 	Val Target R2 Score: : 0.9144
# 	Val Source Mve Loss: : -0.1131
# 	Val Target Mve Loss: : -0.1100
#
# Epoch 24: 10.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0710
# 	Train Regression Loss: : 0.0222
# 	Train Mve Loss: : -0.0709
# 	Train R2 Score: : 0.9322
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0244
# 	Val Target Regression Loss: : 0.0293
# 	Val Source R2 Score: : 0.9241
# 	Val Target R2 Score: : 0.9109
# 	Val Source Mve Loss: : -0.0508
# 	Val Target Mve Loss: : -0.0462
#
# Epoch 25: 10.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0708
# 	Train Regression Loss: : 0.0219
# 	Train Mve Loss: : -0.0793
# 	Train R2 Score: : 0.9327
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0232
# 	Val Target Regression Loss: : 0.0265
# 	Val Source R2 Score: : 0.9294
# 	Val Target R2 Score: : 0.9178
# 	Val Source Mve Loss: : -0.0657
# 	Val Target Mve Loss: : -0.0626
# Saving Model... Done.
#
# Epoch 26: 9.66s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0699
# 	Train Regression Loss: : 0.0215
# 	Train Mve Loss: : -0.0843
# 	Train R2 Score: : 0.9339
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0229
# 	Val Target Regression Loss: : 0.0257
# 	Val Source R2 Score: : 0.9268
# 	Val Target R2 Score: : 0.9199
# 	Val Source Mve Loss: : -0.0500
# 	Val Target Mve Loss: : -0.0478
# Saving Model... Done.
#
# Epoch 27: 11.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0711
# 	Train Regression Loss: : 0.0214
# 	Train Mve Loss: : -0.0934
# 	Train R2 Score: : 0.9342
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0223
# 	Val Target Regression Loss: : 0.0243
# 	Val Source R2 Score: : 0.9322
# 	Val Target R2 Score: : 0.9250
# 	Val Source Mve Loss: : -0.0784
# 	Val Target Mve Loss: : -0.0760
# Saving Model... Done.
#
# Epoch 28: 10.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0700
# 	Train Regression Loss: : 0.0208
# 	Train Mve Loss: : -0.0685
# 	Train R2 Score: : 0.9361
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0222
# 	Val Target Regression Loss: : 0.0252
# 	Val Source R2 Score: : 0.9324
# 	Val Target R2 Score: : 0.9202
# 	Val Source Mve Loss: : -0.0474
# 	Val Target Mve Loss: : -0.0445
#
# Epoch 29: 10.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0703
# 	Train Regression Loss: : 0.0201
# 	Train Mve Loss: : -0.0504
# 	Train R2 Score: : 0.9383
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0207
# 	Val Target Regression Loss: : 0.0228
# 	Val Source R2 Score: : 0.9372
# 	Val Target R2 Score: : 0.9298
# 	Val Source Mve Loss: : -0.0493
# 	Val Target Mve Loss: : -0.0476
# Saving Model... Done.
#
# Epoch 30: 9.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0688
# 	Train Regression Loss: : 0.0197
# 	Train Mve Loss: : -0.0605
# 	Train R2 Score: : 0.9394
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0205
# 	Val Target Regression Loss: : 0.0231
# 	Val Source R2 Score: : 0.9383
# 	Val Target R2 Score: : 0.9288
# 	Val Source Mve Loss: : -0.0310
# 	Val Target Mve Loss: : -0.0292
#
# Epoch 31: 10.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0694
# 	Train Regression Loss: : 0.0192
# 	Train Mve Loss: : -0.0690
# 	Train R2 Score: : 0.9413
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0210
# 	Val Target Regression Loss: : 0.0224
# 	Val Source R2 Score: : 0.9348
# 	Val Target R2 Score: : 0.9303
# 	Val Source Mve Loss: : -0.0452
# 	Val Target Mve Loss: : -0.0437
# Saving Model... Done.
#
# Epoch 32: 10.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0705
# 	Train Regression Loss: : 0.0190
# 	Train Mve Loss: : -0.1101
# 	Train R2 Score: : 0.9420
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0198
# 	Val Target Regression Loss: : 0.0220
# 	Val Source R2 Score: : 0.9396
# 	Val Target R2 Score: : 0.9319
# 	Val Source Mve Loss: : -0.0888
# 	Val Target Mve Loss: : -0.0876
# Saving Model... Done.
#
# Epoch 33: 10.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0701
# 	Train Regression Loss: : 0.0186
# 	Train Mve Loss: : -0.0763
# 	Train R2 Score: : 0.9427
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0192
# 	Val Target Regression Loss: : 0.0214
# 	Val Source R2 Score: : 0.9418
# 	Val Target R2 Score: : 0.9340
# 	Val Source Mve Loss: : -0.0590
# 	Val Target Mve Loss: : -0.0578
# Saving Model... Done.
#
# Epoch 34: 10.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0692
# 	Train Regression Loss: : 0.0183
# 	Train Mve Loss: : -0.1041
# 	Train R2 Score: : 0.9442
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0193
# 	Val Target Regression Loss: : 0.0222
# 	Val Source R2 Score: : 0.9399
# 	Val Target R2 Score: : 0.9307
# 	Val Source Mve Loss: : -0.1992
# 	Val Target Mve Loss: : -0.1975
# Saving Model MVE... Done.
#
# Epoch 35: 10.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0692
# 	Train Regression Loss: : 0.0180
# 	Train Mve Loss: : -0.0962
# 	Train R2 Score: : 0.9449
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0190
# 	Val Target Regression Loss: : 0.0219
# 	Val Source R2 Score: : 0.9423
# 	Val Target R2 Score: : 0.9331
# 	Val Source Mve Loss: : -0.1148
# 	Val Target Mve Loss: : -0.1130
#
# Epoch 36: 10.20s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0704
# 	Train Regression Loss: : 0.0180
# 	Train Mve Loss: : -0.0699
# 	Train R2 Score: : 0.9450
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0186
# 	Val Target Regression Loss: : 0.0217
# 	Val Source R2 Score: : 0.9435
# 	Val Target R2 Score: : 0.9328
# 	Val Source Mve Loss: : -0.0463
# 	Val Target Mve Loss: : -0.0444
#
# Epoch 37: 10.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0696
# 	Train Regression Loss: : 0.0175
# 	Train Mve Loss: : -0.0665
# 	Train R2 Score: : 0.9462
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0185
# 	Val Target Regression Loss: : 0.0212
# 	Val Source R2 Score: : 0.9436
# 	Val Target R2 Score: : 0.9345
# 	Val Source Mve Loss: : -0.0470
# 	Val Target Mve Loss: : -0.0454
# Saving Model... Done.
#
# Epoch 38: 10.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0708
# 	Train Regression Loss: : 0.0173
# 	Train Mve Loss: : -0.0640
# 	Train R2 Score: : 0.9469
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0180
# 	Val Target Regression Loss: : 0.0202
# 	Val Source R2 Score: : 0.9445
# 	Val Target R2 Score: : 0.9378
# 	Val Source Mve Loss: : -0.0494
# 	Val Target Mve Loss: : -0.0470
# Saving Model... Done.
#
# Epoch 39: 9.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0708
# 	Train Regression Loss: : 0.0171
# 	Train Mve Loss: : -0.0578
# 	Train R2 Score: : 0.9475
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0182
# 	Val Target Regression Loss: : 0.0206
# 	Val Source R2 Score: : 0.9449
# 	Val Target R2 Score: : 0.9365
# 	Val Source Mve Loss: : -0.1120
# 	Val Target Mve Loss: : -0.1100
# Generating Isomap...
# Epoch 40: 10.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0690
# 	Train Regression Loss: : 0.0172
# 	Train Mve Loss: : -0.1160
# 	Train R2 Score: : 0.9472
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0187
# 	Val Target Regression Loss: : 0.0219
# 	Val Source R2 Score: : 0.9428
# 	Val Target R2 Score: : 0.9270
# 	Val Source Mve Loss: : -0.0433
# 	Val Target Mve Loss: : -0.0392
#
# Epoch 41: 10.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0690
# 	Train Regression Loss: : 0.0167
# 	Train Mve Loss: : -0.0722
# 	Train R2 Score: : 0.9491
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0173
# 	Val Target Regression Loss: : 0.0203
# 	Val Source R2 Score: : 0.9471
# 	Val Target R2 Score: : 0.9368
# 	Val Source Mve Loss: : -0.1751
# 	Val Target Mve Loss: : -0.1729
#
# Epoch 42: 11.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0694
# 	Train Regression Loss: : 0.0168
# 	Train Mve Loss: : -0.0803
# 	Train R2 Score: : 0.9484
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0176
# 	Val Target Regression Loss: : 0.0203
# 	Val Source R2 Score: : 0.9464
# 	Val Target R2 Score: : 0.9361
# 	Val Source Mve Loss: : -0.1028
# 	Val Target Mve Loss: : -0.1014
#
# Epoch 43: 11.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0691
# 	Train Regression Loss: : 0.0165
# 	Train Mve Loss: : -0.0996
# 	Train R2 Score: : 0.9492
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0183
# 	Val Target Regression Loss: : 0.0197
# 	Val Source R2 Score: : 0.9431
# 	Val Target R2 Score: : 0.9390
# 	Val Source Mve Loss: : -0.0583
# 	Val Target Mve Loss: : -0.0578
# Saving Model... Done.
#
# Epoch 44: 10.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0702
# 	Train Regression Loss: : 0.0164
# 	Train Mve Loss: : -0.1104
# 	Train R2 Score: : 0.9498
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0174
# 	Val Target Regression Loss: : 0.0204
# 	Val Source R2 Score: : 0.9464
# 	Val Target R2 Score: : 0.9370
# 	Val Source Mve Loss: : -0.1050
# 	Val Target Mve Loss: : -0.1011
#
# Epoch 45: 10.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0709
# 	Train Regression Loss: : 0.0162
# 	Train Mve Loss: : -0.1055
# 	Train R2 Score: : 0.9501
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0180
# 	Val Target Regression Loss: : 0.0193
# 	Val Source R2 Score: : 0.9462
# 	Val Target R2 Score: : 0.9402
# 	Val Source Mve Loss: : -0.2016
# 	Val Target Mve Loss: : -0.2006
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 46: 9.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0699
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.0945
# 	Train R2 Score: : 0.9506
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0172
# 	Val Target Regression Loss: : 0.0192
# 	Val Source R2 Score: : 0.9470
# 	Val Target R2 Score: : 0.9393
# 	Val Source Mve Loss: : -0.0535
# 	Val Target Mve Loss: : -0.0510
#
# Epoch 47: 10.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0689
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.1209
# 	Train R2 Score: : 0.9503
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0173
# 	Val Target Regression Loss: : 0.0195
# 	Val Source R2 Score: : 0.9476
# 	Val Target R2 Score: : 0.9397
# 	Val Source Mve Loss: : -0.1724
# 	Val Target Mve Loss: : -0.1711
#
# Epoch 48: 10.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0692
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.0877
# 	Train R2 Score: : 0.9507
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0169
# 	Val Target Regression Loss: : 0.0187
# 	Val Source R2 Score: : 0.9483
# 	Val Target R2 Score: : 0.9419
# 	Val Source Mve Loss: : -0.0497
# 	Val Target Mve Loss: : -0.0481
# Saving Model... Done.
#
# Epoch 49: 10.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0689
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.1517
# 	Train R2 Score: : 0.9506
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0169
# 	Val Target Regression Loss: : 0.0191
# 	Val Source R2 Score: : 0.9487
# 	Val Target R2 Score: : 0.9406
# 	Val Source Mve Loss: : -0.0903
# 	Val Target Mve Loss: : -0.0870
#
# Epoch 50: 10.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0695
# 	Train Regression Loss: : 0.0157
# 	Train Mve Loss: : -0.0709
# 	Train R2 Score: : 0.9520
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0170
# 	Val Target Regression Loss: : 0.0186
# 	Val Source R2 Score: : 0.9486
# 	Val Target R2 Score: : 0.9426
# 	Val Source Mve Loss: : -0.0608
# 	Val Target Mve Loss: : -0.0596
# Saving Model... Done.
#
# Epoch 51: 11.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0697
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.0624
# 	Train R2 Score: : 0.9528
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0162
# 	Val Target Regression Loss: : 0.0187
# 	Val Source R2 Score: : 0.9509
# 	Val Target R2 Score: : 0.9426
# 	Val Source Mve Loss: : -0.0473
# 	Val Target Mve Loss: : -0.0457
#
# Epoch 52: 10.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0702
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.0867
# 	Train R2 Score: : 0.9528
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0171
# 	Val Target Regression Loss: : 0.0196
# 	Val Source R2 Score: : 0.9471
# 	Val Target R2 Score: : 0.9363
# 	Val Source Mve Loss: : -0.0705
# 	Val Target Mve Loss: : -0.0690
#
# Epoch 53: 10.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0706
# 	Train Regression Loss: : 0.0151
# 	Train Mve Loss: : -0.0806
# 	Train R2 Score: : 0.9540
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0161
# 	Val Target Regression Loss: : 0.0181
# 	Val Source R2 Score: : 0.9503
# 	Val Target R2 Score: : 0.9442
# 	Val Source Mve Loss: : -0.0644
# 	Val Target Mve Loss: : -0.0631
# Saving Model... Done.
#
# Epoch 54: 10.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0705
# 	Train Regression Loss: : 0.0153
# 	Train Mve Loss: : -0.1492
# 	Train R2 Score: : 0.9529
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0163
# 	Val Target Regression Loss: : 0.0188
# 	Val Source R2 Score: : 0.9506
# 	Val Target R2 Score: : 0.9419
# 	Val Source Mve Loss: : -0.1105
# 	Val Target Mve Loss: : -0.1078
#
# Epoch 55: 10.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0707
# 	Train Regression Loss: : 0.0153
# 	Train Mve Loss: : -0.0961
# 	Train R2 Score: : 0.9533
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0168
# 	Val Target Regression Loss: : 0.0183
# 	Val Source R2 Score: : 0.9487
# 	Val Target R2 Score: : 0.9433
# 	Val Source Mve Loss: : -0.0815
# 	Val Target Mve Loss: : -0.0796
#
# Epoch 56: 10.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0709
# 	Train Regression Loss: : 0.0153
# 	Train Mve Loss: : -0.0880
# 	Train R2 Score: : 0.9532
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0161
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9509
# 	Val Target R2 Score: : 0.9465
# 	Val Source Mve Loss: : -0.0648
# 	Val Target Mve Loss: : -0.0641
# Saving Model... Done.
#
# Epoch 57: 10.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0701
# 	Train Regression Loss: : 0.0150
# 	Train Mve Loss: : -0.0919
# 	Train R2 Score: : 0.9541
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0158
# 	Val Target Regression Loss: : 0.0181
# 	Val Source R2 Score: : 0.9520
# 	Val Target R2 Score: : 0.9440
# 	Val Source Mve Loss: : -0.0656
# 	Val Target Mve Loss: : -0.0637
#
# Epoch 58: 11.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0710
# 	Train Regression Loss: : 0.0148
# 	Train Mve Loss: : -0.0687
# 	Train R2 Score: : 0.9546
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0151
# 	Val Target Regression Loss: : 0.0178
# 	Val Source R2 Score: : 0.9545
# 	Val Target R2 Score: : 0.9453
# 	Val Source Mve Loss: : -0.0335
# 	Val Target Mve Loss: : -0.0316
#
# Epoch 59: 9.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0712
# 	Train Regression Loss: : 0.0147
# 	Train Mve Loss: : -0.1353
# 	Train R2 Score: : 0.9549
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0164
# 	Val Target Regression Loss: : 0.0181
# 	Val Source R2 Score: : 0.9494
# 	Val Target R2 Score: : 0.9440
# 	Val Source Mve Loss: : -0.2256
# 	Val Target Mve Loss: : -0.2245
# Generating Isomap...
# Saving Model MVE... Done.
#
# Epoch 60: 12.06s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0708
# 	Train Regression Loss: : 0.0147
# 	Train Mve Loss: : -0.0992
# 	Train R2 Score: : 0.9551
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0152
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9538
# 	Val Target R2 Score: : 0.9473
# 	Val Source Mve Loss: : -0.0696
# 	Val Target Mve Loss: : -0.0675
# Saving Model... Done.
#
# Epoch 61: 11.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0719
# 	Train Regression Loss: : 0.0145
# 	Train Mve Loss: : -0.1081
# 	Train R2 Score: : 0.9553
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0160
# 	Val Target Regression Loss: : 0.0188
# 	Val Source R2 Score: : 0.9514
# 	Val Target R2 Score: : 0.9413
# 	Val Source Mve Loss: : -0.2305
# 	Val Target Mve Loss: : -0.2285
# Saving Model MVE... Done.
#
# Epoch 62: 10.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0711
# 	Train Regression Loss: : 0.0150
# 	Train Mve Loss: : -0.1601
# 	Train R2 Score: : 0.9541
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0162
# 	Val Target Regression Loss: : 0.0175
# 	Val Source R2 Score: : 0.9508
# 	Val Target R2 Score: : 0.9452
# 	Val Source Mve Loss: : -0.0824
# 	Val Target Mve Loss: : -0.0802
#
# Epoch 63: 10.73s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0706
# 	Train Regression Loss: : 0.0145
# 	Train Mve Loss: : -0.0772
# 	Train R2 Score: : 0.9553
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0154
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9524
# 	Val Target R2 Score: : 0.9468
# 	Val Source Mve Loss: : -0.0762
# 	Val Target Mve Loss: : -0.0731
#
# Epoch 64: 10.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0706
# 	Train Regression Loss: : 0.0141
# 	Train Mve Loss: : -0.0725
# 	Train R2 Score: : 0.9568
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0154
# 	Val Target Regression Loss: : 0.0180
# 	Val Source R2 Score: : 0.9532
# 	Val Target R2 Score: : 0.9438
# 	Val Source Mve Loss: : -0.0755
# 	Val Target Mve Loss: : -0.0718
#
# Epoch 65: 11.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0708
# 	Train Regression Loss: : 0.0140
# 	Train Mve Loss: : -0.0703
# 	Train R2 Score: : 0.9571
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0150
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9542
# 	Val Target R2 Score: : 0.9419
# 	Val Source Mve Loss: : -0.0550
# 	Val Target Mve Loss: : -0.0509
#
# Epoch 66: 11.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0715
# 	Train Regression Loss: : 0.0142
# 	Train Mve Loss: : -0.0774
# 	Train R2 Score: : 0.9563
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0148
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9551
# 	Val Target R2 Score: : 0.9449
# 	Val Source Mve Loss: : -0.0614
# 	Val Target Mve Loss: : -0.0580
#
# Epoch 67: 10.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0720
# 	Train Regression Loss: : 0.0140
# 	Train Mve Loss: : -0.0801
# 	Train R2 Score: : 0.9568
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0144
# 	Val Target Regression Loss: : 0.0158
# 	Val Source R2 Score: : 0.9557
# 	Val Target R2 Score: : 0.9509
# 	Val Source Mve Loss: : -0.0604
# 	Val Target Mve Loss: : -0.0581
# Saving Model... Done.
#
# Epoch 68: 10.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0712
# 	Train Regression Loss: : 0.0139
# 	Train Mve Loss: : -0.1479
# 	Train R2 Score: : 0.9573
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0148
# 	Val Target Regression Loss: : 0.0185
# 	Val Source R2 Score: : 0.9546
# 	Val Target R2 Score: : 0.9033
# 	Val Source Mve Loss: : -0.1365
# 	Val Target Mve Loss: : -0.1328
#
# Epoch 69: 10.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0712
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.0915
# 	Train R2 Score: : 0.9581
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0141
# 	Val Target Regression Loss: : 0.0164
# 	Val Source R2 Score: : 0.9572
# 	Val Target R2 Score: : 0.9490
# 	Val Source Mve Loss: : -0.0696
# 	Val Target Mve Loss: : -0.0654
#
# Epoch 70: 11.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0718
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.1544
# 	Train R2 Score: : 0.9576
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0148
# 	Val Target Regression Loss: : 0.0167
# 	Val Source R2 Score: : 0.9552
# 	Val Target R2 Score: : 0.9476
# 	Val Source Mve Loss: : -0.2331
# 	Val Target Mve Loss: : -0.2313
# Saving Model MVE... Done.
#
# Epoch 71: 11.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0728
# 	Train Regression Loss: : 0.0142
# 	Train Mve Loss: : -0.1678
# 	Train R2 Score: : 0.9566
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0153
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9519
# 	Val Target R2 Score: : 0.9431
# 	Val Source Mve Loss: : -0.0942
# 	Val Target Mve Loss: : -0.0890
#
# Epoch 72: 12.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0725
# 	Train Regression Loss: : 0.0139
# 	Train Mve Loss: : -0.1171
# 	Train R2 Score: : 0.9575
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0149
# 	Val Target Regression Loss: : 0.0167
# 	Val Source R2 Score: : 0.9544
# 	Val Target R2 Score: : 0.9480
# 	Val Source Mve Loss: : -0.1035
# 	Val Target Mve Loss: : -0.1007
#
# Epoch 73: 11.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0723
# 	Train Regression Loss: : 0.0139
# 	Train Mve Loss: : -0.0974
# 	Train R2 Score: : 0.9574
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0154
# 	Val Target Regression Loss: : 0.0170
# 	Val Source R2 Score: : 0.9526
# 	Val Target R2 Score: : 0.9448
# 	Val Source Mve Loss: : -0.0687
# 	Val Target Mve Loss: : -0.0630
#
# Epoch 74: 12.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0725
# 	Train Regression Loss: : 0.0135
# 	Train Mve Loss: : -0.1541
# 	Train R2 Score: : 0.9585
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0145
# 	Val Target Regression Loss: : 0.0165
# 	Val Source R2 Score: : 0.9554
# 	Val Target R2 Score: : 0.9486
# 	Val Source Mve Loss: : -0.2039
# 	Val Target Mve Loss: : -0.2019
#
# Epoch 75: 12.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0720
# 	Train Regression Loss: : 0.0136
# 	Train Mve Loss: : -0.0929
# 	Train R2 Score: : 0.9582
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0142
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9564
# 	Val Target R2 Score: : 0.9422
# 	Val Source Mve Loss: : -0.0722
# 	Val Target Mve Loss: : -0.0661
#
# Epoch 76: 14.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0713
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.2143
# 	Train R2 Score: : 0.9577
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0152
# 	Val Target Regression Loss: : 0.0181
# 	Val Source R2 Score: : 0.9232
# 	Val Target R2 Score: : 0.9436
# 	Val Source Mve Loss: : -0.2523
# 	Val Target Mve Loss: : -0.2501
# Saving Model MVE... Done.
#
# Epoch 77: 12.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0722
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.2396
# 	Train R2 Score: : 0.9576
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0151
# 	Val Target Regression Loss: : 0.0176
# 	Val Source R2 Score: : 0.9540
# 	Val Target R2 Score: : 0.9457
# 	Val Source Mve Loss: : -0.1849
# 	Val Target Mve Loss: : -0.1835
#
# Epoch 78: 12.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0720
# 	Train Regression Loss: : 0.0144
# 	Train Mve Loss: : -0.1398
# 	Train R2 Score: : 0.9560
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0153
# 	Val Target Regression Loss: : 0.0178
# 	Val Source R2 Score: : 0.9474
# 	Val Target R2 Score: : 0.9429
# 	Val Source Mve Loss: : -0.1055
# 	Val Target Mve Loss: : -0.1022
#
# Epoch 79: 10.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0719
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.1031
# 	Train R2 Score: : 0.9580
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0161
# 	Val Target Regression Loss: : 0.0187
# 	Val Source R2 Score: : 0.9502
# 	Val Target R2 Score: : 0.9422
# 	Val Source Mve Loss: : -0.0794
# 	Val Target Mve Loss: : -0.0742
# Generating Isomap...
# Epoch 80: 12.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0718
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.1116
# 	Train R2 Score: : 0.9589
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0144
# 	Val Target Regression Loss: : 0.0166
# 	Val Source R2 Score: : 0.9561
# 	Val Target R2 Score: : 0.9486
# 	Val Source Mve Loss: : -0.0927
# 	Val Target Mve Loss: : -0.0883
#
# Epoch 81: 10.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0718
# 	Train Regression Loss: : 0.0132
# 	Train Mve Loss: : -0.0979
# 	Train R2 Score: : 0.9595
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0141
# 	Val Target Regression Loss: : 0.0164
# 	Val Source R2 Score: : 0.9565
# 	Val Target R2 Score: : 0.9494
# 	Val Source Mve Loss: : -0.0914
# 	Val Target Mve Loss: : -0.0883
#
# Epoch 82: 10.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0724
# 	Train Regression Loss: : 0.0132
# 	Train Mve Loss: : -0.1937
# 	Train R2 Score: : 0.9594
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0159
# 	Val Source R2 Score: : 0.9589
# 	Val Target R2 Score: : 0.9507
# 	Val Source Mve Loss: : -0.2512
# 	Val Target Mve Loss: : -0.2494
#
# Epoch 83: 11.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0723
# 	Train Regression Loss: : 0.0136
# 	Train Mve Loss: : -0.2427
# 	Train R2 Score: : 0.9583
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0142
# 	Val Target Regression Loss: : 0.0165
# 	Val Source R2 Score: : 0.9548
# 	Val Target R2 Score: : 0.9480
# 	Val Source Mve Loss: : -0.2555
# 	Val Target Mve Loss: : -0.2534
# Saving Model MVE... Done.
#
# Epoch 84: 11.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0732
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.1796
# 	Train R2 Score: : 0.9580
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0165
# 	Val Source R2 Score: : 0.9564
# 	Val Target R2 Score: : 0.9481
# 	Val Source Mve Loss: : -0.1079
# 	Val Target Mve Loss: : -0.1041
#
# Epoch 85: 10.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0730
# 	Train Regression Loss: : 0.0132
# 	Train Mve Loss: : -0.1036
# 	Train R2 Score: : 0.9597
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0142
# 	Val Target Regression Loss: : 0.0162
# 	Val Source R2 Score: : 0.9567
# 	Val Target R2 Score: : 0.9490
# 	Val Source Mve Loss: : -0.0871
# 	Val Target Mve Loss: : -0.0850
#
# Epoch 86: 11.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0726
# 	Train Regression Loss: : 0.0131
# 	Train Mve Loss: : -0.1134
# 	Train R2 Score: : 0.9599
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0134
# 	Val Target Regression Loss: : 0.0156
# 	Val Source R2 Score: : 0.9594
# 	Val Target R2 Score: : 0.9515
# 	Val Source Mve Loss: : -0.0913
# 	Val Target Mve Loss: : -0.0882
# Saving Model... Done.
#
# Epoch 87: 10.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0741
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.0988
# 	Train R2 Score: : 0.9614
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0139
# 	Val Target Regression Loss: : 0.0162
# 	Val Source R2 Score: : 0.9578
# 	Val Target R2 Score: : 0.9496
# 	Val Source Mve Loss: : -0.0876
# 	Val Target Mve Loss: : -0.0833
#
# Epoch 88: 11.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0736
# 	Train Regression Loss: : 0.0127
# 	Train Mve Loss: : -0.1653
# 	Train R2 Score: : 0.9611
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0150
# 	Val Source R2 Score: : 0.9590
# 	Val Target R2 Score: : 0.9535
# 	Val Source Mve Loss: : -0.1710
# 	Val Target Mve Loss: : -0.1695
# Saving Model... Done.
#
# Epoch 89: 11.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0745
# 	Train Regression Loss: : 0.0128
# 	Train Mve Loss: : -0.1217
# 	Train R2 Score: : 0.9607
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0133
# 	Val Target Regression Loss: : 0.0155
# 	Val Source R2 Score: : 0.9598
# 	Val Target R2 Score: : 0.9520
# 	Val Source Mve Loss: : -0.0884
# 	Val Target Mve Loss: : -0.0827
#
# Epoch 90: 10.84s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0733
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.1592
# 	Train R2 Score: : 0.9613
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0135
# 	Val Target Regression Loss: : 0.0151
# 	Val Source R2 Score: : 0.9586
# 	Val Target R2 Score: : 0.9524
# 	Val Source Mve Loss: : -0.1153
# 	Val Target Mve Loss: : -0.1117
#
# Epoch 91: 10.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0743
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.1754
# 	Train R2 Score: : 0.9614
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0139
# 	Val Target Regression Loss: : 0.0161
# 	Val Source R2 Score: : 0.9577
# 	Val Target R2 Score: : 0.9487
# 	Val Source Mve Loss: : -0.1799
# 	Val Target Mve Loss: : -0.1763
#
# Epoch 92: 11.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0741
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.1091
# 	Train R2 Score: : 0.9622
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0134
# 	Val Target Regression Loss: : 0.0156
# 	Val Source R2 Score: : 0.9592
# 	Val Target R2 Score: : 0.9513
# 	Val Source Mve Loss: : -0.0980
# 	Val Target Mve Loss: : -0.0933
#
# Epoch 93: 9.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0745
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.1058
# 	Train R2 Score: : 0.9631
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0128
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9610
# 	Val Target R2 Score: : 0.9555
# 	Val Source Mve Loss: : -0.0847
# 	Val Target Mve Loss: : -0.0768
# Saving Model... Done.
#
# Epoch 94: 10.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0744
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1240
# 	Train R2 Score: : 0.9631
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0131
# 	Val Target Regression Loss: : 0.0153
# 	Val Source R2 Score: : 0.9604
# 	Val Target R2 Score: : 0.9527
# 	Val Source Mve Loss: : -0.0914
# 	Val Target Mve Loss: : -0.0860
#
# Epoch 95: 9.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0737
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.2401
# 	Train R2 Score: : 0.9622
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0127
# 	Val Target Regression Loss: : 0.0156
# 	Val Source R2 Score: : 0.9608
# 	Val Target R2 Score: : 0.9517
# 	Val Source Mve Loss: : -0.2055
# 	Val Target Mve Loss: : -0.2011
#
# Epoch 96: 10.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0745
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.1325
# 	Train R2 Score: : 0.9625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0129
# 	Val Target Regression Loss: : 0.0155
# 	Val Source R2 Score: : 0.9604
# 	Val Target R2 Score: : 0.9520
# 	Val Source Mve Loss: : -0.0966
# 	Val Target Mve Loss: : -0.0900
#
# Epoch 97: 11.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0747
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.1074
# 	Train R2 Score: : 0.9635
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0153
# 	Val Source R2 Score: : 0.9616
# 	Val Target R2 Score: : 0.9525
# 	Val Source Mve Loss: : -0.1017
# 	Val Target Mve Loss: : -0.0942
#
# Epoch 98: 10.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0751
# 	Train Regression Loss: : 0.0118
# 	Train Mve Loss: : -0.1320
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0149
# 	Val Source R2 Score: : 0.9624
# 	Val Target R2 Score: : 0.9540
# 	Val Source Mve Loss: : -0.0875
# 	Val Target Mve Loss: : -0.0777
#
# Epoch 99: 10.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0751
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1454
# 	Train R2 Score: : 0.9631
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0146
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9548
# 	Val Source Mve Loss: : -0.0982
# 	Val Target Mve Loss: : -0.0900
# Generating Isomap...
# Epoch 100: 10.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0751
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.1163
# 	Train R2 Score: : 0.9644
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0147
# 	Val Source R2 Score: : 0.9627
# 	Val Target R2 Score: : 0.9526
# 	Val Source Mve Loss: : -0.2198
# 	Val Target Mve Loss: : -0.2160
#
# Epoch 101: 10.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0761
# 	Train Regression Loss: : 0.0118
# 	Train Mve Loss: : -0.1236
# 	Train R2 Score: : 0.9638
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0152
# 	Val Source R2 Score: : 0.9625
# 	Val Target R2 Score: : 0.9528
# 	Val Source Mve Loss: : -0.1087
# 	Val Target Mve Loss: : -0.0993
#
# Epoch 102: 10.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0777
# 	Train Regression Loss: : 0.0117
# 	Train Mve Loss: : -0.1280
# 	Train R2 Score: : 0.9641
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0128
# 	Val Target Regression Loss: : 0.0145
# 	Val Source R2 Score: : 0.9609
# 	Val Target R2 Score: : 0.9551
# 	Val Source Mve Loss: : -0.1118
# 	Val Target Mve Loss: : -0.1064
#
# Epoch 103: 10.91s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0764
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.1246
# 	Train R2 Score: : 0.9645
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0141
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9569
# 	Val Target R2 Score: : 0.9465
# 	Val Source Mve Loss: : -0.1222
# 	Val Target Mve Loss: : -0.1137
#
# Epoch 104: 10.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0779
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.2349
# 	Train R2 Score: : 0.9634
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0154
# 	Val Target Regression Loss: : 0.0189
# 	Val Source R2 Score: : 0.9527
# 	Val Target R2 Score: : 0.9411
# 	Val Source Mve Loss: : -0.2975
# 	Val Target Mve Loss: : -0.2942
# Saving Model MVE... Done.
#
# Epoch 105: 11.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0776
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2843
# 	Train R2 Score: : 0.9627
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0144
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9560
# 	Val Target R2 Score: : 0.9444
# 	Val Source Mve Loss: : -0.1146
# 	Val Target Mve Loss: : -0.1057
#
# Epoch 106: 10.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0771
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.1401
# 	Train R2 Score: : 0.9624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0149
# 	Val Source R2 Score: : 0.9621
# 	Val Target R2 Score: : 0.9540
# 	Val Source Mve Loss: : -0.1175
# 	Val Target Mve Loss: : -0.1098
#
# Epoch 107: 11.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0788
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.1322
# 	Train R2 Score: : 0.9652
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0143
# 	Val Source R2 Score: : 0.9625
# 	Val Target R2 Score: : 0.9561
# 	Val Source Mve Loss: : -0.1202
# 	Val Target Mve Loss: : -0.1132
# Saving Model... Done.
#
# Epoch 108: 10.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0789
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.1397
# 	Train R2 Score: : 0.9649
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0146
# 	Val Source R2 Score: : 0.9637
# 	Val Target R2 Score: : 0.9548
# 	Val Source Mve Loss: : -0.1328
# 	Val Target Mve Loss: : -0.1245
#
# Epoch 109: 10.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0789
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.1446
# 	Train R2 Score: : 0.9655
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0149
# 	Val Target Regression Loss: : 0.0186
# 	Val Source R2 Score: : 0.9548
# 	Val Target R2 Score: : 0.9415
# 	Val Source Mve Loss: : -0.1224
# 	Val Target Mve Loss: : -0.1095
#
# Epoch 110: 9.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0793
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.1364
# 	Train R2 Score: : 0.9654
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0143
# 	Val Source R2 Score: : 0.9634
# 	Val Target R2 Score: : 0.9545
# 	Val Source Mve Loss: : -0.1401
# 	Val Target Mve Loss: : -0.1328
#
# Epoch 111: 9.85s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0787
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.1372
# 	Train R2 Score: : 0.9650
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0154
# 	Val Source R2 Score: : 0.9610
# 	Val Target R2 Score: : 0.9524
# 	Val Source Mve Loss: : -0.1338
# 	Val Target Mve Loss: : -0.1241
#
# Epoch 112: 10.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0791
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.2202
# 	Train R2 Score: : 0.9631
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0127
# 	Val Target Regression Loss: : 0.0147
# 	Val Source R2 Score: : 0.9611
# 	Val Target R2 Score: : 0.9548
# 	Val Source Mve Loss: : -0.3191
# 	Val Target Mve Loss: : -0.3170
# Saving Model MVE... Done.
#
# Epoch 113: 10.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0796
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2445
# 	Train R2 Score: : 0.9627
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0150
# ...
# Saving Model... Done.
#
# Epoch 125: 11.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0852
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.2182
# 	Train R2 Score: : 0.9652
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9653
# 	Val Target R2 Score: : 0.9577
# 	Val Source Mve Loss: : -0.1674
# 	Val Target Mve Loss: : -0.1580
#
# Epoch 126: 10.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0847
# 	Train Regression Loss: : 0.0111
# 	Train Mve Loss: : -0.1779
# 	Train R2 Score: : 0.9659
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0152
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9525
# 	Val Source Mve Loss: : -0.1803
# 	Val Target Mve Loss: : -0.1686
#
# Epoch 127: 11.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0846
# 	Train Regression Loss: : 0.0111
# 	Train Mve Loss: : -0.1851
# 	Train R2 Score: : 0.9660
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9639
# 	Val Target R2 Score: : 0.9576
# 	Val Source Mve Loss: : -0.1804
# 	Val Target Mve Loss: : -0.1723
#
# Epoch 128: 10.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0847
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.1983
# 	Train R2 Score: : 0.9649
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0142
# 	Val Source R2 Score: : 0.9635
# 	Val Target R2 Score: : 0.9561
# 	Val Source Mve Loss: : -0.1908
# 	Val Target Mve Loss: : -0.1799
#
# Epoch 129: 11.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0848
# 	Train Regression Loss: : 0.0109
# 	Train Mve Loss: : -0.2076
# 	Train R2 Score: : 0.9667
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0111
# 	Val Target Regression Loss: : 0.0135
# 	Val Source R2 Score: : 0.9659
# 	Val Target R2 Score: : 0.9577
# 	Val Source Mve Loss: : -0.1531
# 	Val Target Mve Loss: : -0.1578
#
# Epoch 130: 10.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0856
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.2769
# 	Train R2 Score: : 0.9620
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0138
# 	Val Target Regression Loss: : 0.0164
# 	Val Source R2 Score: : 0.9577
# 	Val Target R2 Score: : 0.9491
# 	Val Source Mve Loss: : -0.3552
# 	Val Target Mve Loss: : -0.3522
# Saving Model MVE... Done.
#
# Epoch 131: 10.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0850
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.3629
# 	Train R2 Score: : 0.9634
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0147
# 	Val Source R2 Score: : 0.9622
# 	Val Target R2 Score: : 0.9536
# 	Val Source Mve Loss: : -0.3656
# 	Val Target Mve Loss: : -0.3625
# Saving Model MVE... Done.
#
# Epoch 132: 10.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0837
# 	Train Regression Loss: : 0.0115
# 	Train Mve Loss: : -0.3715
# 	Train R2 Score: : 0.9649
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9635
# 	Val Target R2 Score: : 0.9547
# 	Val Source Mve Loss: : -0.3720
# 	Val Target Mve Loss: : -0.3684
# Saving Model MVE... Done.
#
# Epoch 133: 10.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0848
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.3720
# 	Train R2 Score: : 0.9655
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0118
# 	Val Target Regression Loss: : 0.0141
# 	Val Source R2 Score: : 0.9640
# 	Val Target R2 Score: : 0.9567
# 	Val Source Mve Loss: : -0.3596
# 	Val Target Mve Loss: : -0.3551
#
# Epoch 134: 10.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0844
# 	Train Regression Loss: : 0.0112
# 	Train Mve Loss: : -0.2841
# 	Train R2 Score: : 0.9656
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0114
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9650
# 	Val Target R2 Score: : 0.9558
# 	Val Source Mve Loss: : -0.1961
# 	Val Target Mve Loss: : -0.1814
#
# Epoch 135: 11.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0851
# 	Train Regression Loss: : 0.0107
# 	Train Mve Loss: : -0.2068
# 	Train R2 Score: : 0.9672
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0112
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9659
# 	Val Target R2 Score: : 0.9582
# 	Val Source Mve Loss: : -0.1996
# 	Val Target Mve Loss: : -0.1862
# Saving Model... Done.
#
# Epoch 136: 10.45s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0856
# 	Train Regression Loss: : 0.0106
# 	Train Mve Loss: : -0.2087
# 	Train R2 Score: : 0.9675
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0109
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9660
# 	Val Target R2 Score: : 0.9582
# 	Val Source Mve Loss: : -0.2076
# 	Val Target Mve Loss: : -0.1875
#
# Epoch 137: 10.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0842
# 	Train Regression Loss: : 0.0105
# 	Train Mve Loss: : -0.2148
# 	Train R2 Score: : 0.9679
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0113
# 	Val Target Regression Loss: : 0.0129
# 	Val Source R2 Score: : 0.9659
# 	Val Target R2 Score: : 0.9604
# 	Val Source Mve Loss: : -0.2075
# 	Val Target Mve Loss: : -0.1968
# Saving Model... Done.
#
# Epoch 138: 9.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0848
# 	Train Regression Loss: : 0.0103
# 	Train Mve Loss: : -0.2167
# 	Train R2 Score: : 0.9685
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0110
# 	Val Target Regression Loss: : 0.0132
# 	Val Source R2 Score: : 0.9667
# 	Val Target R2 Score: : 0.9590
# 	Val Source Mve Loss: : -0.2146
# 	Val Target Mve Loss: : -0.1964
#
# Epoch 139: 9.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0849
# 	Train Regression Loss: : 0.0102
# 	Train Mve Loss: : -0.2226
# 	Train R2 Score: : 0.9687
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0107
# 	Val Target Regression Loss: : 0.0129
# 	Val Source R2 Score: : 0.9669
# 	Val Target R2 Score: : 0.9604
# 	Val Source Mve Loss: : -0.2079
# 	Val Target Mve Loss: : -0.1825
# Generating Isomap...
# Epoch 140: 10.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0849
# 	Train Regression Loss: : 0.0101
# 	Train Mve Loss: : -0.2525
# 	Train R2 Score: : 0.9691
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0110
# 	Val Target Regression Loss: : 0.0131
# 	Val Source R2 Score: : 0.9665
# 	Val Target R2 Score: : 0.9590
# 	Val Source Mve Loss: : -0.3991
# 	Val Target Mve Loss: : -0.3956
# Saving Model MVE... Done.
#
# Epoch 141: 11.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0848
# 	Train Regression Loss: : 0.0102
# 	Train Mve Loss: : -0.2692
# 	Train R2 Score: : 0.9687
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0106
# 	Val Target Regression Loss: : 0.0131
# 	Val Source R2 Score: : 0.9680
# 	Val Target R2 Score: : 0.9594
# 	Val Source Mve Loss: : -0.2186
# 	Val Target Mve Loss: : -0.1977
#
# Epoch 142: 11.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0851
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.2911
# 	Train R2 Score: : 0.9635
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0144
# 	Val Target Regression Loss: : 0.0167
# 	Val Source R2 Score: : 0.9559
# 	Val Target R2 Score: : 0.9485
# 	Val Source Mve Loss: : -0.3849
# 	Val Target Mve Loss: : -0.3821
#
# Epoch 143: 10.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0855
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.3924
# 	Train R2 Score: : 0.9626
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0143
# 	Val Source R2 Score: : 0.9619
# 	Val Target R2 Score: : 0.9559
# 	Val Source Mve Loss: : -0.3945
# 	Val Target Mve Loss: : -0.3919
#
# Epoch 144: 11.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0860
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.4010
# 	Train R2 Score: : 0.9654
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9618
# 	Val Target R2 Score: : 0.9583
# 	Val Source Mve Loss: : -0.4026
# 	Val Target Mve Loss: : -0.4004
# Saving Model MVE... Done.
#
# Epoch 145: 11.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0835
# 	Train Regression Loss: : 0.0108
# 	Train Mve Loss: : -0.4101
# 	Train R2 Score: : 0.9672
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0140
# 	Val Source R2 Score: : 0.9649
# 	Val Target R2 Score: : 0.9561
# 	Val Source Mve Loss: : -0.4116
# 	Val Target Mve Loss: : -0.4080
# Saving Model MVE... Done.
#
# Epoch 146: 11.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0852
# 	Train Regression Loss: : 0.0108
# 	Train Mve Loss: : -0.4187
# 	Train R2 Score: : 0.9671
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0135
# 	Val Source R2 Score: : 0.9636
# 	Val Target R2 Score: : 0.9581
# 	Val Source Mve Loss: : -0.4188
# 	Val Target Mve Loss: : -0.4160
# Saving Model MVE... Done.
#
# Epoch 147: 11.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0849
# 	Train Regression Loss: : 0.0111
# 	Train Mve Loss: : -0.4235
# 	Train R2 Score: : 0.9659
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0151
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9528
# 	Val Source Mve Loss: : -0.4170
# 	Val Target Mve Loss: : -0.4109
#
# Epoch 148: 11.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0853
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.3891
# 	Train R2 Score: : 0.9646
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0155
# 	Val Source R2 Score: : 0.9622
# 	Val Target R2 Score: : 0.9219
# 	Val Source Mve Loss: : -0.3086
# 	Val Target Mve Loss: : -0.2886
#
# Epoch 149: 11.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0858
# 	Train Regression Loss: : 0.0108
# 	Train Mve Loss: : -0.2938
# 	Train R2 Score: : 0.9669
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0109
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9668
# 	Val Target R2 Score: : 0.9587
# 	Val Source Mve Loss: : -0.2797
# 	Val Target Mve Loss: : -0.2598
#
# Epoch 150: 10.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0861
# 	Train Regression Loss: : 0.0103
# 	Train Mve Loss: : -0.2757
# 	Train R2 Score: : 0.9685
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0103
# 	Val Target Regression Loss: : 0.0126
# 	Val Source R2 Score: : 0.9685
# 	Val Target R2 Score: : 0.9604
# 	Val Source Mve Loss: : -0.2748
# 	Val Target Mve Loss: : -0.2554
#
# Epoch 151: 10.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0858
# 	Train Regression Loss: : 0.0107
# 	Train Mve Loss: : -0.2793
# 	Train R2 Score: : 0.9673
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0112
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9634
# 	Val Target R2 Score: : 0.9589
# 	Val Source Mve Loss: : -0.2593
# 	Val Target Mve Loss: : -0.2030
#
# Epoch 152: 10.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0859
# 	Train Regression Loss: : 0.0098
# 	Train Mve Loss: : -0.3129
# 	Train R2 Score: : 0.9700
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0101
# 	Val Target Regression Loss: : 0.0125
# 	Val Source R2 Score: : 0.9692
# 	Val Target R2 Score: : 0.9616
# 	Val Source Mve Loss: : -0.3940
# 	Val Target Mve Loss: : -0.3835
# Saving Model... Done.
#
# Epoch 153: 11.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0866
# 	Train Regression Loss: : 0.0101
# 	Train Mve Loss: : -0.3171
# 	Train R2 Score: : 0.9691
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0107
# 	Val Target Regression Loss: : 0.0124
# 	Val Source R2 Score: : 0.9678
# 	Val Target R2 Score: : 0.9615
# 	Val Source Mve Loss: : -0.2771
# 	Val Target Mve Loss: : -0.2585
#
# Epoch 154: 11.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0860
# 	Train Regression Loss: : 0.0097
# 	Train Mve Loss: : -0.2952
# 	Train R2 Score: : 0.9703
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0104
# 	Val Target Regression Loss: : 0.0125
# 	Val Source R2 Score: : 0.9683
# 	Val Target R2 Score: : 0.9617
# 	Val Source Mve Loss: : -0.2869
# 	Val Target Mve Loss: : -0.2678
# Saving Model... Done.
#
# Epoch 155: 11.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0851
# 	Train Regression Loss: : 0.0098
# 	Train Mve Loss: : -0.3834
# 	Train R2 Score: : 0.9700
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0105
# 	Val Target Regression Loss: : 0.0130
# 	Val Source R2 Score: : 0.9678
# 	Val Target R2 Score: : 0.9597
# 	Val Source Mve Loss: : -0.4593
# 	Val Target Mve Loss: : -0.4536
# Saving Model MVE... Done.
#
# Epoch 156: 10.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0858
# 	Train Regression Loss: : 0.0097
# 	Train Mve Loss: : -0.3474
# 	Train R2 Score: : 0.9704
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0102
# 	Val Target Regression Loss: : 0.0125
# 	Val Source R2 Score: : 0.9689
# 	Val Target R2 Score: : 0.9612
# 	Val Source Mve Loss: : -0.2877
# 	Val Target Mve Loss: : -0.2667
#
# Epoch 157: 11.11s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0854
# 	Train Regression Loss: : 0.0095
# 	Train Mve Loss: : -0.3531
# 	Train R2 Score: : 0.9709
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0110
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9667
# 	Val Target R2 Score: : 0.9576
# 	Val Source Mve Loss: : -0.2970
# 	Val Target Mve Loss: : -0.2704
#
# Epoch 158: 9.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0853
# 	Train Regression Loss: : 0.0110
# 	Train Mve Loss: : -0.3240
# 	Train R2 Score: : 0.9664
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0099
# 	Val Target Regression Loss: : 0.0119
# 	Val Source R2 Score: : 0.9698
# 	Val Target R2 Score: : 0.9633
# 	Val Source Mve Loss: : -0.3030
# 	Val Target Mve Loss: : -0.2823
# Saving Model... Done.
#
# Epoch 159: 12.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0861
# 	Train Regression Loss: : 0.0103
# 	Train Mve Loss: : -0.3262
# 	Train R2 Score: : 0.9684
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0103
# 	Val Target Regression Loss: : 0.0121
# 	Val Source R2 Score: : 0.9674
# 	Val Target R2 Score: : 0.9623
# 	Val Source Mve Loss: : -0.2885
# 	Val Target Mve Loss: : -0.2650
# Generating Isomap...
# Epoch 160: 14.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0855
# 	Train Regression Loss: : 0.0105
# 	Train Mve Loss: : -0.3452
# 	Train R2 Score: : 0.9678
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0101
# 	Val Target Regression Loss: : 0.0124
# 	Val Source R2 Score: : 0.9689
# 	Val Target R2 Score: : 0.9611
# 	Val Source Mve Loss: : -0.3442
# 	Val Target Mve Loss: : -0.3237
#
# Epoch 161: 11.51s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0843
# 	Train Regression Loss: : 0.0096
# 	Train Mve Loss: : -0.4666
# 	Train R2 Score: : 0.9709
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0102
# 	Val Target Regression Loss: : 0.0124
# 	Val Source R2 Score: : 0.9688
# 	Val Target R2 Score: : 0.9613
# 	Val Source Mve Loss: : -0.4861
# 	Val Target Mve Loss: : -0.4813
# Saving Model MVE... Done.
#
# Epoch 162: 11.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0859
# 	Train Regression Loss: : 0.0095
# 	Train Mve Loss: : -0.4322
# 	Train R2 Score: : 0.9707
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9633
# 	Val Target R2 Score: : 0.9556
# 	Val Source Mve Loss: : -0.3234
# 	Val Target Mve Loss: : -0.2961

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = final_mod_name # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
