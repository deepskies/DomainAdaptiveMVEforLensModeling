# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 12
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    # if epoch < evolv_epoch:
    #     da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    # else:
    #     da_weight = final_wt_da
    return 1.4

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    if epoch < evolv_epoch:
        beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    else:
        beta_val = beta_final
    return beta_val

# Initialize hyperparameters
#learning_rate = 3e-5

n_epoch = 250
evolv_epoch = 50

beta_init = 0.7
beta_final = 0.7

# init_wt_da = 1.4
# final_wt_da = 1.0

# %%
s = np.arange(250)
plt.plot(s, [da_weight_function(i) for i in s])
plt.plot(s, [beta_function(i) for i in s])

# %%
from torch.optim.lr_scheduler import MultiStepLR
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.AdamW(model.parameters())
scheduler = MultiStepLR(optimizer, milestones=[50, 100, 150, 200], gamma=0.5)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None 
stats, model, optimizer, best_target_R2, best_mve_loss, best_nll_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/papermve_v28_aug26_0030"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")

for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)
            
            print("Saving Model...", end = ' ')
            save_model(save_mod_name + "_{}".format(curr_epoch), model, optimizer, stats)
            print("Done.")

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_nll_loss'][-1] < best_nll_loss):
                print("Saving Model NLL...", end = ' ')
                nll_name = save_mod_name + "_nll"
                save_model(nll_name, model, optimizer, stats)
                best_nll_loss = stats['val_target_nll_loss'][-1]
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        scheduler.step()

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        stats['val_source_nll_loss'].append(vals_validate[6])
        stats['val_target_nll_loss'].append(vals_validate[7])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        #stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Saving Model... Done.
#
# Epoch 0: 33.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1179
# 	Train Regression Loss: : 0.2778
# 	Train Mve Loss: : 0.8462
# 	Train R2 Score: : 0.1536
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0864
# 	Val Target Regression Loss: : 0.1301
# 	Val Source R2 Score: : 0.7347
# 	Val Target R2 Score: : 0.6106
# 	Val Source Mve Loss: : 0.4450
# 	Val Target Mve Loss: : 0.4232
# 	Val Source Nll Loss: : 8408.7495
# 	Val Target Nll Loss: : 1280.7229
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 1: 35.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0865
# 	Train Regression Loss: : 0.0566
# 	Train Mve Loss: : 0.1796
# 	Train R2 Score: : 0.8292
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0381
# 	Val Target Regression Loss: : 0.0555
# 	Val Source R2 Score: : 0.8837
# 	Val Target R2 Score: : 0.8356
# 	Val Source Mve Loss: : -0.0164
# 	Val Target Mve Loss: : 0.0030
# 	Val Source Nll Loss: : 652.0650
# 	Val Target Nll Loss: : 278.3169
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 2: 34.67s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0589
# 	Train Regression Loss: : 0.0721
# 	Train Mve Loss: : 0.1735
# 	Train R2 Score: : 0.7810
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0257
# 	Val Target Regression Loss: : 0.0307
# 	Val Source R2 Score: : 0.9204
# 	Val Target R2 Score: : 0.9088
# 	Val Source Mve Loss: : -0.0429
# 	Val Target Mve Loss: : 0.0338
# 	Val Source Nll Loss: : 8937.7848
# 	Val Target Nll Loss: : 13735.0763
# Saving Model... Done.
#
# Epoch 3: 34.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0423
# 	Train Regression Loss: : 0.0267
# 	Train Mve Loss: : -0.0795
# 	Train R2 Score: : 0.9194
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0411
# 	Val Target Regression Loss: : 0.0459
# 	Val Source R2 Score: : 0.8743
# 	Val Target R2 Score: : 0.8639
# 	Val Source Mve Loss: : -0.1252
# 	Val Target Mve Loss: : -0.1080
# 	Val Source Nll Loss: : 1837.5623
# 	Val Target Nll Loss: : 1709.9956
# Saving Model MVE... Done.
#
# Epoch 4: 34.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0382
# 	Train Regression Loss: : 0.0273
# 	Train Mve Loss: : -0.1318
# 	Train R2 Score: : 0.9174
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0213
# 	Val Target Regression Loss: : 0.0253
# 	Val Source R2 Score: : 0.9346
# 	Val Target R2 Score: : 0.9249
# 	Val Source Mve Loss: : -0.2330
# 	Val Target Mve Loss: : -0.2183
# 	Val Source Nll Loss: : 124.4355
# 	Val Target Nll Loss: : 148.3841
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 5: 34.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0361
# 	Train Regression Loss: : 0.0189
# 	Train Mve Loss: : -0.1707
# 	Train R2 Score: : 0.9428
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0197
# 	Val Target Regression Loss: : 0.0230
# 	Val Source R2 Score: : 0.9398
# 	Val Target R2 Score: : 0.9312
# 	Val Source Mve Loss: : -0.2332
# 	Val Target Mve Loss: : -0.2275
# 	Val Source Nll Loss: : -0.8738
# 	Val Target Nll Loss: : -0.8376
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 6: 34.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0356
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.1532
# 	Train R2 Score: : 0.9513
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0216
# 	Val Target Regression Loss: : 0.0255
# 	Val Source R2 Score: : 0.9340
# 	Val Target R2 Score: : 0.9244
# 	Val Source Mve Loss: : -0.1292
# 	Val Target Mve Loss: : -0.1219
# 	Val Source Nll Loss: : -0.1675
# 	Val Target Nll Loss: : -0.1585
#
# Epoch 7: 34.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0180
# 	Train Mve Loss: : -0.1649
# 	Train R2 Score: : 0.9455
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0166
# 	Val Source R2 Score: : 0.9584
# 	Val Target R2 Score: : 0.9493
# 	Val Source Mve Loss: : -0.1215
# 	Val Target Mve Loss: : -0.1182
# 	Val Source Nll Loss: : 13.4831
# 	Val Target Nll Loss: : 126.6692
# Saving Model... Done.
#
# Epoch 8: 34.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0338
# 	Train Regression Loss: : 0.0171
# 	Train Mve Loss: : -0.1736
# 	Train R2 Score: : 0.9482
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9562
# 	Val Target R2 Score: : 0.9490
# 	Val Source Mve Loss: : -0.0982
# 	Val Target Mve Loss: : -0.0519
# 	Val Source Nll Loss: : 659.8019
# 	Val Target Nll Loss: : 3865.8830
#
# Epoch 9: 34.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0337
# 	Train Regression Loss: : 0.0157
# 	Train Mve Loss: : -0.1786
# 	Train R2 Score: : 0.9525
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0130
# 	Val Target Regression Loss: : 0.0160
# 	Val Source R2 Score: : 0.9598
# 	Val Target R2 Score: : 0.9523
# 	Val Source Mve Loss: : -0.1200
# 	Val Target Mve Loss: : -0.1164
# 	Val Source Nll Loss: : 193.9649
# 	Val Target Nll Loss: : 237.9370
# Saving Model... Done.
#
# Epoch 10: 34.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0340
# 	Train Regression Loss: : 0.0172
# 	Train Mve Loss: : -0.1943
# 	Train R2 Score: : 0.9477
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0163
# 	Val Target Regression Loss: : 0.0197
# 	Val Source R2 Score: : 0.9496
# 	Val Target R2 Score: : 0.9417
# 	Val Source Mve Loss: : -0.2301
# 	Val Target Mve Loss: : -0.2270
# 	Val Source Nll Loss: : -0.9323
# 	Val Target Nll Loss: : -0.9132
# Saving Model NLL... Done.
#
# Epoch 11: 33.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0339
# 	Train Regression Loss: : 0.0212
# 	Train Mve Loss: : -0.2157
# 	Train R2 Score: : 0.9358
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0191
# 	Val Target Regression Loss: : 0.0209
# 	Val Source R2 Score: : 0.9419
# 	Val Target R2 Score: : 0.9366
# 	Val Source Mve Loss: : -0.2447
# 	Val Target Mve Loss: : -0.2432
# 	Val Source Nll Loss: : -0.6728
# 	Val Target Nll Loss: : -0.6655
# Saving Model MVE... Done.
#
# Epoch 12: 35.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0326
# 	Train Regression Loss: : 0.0142
# 	Train Mve Loss: : -0.1396
# 	Train R2 Score: : 0.9570
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0107
# 	Val Target Regression Loss: : 0.0122
# 	Val Source R2 Score: : 0.9671
# 	Val Target R2 Score: : 0.9637
# 	Val Source Mve Loss: : -0.0945
# 	Val Target Mve Loss: : -0.0915
# 	Val Source Nll Loss: : 23.9196
# 	Val Target Nll Loss: : 121.1617
# Saving Model... Done.
#
# Epoch 13: 33.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0320
# 	Train Regression Loss: : 0.0125
# 	Train Mve Loss: : -0.1354
# 	Train R2 Score: : 0.9622
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0097
# 	Val Target Regression Loss: : 0.0113
# 	Val Source R2 Score: : 0.9702
# 	Val Target R2 Score: : 0.9665
# 	Val Source Mve Loss: : -0.0707
# 	Val Target Mve Loss: : -0.0685
# 	Val Source Nll Loss: : -0.4438
# 	Val Target Nll Loss: : 4.4306
# Saving Model... Done.
#
# Epoch 14: 33.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0310
# 	Train Regression Loss: : 0.0082
# 	Train Mve Loss: : -0.0743
# 	Train R2 Score: : 0.9750
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0072
# 	Val Target Regression Loss: : 0.0092
# 	Val Source R2 Score: : 0.9780
# 	Val Target R2 Score: : 0.9726
# 	Val Source Mve Loss: : -0.0858
# 	Val Target Mve Loss: : -0.0832
# 	Val Source Nll Loss: : -1.8552
# 	Val Target Nll Loss: : 8.6870
# Saving Model... Done.
#
# Epoch 15: 35.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0331
# 	Train Regression Loss: : 0.0251
# 	Train Mve Loss: : -0.0797
# 	Train R2 Score: : 0.9237
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0207
# 	Val Target Regression Loss: : 0.0246
# 	Val Source R2 Score: : 0.9366
# 	Val Target R2 Score: : 0.9261
# 	Val Source Mve Loss: : -0.1413
# 	Val Target Mve Loss: : -0.1421
# 	Val Source Nll Loss: : 1805.5923
# 	Val Target Nll Loss: : 1577.7842
#
# Epoch 16: 35.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0517
# 	Train Mve Loss: : -0.0772
# 	Train R2 Score: : 0.8404
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0515
# 	Val Target Regression Loss: : 0.0561
# 	Val Source R2 Score: : 0.8423
# 	Val Target R2 Score: : 0.8329
# 	Val Source Mve Loss: : -0.1035
# 	Val Target Mve Loss: : -0.0918
# 	Val Source Nll Loss: : -0.1754
# 	Val Target Nll Loss: : -0.1640
#
# Epoch 17: 35.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0355
# 	Train Regression Loss: : 0.0316
# 	Train Mve Loss: : -0.2070
# 	Train R2 Score: : 0.9042
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0254
# 	Val Target Regression Loss: : 0.0276
# 	Val Source R2 Score: : 0.9219
# 	Val Target R2 Score: : 0.9177
# 	Val Source Mve Loss: : -0.2389
# 	Val Target Mve Loss: : -0.2369
# 	Val Source Nll Loss: : -0.6838
# 	Val Target Nll Loss: : -0.6759
#
# Epoch 18: 35.20s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0347
# 	Train Regression Loss: : 0.0197
# 	Train Mve Loss: : -0.1721
# 	Train R2 Score: : 0.9402
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0241
# 	Val Target Regression Loss: : 0.0263
# 	Val Source R2 Score: : 0.9265
# 	Val Target R2 Score: : 0.9219
# 	Val Source Mve Loss: : -0.2120
# 	Val Target Mve Loss: : -0.2100
# 	Val Source Nll Loss: : -0.9857
# 	Val Target Nll Loss: : -0.9744
# Saving Model NLL... Done.
#
# Epoch 19: 35.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0204
# 	Train Mve Loss: : -0.1691
# 	Train R2 Score: : 0.9383
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0168
# 	Val Target Regression Loss: : 0.0183
# 	Val Source R2 Score: : 0.9486
# 	Val Target R2 Score: : 0.9454
# 	Val Source Mve Loss: : -0.1239
# 	Val Target Mve Loss: : -0.1195
# 	Val Source Nll Loss: : 18.7072
# 	Val Target Nll Loss: : 132.8137
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 20: 47.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.1025
# 	Train R2 Score: : 0.9594
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0108
# 	Val Target Regression Loss: : 0.0127
# 	Val Source R2 Score: : 0.9666
# 	Val Target R2 Score: : 0.9623
# 	Val Source Mve Loss: : -0.0865
# 	Val Target Mve Loss: : -0.0823
# 	Val Source Nll Loss: : -1.7658
# 	Val Target Nll Loss: : 87.7360
#
# Epoch 21: 50.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0351
# 	Train Regression Loss: : 0.0178
# 	Train Mve Loss: : -0.1698
# 	Train R2 Score: : 0.9460
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0178
# 	Val Target Regression Loss: : 0.0189
# 	Val Source R2 Score: : 0.9455
# 	Val Target R2 Score: : 0.9437
# 	Val Source Mve Loss: : -0.2332
# 	Val Target Mve Loss: : -0.2321
# 	Val Source Nll Loss: : -0.4600
# 	Val Target Nll Loss: : -0.4569
#
# Epoch 22: 41.45s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0338
# 	Train Regression Loss: : 0.0149
# 	Train Mve Loss: : -0.2445
# 	Train R2 Score: : 0.9546
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0147
# 	Val Source R2 Score: : 0.9582
# 	Val Target R2 Score: : 0.9562
# 	Val Source Mve Loss: : -0.2508
# 	Val Target Mve Loss: : -0.2500
# 	Val Source Nll Loss: : -0.6790
# 	Val Target Nll Loss: : -0.6755
# Saving Model MVE... Done.
#
# Epoch 23: 46.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0111
# 	Train Mve Loss: : -0.2401
# 	Train R2 Score: : 0.9662
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0104
# 	Val Target Regression Loss: : 0.0112
# 	Val Source R2 Score: : 0.9679
# 	Val Target R2 Score: : 0.9669
# 	Val Source Mve Loss: : -0.2063
# 	Val Target Mve Loss: : -0.2057
# 	Val Source Nll Loss: : -1.1823
# 	Val Target Nll Loss: : -1.1757
# Saving Model NLL... Done.
#
# Epoch 24: 47.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0342
# 	Train Regression Loss: : 0.0110
# 	Train Mve Loss: : -0.1108
# 	Train R2 Score: : 0.9667
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0094
# 	Val Target Regression Loss: : 0.0101
# 	Val Source R2 Score: : 0.9714
# 	Val Target R2 Score: : 0.9702
# 	Val Source Mve Loss: : -0.0795
# 	Val Target Mve Loss: : -0.0790
# 	Val Source Nll Loss: : -1.8570
# 	Val Target Nll Loss: : -1.8146
# Saving Model NLL... Done.
#
# Epoch 25: 46.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0332
# 	Train Regression Loss: : 0.0080
# 	Train Mve Loss: : -0.0692
# 	Train R2 Score: : 0.9758
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0070
# 	Val Target Regression Loss: : 0.0088
# 	Val Source R2 Score: : 0.9786
# 	Val Target R2 Score: : 0.9736
# 	Val Source Mve Loss: : -0.0617
# 	Val Target Mve Loss: : -0.0586
# 	Val Source Nll Loss: : -1.4783
# 	Val Target Nll Loss: : -1.8691
# Saving Model... Done.
# Saving Model NLL... Done.
#
# Epoch 26: 49.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0337
# 	Train Regression Loss: : 0.0068
# 	Train Mve Loss: : -0.0634
# 	Train R2 Score: : 0.9793
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0072
# 	Val Target Regression Loss: : 0.0082
# 	Val Source R2 Score: : 0.9778
# 	Val Target R2 Score: : 0.9754
# 	Val Source Mve Loss: : -0.0640
# 	Val Target Mve Loss: : -0.0632
# 	Val Source Nll Loss: : -0.1317
# 	Val Target Nll Loss: : -1.9398
# Saving Model... Done.
# Saving Model NLL... Done.
#
# Epoch 27: 47.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0333
# 	Train Regression Loss: : 0.0073
# 	Train Mve Loss: : -0.0991
# 	Train R2 Score: : 0.9778
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0054
# 	Val Target Regression Loss: : 0.0068
# 	Val Source R2 Score: : 0.9833
# 	Val Target R2 Score: : 0.9797
# 	Val Source Mve Loss: : -0.0582
# 	Val Target Mve Loss: : -0.0560
# 	Val Source Nll Loss: : -2.1284
# 	Val Target Nll Loss: : -2.0111
# Saving Model... Done.
# Saving Model NLL... Done.
#
# Epoch 28: 47.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0332
# 	Train Regression Loss: : 0.0055
# 	Train Mve Loss: : -0.0555
# 	Train R2 Score: : 0.9833
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0047
# 	Val Target Regression Loss: : 0.0065
# 	Val Source R2 Score: : 0.9854
# 	Val Target R2 Score: : 0.9806
# 	Val Source Mve Loss: : -0.0434
# 	Val Target Mve Loss: : -0.0395
# 	Val Source Nll Loss: : -2.2444
# 	Val Target Nll Loss: : -2.0027
# Saving Model... Done.
#
# Epoch 29: 49.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0342
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.0521
# 	Train R2 Score: : 0.9851
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0050
# 	Val Target Regression Loss: : 0.0073
# 	Val Source R2 Score: : 0.9847
# 	Val Target R2 Score: : 0.9779
# 	Val Source Mve Loss: : -0.0458
# 	Val Target Mve Loss: : -0.0405
# 	Val Source Nll Loss: : 3.0627
# 	Val Target Nll Loss: : 3.8225
#
# Epoch 30: 51.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0045
# 	Train Mve Loss: : -0.0700
# 	Train R2 Score: : 0.9864
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0047
# 	Val Target Regression Loss: : 0.0058
# 	Val Source R2 Score: : 0.9854
# 	Val Target R2 Score: : 0.9826
# 	Val Source Mve Loss: : -0.0649
# 	Val Target Mve Loss: : -0.0626
# 	Val Source Nll Loss: : -2.1563
# 	Val Target Nll Loss: : -2.0655
# Saving Model... Done.
# Saving Model NLL... Done.
#
# Epoch 31: 51.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0353
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.0527
# 	Train R2 Score: : 0.9852
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0051
# 	Val Target Regression Loss: : 0.0064
# 	Val Source R2 Score: : 0.9845
# 	Val Target R2 Score: : 0.9809
# 	Val Source Mve Loss: : -0.0593
# 	Val Target Mve Loss: : -0.0568
# 	Val Source Nll Loss: : -2.2058
# 	Val Target Nll Loss: : -2.0994
# Saving Model NLL... Done.
#
# Epoch 32: 52.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0380
# 	Train Regression Loss: : 0.0057
# 	Train Mve Loss: : -0.0730
# 	Train R2 Score: : 0.9828
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0074
# 	Val Target Regression Loss: : 0.0077
# 	Val Source R2 Score: : 0.9773
# 	Val Target R2 Score: : 0.9771
# 	Val Source Mve Loss: : -0.1237
# 	Val Target Mve Loss: : -0.1234
# 	Val Source Nll Loss: : -1.7158
# 	Val Target Nll Loss: : -1.7093
#
# Epoch 33: 51.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0401
# 	Train Regression Loss: : 0.0098
# 	Train Mve Loss: : -0.1024
# 	Train R2 Score: : 0.9704
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0083
# 	Val Target Regression Loss: : 0.0093
# 	Val Source R2 Score: : 0.9744
# 	Val Target R2 Score: : 0.9724
# 	Val Source Mve Loss: : -0.0670
# 	Val Target Mve Loss: : -0.0638
# 	Val Source Nll Loss: : 22.6003
# 	Val Target Nll Loss: : 157.1598
#
# Epoch 34: 50.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0421
# 	Train Regression Loss: : 0.0125
# 	Train Mve Loss: : -0.0793
# 	Train R2 Score: : 0.9621
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0105
# 	Val Target Regression Loss: : 0.0112
# 	Val Source R2 Score: : 0.9675
# 	Val Target R2 Score: : 0.9667
# 	Val Source Mve Loss: : -0.0762
# 	Val Target Mve Loss: : -0.0749
# 	Val Source Nll Loss: : -1.8117
# 	Val Target Nll Loss: : 23.0889
#
# Epoch 35: 47.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0418
# 	Train Regression Loss: : 0.0112
# 	Train Mve Loss: : -0.0774
# 	Train R2 Score: : 0.9660
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0117
# 	Val Target Regression Loss: : 0.0123
# 	Val Source R2 Score: : 0.9639
# 	Val Target R2 Score: : 0.9634
# 	Val Source Mve Loss: : -0.0927
# 	Val Target Mve Loss: : -0.0921
# 	Val Source Nll Loss: : -1.7270
# 	Val Target Nll Loss: : -1.7122
#
# Epoch 36: 47.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0425
# 	Train Regression Loss: : 0.0111
# 	Train Mve Loss: : -0.0780
# 	Train R2 Score: : 0.9663
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0103
# 	Val Target Regression Loss: : 0.0115
# 	Val Source R2 Score: : 0.9684
# 	Val Target R2 Score: : 0.9655
# 	Val Source Mve Loss: : -0.1010
# 	Val Target Mve Loss: : -0.0993
# 	Val Source Nll Loss: : -1.7519
# 	Val Target Nll Loss: : -1.7167
#
# Epoch 37: 49.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0420
# 	Train Regression Loss: : 0.0117
# 	Train Mve Loss: : -0.0790
# 	Train R2 Score: : 0.9645
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0146
# 	Val Target Regression Loss: : 0.0149
# 	Val Source R2 Score: : 0.9550
# 	Val Target R2 Score: : 0.9558
# 	Val Source Mve Loss: : -0.1205
# 	Val Target Mve Loss: : -0.1203
# 	Val Source Nll Loss: : -1.5544
# 	Val Target Nll Loss: : -1.5483
#
# Epoch 38: 50.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0408
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.0894
# 	Train R2 Score: : 0.9618
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0134
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9593
# 	Val Target R2 Score: : 0.9588
# 	Val Source Mve Loss: : -0.0743
# 	Val Target Mve Loss: : -0.0737
# 	Val Source Nll Loss: : -1.7004
# 	Val Target Nll Loss: : -1.6809
#
# Epoch 39: 47.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0115
# 	Train Mve Loss: : -0.0772
# 	Train R2 Score: : 0.9653
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0093
# 	Val Target Regression Loss: : 0.0103
# 	Val Source R2 Score: : 0.9714
# 	Val Target R2 Score: : 0.9693
# 	Val Source Mve Loss: : -0.0521
# 	Val Target Mve Loss: : -0.0506
# 	Val Source Nll Loss: : -1.9035
# 	Val Target Nll Loss: : -1.8401
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 40: 46.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0414
# 	Train Regression Loss: : 0.0155
# 	Train Mve Loss: : -0.1162
# 	Train R2 Score: : 0.9526
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0110
# 	Val Target Regression Loss: : 0.0118
# 	Val Source R2 Score: : 0.9665
# 	Val Target R2 Score: : 0.9652
# 	Val Source Mve Loss: : -0.0888
# 	Val Target Mve Loss: : -0.0876
# 	Val Source Nll Loss: : -1.7524
# 	Val Target Nll Loss: : -1.7262
#
# Epoch 41: 55.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0438
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.0767
# 	Train R2 Score: : 0.9655
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0093
# 	Val Target Regression Loss: : 0.0105
# 	Val Source R2 Score: : 0.9715
# 	Val Target R2 Score: : 0.9690
# 	Val Source Mve Loss: : -0.0566
# 	Val Target Mve Loss: : -0.0545
# 	Val Source Nll Loss: : -1.8630
# 	Val Target Nll Loss: : -1.7867
#
# Epoch 42: 50.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0417
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.0773
# 	Train R2 Score: : 0.9656
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0122
# 	Val Source R2 Score: : 0.9647
# 	Val Target R2 Score: : 0.9635
# 	Val Source Mve Loss: : -0.0842
# 	Val Target Mve Loss: : -0.0833
# 	Val Source Nll Loss: : -1.7516
# 	Val Target Nll Loss: : -1.7289
#
# Epoch 43: 51.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0425
# 	Train Regression Loss: : 0.0118
# 	Train Mve Loss: : -0.0809
# 	Train R2 Score: : 0.9643
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0118
# 	Val Target Regression Loss: : 0.0130
# 	Val Source R2 Score: : 0.9637
# 	Val Target R2 Score: : 0.9616
# 	Val Source Mve Loss: : -0.0408
# 	Val Target Mve Loss: : -0.0386
# 	Val Source Nll Loss: : -1.5736
# 	Val Target Nll Loss: : -1.4796
#
# Epoch 44: 53.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0406
# 	Train Regression Loss: : 0.0146
# 	Train Mve Loss: : -0.1256
# 	Train R2 Score: : 0.9557
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0134
# 	Val Target Regression Loss: : 0.0141
# 	Val Source R2 Score: : 0.9590
# 	Val Target R2 Score: : 0.9581
# 	Val Source Mve Loss: : -0.1219
# 	Val Target Mve Loss: : -0.1210
# 	Val Source Nll Loss: : -1.5745
# 	Val Target Nll Loss: : -1.5620
#
# Epoch 45: 47.67s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0419
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.0787
# 	Train R2 Score: : 0.9640
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0210
# 	Val Target Regression Loss: : 0.0213
# 	Val Source R2 Score: : 0.9354
# 	Val Target R2 Score: : 0.9368
# 	Val Source Mve Loss: : -0.0753
# 	Val Target Mve Loss: : -0.0749
# 	Val Source Nll Loss: : -1.4227
# 	Val Target Nll Loss: : -1.4131
#
# Epoch 46: 48.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0420
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.0766
# 	Train R2 Score: : 0.9647
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0160
# 	Val Target Regression Loss: : 0.0163
# 	Val Source R2 Score: : 0.9508
# 	Val Target R2 Score: : 0.9516
# 	Val Source Mve Loss: : -0.0893
# 	Val Target Mve Loss: : -0.0891
# 	Val Source Nll Loss: : -1.5776
# 	Val Target Nll Loss: : -1.5700
#
# Epoch 47: 45.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0425
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.0791
# 	Train R2 Score: : 0.9638
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0092
# 	Val Target Regression Loss: : 0.0099
# 	Val Source R2 Score: : 0.9716
# 	Val Target R2 Score: : 0.9703
# 	Val Source Mve Loss: : -0.0611
# 	Val Target Mve Loss: : -0.0599
# 	Val Source Nll Loss: : -1.8667
# 	Val Target Nll Loss: : -1.8260
#
# Epoch 48: 48.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0424
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.0808
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0094
# 	Val Target Regression Loss: : 0.0102
# 	Val Source R2 Score: : 0.9710
# 	Val Target R2 Score: : 0.9695
# 	Val Source Mve Loss: : -0.0957
# 	Val Target Mve Loss: : -0.0945
# 	Val Source Nll Loss: : -1.7905
# 	Val Target Nll Loss: : -1.7644
#
# Epoch 49: 48.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0417
# 	Train Regression Loss: : 0.0115
# 	Train Mve Loss: : -0.0784
# 	Train R2 Score: : 0.9653
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0104
# 	Val Target Regression Loss: : 0.0113
# 	Val Source R2 Score: : 0.9679
# 	Val Target R2 Score: : 0.9665
# 	Val Source Mve Loss: : -0.0758
# 	Val Target Mve Loss: : -0.0743
# 	Val Source Nll Loss: : -1.7963
# 	Val Target Nll Loss: : -1.7552
#
# Epoch 50: 49.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0415
# 	Train Regression Loss: : 0.0102
# 	Train Mve Loss: : -0.0730
# 	Train R2 Score: : 0.9691
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0109
# 	Val Target Regression Loss: : 0.0119
# 	Val Source R2 Score: : 0.9667
# 	Val Target R2 Score: : 0.9646
# 	Val Source Mve Loss: : -0.0705
# 	Val Target Mve Loss: : -0.0688
# 	Val Source Nll Loss: : -1.7825
# 	Val Target Nll Loss: : -1.7342
#
# Epoch 51: 47.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0412
# 	Train Regression Loss: : 0.0104
# 	Train Mve Loss: : -0.0735
# 	Train R2 Score: : 0.9685
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0094
# 	Val Target Regression Loss: : 0.0101
# 	Val Source R2 Score: : 0.9712
# 	Val Target R2 Score: : 0.9697
# 	Val Source Mve Loss: : -0.0675
# 	Val Target Mve Loss: : -0.0664
# 	Val Source Nll Loss: : -1.8651
# 	Val Target Nll Loss: : -1.8299
#
# Epoch 52: 49.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0422
# 	Train Regression Loss: : 0.0105
# 	Train Mve Loss: : -0.0748
# 	Train R2 Score: : 0.9681
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0122
# 	Val Source R2 Score: : 0.9632
# 	Val Target R2 Score: : 0.9639
# 	Val Source Mve Loss: : -0.0719
# 	Val Target Mve Loss: : -0.0718
# 	Val Source Nll Loss: : -1.7472
# 	Val Target Nll Loss: : -1.7363
#
# Epoch 53: 49.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0413
# 	Train Regression Loss: : 0.0106
# 	Train Mve Loss: : -0.0738
# 	Train R2 Score: : 0.9680
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0128
# 	Val Target Regression Loss: : 0.0132
# 	Val Source R2 Score: : 0.9607
# 	Val Target R2 Score: : 0.9607
# 	Val Source Mve Loss: : -0.0692
# 	Val Target Mve Loss: : -0.0688
# 	Val Source Nll Loss: : -1.7142
# 	Val Target Nll Loss: : -1.6961
#
# Epoch 54: 48.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0411
# 	Train Regression Loss: : 0.0106
# 	Train Mve Loss: : -0.0802
# 	Train R2 Score: : 0.9679
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0097
# 	Val Target Regression Loss: : 0.0105
# 	Val Source R2 Score: : 0.9703
# 	Val Target R2 Score: : 0.9690
# 	Val Source Mve Loss: : -0.0704
# 	Val Target Mve Loss: : -0.0692
# 	Val Source Nll Loss: : -1.8564
# 	Val Target Nll Loss: : -1.8196
#
# Epoch 55: 47.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0413
# 	Train Regression Loss: : 0.0104
# 	Train Mve Loss: : -0.0750
# 	Train R2 Score: : 0.9686
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0124
# 	Val Source R2 Score: : 0.9630
# 	Val Target R2 Score: : 0.9628
# 	Val Source Mve Loss: : -0.0636
# 	Val Target Mve Loss: : -0.0631
# 	Val Source Nll Loss: : -1.7391
# 	Val Target Nll Loss: : -1.7187

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = save_mod_name#"models/papermve_v3_aug22_1315_C_mve" # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['val_source_nll_loss'], label = "Source Val NLL Loss")
plt.plot(eps, stats['val_target_nll_loss'], label = "Target Val NLL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-2, 1)
# Out:
# (-2.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.0))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9687

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.969')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | NLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | NLL: 131.683')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9579

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.273')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
