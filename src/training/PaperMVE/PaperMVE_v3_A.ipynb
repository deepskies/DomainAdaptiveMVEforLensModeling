# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 11
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    if epoch < evolv_epoch:
        da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    else:
        da_weight = final_wt_da
    return da_weight

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    if epoch < evolv_epoch:
        beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    else:
        beta_val = beta_final
    return beta_val

# Initialize hyperparameters
learning_rate = 1e-5
n_epoch = 300

evolv_epoch = 250
init_wt_da = 1.4
final_wt_da = 1.0
beta_init = 1.0
beta_final = 0.0

# %%
from torch.optim.lr_scheduler import MultiStepLR
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = MultiStepLR(optimizer, milestones=[100, 200, 250, 275], gamma=0.5)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None #"models/papermve_v1_aug20_1940_A" # "models/start_code_test_2"
stats, model, optimizer, best_target_R2, best_mve_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/papermve_v3_aug22_1315_A"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")

stats['lr'] = []
for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            if ((curr_epoch > 250) and (stats['val_target_r2_score'][-1] > 0.95) and (stats['val_target_mve_loss'][-1] < -1)):
                print("Saving Model Minima...", end = ' ')
                m_name = save_mod_name + f"_{curr_epoch}"
                save_model(m_name, model, optimizer, stats)
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        scheduler.step()

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Epoch 0: 37.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1074
# 	Train Regression Loss: : 1.9965
# 	Train Mve Loss: : 0.8671
# 	Train R2 Score: : -5.0677
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.8399
# 	Val Target Regression Loss: : 0.7961
# 	Val Source R2 Score: : -1.5776
# 	Val Target R2 Score: : -1.3703
# 	Val Source Mve Loss: : 0.3252
# 	Val Target Mve Loss: : 0.3011
# Saving Model MVE... Done.
#
# Epoch 1: 34.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0802
# 	Train Regression Loss: : 0.4634
# 	Train Mve Loss: : 0.0991
# 	Train R2 Score: : -0.4025
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2725
# 	Val Target Regression Loss: : 0.2771
# 	Val Source R2 Score: : 0.1666
# 	Val Target R2 Score: : 0.1756
# 	Val Source Mve Loss: : -0.0378
# 	Val Target Mve Loss: : -0.0349
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 2: 34.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0657
# 	Train Regression Loss: : 0.2049
# 	Train Mve Loss: : -0.0572
# 	Train R2 Score: : 0.3798
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1404
# 	Val Target Regression Loss: : 0.1470
# 	Val Source R2 Score: : 0.5689
# 	Val Target R2 Score: : 0.5629
# 	Val Source Mve Loss: : -0.0648
# 	Val Target Mve Loss: : -0.0570
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 3: 36.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0557
# 	Train Regression Loss: : 0.1060
# 	Train Mve Loss: : -0.0690
# 	Train R2 Score: : 0.6795
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0777
# 	Val Target Regression Loss: : 0.0835
# 	Val Source R2 Score: : 0.7629
# 	Val Target R2 Score: : 0.7522
# 	Val Source Mve Loss: : -0.0616
# 	Val Target Mve Loss: : -0.0546
# Saving Model... Done.
#
# Epoch 4: 35.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0513
# 	Train Regression Loss: : 0.0631
# 	Train Mve Loss: : -0.0703
# 	Train R2 Score: : 0.8091
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0515
# 	Val Target Regression Loss: : 0.0553
# 	Val Source R2 Score: : 0.8421
# 	Val Target R2 Score: : 0.8357
# 	Val Source Mve Loss: : -0.0666
# 	Val Target Mve Loss: : -0.0597
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 5: 34.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0474
# 	Train Regression Loss: : 0.0451
# 	Train Mve Loss: : -0.0666
# 	Train R2 Score: : 0.8633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0399
# 	Val Target Regression Loss: : 0.0424
# 	Val Source R2 Score: : 0.8775
# 	Val Target R2 Score: : 0.8732
# 	Val Source Mve Loss: : -0.0676
# 	Val Target Mve Loss: : -0.0589
# Saving Model... Done.
#
# Epoch 6: 34.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0440
# 	Train Regression Loss: : 0.0370
# 	Train Mve Loss: : -0.0627
# 	Train R2 Score: : 0.8879
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0342
# 	Val Target Regression Loss: : 0.0368
# 	Val Source R2 Score: : 0.8948
# 	Val Target R2 Score: : 0.8909
# 	Val Source Mve Loss: : -0.1275
# 	Val Target Mve Loss: : -0.1231
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 7: 33.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0427
# 	Train Regression Loss: : 0.0331
# 	Train Mve Loss: : -0.0657
# 	Train R2 Score: : 0.8996
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0314
# 	Val Target Regression Loss: : 0.0336
# 	Val Source R2 Score: : 0.9037
# 	Val Target R2 Score: : 0.8999
# 	Val Source Mve Loss: : -0.0533
# 	Val Target Mve Loss: : -0.0451
# Saving Model... Done.
#
# Epoch 8: 38.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0408
# 	Train Regression Loss: : 0.0304
# 	Train Mve Loss: : -0.0729
# 	Train R2 Score: : 0.9077
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0293
# 	Val Target Regression Loss: : 0.0312
# 	Val Source R2 Score: : 0.9100
# 	Val Target R2 Score: : 0.9069
# 	Val Source Mve Loss: : -0.0546
# 	Val Target Mve Loss: : -0.0470
# Saving Model... Done.
#
# Epoch 9: 51.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0408
# 	Train Regression Loss: : 0.0288
# 	Train Mve Loss: : -0.0737
# 	Train R2 Score: : 0.9126
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0278
# 	Val Target Regression Loss: : 0.0299
# 	Val Source R2 Score: : 0.9140
# 	Val Target R2 Score: : 0.9111
# 	Val Source Mve Loss: : -0.1056
# 	Val Target Mve Loss: : -0.1005
# Saving Model... Done.
#
# Epoch 10: 46.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0405
# 	Train Regression Loss: : 0.0274
# 	Train Mve Loss: : -0.0643
# 	Train R2 Score: : 0.9169
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0268
# 	Val Target Regression Loss: : 0.0283
# 	Val Source R2 Score: : 0.9175
# 	Val Target R2 Score: : 0.9158
# 	Val Source Mve Loss: : -0.0600
# 	Val Target Mve Loss: : -0.0530
# Saving Model... Done.
#
# Epoch 11: 46.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0394
# 	Train Regression Loss: : 0.0262
# 	Train Mve Loss: : -0.0586
# 	Train R2 Score: : 0.9205
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0254
# 	Val Target Regression Loss: : 0.0276
# 	Val Source R2 Score: : 0.9221
# 	Val Target R2 Score: : 0.9176
# 	Val Source Mve Loss: : -0.0522
# 	Val Target Mve Loss: : -0.0455
# Saving Model... Done.
#
# Epoch 12: 46.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0393
# 	Train Regression Loss: : 0.0251
# 	Train Mve Loss: : -0.0646
# 	Train R2 Score: : 0.9239
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0246
# 	Val Target Regression Loss: : 0.0264
# 	Val Source R2 Score: : 0.9247
# 	Val Target R2 Score: : 0.9216
# 	Val Source Mve Loss: : -0.0486
# 	Val Target Mve Loss: : -0.0422
# Saving Model... Done.
#
# Epoch 13: 47.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0394
# 	Train Regression Loss: : 0.0243
# 	Train Mve Loss: : -0.0958
# 	Train R2 Score: : 0.9264
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0235
# 	Val Target Regression Loss: : 0.0255
# 	Val Source R2 Score: : 0.9279
# 	Val Target R2 Score: : 0.9243
# 	Val Source Mve Loss: : -0.0773
# 	Val Target Mve Loss: : -0.0723
# Saving Model... Done.
#
# Epoch 14: 57.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0386
# 	Train Regression Loss: : 0.0235
# 	Train Mve Loss: : -0.0592
# 	Train R2 Score: : 0.9287
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0232
# 	Val Target Regression Loss: : 0.0251
# 	Val Source R2 Score: : 0.9285
# 	Val Target R2 Score: : 0.9252
# 	Val Source Mve Loss: : -0.0548
# 	Val Target Mve Loss: : -0.0483
# Saving Model... Done.
#
# Epoch 15: 49.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0388
# 	Train Regression Loss: : 0.0228
# 	Train Mve Loss: : -0.0611
# 	Train R2 Score: : 0.9308
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0224
# 	Val Target Regression Loss: : 0.0242
# 	Val Source R2 Score: : 0.9314
# 	Val Target R2 Score: : 0.9278
# 	Val Source Mve Loss: : -0.0515
# 	Val Target Mve Loss: : -0.0444
# Saving Model... Done.
#
# Epoch 16: 45.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0373
# 	Train Regression Loss: : 0.0221
# 	Train Mve Loss: : -0.0590
# 	Train R2 Score: : 0.9329
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0217
# 	Val Target Regression Loss: : 0.0234
# 	Val Source R2 Score: : 0.9336
# 	Val Target R2 Score: : 0.9302
# 	Val Source Mve Loss: : -0.0619
# 	Val Target Mve Loss: : -0.0565
# Saving Model... Done.
#
# Epoch 17: 47.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0377
# 	Train Regression Loss: : 0.0215
# 	Train Mve Loss: : -0.0622
# 	Train R2 Score: : 0.9349
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0209
# 	Val Target Regression Loss: : 0.0228
# 	Val Source R2 Score: : 0.9363
# 	Val Target R2 Score: : 0.9322
# 	Val Source Mve Loss: : -0.0517
# 	Val Target Mve Loss: : -0.0440
# Saving Model... Done.
#
# Epoch 18: 46.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0374
# 	Train Regression Loss: : 0.0209
# 	Train Mve Loss: : -0.0834
# 	Train R2 Score: : 0.9366
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0205
# 	Val Target Regression Loss: : 0.0227
# 	Val Source R2 Score: : 0.9374
# 	Val Target R2 Score: : 0.9322
# 	Val Source Mve Loss: : -0.0750
# 	Val Target Mve Loss: : -0.0673
#
# Epoch 19: 48.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0369
# 	Train Regression Loss: : 0.0204
# 	Train Mve Loss: : -0.0831
# 	Train R2 Score: : 0.9380
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0202
# 	Val Target Regression Loss: : 0.0218
# 	Val Source R2 Score: : 0.9381
# 	Val Target R2 Score: : 0.9350
# 	Val Source Mve Loss: : -0.0574
# 	Val Target Mve Loss: : -0.0496
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 20: 42.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0368
# 	Train Regression Loss: : 0.0200
# 	Train Mve Loss: : -0.0576
# 	Train R2 Score: : 0.9393
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0196
# 	Val Target Regression Loss: : 0.0215
# 	Val Source R2 Score: : 0.9399
# 	Val Target R2 Score: : 0.9363
# 	Val Source Mve Loss: : -0.0638
# 	Val Target Mve Loss: : -0.0564
# Saving Model... Done.
#
# Epoch 21: 48.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0381
# 	Train Regression Loss: : 0.0197
# 	Train Mve Loss: : -0.1021
# 	Train R2 Score: : 0.9402
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0197
# 	Val Target Regression Loss: : 0.0213
# 	Val Source R2 Score: : 0.9397
# 	Val Target R2 Score: : 0.9367
# 	Val Source Mve Loss: : -0.0618
# 	Val Target Mve Loss: : -0.0547
# Saving Model... Done.
#
# Epoch 22: 47.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0370
# 	Train Regression Loss: : 0.0195
# 	Train Mve Loss: : -0.0865
# 	Train R2 Score: : 0.9409
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0194
# 	Val Target Regression Loss: : 0.0211
# 	Val Source R2 Score: : 0.9397
# 	Val Target R2 Score: : 0.9374
# 	Val Source Mve Loss: : -0.1650
# 	Val Target Mve Loss: : -0.1623
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 23: 42.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0364
# 	Train Regression Loss: : 0.0193
# 	Train Mve Loss: : -0.1208
# 	Train R2 Score: : 0.9416
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0190
# 	Val Target Regression Loss: : 0.0208
# 	Val Source R2 Score: : 0.9420
# 	Val Target R2 Score: : 0.9377
# 	Val Source Mve Loss: : -0.0794
# 	Val Target Mve Loss: : -0.0730
# Saving Model... Done.
#
# Epoch 24: 43.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0363
# 	Train Regression Loss: : 0.0190
# 	Train Mve Loss: : -0.0767
# 	Train R2 Score: : 0.9424
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0189
# 	Val Target Regression Loss: : 0.0205
# 	Val Source R2 Score: : 0.9424
# 	Val Target R2 Score: : 0.9392
# 	Val Source Mve Loss: : -0.0694
# 	Val Target Mve Loss: : -0.0633
# Saving Model... Done.
#
# Epoch 25: 50.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0369
# 	Train Regression Loss: : 0.0189
# 	Train Mve Loss: : -0.1301
# 	Train R2 Score: : 0.9429
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0191
# 	Val Target Regression Loss: : 0.0203
# 	Val Source R2 Score: : 0.9418
# 	Val Target R2 Score: : 0.9398
# 	Val Source Mve Loss: : -0.0795
# 	Val Target Mve Loss: : -0.0729
# Saving Model... Done.
#
# Epoch 26: 45.96s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0361
# 	Train Regression Loss: : 0.0185
# 	Train Mve Loss: : -0.0719
# 	Train R2 Score: : 0.9437
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0184
# 	Val Target Regression Loss: : 0.0200
# 	Val Source R2 Score: : 0.9436
# 	Val Target R2 Score: : 0.9406
# 	Val Source Mve Loss: : -0.0569
# 	Val Target Mve Loss: : -0.0506
# Saving Model... Done.
#
# Epoch 27: 46.36s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0367
# 	Train Regression Loss: : 0.0183
# 	Train Mve Loss: : -0.0750
# 	Train R2 Score: : 0.9445
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0182
# 	Val Target Regression Loss: : 0.0201
# 	Val Source R2 Score: : 0.9445
# 	Val Target R2 Score: : 0.9404
# 	Val Source Mve Loss: : -0.0589
# 	Val Target Mve Loss: : -0.0529
#
# Epoch 28: 44.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0368
# 	Train Regression Loss: : 0.0181
# 	Train Mve Loss: : -0.0599
# 	Train R2 Score: : 0.9451
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0180
# 	Val Target Regression Loss: : 0.0195
# 	Val Source R2 Score: : 0.9452
# 	Val Target R2 Score: : 0.9419
# 	Val Source Mve Loss: : -0.0597
# 	Val Target Mve Loss: : -0.0538
# Saving Model... Done.
#
# Epoch 29: 42.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0371
# 	Train Regression Loss: : 0.0179
# 	Train Mve Loss: : -0.0671
# 	Train R2 Score: : 0.9456
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0178
# 	Val Target Regression Loss: : 0.0196
# 	Val Source R2 Score: : 0.9455
# 	Val Target R2 Score: : 0.9415
# 	Val Source Mve Loss: : -0.0608
# 	Val Target Mve Loss: : -0.0542
#
# Epoch 30: 41.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0366
# 	Train Regression Loss: : 0.0176
# 	Train Mve Loss: : -0.0751
# 	Train R2 Score: : 0.9466
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0177
# 	Val Target Regression Loss: : 0.0191
# 	Val Source R2 Score: : 0.9461
# 	Val Target R2 Score: : 0.9430
# 	Val Source Mve Loss: : -0.0669
# 	Val Target Mve Loss: : -0.0585
# Saving Model... Done.
#
# Epoch 31: 39.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0357
# 	Train Regression Loss: : 0.0173
# 	Train Mve Loss: : -0.0693
# 	Train R2 Score: : 0.9476
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0172
# 	Val Target Regression Loss: : 0.0190
# 	Val Source R2 Score: : 0.9475
# 	Val Target R2 Score: : 0.9437
# 	Val Source Mve Loss: : -0.0556
# 	Val Target Mve Loss: : -0.0472
# Saving Model... Done.
#
# Epoch 32: 39.45s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0362
# 	Train Regression Loss: : 0.0170
# 	Train Mve Loss: : -0.0797
# 	Train R2 Score: : 0.9485
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0171
# 	Val Target Regression Loss: : 0.0188
# 	Val Source R2 Score: : 0.9477
# 	Val Target R2 Score: : 0.9441
# 	Val Source Mve Loss: : -0.1249
# 	Val Target Mve Loss: : -0.1220
# Saving Model... Done.
#
# Epoch 33: 40.67s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0358
# 	Train Regression Loss: : 0.0169
# 	Train Mve Loss: : -0.0972
# 	Train R2 Score: : 0.9487
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0169
# 	Val Target Regression Loss: : 0.0185
# 	Val Source R2 Score: : 0.9479
# 	Val Target R2 Score: : 0.9450
# 	Val Source Mve Loss: : -0.1440
# 	Val Target Mve Loss: : -0.1412
# Saving Model... Done.
#
# Epoch 34: 40.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0362
# 	Train Regression Loss: : 0.0166
# 	Train Mve Loss: : -0.0872
# 	Train R2 Score: : 0.9498
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0166
# 	Val Target Regression Loss: : 0.0183
# 	Val Source R2 Score: : 0.9493
# 	Val Target R2 Score: : 0.9455
# 	Val Source Mve Loss: : -0.0615
# 	Val Target Mve Loss: : -0.0555
# Saving Model... Done.
#
# Epoch 35: 45.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0364
# 	Train Regression Loss: : 0.0165
# 	Train Mve Loss: : -0.1204
# 	Train R2 Score: : 0.9501
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0167
# 	Val Target Regression Loss: : 0.0179
# 	Val Source R2 Score: : 0.9488
# 	Val Target R2 Score: : 0.9467
# 	Val Source Mve Loss: : -0.1740
# 	Val Target Mve Loss: : -0.1722
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 36: 44.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0362
# 	Train Regression Loss: : 0.0164
# 	Train Mve Loss: : -0.1540
# 	Train R2 Score: : 0.9504
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0165
# 	Val Target Regression Loss: : 0.0183
# 	Val Source R2 Score: : 0.9493
# 	Val Target R2 Score: : 0.9454
# 	Val Source Mve Loss: : -0.1683
# 	Val Target Mve Loss: : -0.1662
#
# Epoch 37: 47.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0357
# 	Train Regression Loss: : 0.0163
# 	Train Mve Loss: : -0.1263
# 	Train R2 Score: : 0.9507
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0163
# 	Val Target Regression Loss: : 0.0179
# 	Val Source R2 Score: : 0.9497
# 	Val Target R2 Score: : 0.9466
# 	Val Source Mve Loss: : -0.0794
# 	Val Target Mve Loss: : -0.0746
#
# Epoch 38: 41.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0355
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.0978
# 	Train R2 Score: : 0.9512
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0161
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9505
# 	Val Target R2 Score: : 0.9473
# 	Val Source Mve Loss: : -0.0807
# 	Val Target Mve Loss: : -0.0746
# Saving Model... Done.
#
# Epoch 39: 43.84s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0354
# 	Train Regression Loss: : 0.0160
# 	Train Mve Loss: : -0.0879
# 	Train R2 Score: : 0.9517
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0160
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9511
# 	Val Target R2 Score: : 0.9469
# 	Val Source Mve Loss: : -0.1093
# 	Val Target Mve Loss: : -0.1032
# Generating Isomap...
# Epoch 40: 44.06s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0363
# 	Train Regression Loss: : 0.0159
# 	Train Mve Loss: : -0.1143
# 	Train R2 Score: : 0.9518
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0159
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9513
# 	Val Target R2 Score: : 0.9485
# 	Val Source Mve Loss: : -0.0778
# 	Val Target Mve Loss: : -0.0725
# Saving Model... Done.
#
# Epoch 41: 46.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0358
# 	Train Regression Loss: : 0.0157
# 	Train Mve Loss: : -0.0852
# 	Train R2 Score: : 0.9524
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0157
# 	Val Target Regression Loss: : 0.0175
# 	Val Source R2 Score: : 0.9518
# 	Val Target R2 Score: : 0.9483
# 	Val Source Mve Loss: : -0.0695
# 	Val Target Mve Loss: : -0.0605
#
# Epoch 42: 44.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0363
# 	Train Regression Loss: : 0.0156
# 	Train Mve Loss: : -0.0851
# 	Train R2 Score: : 0.9528
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0158
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9514
# 	Val Target R2 Score: : 0.9473
# 	Val Source Mve Loss: : -0.1847
# 	Val Target Mve Loss: : -0.1821
# Saving Model MVE... Done.
#
# Epoch 43: 46.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0361
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.1587
# 	Train R2 Score: : 0.9532
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0157
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9520
# 	Val Target R2 Score: : 0.9485
# 	Val Source Mve Loss: : -0.1222
# 	Val Target Mve Loss: : -0.1194
#
# Epoch 44: 41.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0361
# 	Train Regression Loss: : 0.0153
# 	Train Mve Loss: : -0.1154
# 	Train R2 Score: : 0.9537
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0153
# 	Val Target Regression Loss: : 0.0170
# 	Val Source R2 Score: : 0.9534
# 	Val Target R2 Score: : 0.9494
# 	Val Source Mve Loss: : -0.1593
# 	Val Target Mve Loss: : -0.1563
# Saving Model... Done.
#
# Epoch 45: 45.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0151
# 	Train Mve Loss: : -0.1132
# 	Train R2 Score: : 0.9542
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0154
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9528
# 	Val Target R2 Score: : 0.9486
# 	Val Source Mve Loss: : -0.0880
# 	Val Target Mve Loss: : -0.0784
#
# Epoch 46: 42.06s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0356
# 	Train Regression Loss: : 0.0151
# 	Train Mve Loss: : -0.0870
# 	Train R2 Score: : 0.9543
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0150
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9538
# 	Val Target R2 Score: : 0.9498
# 	Val Source Mve Loss: : -0.0849
# 	Val Target Mve Loss: : -0.0775
# Saving Model... Done.
#
# Epoch 47: 48.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0353
# 	Train Regression Loss: : 0.0149
# 	Train Mve Loss: : -0.0805
# 	Train R2 Score: : 0.9549
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0150
# 	Val Target Regression Loss: : 0.0166
# 	Val Source R2 Score: : 0.9538
# 	Val Target R2 Score: : 0.9508
# 	Val Source Mve Loss: : -0.0721
# 	Val Target Mve Loss: : -0.0616
# Saving Model... Done.
#
# Epoch 48: 46.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0353
# 	Train Regression Loss: : 0.0148
# 	Train Mve Loss: : -0.0963
# 	Train R2 Score: : 0.9552
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0149
# 	Val Target Regression Loss: : 0.0163
# 	Val Source R2 Score: : 0.9543
# 	Val Target R2 Score: : 0.9512
# 	Val Source Mve Loss: : -0.0978
# 	Val Target Mve Loss: : -0.0907
# Saving Model... Done.
#
# Epoch 49: 43.20s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0347
# 	Train Regression Loss: : 0.0146
# 	Train Mve Loss: : -0.1060
# 	Train R2 Score: : 0.9557
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0147
# 	Val Target Regression Loss: : 0.0164
# 	Val Source R2 Score: : 0.9549
# 	Val Target R2 Score: : 0.9512
# 	Val Source Mve Loss: : -0.0686
# 	Val Target Mve Loss: : -0.0558
#
# Epoch 50: 49.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0145
# 	Train Mve Loss: : -0.1209
# 	Train R2 Score: : 0.9560
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0151
# 	Val Target Regression Loss: : 0.0165
# 	Val Source R2 Score: : 0.9537
# 	Val Target R2 Score: : 0.9510
# 	Val Source Mve Loss: : -0.1987
# 	Val Target Mve Loss: : -0.1961
# Saving Model MVE... Done.
#
# Epoch 51: 42.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0145
# 	Train Mve Loss: : -0.1838
# 	Train R2 Score: : 0.9561
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0144
# 	Val Target Regression Loss: : 0.0163
# 	Val Source R2 Score: : 0.9560
# 	Val Target R2 Score: : 0.9515
# 	Val Source Mve Loss: : -0.1850
# 	Val Target Mve Loss: : -0.1817
# Saving Model... Done.
#
# Epoch 52: 46.66s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0143
# 	Train Mve Loss: : -0.1592
# 	Train R2 Score: : 0.9566
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0145
# 	Val Target Regression Loss: : 0.0161
# 	Val Source R2 Score: : 0.9556
# 	Val Target R2 Score: : 0.9522
# 	Val Source Mve Loss: : -0.1257
# 	Val Target Mve Loss: : -0.1183
# Saving Model... Done.
#
# Epoch 53: 40.96s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0362
# 	Train Regression Loss: : 0.0143
# 	Train Mve Loss: : -0.1062
# 	Train R2 Score: : 0.9567
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0160
# 	Val Source R2 Score: : 0.9560
# 	Val Target R2 Score: : 0.9522
# 	Val Source Mve Loss: : -0.1049
# 	Val Target Mve Loss: : -0.0949
# Saving Model... Done.
#
# Epoch 54: 41.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0353
# 	Train Regression Loss: : 0.0141
# 	Train Mve Loss: : -0.1521
# 	Train R2 Score: : 0.9571
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0159
# 	Val Source R2 Score: : 0.9560
# 	Val Target R2 Score: : 0.9526
# 	Val Source Mve Loss: : -0.2016
# 	Val Target Mve Loss: : -0.1992
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 55: 45.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0348
# 	Train Regression Loss: : 0.0140
# 	Train Mve Loss: : -0.1789
# 	Train R2 Score: : 0.9576
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0159
# 	Val Source R2 Score: : 0.9564
# 	Val Target R2 Score: : 0.9530
# 	Val Source Mve Loss: : -0.1451
# 	Val Target Mve Loss: : -0.1388
# Saving Model... Done.
#
# Epoch 56: 46.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0140
# 	Train Mve Loss: : -0.1361
# 	Train R2 Score: : 0.9575
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0142
# 	Val Target Regression Loss: : 0.0159
# 	Val Source R2 Score: : 0.9565
# 	Val Target R2 Score: : 0.9526
# 	Val Source Mve Loss: : -0.2023
# 	Val Target Mve Loss: : -0.1999
# Saving Model MVE... Done.
#
# Epoch 57: 47.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.1745
# 	Train R2 Score: : 0.9581
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0140
# 	Val Target Regression Loss: : 0.0155
# 	Val Source R2 Score: : 0.9566
# 	Val Target R2 Score: : 0.9536
# 	Val Source Mve Loss: : -0.1316
# 	Val Target Mve Loss: : -0.1289
# Saving Model... Done.
#
# Epoch 58: 48.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.1281
# 	Train R2 Score: : 0.9586
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0139
# 	Val Target Regression Loss: : 0.0155
# 	Val Source R2 Score: : 0.9576
# 	Val Target R2 Score: : 0.9541
# 	Val Source Mve Loss: : -0.1120
# 	Val Target Mve Loss: : -0.1070
# Saving Model... Done.
#
# Epoch 59: 48.09s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0348
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.1715
# 	Train R2 Score: : 0.9582
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0138
# 	Val Target Regression Loss: : 0.0153
# 	Val Source R2 Score: : 0.9577
# 	Val Target R2 Score: : 0.9544
# 	Val Source Mve Loss: : -0.2014
# 	Val Target Mve Loss: : -0.1992
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 60: 43.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0136
# 	Train Mve Loss: : -0.1959
# 	Train R2 Score: : 0.9588
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0152
# 	Val Source R2 Score: : 0.9582
# 	Val Target R2 Score: : 0.9546
# 	Val Source Mve Loss: : -0.1871
# 	Val Target Mve Loss: : -0.1846
# Saving Model... Done.
#
# Epoch 61: 38.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.1757
# 	Train R2 Score: : 0.9593
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0135
# 	Val Target Regression Loss: : 0.0153
# 	Val Source R2 Score: : 0.9586
# 	Val Target R2 Score: : 0.9541
# 	Val Source Mve Loss: : -0.2002
# 	Val Target Mve Loss: : -0.1977
#
# Epoch 62: 44.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0133
# 	Train Mve Loss: : -0.1984
# 	Train R2 Score: : 0.9595
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0134
# 	Val Target Regression Loss: : 0.0151
# 	Val Source R2 Score: : 0.9588
# 	Val Target R2 Score: : 0.9547
# 	Val Source Mve Loss: : -0.1885
# 	Val Target Mve Loss: : -0.1854
# Saving Model... Done.
#
# Epoch 63: 43.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0132
# 	Train Mve Loss: : -0.1723
# 	Train R2 Score: : 0.9599
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0151
# 	Val Source R2 Score: : 0.9578
# 	Val Target R2 Score: : 0.9549
# 	Val Source Mve Loss: : -0.1566
# 	Val Target Mve Loss: : -0.1507
# Saving Model... Done.
#
# Epoch 64: 45.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0354
# 	Train Regression Loss: : 0.0131
# 	Train Mve Loss: : -0.1635
# 	Train R2 Score: : 0.9603
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0132
# 	Val Target Regression Loss: : 0.0148
# 	Val Source R2 Score: : 0.9595
# 	Val Target R2 Score: : 0.9557
# 	Val Source Mve Loss: : -0.1485
# 	Val Target Mve Loss: : -0.1426
# Saving Model... Done.
#
# Epoch 65: 48.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0130
# 	Train Mve Loss: : -0.1472
# 	Train R2 Score: : 0.9604
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0132
# 	Val Target Regression Loss: : 0.0150
# 	Val Source R2 Score: : 0.9597
# 	Val Target R2 Score: : 0.9555
# 	Val Source Mve Loss: : -0.1437
# 	Val Target Mve Loss: : -0.1352
#
# Epoch 66: 51.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0130
# 	Train Mve Loss: : -0.2046
# 	Train R2 Score: : 0.9607
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0131
# 	Val Target Regression Loss: : 0.0153
# 	Val Source R2 Score: : 0.9597
# 	Val Target R2 Score: : 0.9547
# 	Val Source Mve Loss: : -0.2130
# 	Val Target Mve Loss: : -0.2092
# Saving Model MVE... Done.
#
# Epoch 67: 45.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0130
# 	Train Mve Loss: : -0.2008
# 	Train R2 Score: : 0.9607
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0130
# 	Val Target Regression Loss: : 0.0149
# 	Val Source R2 Score: : 0.9602
# 	Val Target R2 Score: : 0.9557
# 	Val Source Mve Loss: : -0.1871
# 	Val Target Mve Loss: : -0.1831
# Saving Model... Done.
#
# Epoch 68: 44.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0129
# 	Train Mve Loss: : -0.1669
# 	Train R2 Score: : 0.9609
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0131
# 	Val Target Regression Loss: : 0.0154
# 	Val Source R2 Score: : 0.9598
# 	Val Target R2 Score: : 0.9546
# 	Val Source Mve Loss: : -0.1571
# 	Val Target Mve Loss: : -0.1492
#
# Epoch 69: 42.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0129
# 	Train Mve Loss: : -0.1365
# 	Train R2 Score: : 0.9609
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0135
# 	Val Target Regression Loss: : 0.0147
# 	Val Source R2 Score: : 0.9588
# 	Val Target R2 Score: : 0.9566
# 	Val Source Mve Loss: : -0.1224
# 	Val Target Mve Loss: : -0.1111
# Saving Model... Done.
#
# Epoch 70: 44.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0348
# 	Train Regression Loss: : 0.0128
# 	Train Mve Loss: : -0.1210
# 	Train R2 Score: : 0.9611
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0131
# 	Val Target Regression Loss: : 0.0148
# 	Val Source R2 Score: : 0.9599
# 	Val Target R2 Score: : 0.9560
# 	Val Source Mve Loss: : -0.1005
# 	Val Target Mve Loss: : -0.0843
#
# Epoch 71: 47.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0353
# 	Train Regression Loss: : 0.0127
# 	Train Mve Loss: : -0.1217
# 	Train R2 Score: : 0.9615
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0129
# 	Val Target Regression Loss: : 0.0148
# 	Val Source R2 Score: : 0.9606
# 	Val Target R2 Score: : 0.9560
# 	Val Source Mve Loss: : -0.1180
# 	Val Target Mve Loss: : -0.1044
#
# Epoch 72: 49.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0343
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.1271
# 	Train R2 Score: : 0.9618
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0129
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9607
# 	Val Target R2 Score: : 0.9571
# 	Val Source Mve Loss: : -0.1016
# 	Val Target Mve Loss: : -0.0745
# Saving Model... Done.
#
# Epoch 73: 49.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0128
# 	Train Mve Loss: : -0.1315
# 	Train R2 Score: : 0.9614
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0130
# 	Val Target Regression Loss: : 0.0148
# 	Val Source R2 Score: : 0.9602
# 	Val Target R2 Score: : 0.9560
# 	Val Source Mve Loss: : -0.1545
# 	Val Target Mve Loss: : -0.1370
#
# Epoch 74: 45.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.1580
# 	Train R2 Score: : 0.9619
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0127
# 	Val Target Regression Loss: : 0.0145
# 	Val Source R2 Score: : 0.9610
# 	Val Target R2 Score: : 0.9569
# 	Val Source Mve Loss: : -0.1444
# 	Val Target Mve Loss: : -0.1342
#
# Epoch 75: 45.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0343
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.1775
# 	Train R2 Score: : 0.9617
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0129
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9600
# 	Val Target R2 Score: : 0.9573
# 	Val Source Mve Loss: : -0.1977
# 	Val Target Mve Loss: : -0.1932
# Saving Model... Done.
#
# Epoch 76: 48.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0127
# 	Train Mve Loss: : -0.1954
# 	Train R2 Score: : 0.9616
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0131
# 	Val Target Regression Loss: : 0.0149
# 	Val Source R2 Score: : 0.9599
# 	Val Target R2 Score: : 0.9554
# 	Val Source Mve Loss: : -0.2507
# 	Val Target Mve Loss: : -0.2490
# Saving Model MVE... Done.
#
# Epoch 77: 44.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0358
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.2525
# 	Train R2 Score: : 0.9617
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0128
# 	Val Target Regression Loss: : 0.0147
# 	Val Source R2 Score: : 0.9605
# 	Val Target R2 Score: : 0.9563
# 	Val Source Mve Loss: : -0.2521
# 	Val Target Mve Loss: : -0.2503
# Saving Model MVE... Done.
#
# Epoch 78: 61.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0353
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.2538
# 	Train R2 Score: : 0.9624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0127
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9609
# 	Val Target R2 Score: : 0.9571
# 	Val Source Mve Loss: : -0.2533
# 	Val Target Mve Loss: : -0.2515
# Saving Model MVE... Done.
#
# Epoch 79: 42.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.2547
# 	Train R2 Score: : 0.9625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0143
# 	Val Source R2 Score: : 0.9615
# 	Val Target R2 Score: : 0.9574
# 	Val Source Mve Loss: : -0.2540
# 	Val Target Mve Loss: : -0.2520
# Generating Isomap...
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 80: 42.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0347
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2550
# 	Train R2 Score: : 0.9629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0142
# 	Val Source R2 Score: : 0.9622
# 	Val Target R2 Score: : 0.9579
# 	Val Source Mve Loss: : -0.2537
# 	Val Target Mve Loss: : -0.2515
# Saving Model... Done.
#
# Epoch 81: 42.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0340
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2536
# 	Train R2 Score: : 0.9630
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0142
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9577
# 	Val Source Mve Loss: : -0.2507
# 	Val Target Mve Loss: : -0.2476
#
# Epoch 82: 43.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0359
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.2480
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0141
# 	Val Source R2 Score: : 0.9624
# 	Val Target R2 Score: : 0.9582
# 	Val Source Mve Loss: : -0.2388
# 	Val Target Mve Loss: : -0.2348
# Saving Model... Done.
#
# Epoch 83: 39.85s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.2289
# 	Train R2 Score: : 0.9635
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0140
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9584
# 	Val Source Mve Loss: : -0.2105
# 	Val Target Mve Loss: : -0.2066
# Saving Model... Done.
#
# Epoch 84: 45.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.2137
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0138
# 	Val Source R2 Score: : 0.9622
# 	Val Target R2 Score: : 0.9588
# 	Val Source Mve Loss: : -0.2141
# 	Val Target Mve Loss: : -0.2070
# Saving Model... Done.
#
# Epoch 85: 46.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0343
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1933
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9625
# 	Val Target R2 Score: : 0.9585
# 	Val Source Mve Loss: : -0.2034
# 	Val Target Mve Loss: : -0.1929
#
# Epoch 86: 45.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0347
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1666
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0138
# 	Val Source R2 Score: : 0.9627
# 	Val Target R2 Score: : 0.9589
# 	Val Source Mve Loss: : -0.1021
# 	Val Target Mve Loss: : -0.0935
# Saving Model... Done.
#
# Epoch 87: 46.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1609
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0141
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9580
# 	Val Source Mve Loss: : -0.1748
# 	Val Target Mve Loss: : -0.1586
#
# Epoch 88: 45.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.1624
# 	Train R2 Score: : 0.9640
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0140
# 	Val Source R2 Score: : 0.9625
# 	Val Target R2 Score: : 0.9580
# 	Val Source Mve Loss: : -0.0992
# 	Val Target Mve Loss: : -0.0745
#
# Epoch 89: 49.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0351
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.2612
# 	Train R2 Score: : 0.9633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9631
# 	Val Target R2 Score: : 0.9586
# 	Val Source Mve Loss: : -0.2562
# 	Val Target Mve Loss: : -0.2516
#
# Epoch 90: 47.84s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.2577
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0141
# 	Val Source R2 Score: : 0.9630
# 	Val Target R2 Score: : 0.9575
# 	Val Source Mve Loss: : -0.2669
# 	Val Target Mve Loss: : -0.2645
# Saving Model MVE... Done.
#
# Epoch 91: 43.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0118
# 	Train Mve Loss: : -0.2509
# 	Train R2 Score: : 0.9643
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9635
# 	Val Target R2 Score: : 0.9594
# 	Val Source Mve Loss: : -0.2110
# 	Val Target Mve Loss: : -0.2064
# Saving Model... Done.
#
# Epoch 92: 48.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0343
# 	Train Regression Loss: : 0.0117
# 	Train Mve Loss: : -0.1617
# 	Train R2 Score: : 0.9645
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0142
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9579
# 	Val Source Mve Loss: : -0.1619
# 	Val Target Mve Loss: : -0.1459
#
# Epoch 93: 44.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0118
# 	Train Mve Loss: : -0.1749
# 	Train R2 Score: : 0.9642
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0142
# 	Val Source R2 Score: : 0.9628
# 	Val Target R2 Score: : 0.9578
# 	Val Source Mve Loss: : -0.2105
# 	Val Target Mve Loss: : -0.2018
#
# Epoch 94: 52.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0117
# 	Train Mve Loss: : -0.1990
# 	Train R2 Score: : 0.9646
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0138
# 	Val Source R2 Score: : 0.9635
# 	Val Target R2 Score: : 0.9586
# 	Val Source Mve Loss: : -0.2252
# 	Val Target Mve Loss: : -0.2192
#
# Epoch 95: 47.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0343
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.1569
# 	Train R2 Score: : 0.9649
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0135
# 	Val Source R2 Score: : 0.9637
# 	Val Target R2 Score: : 0.9599
# 	Val Source Mve Loss: : -0.1600
# 	Val Target Mve Loss: : -0.1367
# Saving Model... Done.
#
# Epoch 96: 44.51s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0117
# 	Train Mve Loss: : -0.2387
# 	Train R2 Score: : 0.9645
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0118
# 	Val Target Regression Loss: : 0.0138
# 	Val Source R2 Score: : 0.9635
# 	Val Target R2 Score: : 0.9590
# 	Val Source Mve Loss: : -0.2554
# 	Val Target Mve Loss: : -0.2475
#
# Epoch 97: 40.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0340
# 	Train Regression Loss: : 0.0115
# 	Train Mve Loss: : -0.1977
# 	Train R2 Score: : 0.9651
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0118
# 	Val Target Regression Loss: : 0.0137
# 	Val Source R2 Score: : 0.9637
# 	Val Target R2 Score: : 0.9592
# 	Val Source Mve Loss: : -0.0893
# 	Val Target Mve Loss: : -0.0305
#
# Epoch 98: 41.20s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0115
# 	Train Mve Loss: : -0.1935
# 	Train R2 Score: : 0.9652
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0117
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9643
# 	Val Target R2 Score: : 0.9594
# 	Val Source Mve Loss: : -0.2377
# 	Val Target Mve Loss: : -0.2349
#
# Epoch 99: 47.00s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0115
# 	Train Mve Loss: : -0.1485
# 	Train R2 Score: : 0.9650
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0145
# 	Val Source R2 Score: : 0.9628
# 	Val Target R2 Score: : 0.9570
# 	Val Source Mve Loss: : -0.1543
# 	Val Target Mve Loss: : -0.0733
# Generating Isomap...
# Epoch 100: 41.96s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0339
# 	Train Regression Loss: : 0.0118
# 	Train Mve Loss: : -0.2007
# 	Train R2 Score: : 0.9642
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0118
# 	Val Target Regression Loss: : 0.0140
# 	Val Source R2 Score: : 0.9637
# 	Val Target R2 Score: : 0.9585
# 	Val Source Mve Loss: : -0.1237
# 	Val Target Mve Loss: : -0.1049
#
# Epoch 101: 45.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.1983
# 	Train R2 Score: : 0.9649
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0118
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9640
# 	Val Target R2 Score: : 0.9583
# 	Val Source Mve Loss: : -0.1835
# 	Val Target Mve Loss: : -0.1394
#
# Epoch 102: 41.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0117
# 	Train Mve Loss: : -0.2382
# 	Train R2 Score: : 0.9647
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0142
# 	Val Source R2 Score: : 0.9629
# 	Val Target R2 Score: : 0.9580
# 	Val Source Mve Loss: : -0.2640
# 	Val Target Mve Loss: : -0.2544
#
# Epoch 103: 41.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.2588
# 	Train R2 Score: : 0.9648
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0141
# 	Val Source R2 Score: : 0.9633
# 	Val Target R2 Score: : 0.9582
# 	Val Source Mve Loss: : -0.2892
# 	Val Target Mve Loss: : -0.2860
# Saving Model MVE... Done.
#
# Epoch 104: 41.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.2893
# 	Train R2 Score: : 0.9648
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9632
# 	Val Target R2 Score: : 0.9602
# 	Val Source Mve Loss: : -0.2864
# 	Val Target Mve Loss: : -0.2831
# Saving Model... Done.
#
# Epoch 105: 43.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.2844
# 	Train R2 Score: : 0.9653
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0117
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9641
# 	Val Target R2 Score: : 0.9601
# 	Val Source Mve Loss: : -0.2781
# 	Val Target Mve Loss: : -0.2747
#
# Epoch 106: 44.51s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0347
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.2701
# 	Train R2 Score: : 0.9655
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0115
# 	Val Target Regression Loss: : 0.0135
# 	Val Source R2 Score: : 0.9648
# 	Val Target R2 Score: : 0.9599
# 	Val Source Mve Loss: : -0.2541
# 	Val Target Mve Loss: : -0.2457
#
# Epoch 107: 42.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0348
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.2236
# 	Train R2 Score: : 0.9656
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9646
# 	Val Target R2 Score: : 0.9599
# 	Val Source Mve Loss: : -0.1621
# 	Val Target Mve Loss: : -0.0799
#
# Epoch 108: 42.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.2348
# 	Train R2 Score: : 0.9656
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0133
# 	Val Source R2 Score: : 0.9644
# 	Val Target R2 Score: : 0.9605
# 	Val Source Mve Loss: : -0.2583
# 	Val Target Mve Loss: : -0.2243
# Saving Model... Done.
#
# Epoch 109: 41.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0343
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.2503
# 	Train R2 Score: : 0.9658
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0131
# 	Val Source R2 Score: : 0.9644
# 	Val Target R2 Score: : 0.9611
# 	Val Source Mve Loss: : -0.2228
# 	Val Target Mve Loss: : -0.1349
# Saving Model... Done.
#
# Epoch 110: 44.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0112
# 	Train Mve Loss: : -0.2159
# 	Train R2 Score: : 0.9660
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0114
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9649
# 	Val Target R2 Score: : 0.9600
# 	Val Source Mve Loss: : -0.1410
# 	Val Target Mve Loss: : 0.0311
#
# Epoch 111: 44.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0112
# 	Train Mve Loss: : -0.2138
# 	Train R2 Score: : 0.9660
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0133
# 	Val Source R2 Score: : 0.9645
# 	Val Target R2 Score: : 0.9603
# 	Val Source Mve Loss: : -0.2742
# 	Val Target Mve Loss: : -0.2697
#
# Epoch 112: 45.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0345
# 	Train Regression Loss: : 0.0112
# 	Train Mve Loss: : -0.2271
# 	Train R2 Score: : 0.9661
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0117
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9644
# 	Val Target R2 Score: : 0.9599
# 	Val Source Mve Loss: : -0.1711
# 	Val Target Mve Loss: : -0.0127
#
# Epoch 113: 40.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0112
# 	Train Mve Loss: : -0.2689
# 	Train R2 Score: : 0.9661
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0114
# 	Val Target Regression Loss: : 0.0133
# 	Val Source R2 Score: : 0.9652
# 	Val Target R2 Score: : 0.9605
# 	Val Source Mve Loss: : -0.2224
# 	Val Target Mve Loss: : -0.2015
#
# Epoch 114: 47.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0112
# 	Train Mve Loss: : -0.1833
# 	Train R2 Score: : 0.9659
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9645
# 	Val Target R2 Score: : 0.9601
# 	Val Source Mve Loss: : -0.2204
# 	Val Target Mve Loss: : -0.1421
#
# Epoch 115: 40.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.1785
# 	Train R2 Score: : 0.9655
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9630
# 	Val Target R2 Score: : 0.9571
# 	Val Source Mve Loss: : -0.2862
# 	Val Target Mve Loss: : -0.2792
#
# Epoch 116: 41.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0114
# 	Train Mve Loss: : -0.2786
# 	Train R2 Score: : 0.9654
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0117
# 	Val Target Regression Loss: : 0.0136
# 	Val Source R2 Score: : 0.9644
# 	Val Target R2 Score: : 0.9594
# 	Val Source Mve Loss: : -0.2670
# 	Val Target Mve Loss: : -0.2563
#
# Epoch 117: 48.45s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0349
# 	Train Regression Loss: : 0.0113
# 	Train Mve Loss: : -0.2220
# 	Train R2 Score: : 0.9658
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0116
# 	Val Target Regression Loss: : 0.0137
# 	Val Source R2 Score: : 0.9646
# 	Val Target R2 Score: : 0.9590
# 	Val Source Mve Loss: : -0.1885
# 	Val Target Mve Loss: : -0.1094
#
# Epoch 118: 44.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0347
# 	Train Regression Loss: : 0.0115
# 	Train Mve Loss: : -0.2415
# 	Train R2 Score: : 0.9651
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0144
# 	Val Source R2 Score: : 0.9627
# 	Val Target R2 Score: : 0.9571
# 	Val Source Mve Loss: : -0.3286
# 	Val Target Mve Loss: : -0.3251
# Saving Model MVE... Done.
#
# Epoch 119: 44.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0351
# 	Train Regression Loss: : 0.0116
# 	Train Mve Loss: : -0.3319
# 	Train R2 Score: : 0.9649
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9635
# 	Val Target R2 Score: : 0.9587
# 	Val Source Mve Loss: : -0.3311
# 	Val Target Mve Loss: : -0.3278
# Generating Isomap...
# Saving Model MVE... Done.

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = final_mod_name # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9767

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.977')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | BNLL: -0.175')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9661

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.966')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.966')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.156')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
