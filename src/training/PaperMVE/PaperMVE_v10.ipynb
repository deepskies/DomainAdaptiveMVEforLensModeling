# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 13
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    # if epoch < evolv_epoch:
    #     da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    # else:
    #     da_weight = final_wt_da
    return 1.4

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    if epoch < evolv_epoch:
        beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    else:
        beta_val = beta_final
    return beta_val

# Initialize hyperparameters
learning_rate = 3e-5

n_epoch = 200
evolv_epoch = 50

beta_init = 1.0
beta_final = 0.6

# init_wt_da = 1.4
# final_wt_da = 1.0

# %%
s = np.arange(250)
plt.plot(s, [da_weight_function(i) for i in s])
plt.plot(s, [beta_function(i) for i in s])

# %%
from torch.optim.lr_scheduler import MultiStepLR
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = MultiStepLR(optimizer, milestones=[50, 100, 150, 200], gamma=0.1)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None 
stats, model, optimizer, best_target_R2, best_mve_loss, best_nll_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/papermve_v10_aug24_2250"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")
stats['lr'] = []
for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_nll_loss'][-1] < best_nll_loss):
                print("Saving Model NLL...", end = ' ')
                nll_name = save_mod_name + "_nll"
                save_model(nll_name, model, optimizer, stats)
                best_nll_loss = stats['val_target_nll_loss'][-1]
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        scheduler.step()

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        stats['val_source_nll_loss'].append(vals_validate[6])
        stats['val_target_nll_loss'].append(vals_validate[7])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Epoch 0: 60.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.4657
# 	Train Regression Loss: : 2.0740
# 	Train Mve Loss: : 0.8835
# 	Train R2 Score: : -5.3215
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.7792
# 	Val Target Regression Loss: : 0.7237
# 	Val Source R2 Score: : -1.3843
# 	Val Target R2 Score: : -1.1479
# 	Val Source Mve Loss: : 0.2336
# 	Val Target Mve Loss: : 0.2026
# 	Val Source Nll Loss: : 0.4683
# 	Val Target Nll Loss: : 0.4784
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 1: 59.09s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.3152
# 	Train Regression Loss: : 0.4472
# 	Train Mve Loss: : 0.0646
# 	Train R2 Score: : -0.3519
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2844
# 	Val Target Regression Loss: : 0.2970
# 	Val Source R2 Score: : 0.1331
# 	Val Target R2 Score: : 0.1148
# 	Val Source Mve Loss: : -0.0219
# 	Val Target Mve Loss: : -0.0201
# 	Val Source Nll Loss: : -0.0729
# 	Val Target Nll Loss: : -0.0431
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 2: 62.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2009
# 	Train Regression Loss: : 0.2440
# 	Train Mve Loss: : -0.0482
# 	Train R2 Score: : 0.2629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2005
# 	Val Target Regression Loss: : 0.2335
# 	Val Source R2 Score: : 0.3886
# 	Val Target R2 Score: : 0.3089
# 	Val Source Mve Loss: : -0.0726
# 	Val Target Mve Loss: : -0.0572
# 	Val Source Nll Loss: : 291.8085
# 	Val Target Nll Loss: : 113.4584
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 3: 58.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1354
# 	Train Regression Loss: : 0.1677
# 	Train Mve Loss: : -0.0841
# 	Train R2 Score: : 0.4935
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1320
# 	Val Target Regression Loss: : 0.1655
# 	Val Source R2 Score: : 0.5965
# 	Val Target R2 Score: : 0.5091
# 	Val Source Mve Loss: : -0.0902
# 	Val Target Mve Loss: : -0.0640
# 	Val Source Nll Loss: : 2048.2808
# 	Val Target Nll Loss: : 7019.2150
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 4: 49.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0966
# 	Train Regression Loss: : 0.1100
# 	Train Mve Loss: : -0.0883
# 	Train R2 Score: : 0.6681
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0906
# 	Val Target Regression Loss: : 0.1183
# 	Val Source R2 Score: : 0.7231
# 	Val Target R2 Score: : 0.6491
# 	Val Source Mve Loss: : -0.0817
# 	Val Target Mve Loss: : -0.0550
# 	Val Source Nll Loss: : 5061.3241
# 	Val Target Nll Loss: : 11928.1402
# Saving Model... Done.
#
# Epoch 5: 45.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0782
# 	Train Regression Loss: : 0.0810
# 	Train Mve Loss: : -0.1010
# 	Train R2 Score: : 0.7551
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0725
# 	Val Target Regression Loss: : 0.0949
# 	Val Source R2 Score: : 0.7791
# 	Val Target R2 Score: : 0.7169
# 	Val Source Mve Loss: : -0.0779
# 	Val Target Mve Loss: : -0.0633
# 	Val Source Nll Loss: : 4641.4578
# 	Val Target Nll Loss: : 7780.1475
# Saving Model... Done.
#
# Epoch 6: 45.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0667
# 	Train Regression Loss: : 0.0656
# 	Train Mve Loss: : -0.0742
# 	Train R2 Score: : 0.8015
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0588
# 	Val Target Regression Loss: : 0.0773
# 	Val Source R2 Score: : 0.8201
# 	Val Target R2 Score: : 0.7706
# 	Val Source Mve Loss: : -0.0774
# 	Val Target Mve Loss: : -0.0645
# 	Val Source Nll Loss: : 1533.4012
# 	Val Target Nll Loss: : 4811.1037
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 7: 47.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0588
# 	Train Regression Loss: : 0.0543
# 	Train Mve Loss: : -0.0793
# 	Train R2 Score: : 0.8360
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0490
# 	Val Target Regression Loss: : 0.0642
# 	Val Source R2 Score: : 0.8502
# 	Val Target R2 Score: : 0.8097
# 	Val Source Mve Loss: : -0.0659
# 	Val Target Mve Loss: : -0.0567
# 	Val Source Nll Loss: : 4989.6468
# 	Val Target Nll Loss: : 10602.6708
# Saving Model... Done.
#
# Epoch 8: 48.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0532
# 	Train Regression Loss: : 0.0454
# 	Train Mve Loss: : -0.0676
# 	Train R2 Score: : 0.8629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0417
# 	Val Target Regression Loss: : 0.0529
# 	Val Source R2 Score: : 0.8734
# 	Val Target R2 Score: : 0.8430
# 	Val Source Mve Loss: : -0.0667
# 	Val Target Mve Loss: : -0.0587
# 	Val Source Nll Loss: : 2938.6946
# 	Val Target Nll Loss: : 7889.9433
# Saving Model... Done.
#
# Epoch 9: 51.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0476
# 	Train Regression Loss: : 0.0381
# 	Train Mve Loss: : -0.0763
# 	Train R2 Score: : 0.8847
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0357
# 	Val Target Regression Loss: : 0.0442
# 	Val Source R2 Score: : 0.8910
# 	Val Target R2 Score: : 0.8680
# 	Val Source Mve Loss: : -0.0961
# 	Val Target Mve Loss: : -0.0891
# 	Val Source Nll Loss: : 1129.6897
# 	Val Target Nll Loss: : 2455.0105
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 10: 55.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0440
# 	Train Regression Loss: : 0.0328
# 	Train Mve Loss: : -0.0673
# 	Train R2 Score: : 0.9006
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0302
# 	Val Target Regression Loss: : 0.0382
# 	Val Source R2 Score: : 0.9071
# 	Val Target R2 Score: : 0.8860
# 	Val Source Mve Loss: : -0.0580
# 	Val Target Mve Loss: : -0.0526
# 	Val Source Nll Loss: : 2641.1189
# 	Val Target Nll Loss: : 9774.5654
# Saving Model... Done.
#
# Epoch 11: 66.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0417
# 	Train Regression Loss: : 0.0286
# 	Train Mve Loss: : -0.0834
# 	Train R2 Score: : 0.9132
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0269
# 	Val Target Regression Loss: : 0.0343
# 	Val Source R2 Score: : 0.9167
# 	Val Target R2 Score: : 0.8972
# 	Val Source Mve Loss: : -0.0638
# 	Val Target Mve Loss: : -0.0558
# 	Val Source Nll Loss: : 4005.6908
# 	Val Target Nll Loss: : 9663.5742
# Saving Model... Done.
#
# Epoch 12: 55.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0394
# 	Train Regression Loss: : 0.0256
# 	Train Mve Loss: : -0.0846
# 	Train R2 Score: : 0.9225
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0242
# 	Val Target Regression Loss: : 0.0311
# 	Val Source R2 Score: : 0.9255
# 	Val Target R2 Score: : 0.9079
# 	Val Source Mve Loss: : -0.0731
# 	Val Target Mve Loss: : -0.0654
# 	Val Source Nll Loss: : 5151.0219
# 	Val Target Nll Loss: : 11504.0041
# Saving Model... Done.
#
# Epoch 13: 53.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0374
# 	Train Regression Loss: : 0.0241
# 	Train Mve Loss: : -0.1176
# 	Train R2 Score: : 0.9271
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0237
# 	Val Target Regression Loss: : 0.0300
# 	Val Source R2 Score: : 0.9268
# 	Val Target R2 Score: : 0.9110
# 	Val Source Mve Loss: : -0.1059
# 	Val Target Mve Loss: : -0.0983
# 	Val Source Nll Loss: : 13768.9954
# 	Val Target Nll Loss: : 16691.0166
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 14: 51.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0362
# 	Train Regression Loss: : 0.0228
# 	Train Mve Loss: : -0.0832
# 	Train R2 Score: : 0.9311
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0216
# 	Val Target Regression Loss: : 0.0274
# 	Val Source R2 Score: : 0.9340
# 	Val Target R2 Score: : 0.9182
# 	Val Source Mve Loss: : -0.0599
# 	Val Target Mve Loss: : -0.0559
# 	Val Source Nll Loss: : 7703.7259
# 	Val Target Nll Loss: : 9679.6764
# Saving Model... Done.
#
# Epoch 15: 49.11s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0211
# 	Train Mve Loss: : -0.0920
# 	Train R2 Score: : 0.9360
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0203
# 	Val Target Regression Loss: : 0.0267
# 	Val Source R2 Score: : 0.9376
# 	Val Target R2 Score: : 0.9207
# 	Val Source Mve Loss: : -0.0879
# 	Val Target Mve Loss: : -0.0836
# 	Val Source Nll Loss: : 1094.6636
# 	Val Target Nll Loss: : 1964.7648
# Saving Model... Done.
#
# Epoch 16: 57.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0336
# 	Train Regression Loss: : 0.0200
# 	Train Mve Loss: : -0.0723
# 	Train R2 Score: : 0.9394
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0197
# 	Val Target Regression Loss: : 0.0255
# 	Val Source R2 Score: : 0.9397
# 	Val Target R2 Score: : 0.9231
# 	Val Source Mve Loss: : -0.0709
# 	Val Target Mve Loss: : -0.0669
# 	Val Source Nll Loss: : 1428.5908
# 	Val Target Nll Loss: : 3092.7449
# Saving Model... Done.
#
# Epoch 17: 49.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0329
# 	Train Regression Loss: : 0.0192
# 	Train Mve Loss: : -0.0766
# 	Train R2 Score: : 0.9417
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0192
# 	Val Target Regression Loss: : 0.0243
# 	Val Source R2 Score: : 0.9412
# 	Val Target R2 Score: : 0.9278
# 	Val Source Mve Loss: : -0.0711
# 	Val Target Mve Loss: : -0.0658
# 	Val Source Nll Loss: : 1740.1813
# 	Val Target Nll Loss: : 3732.1606
# Saving Model... Done.
#
# Epoch 18: 49.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0330
# 	Train Regression Loss: : 0.0188
# 	Train Mve Loss: : -0.1439
# 	Train R2 Score: : 0.9431
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0185
# 	Val Target Regression Loss: : 0.0246
# 	Val Source R2 Score: : 0.9432
# 	Val Target R2 Score: : 0.9267
# 	Val Source Mve Loss: : -0.1676
# 	Val Target Mve Loss: : -0.1620
# 	Val Source Nll Loss: : 3767.3767
# 	Val Target Nll Loss: : 4419.1229
# Saving Model MVE... Done.
#
# Epoch 19: 45.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0329
# 	Train Regression Loss: : 0.0183
# 	Train Mve Loss: : -0.1768
# 	Train R2 Score: : 0.9447
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0186
# 	Val Target Regression Loss: : 0.0241
# 	Val Source R2 Score: : 0.9419
# 	Val Target R2 Score: : 0.9285
# 	Val Source Mve Loss: : -0.1897
# 	Val Target Mve Loss: : -0.1850
# 	Val Source Nll Loss: : 1138.2751
# 	Val Target Nll Loss: : 1510.6496
# Generating Isomap...
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 20: 48.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0322
# 	Train Regression Loss: : 0.0180
# 	Train Mve Loss: : -0.1795
# 	Train R2 Score: : 0.9454
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0184
# 	Val Target Regression Loss: : 0.0240
# 	Val Source R2 Score: : 0.9437
# 	Val Target R2 Score: : 0.9280
# 	Val Source Mve Loss: : -0.1638
# 	Val Target Mve Loss: : -0.1579
# 	Val Source Nll Loss: : 3740.6625
# 	Val Target Nll Loss: : 4593.4506
#
# Epoch 21: 50.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0315
# 	Train Regression Loss: : 0.0175
# 	Train Mve Loss: : -0.1508
# 	Train R2 Score: : 0.9469
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0173
# 	Val Target Regression Loss: : 0.0232
# 	Val Source R2 Score: : 0.9469
# 	Val Target R2 Score: : 0.9312
# 	Val Source Mve Loss: : -0.1257
# 	Val Target Mve Loss: : -0.1175
# 	Val Source Nll Loss: : 6533.5665
# 	Val Target Nll Loss: : 8692.3322
# Saving Model... Done.
#
# Epoch 22: 57.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0311
# 	Train Regression Loss: : 0.0173
# 	Train Mve Loss: : -0.1647
# 	Train R2 Score: : 0.9476
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0170
# 	Val Target Regression Loss: : 0.0235
# 	Val Source R2 Score: : 0.9477
# 	Val Target R2 Score: : 0.9302
# 	Val Source Mve Loss: : -0.1660
# 	Val Target Mve Loss: : -0.1596
# 	Val Source Nll Loss: : 2135.1031
# 	Val Target Nll Loss: : 2572.9069
#
# Epoch 23: 52.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0311
# 	Train Regression Loss: : 0.0171
# 	Train Mve Loss: : -0.1443
# 	Train R2 Score: : 0.9481
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0170
# 	Val Target Regression Loss: : 0.0233
# 	Val Source R2 Score: : 0.9481
# 	Val Target R2 Score: : 0.9305
# 	Val Source Mve Loss: : -0.1092
# 	Val Target Mve Loss: : -0.0995
# 	Val Source Nll Loss: : 4066.5393
# 	Val Target Nll Loss: : 6047.7014
#
# Epoch 24: 47.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0321
# 	Train Regression Loss: : 0.0169
# 	Train Mve Loss: : -0.1474
# 	Train R2 Score: : 0.9487
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0171
# 	Val Target Regression Loss: : 0.0228
# 	Val Source R2 Score: : 0.9471
# 	Val Target R2 Score: : 0.9318
# 	Val Source Mve Loss: : -0.1586
# 	Val Target Mve Loss: : -0.1555
# 	Val Source Nll Loss: : 6610.9779
# 	Val Target Nll Loss: : 6480.0810
# Saving Model... Done.
#
# Epoch 25: 61.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0302
# 	Train Regression Loss: : 0.0168
# 	Train Mve Loss: : -0.1711
# 	Train R2 Score: : 0.9491
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0169
# 	Val Target Regression Loss: : 0.0230
# 	Val Source R2 Score: : 0.9480
# 	Val Target R2 Score: : 0.9313
# 	Val Source Mve Loss: : -0.1883
# 	Val Target Mve Loss: : -0.1863
# 	Val Source Nll Loss: : -0.4945
# 	Val Target Nll Loss: : -0.4832
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 26: 47.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0310
# 	Train Regression Loss: : 0.0168
# 	Train Mve Loss: : -0.1936
# 	Train R2 Score: : 0.9490
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0168
# 	Val Target Regression Loss: : 0.0226
# 	Val Source R2 Score: : 0.9483
# 	Val Target R2 Score: : 0.9325
# 	Val Source Mve Loss: : -0.1949
# 	Val Target Mve Loss: : -0.1931
# 	Val Source Nll Loss: : -0.6073
# 	Val Target Nll Loss: : -0.5880
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 27: 50.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0297
# 	Train Regression Loss: : 0.0167
# 	Train Mve Loss: : -0.1942
# 	Train R2 Score: : 0.9495
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0175
# 	Val Target Regression Loss: : 0.0230
# 	Val Source R2 Score: : 0.9465
# 	Val Target R2 Score: : 0.9315
# 	Val Source Mve Loss: : -0.1845
# 	Val Target Mve Loss: : -0.1841
# 	Val Source Nll Loss: : 7.2458
# 	Val Target Nll Loss: : -0.7800
# Saving Model NLL... Done.
#
# Epoch 28: 52.85s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0303
# 	Train Regression Loss: : 0.0169
# 	Train Mve Loss: : -0.1797
# 	Train R2 Score: : 0.9489
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0170
# 	Val Target Regression Loss: : 0.0237
# 	Val Source R2 Score: : 0.9478
# 	Val Target R2 Score: : 0.9292
# 	Val Source Mve Loss: : -0.1565
# 	Val Target Mve Loss: : -0.1549
# 	Val Source Nll Loss: : 1150.6290
# 	Val Target Nll Loss: : 1558.4404
#
# Epoch 29: 73.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0297
# 	Train Regression Loss: : 0.0171
# 	Train Mve Loss: : -0.1860
# 	Train R2 Score: : 0.9482
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0167
# 	Val Target Regression Loss: : 0.0232
# 	Val Source R2 Score: : 0.9487
# 	Val Target R2 Score: : 0.9312
# 	Val Source Mve Loss: : -0.1867
# 	Val Target Mve Loss: : -0.1836
# 	Val Source Nll Loss: : 226.0919
# 	Val Target Nll Loss: : 150.4885
#
# Epoch 30: 51.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0295
# 	Train Regression Loss: : 0.0167
# 	Train Mve Loss: : -0.1530
# 	Train R2 Score: : 0.9493
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0164
# 	Val Target Regression Loss: : 0.0224
# 	Val Source R2 Score: : 0.9498
# 	Val Target R2 Score: : 0.9333
# 	Val Source Mve Loss: : -0.1865
# 	Val Target Mve Loss: : -0.1849
# 	Val Source Nll Loss: : 63.6825
# 	Val Target Nll Loss: : 2.2451
# Saving Model... Done.
#
# Epoch 31: 47.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0283
# 	Train Regression Loss: : 0.0165
# 	Train Mve Loss: : -0.1802
# 	Train R2 Score: : 0.9500
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0163
# 	Val Target Regression Loss: : 0.0232
# 	Val Source R2 Score: : 0.9505
# 	Val Target R2 Score: : 0.9307
# 	Val Source Mve Loss: : -0.1923
# 	Val Target Mve Loss: : -0.1883
# 	Val Source Nll Loss: : 68.9491
# 	Val Target Nll Loss: : 32.6457
#
# Epoch 32: 51.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0290
# 	Train Regression Loss: : 0.0163
# 	Train Mve Loss: : -0.1738
# 	Train R2 Score: : 0.9505
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0162
# 	Val Target Regression Loss: : 0.0228
# 	Val Source R2 Score: : 0.9503
# 	Val Target R2 Score: : 0.9317
# 	Val Source Mve Loss: : -0.1581
# 	Val Target Mve Loss: : -0.1533
# 	Val Source Nll Loss: : 399.2110
# 	Val Target Nll Loss: : 597.9938
#
# Epoch 33: 54.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0296
# 	Train Regression Loss: : 0.0159
# 	Train Mve Loss: : -0.1528
# 	Train R2 Score: : 0.9516
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0158
# 	Val Target Regression Loss: : 0.0217
# 	Val Source R2 Score: : 0.9514
# 	Val Target R2 Score: : 0.9353
# 	Val Source Mve Loss: : -0.1223
# 	Val Target Mve Loss: : -0.0984
# 	Val Source Nll Loss: : 2203.5803
# 	Val Target Nll Loss: : 4579.4866
# Saving Model... Done.
#
# Epoch 34: 59.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0292
# 	Train Regression Loss: : 0.0155
# 	Train Mve Loss: : -0.1497
# 	Train R2 Score: : 0.9529
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0158
# 	Val Target Regression Loss: : 0.0222
# 	Val Source R2 Score: : 0.9512
# 	Val Target R2 Score: : 0.9342
# 	Val Source Mve Loss: : -0.1253
# 	Val Target Mve Loss: : -0.1090
# 	Val Source Nll Loss: : 1443.6403
# 	Val Target Nll Loss: : 2577.5948
#
# Epoch 35: 60.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0297
# 	Train Regression Loss: : 0.0152
# 	Train Mve Loss: : -0.1814
# 	Train R2 Score: : 0.9539
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0149
# 	Val Target Regression Loss: : 0.0211
# 	Val Source R2 Score: : 0.9542
# 	Val Target R2 Score: : 0.9371
# 	Val Source Mve Loss: : -0.2245
# 	Val Target Mve Loss: : -0.2186
# 	Val Source Nll Loss: : 131.7657
# 	Val Target Nll Loss: : 224.2389
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 36: 70.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0289
# 	Train Regression Loss: : 0.0149
# 	Train Mve Loss: : -0.1804
# 	Train R2 Score: : 0.9548
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0148
# 	Val Target Regression Loss: : 0.0209
# 	Val Source R2 Score: : 0.9543
# 	Val Target R2 Score: : 0.9378
# 	Val Source Mve Loss: : -0.1538
# 	Val Target Mve Loss: : -0.1408
# 	Val Source Nll Loss: : 1988.0878
# 	Val Target Nll Loss: : 2628.4347
# Saving Model... Done.
#
# Epoch 37: 56.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0293
# 	Train Regression Loss: : 0.0146
# 	Train Mve Loss: : -0.1920
# 	Train R2 Score: : 0.9557
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0150
# 	Val Target Regression Loss: : 0.0211
# 	Val Source R2 Score: : 0.9544
# 	Val Target R2 Score: : 0.9372
# 	Val Source Mve Loss: : -0.1685
# 	Val Target Mve Loss: : -0.1536
# 	Val Source Nll Loss: : 984.2520
# 	Val Target Nll Loss: : 1826.2890
#
# Epoch 38: 60.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.1955
# 	Train R2 Score: : 0.9533
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0164
# 	Val Target Regression Loss: : 0.0220
# 	Val Source R2 Score: : 0.9496
# 	Val Target R2 Score: : 0.9347
# 	Val Source Mve Loss: : -0.2305
# 	Val Target Mve Loss: : -0.2273
# 	Val Source Nll Loss: : 78.9768
# 	Val Target Nll Loss: : 112.6694
# Saving Model MVE... Done.
#
# Epoch 39: 48.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0288
# 	Train Regression Loss: : 0.0157
# 	Train Mve Loss: : -0.2373
# 	Train R2 Score: : 0.9524
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0159
# 	Val Target Regression Loss: : 0.0217
# 	Val Source R2 Score: : 0.9518
# 	Val Target R2 Score: : 0.9353
# 	Val Source Mve Loss: : -0.2386
# 	Val Target Mve Loss: : -0.2343
# 	Val Source Nll Loss: : 255.1570
# 	Val Target Nll Loss: : 251.2234
# Generating Isomap...
# Saving Model MVE... Done.
#
# Epoch 40: 50.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0290
# 	Train Regression Loss: : 0.0152
# 	Train Mve Loss: : -0.2375
# 	Train R2 Score: : 0.9539
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0152
# 	Val Target Regression Loss: : 0.0205
# 	Val Source R2 Score: : 0.9536
# 	Val Target R2 Score: : 0.9393
# 	Val Source Mve Loss: : -0.2263
# 	Val Target Mve Loss: : -0.2204
# 	Val Source Nll Loss: : 1066.7448
# 	Val Target Nll Loss: : 1117.0950
# Saving Model... Done.
#
# Epoch 41: 49.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0149
# 	Train Mve Loss: : -0.2074
# 	Train R2 Score: : 0.9549
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0152
# 	Val Target Regression Loss: : 0.0204
# 	Val Source R2 Score: : 0.9534
# 	Val Target R2 Score: : 0.9395
# 	Val Source Mve Loss: : -0.2095
# 	Val Target Mve Loss: : -0.2017
# 	Val Source Nll Loss: : 1462.0129
# 	Val Target Nll Loss: : 1596.8261
# Saving Model... Done.
#
# Epoch 42: 49.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0286
# 	Train Regression Loss: : 0.0146
# 	Train Mve Loss: : -0.1784
# 	Train R2 Score: : 0.9557
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0146
# 	Val Target Regression Loss: : 0.0209
# 	Val Source R2 Score: : 0.9545
# 	Val Target R2 Score: : 0.9372
# 	Val Source Mve Loss: : -0.1318
# 	Val Target Mve Loss: : -0.0887
# 	Val Source Nll Loss: : 3225.5846
# 	Val Target Nll Loss: : 4817.7008
#
# Epoch 43: 59.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0145
# 	Train Mve Loss: : -0.1271
# 	Train R2 Score: : 0.9563
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0198
# 	Val Source R2 Score: : 0.9560
# 	Val Target R2 Score: : 0.9414
# 	Val Source Mve Loss: : -0.1799
# 	Val Target Mve Loss: : -0.1660
# 	Val Source Nll Loss: : 1000.4843
# 	Val Target Nll Loss: : 1289.6133
# Saving Model... Done.
#
# Epoch 44: 66.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0277
# 	Train Regression Loss: : 0.0143
# 	Train Mve Loss: : -0.1771
# 	Train R2 Score: : 0.9567
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0142
# 	Val Target Regression Loss: : 0.0188
# 	Val Source R2 Score: : 0.9562
# 	Val Target R2 Score: : 0.9439
# 	Val Source Mve Loss: : -0.1098
# 	Val Target Mve Loss: : -0.1017
# 	Val Source Nll Loss: : 3992.4483
# 	Val Target Nll Loss: : 4164.6912
# Saving Model... Done.
#
# Epoch 45: 52.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0290
# 	Train Regression Loss: : 0.0140
# 	Train Mve Loss: : -0.2309
# 	Train R2 Score: : 0.9578
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0139
# 	Val Target Regression Loss: : 0.0194
# 	Val Source R2 Score: : 0.9573
# 	Val Target R2 Score: : 0.9423
# 	Val Source Mve Loss: : -0.2275
# 	Val Target Mve Loss: : -0.2101
# 	Val Source Nll Loss: : 839.0367
# 	Val Target Nll Loss: : 1197.7251
#
# Epoch 46: 57.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0285
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.1885
# 	Train R2 Score: : 0.9581
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0191
# 	Val Source R2 Score: : 0.9581
# 	Val Target R2 Score: : 0.9426
# 	Val Source Mve Loss: : -0.2173
# 	Val Target Mve Loss: : -0.1998
# 	Val Source Nll Loss: : 450.8471
# 	Val Target Nll Loss: : 733.2660
#
# Epoch 47: 48.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0136
# 	Train Mve Loss: : -0.1443
# 	Train R2 Score: : 0.9588
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0140
# 	Val Target Regression Loss: : 0.0190
# 	Val Source R2 Score: : 0.9573
# 	Val Target R2 Score: : 0.9433
# 	Val Source Mve Loss: : -0.0936
# 	Val Target Mve Loss: : -0.0519
# 	Val Source Nll Loss: : 1804.6760
# 	Val Target Nll Loss: : 2609.2246
#
# Epoch 48: 56.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.0942
# 	Train R2 Score: : 0.9592
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0131
# 	Val Target Regression Loss: : 0.0184
# 	Val Source R2 Score: : 0.9598
# 	Val Target R2 Score: : 0.9454
# 	Val Source Mve Loss: : -0.0485
# 	Val Target Mve Loss: : 0.0288
# 	Val Source Nll Loss: : 2174.1023
# 	Val Target Nll Loss: : 3570.3803
# Saving Model... Done.
#
# Epoch 49: 55.73s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0278
# 	Train Regression Loss: : 0.0130
# 	Train Mve Loss: : -0.1016
# 	Train R2 Score: : 0.9605
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0180
# 	Val Source R2 Score: : 0.9618
# 	Val Target R2 Score: : 0.9465
# 	Val Source Mve Loss: : -0.2508
# 	Val Target Mve Loss: : -0.2472
# 	Val Source Nll Loss: : -1.0430
# 	Val Target Nll Loss: : -0.8407
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
#
# Epoch 50: 43.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0280
# 	Train Regression Loss: : 0.0127
# 	Train Mve Loss: : -0.2432
# 	Train R2 Score: : 0.9615
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0127
# 	Val Target Regression Loss: : 0.0175
# 	Val Source R2 Score: : 0.9612
# 	Val Target R2 Score: : 0.9480
# 	Val Source Mve Loss: : -0.2230
# 	Val Target Mve Loss: : -0.2199
# 	Val Source Nll Loss: : 234.4382
# 	Val Target Nll Loss: : 231.7396
# Saving Model... Done.
#
# Epoch 51: 50.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0127
# 	Train Mve Loss: : -0.2252
# 	Train R2 Score: : 0.9616
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0180
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9464
# 	Val Source Mve Loss: : -0.1955
# 	Val Target Mve Loss: : -0.1307
# 	Val Source Nll Loss: : 304.2693
# 	Val Target Nll Loss: : 1194.3046
#
# Epoch 52: 62.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0125
# 	Train Mve Loss: : -0.1684
# 	Train R2 Score: : 0.9620
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0176
# 	Val Source R2 Score: : 0.9619
# 	Val Target R2 Score: : 0.9476
# 	Val Source Mve Loss: : -0.1202
# 	Val Target Mve Loss: : -0.0473
# 	Val Source Nll Loss: : 970.5860
# 	Val Target Nll Loss: : 1987.7501
#
# Epoch 53: 59.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0291
# 	Train Regression Loss: : 0.0126
# 	Train Mve Loss: : -0.1378
# 	Train R2 Score: : 0.9619
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0175
# 	Val Source R2 Score: : 0.9613
# 	Val Target R2 Score: : 0.9484
# 	Val Source Mve Loss: : -0.1138
# 	Val Target Mve Loss: : -0.0471
# 	Val Source Nll Loss: : 1010.7619
# 	Val Target Nll Loss: : 1929.7627
# Saving Model... Done.
#
# Epoch 54: 50.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1931
# 	Train R2 Score: : 0.9623
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9618
# 	Val Target R2 Score: : 0.9487
# 	Val Source Mve Loss: : -0.1839
# 	Val Target Mve Loss: : -0.1572
# 	Val Source Nll Loss: : 353.9121
# 	Val Target Nll Loss: : 667.5194
# Saving Model... Done.
#
# Epoch 55: 46.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0125
# 	Train Mve Loss: : -0.1866
# 	Train R2 Score: : 0.9621
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0174
# 	Val Source R2 Score: : 0.9616
# 	Val Target R2 Score: : 0.9483
# 	Val Source Mve Loss: : -0.1854
# 	Val Target Mve Loss: : -0.1581
# 	Val Source Nll Loss: : 272.4296
# 	Val Target Nll Loss: : 592.7260
#
# Epoch 56: 47.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0271
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1860
# 	Train R2 Score: : 0.9623
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9619
# 	Val Target R2 Score: : 0.9475
# 	Val Source Mve Loss: : -0.1901
# 	Val Target Mve Loss: : -0.1708
# 	Val Source Nll Loss: : 344.0823
# 	Val Target Nll Loss: : 526.9553
#
# Epoch 57: 55.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0273
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.2000
# 	Train R2 Score: : 0.9624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0130
# 	Val Target Regression Loss: : 0.0176
# 	Val Source R2 Score: : 0.9596
# 	Val Target R2 Score: : 0.9476
# 	Val Source Mve Loss: : -0.1916
# 	Val Target Mve Loss: : -0.1882
# 	Val Source Nll Loss: : 529.5437
# 	Val Target Nll Loss: : 471.7828
#
# Epoch 58: 59.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1939
# 	Train R2 Score: : 0.9625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0176
# 	Val Source R2 Score: : 0.9615
# 	Val Target R2 Score: : 0.9476
# 	Val Source Mve Loss: : -0.1743
# 	Val Target Mve Loss: : -0.1618
# 	Val Source Nll Loss: : 593.1750
# 	Val Target Nll Loss: : 672.8693
#
# Epoch 59: 47.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1720
# 	Train R2 Score: : 0.9623
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9471
# 	Val Source Mve Loss: : -0.1595
# 	Val Target Mve Loss: : -0.1368
# 	Val Source Nll Loss: : 606.5157
# 	Val Target Nll Loss: : 827.0352
# Generating Isomap...
# Epoch 60: 48.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0286
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1538
# 	Train R2 Score: : 0.9625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9485
# 	Val Source Mve Loss: : -0.1950
# 	Val Target Mve Loss: : -0.1780
# 	Val Source Nll Loss: : 272.9426
# 	Val Target Nll Loss: : 411.9500
#
# Epoch 61: 72.66s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0294
# 	Train Regression Loss: : 0.0125
# 	Train Mve Loss: : -0.1942
# 	Train R2 Score: : 0.9623
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0178
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9471
# 	Val Source Mve Loss: : -0.1746
# 	Val Target Mve Loss: : -0.1259
# 	Val Source Nll Loss: : 389.7971
# 	Val Target Nll Loss: : 1014.0356
#
# Epoch 62: 63.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0275
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1776
# 	Train R2 Score: : 0.9625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0176
# 	Val Source R2 Score: : 0.9613
# 	Val Target R2 Score: : 0.9466
# 	Val Source Mve Loss: : -0.1696
# 	Val Target Mve Loss: : -0.1036
# 	Val Source Nll Loss: : 335.1296
# 	Val Target Nll Loss: : 1244.7545
#
# Epoch 63: 67.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0280
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1919
# 	Train R2 Score: : 0.9624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0127
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9614
# 	Val Target R2 Score: : 0.9487
# 	Val Source Mve Loss: : -0.1813
# 	Val Target Mve Loss: : -0.1575
# 	Val Source Nll Loss: : 306.3580
# 	Val Target Nll Loss: : 545.3362
#
# Epoch 64: 49.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0286
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.1684
# 	Train R2 Score: : 0.9626
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0181
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9463
# 	Val Source Mve Loss: : -0.1373
# 	Val Target Mve Loss: : -0.0846
# 	Val Source Nll Loss: : 798.3429
# 	Val Target Nll Loss: : 1460.2770
#
# Epoch 65: 59.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1688
# 	Train R2 Score: : 0.9626
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0179
# 	Val Source R2 Score: : 0.9616
# 	Val Target R2 Score: : 0.9463
# 	Val Source Mve Loss: : -0.1776
# 	Val Target Mve Loss: : -0.1705
# 	Val Source Nll Loss: : 583.0654
# 	Val Target Nll Loss: : 557.2078
#
# Epoch 66: 60.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0283
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1789
# 	Train R2 Score: : 0.9624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0176
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9475
# 	Val Source Mve Loss: : -0.1679
# 	Val Target Mve Loss: : -0.1460
# 	Val Source Nll Loss: : 515.0212
# 	Val Target Nll Loss: : 723.9621
#
# Epoch 67: 47.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0287
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1735
# 	Train R2 Score: : 0.9623
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0175
# 	Val Source R2 Score: : 0.9621
# 	Val Target R2 Score: : 0.9479
# 	Val Source Mve Loss: : -0.1464
# 	Val Target Mve Loss: : -0.0885
# 	Val Source Nll Loss: : 622.1734
# 	Val Target Nll Loss: : 1367.2336
#
# Epoch 68: 51.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0280
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.1524
# 	Train R2 Score: : 0.9628
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9490
# 	Val Source Mve Loss: : -0.1816
# 	Val Target Mve Loss: : -0.1201
# 	Val Source Nll Loss: : 200.2966
# 	Val Target Nll Loss: : 1022.7537
# Saving Model... Done.
#
# Epoch 69: 64.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0285
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1702
# 	Train R2 Score: : 0.9624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9611
# 	Val Target R2 Score: : 0.9485
# 	Val Source Mve Loss: : -0.1992
# 	Val Target Mve Loss: : -0.1668
# 	Val Source Nll Loss: : 117.6614
# 	Val Target Nll Loss: : 510.9089
#
# Epoch 70: 59.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0272
# 	Train Regression Loss: : 0.0125
# 	Train Mve Loss: : -0.1993
# 	Train R2 Score: : 0.9622
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9619
# 	Val Target R2 Score: : 0.9487
# 	Val Source Mve Loss: : -0.1862
# 	Val Target Mve Loss: : -0.1340
# 	Val Source Nll Loss: : 167.1940
# 	Val Target Nll Loss: : 854.7828
#
# Epoch 71: 51.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0274
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1788
# 	Train R2 Score: : 0.9625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0131
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9596
# 	Val Target R2 Score: : 0.9488
# 	Val Source Mve Loss: : -0.2031
# 	Val Target Mve Loss: : -0.2008
# 	Val Source Nll Loss: : 234.7334
# 	Val Target Nll Loss: : 168.0498
#
# Epoch 72: 54.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.1822
# 	Train R2 Score: : 0.9625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9619
# 	Val Target R2 Score: : 0.9489
# 	Val Source Mve Loss: : -0.1552
# 	Val Target Mve Loss: : -0.0995
# 	Val Source Nll Loss: : 577.5164
# 	Val Target Nll Loss: : 1291.1150
#
# Epoch 73: 59.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.1724
# 	Train R2 Score: : 0.9628
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0174
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9483
# 	Val Source Mve Loss: : -0.1649
# 	Val Target Mve Loss: : -0.1138
# 	Val Source Nll Loss: : 378.5451
# 	Val Target Nll Loss: : 1026.7471
#
# Epoch 74: 52.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0290
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.2180
# 	Train R2 Score: : 0.9626
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9485
# 	Val Source Mve Loss: : -0.2198
# 	Val Target Mve Loss: : -0.2137
# 	Val Source Nll Loss: : 124.8299
# 	Val Target Nll Loss: : 108.6076
#
# Epoch 75: 49.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2221
# 	Train R2 Score: : 0.9630
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9615
# 	Val Target R2 Score: : 0.9490
# 	Val Source Mve Loss: : -0.2174
# 	Val Target Mve Loss: : -0.2077
# 	Val Source Nll Loss: : 125.6476
# 	Val Target Nll Loss: : 160.4630
# Saving Model... Done.
#
# Epoch 76: 54.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0289
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2175
# 	Train R2 Score: : 0.9628
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9620
# 	Val Target R2 Score: : 0.9482
# 	Val Source Mve Loss: : -0.2129
# 	Val Target Mve Loss: : -0.1991
# 	Val Source Nll Loss: : 147.4280
# 	Val Target Nll Loss: : 239.6722
#
# Epoch 77: 51.13s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0278
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2133
# 	Train R2 Score: : 0.9631
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0180
# 	Val Source R2 Score: : 0.9618
# 	Val Target R2 Score: : 0.9462
# 	Val Source Mve Loss: : -0.2046
# 	Val Target Mve Loss: : -0.1932
# 	Val Source Nll Loss: : 211.2353
# 	Val Target Nll Loss: : 247.3998
#
# Epoch 78: 53.91s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0283
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.2067
# 	Train R2 Score: : 0.9629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9622
# 	Val Target R2 Score: : 0.9493
# 	Val Source Mve Loss: : -0.2018
# 	Val Target Mve Loss: : -0.1830
# 	Val Source Nll Loss: : 220.0079
# 	Val Target Nll Loss: : 389.1296
# Saving Model... Done.
#
# Epoch 79: 52.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0288
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2036
# 	Train R2 Score: : 0.9629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9629
# 	Val Target R2 Score: : 0.9486
# 	Val Source Mve Loss: : -0.1942
# 	Val Target Mve Loss: : -0.1719
# 	Val Source Nll Loss: : 245.5765
# 	Val Target Nll Loss: : 466.8466
# Generating Isomap...
# Epoch 80: 46.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0286
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.1908
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0168
# 	Val Source R2 Score: : 0.9617
# 	Val Target R2 Score: : 0.9498
# 	Val Source Mve Loss: : -0.1760
# 	Val Target Mve Loss: : -0.1481
# 	Val Source Nll Loss: : 396.0761
# 	Val Target Nll Loss: : 710.8480
# Saving Model... Done.
#
# Epoch 81: 55.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0290
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.1764
# 	Train R2 Score: : 0.9633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0166
# 	Val Source R2 Score: : 0.9622
# 	Val Target R2 Score: : 0.9509
# 	Val Source Mve Loss: : -0.1548
# 	Val Target Mve Loss: : -0.1171
# 	Val Source Nll Loss: : 592.2097
# 	Val Target Nll Loss: : 1047.7975
# Saving Model... Done.
#
# Epoch 82: 55.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0288
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.1581
# 	Train R2 Score: : 0.9633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9631
# 	Val Target R2 Score: : 0.9492
# 	Val Source Mve Loss: : -0.1572
# 	Val Target Mve Loss: : -0.0912
# 	Val Source Nll Loss: : 520.6119
# 	Val Target Nll Loss: : 1396.3535
#
# Epoch 83: 53.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.1555
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0174
# 	Val Source R2 Score: : 0.9621
# 	Val Target R2 Score: : 0.9476
# 	Val Source Mve Loss: : -0.1432
# 	Val Target Mve Loss: : -0.0488
# 	Val Source Nll Loss: : 632.5945
# 	Val Target Nll Loss: : 1972.2151
#
# Epoch 84: 49.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0286
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.1465
# 	Train R2 Score: : 0.9630
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0170
# 	Val Source R2 Score: : 0.9626
# 	Val Target R2 Score: : 0.9494
# 	Val Source Mve Loss: : -0.1387
# 	Val Target Mve Loss: : -0.0870
# 	Val Source Nll Loss: : 699.8636
# 	Val Target Nll Loss: : 1363.6505
#
# Epoch 85: 53.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0278
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.1419
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0174
# 	Val Source R2 Score: : 0.9621
# 	Val Target R2 Score: : 0.9488
# 	Val Source Mve Loss: : -0.1198
# 	Val Target Mve Loss: : -0.0125
# 	Val Source Nll Loss: : 860.7675
# 	Val Target Nll Loss: : 2400.2596
#
# Epoch 86: 52.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0291
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.1419
# 	Train R2 Score: : 0.9629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9618
# 	Val Target R2 Score: : 0.9489
# 	Val Source Mve Loss: : -0.1343
# 	Val Target Mve Loss: : -0.0247
# 	Val Source Nll Loss: : 653.3484
# 	Val Target Nll Loss: : 2221.3479
#
# Epoch 87: 64.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0278
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.1750
# 	Train R2 Score: : 0.9630
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9622
# 	Val Target R2 Score: : 0.9494
# 	Val Source Mve Loss: : -0.2015
# 	Val Target Mve Loss: : -0.1957
# 	Val Source Nll Loss: : 334.4053
# 	Val Target Nll Loss: : 308.2949
#
# Epoch 88: 67.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0285
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.2087
# 	Train R2 Score: : 0.9628
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9491
# 	Val Source Mve Loss: : -0.1992
# 	Val Target Mve Loss: : -0.1869
# 	Val Source Nll Loss: : 313.5490
# 	Val Target Nll Loss: : 373.4823
#
# Epoch 89: 65.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0287
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.1986
# 	Train R2 Score: : 0.9629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0168
# 	Val Source R2 Score: : 0.9617
# 	Val Target R2 Score: : 0.9499
# 	Val Source Mve Loss: : -0.1944
# 	Val Target Mve Loss: : -0.1774
# 	Val Source Nll Loss: : 328.6939
# 	Val Target Nll Loss: : 473.5148
#
# Epoch 90: 64.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.1917
# 	Train R2 Score: : 0.9629
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9498
# 	Val Source Mve Loss: : -0.1822
# 	Val Target Mve Loss: : -0.1664
# 	Val Source Nll Loss: : 428.9730
# 	Val Target Nll Loss: : 532.4099
#
# Epoch 91: 47.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0285
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2214
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9490
# 	Val Source Mve Loss: : -0.2196
# 	Val Target Mve Loss: : -0.2130
# 	Val Source Nll Loss: : 107.1473
# 	Val Target Nll Loss: : 90.3341
#
# Epoch 92: 55.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0277
# 	Train Regression Loss: : 0.0122
# 	Train Mve Loss: : -0.2204
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0127
# 	Val Target Regression Loss: : 0.0170
# 	Val Source R2 Score: : 0.9612
# 	Val Target R2 Score: : 0.9495
# 	Val Source Mve Loss: : -0.2140
# 	Val Target Mve Loss: : -0.2026
# 	Val Source Nll Loss: : 88.0296
# 	Val Target Nll Loss: : 148.4624
#
# Epoch 93: 64.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0277
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.2168
# 	Train R2 Score: : 0.9633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9610
# 	Val Target R2 Score: : 0.9470
# 	Val Source Mve Loss: : -0.2184
# 	Val Target Mve Loss: : -0.1877
# 	Val Source Nll Loss: : 80.2902
# 	Val Target Nll Loss: : 431.1274
#
# Epoch 94: 67.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0269
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.2163
# 	Train R2 Score: : 0.9634
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0170
# 	Val Source R2 Score: : 0.9628
# 	Val Target R2 Score: : 0.9494
# 	Val Source Mve Loss: : -0.2134
# 	Val Target Mve Loss: : -0.2017
# 	Val Source Nll Loss: : 104.1509
# 	Val Target Nll Loss: : 155.9927
#
# Epoch 95: 70.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0281
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.2076
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0174
# 	Val Source R2 Score: : 0.9627
# 	Val Target R2 Score: : 0.9480
# 	Val Source Mve Loss: : -0.1937
# 	Val Target Mve Loss: : -0.1437
# 	Val Source Nll Loss: : 196.1556
# 	Val Target Nll Loss: : 832.0565
#
# Epoch 96: 56.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0283
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.2068
# 	Train R2 Score: : 0.9632
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0170
# 	Val Source R2 Score: : 0.9632
# 	Val Target R2 Score: : 0.9495
# 	Val Source Mve Loss: : -0.2045
# 	Val Target Mve Loss: : -0.1712
# 	Val Source Nll Loss: : 72.4979
# 	Val Target Nll Loss: : 454.3325
#
# Epoch 97: 63.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0280
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1974
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# ...
# 	Val Source Mve Loss: : -0.1874
# 	Val Target Mve Loss: : -0.1250
# 	Val Source Nll Loss: : 172.4448
# 	Val Target Nll Loss: : 977.2395
#
# Epoch 136: 45.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0285
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1886
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0168
# 	Val Source R2 Score: : 0.9631
# 	Val Target R2 Score: : 0.9500
# 	Val Source Mve Loss: : -0.1889
# 	Val Target Mve Loss: : -0.1140
# 	Val Source Nll Loss: : 149.0855
# 	Val Target Nll Loss: : 1149.3268
#
# Epoch 137: 49.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0280
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.1906
# 	Train R2 Score: : 0.9638
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9628
# 	Val Target R2 Score: : 0.9488
# 	Val Source Mve Loss: : -0.1885
# 	Val Target Mve Loss: : -0.1332
# 	Val Source Nll Loss: : 155.2675
# 	Val Target Nll Loss: : 855.6945
#
# Epoch 138: 52.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1894
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9631
# 	Val Target R2 Score: : 0.9493
# 	Val Source Mve Loss: : -0.1868
# 	Val Target Mve Loss: : -0.1277
# 	Val Source Nll Loss: : 169.2134
# 	Val Target Nll Loss: : 933.5970
#
# Epoch 139: 80.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1875
# 	Train R2 Score: : 0.9635
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9635
# 	Val Target R2 Score: : 0.9498
# 	Val Source Mve Loss: : -0.1833
# 	Val Target Mve Loss: : -0.1267
# 	Val Source Nll Loss: : 223.1748
# 	Val Target Nll Loss: : 939.0986
# Generating Isomap...
# Epoch 140: 60.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0276
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1870
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0173
# 	Val Source R2 Score: : 0.9624
# 	Val Target R2 Score: : 0.9390
# 	Val Source Mve Loss: : -0.1853
# 	Val Target Mve Loss: : -0.1290
# 	Val Source Nll Loss: : 162.8767
# 	Val Target Nll Loss: : 874.8400
#
# Epoch 141: 61.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0278
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.1892
# 	Train R2 Score: : 0.9638
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0174
# 	Val Source R2 Score: : 0.9630
# 	Val Target R2 Score: : 0.9467
# 	Val Source Mve Loss: : -0.1847
# 	Val Target Mve Loss: : -0.1163
# 	Val Source Nll Loss: : 198.1162
# 	Val Target Nll Loss: : 1073.4396
#
# Epoch 142: 53.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1863
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9626
# 	Val Target R2 Score: : 0.9494
# 	Val Source Mve Loss: : -0.1839
# 	Val Target Mve Loss: : -0.0979
# 	Val Source Nll Loss: : 179.3538
# 	Val Target Nll Loss: : 1372.7951
#
# Epoch 143: 47.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0278
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.1859
# 	Train R2 Score: : 0.9638
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0172
# 	Val Source R2 Score: : 0.9632
# 	Val Target R2 Score: : 0.9489
# 	Val Source Mve Loss: : -0.1835
# 	Val Target Mve Loss: : -0.1201
# 	Val Source Nll Loss: : 196.4916
# 	Val Target Nll Loss: : 1002.5615
#
# Epoch 144: 68.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1826
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9621
# 	Val Target R2 Score: : 0.9490
# 	Val Source Mve Loss: : -0.1798
# 	Val Target Mve Loss: : -0.0879
# 	Val Source Nll Loss: : 202.0324
# 	Val Target Nll Loss: : 1474.9528
#
# Epoch 145: 72.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0287
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1789
# 	Train R2 Score: : 0.9635
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9631
# 	Val Target R2 Score: : 0.9499
# 	Val Source Mve Loss: : -0.1752
# 	Val Target Mve Loss: : -0.0887
# 	Val Source Nll Loss: : 251.6933
# 	Val Target Nll Loss: : 1423.3317
#
# Epoch 146: 56.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1818
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0119
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9634
# 	Val Target R2 Score: : 0.9479
# 	Val Source Mve Loss: : -0.1823
# 	Val Target Mve Loss: : -0.1131
# 	Val Source Nll Loss: : 196.5883
# 	Val Target Nll Loss: : 1103.3972
#
# Epoch 147: 56.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0278
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1840
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0167
# 	Val Source R2 Score: : 0.9632
# 	Val Target R2 Score: : 0.9501
# 	Val Source Mve Loss: : -0.1798
# 	Val Target Mve Loss: : -0.1123
# 	Val Source Nll Loss: : 223.0424
# 	Val Target Nll Loss: : 1110.2863
#
# Epoch 148: 65.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0280
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1802
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0168
# 	Val Source R2 Score: : 0.9629
# 	Val Target R2 Score: : 0.9500
# 	Val Source Mve Loss: : -0.1768
# 	Val Target Mve Loss: : -0.1037
# 	Val Source Nll Loss: : 236.6954
# 	Val Target Nll Loss: : 1199.3006
#
# Epoch 149: 46.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0276
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1802
# 	Train R2 Score: : 0.9638
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0167
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9501
# 	Val Source Mve Loss: : -0.1756
# 	Val Target Mve Loss: : -0.0985
# 	Val Source Nll Loss: : 227.9284
# 	Val Target Nll Loss: : 1274.4169
#
# Epoch 150: 54.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0274
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1775
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0165
# 	Val Source R2 Score: : 0.9623
# 	Val Target R2 Score: : 0.9506
# 	Val Source Mve Loss: : -0.1761
# 	Val Target Mve Loss: : -0.0794
# 	Val Source Nll Loss: : 234.5504
# 	Val Target Nll Loss: : 1582.8538
#
# Epoch 151: 54.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0277
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1792
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9631
# 	Val Target R2 Score: : 0.9492
# 	Val Source Mve Loss: : -0.1781
# 	Val Target Mve Loss: : -0.1135
# 	Val Source Nll Loss: : 213.3212
# 	Val Target Nll Loss: : 1043.9013
#
# Epoch 152: 64.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1808
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0168
# 	Val Source R2 Score: : 0.9633
# 	Val Target R2 Score: : 0.9499
# 	Val Source Mve Loss: : -0.1765
# 	Val Target Mve Loss: : -0.1128
# 	Val Source Nll Loss: : 253.2055
# 	Val Target Nll Loss: : 1077.5786
#
# Epoch 153: 52.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0287
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.1806
# 	Train R2 Score: : 0.9633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0170
# 	Val Source R2 Score: : 0.9632
# 	Val Target R2 Score: : 0.9497
# 	Val Source Mve Loss: : -0.1796
# 	Val Target Mve Loss: : -0.0959
# 	Val Source Nll Loss: : 212.1857
# 	Val Target Nll Loss: : 1351.2137
#
# Epoch 154: 61.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0286
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1829
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0124
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9618
# 	Val Target R2 Score: : 0.9499
# 	Val Source Mve Loss: : -0.1773
# 	Val Target Mve Loss: : -0.1145
# 	Val Source Nll Loss: : 247.5355
# 	Val Target Nll Loss: : 1075.6649
#
# Epoch 155: 47.24s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0282
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1821
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0167
# 	Val Source R2 Score: : 0.9630
# 	Val Target R2 Score: : 0.9505
# 	Val Source Mve Loss: : -0.1787
# 	Val Target Mve Loss: : -0.1087
# 	Val Source Nll Loss: : 231.1734
# 	Val Target Nll Loss: : 1161.5855
#
# Epoch 156: 50.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0289
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1814
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0121
# 	Val Target Regression Loss: : 0.0168
# 	Val Source R2 Score: : 0.9629
# 	Val Target R2 Score: : 0.9501
# 	Val Source Mve Loss: : -0.1796
# 	Val Target Mve Loss: : -0.1059
# 	Val Source Nll Loss: : 215.5179
# 	Val Target Nll Loss: : 1210.7423
#
# Epoch 157: 58.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0277
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.1822
# 	Train R2 Score: : 0.9638
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0169
# 	Val Source R2 Score: : 0.9633
# 	Val Target R2 Score: : 0.9496
# 	Val Source Mve Loss: : -0.1838
# 	Val Target Mve Loss: : -0.1080
# 	Val Source Nll Loss: : 149.9471
# 	Val Target Nll Loss: : 1167.3112
#
# Epoch 158: 54.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0289
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.1822
# 	Train R2 Score: : 0.9637
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0122
# 	Val Target Regression Loss: : 0.0184
# 	Val Source R2 Score: : 0.9627
# 	Val Target R2 Score: : 0.9428
# 	Val Source Mve Loss: : -0.1793
# 	Val Target Mve Loss: : -0.0868
# 	Val Source Nll Loss: : 220.2377
# 	Val Target Nll Loss: : 1469.5886
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 50
#      47 da_weight = da_weight_function(curr_epoch)
#      49 # Train, backpropagate
# ---> 50 vals = train_loop_mve(source_train_dataloader,
#      51                       target_train_dataloader,
#      52                       model,
#      53                       regressor_loss_fn,
#      54                       da_loss_fn,
#      55                       optimizer,
#      56                       da_weight,
#      57                       beta)
#      59 # Test, validate metrics
#      60 vals_validate = test_loop_mve(source_val_dataloader,
#      61                               target_val_dataloader,
#      62                               model,
#      63                               regressor_loss_fn,
#      64                               beta)
#
# File ~/work/dauq/src/training/PaperMVE/train_utils.py:417, in train_loop_mve(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, optimizer, da_weight, beta_val)
#     414 domain_label = domain_label.cuda()
#     416 # Apply data to model and get predictions, embeddings, apply gradients
# --> 417 estimate_output, domain_output_source = model(X)
#     418 mean = estimate_output[:, 0]
#     419 variance = estimate_output[:, 1]
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/work/dauq/src/training/PaperMVE/train_utils.py:152, in NeuralNetworkMVE.forward(self, x)
#     149 def forward(self, x):
#     150     x = x.view(-1, 3, self.npix, self.npix)
# --> 152     features = self.feature(x)
#     153     features = features.view(-1, 32*5*5)
#     154     estimate = self.regressor(features)
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File /deepskieslab/agarwal/.conda/envs/neural/lib/python3.9/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = save_mod_name#"models/papermve_v3_aug22_1315_C_mve" # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['val_source_nll_loss'], label = "Source Val NLL Loss")
plt.plot(eps, stats['val_target_nll_loss'], label = "Target Val NLL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-2, 1)
# Out:
# (-2.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.0))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9687

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.969')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | NLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | NLL: 131.683')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9579

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.273')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
