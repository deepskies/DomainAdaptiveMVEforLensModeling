# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 13
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    if epoch < evolv_epoch:
        da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    else:
        da_weight = final_wt_da
    return da_weight

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    if epoch < evolv_epoch:
        beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    else:
        beta_val = beta_final
    return beta_val

# Initialize hyperparameters
learning_rate = 1e-5
n_epoch = 300

evolv_epoch = 250
init_wt_da = 1.4
final_wt_da = 1.0
beta_init = 1.0
beta_final = 0.0

# %%
from torch.optim.lr_scheduler import MultiStepLR
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = MultiStepLR(optimizer, milestones=[100, 200, 250, 275], gamma=0.5)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None #"models/papermve_v1_aug20_1940_A" # "models/start_code_test_2"
stats, model, optimizer, best_target_R2, best_mve_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/papermve_v3_aug22_1315_C"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")

stats['lr'] = []
for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            if ((curr_epoch > 250) and (stats['val_target_r2_score'][-1] > 0.95) and (stats['val_target_mve_loss'][-1] < -1)):
                print("Saving Model Minima...", end = ' ')
                m_name = save_mod_name + f"_{curr_epoch}"
                save_model(m_name, model, optimizer, stats)
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        scheduler.step()

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Epoch 0: 50.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.5151
# 	Train Regression Loss: : 3.3442
# 	Train Mve Loss: : 1.5562
# 	Train R2 Score: : -9.1701
#  Validation Statistics:
# 	Val Source Regression Loss: : 2.6911
# 	Val Target Regression Loss: : 2.5136
# 	Val Source R2 Score: : -7.2616
# 	Val Target R2 Score: : -6.4760
# 	Val Source Mve Loss: : 1.1986
# 	Val Target Mve Loss: : 1.1056
# Saving Model MVE... Done.
#
# Epoch 1: 51.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.5037
# 	Train Regression Loss: : 2.1519
# 	Train Mve Loss: : 0.9267
# 	Train R2 Score: : -5.5277
#  Validation Statistics:
# 	Val Source Regression Loss: : 1.6549
# 	Val Target Regression Loss: : 1.5127
# 	Val Source R2 Score: : -4.0642
# 	Val Target R2 Score: : -3.5269
# 	Val Source Mve Loss: : 0.6707
# 	Val Target Mve Loss: : 0.5962
# Saving Model MVE... Done.
#
# Epoch 2: 47.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.4915
# 	Train Regression Loss: : 1.3035
# 	Train Mve Loss: : 0.4942
# 	Train R2 Score: : -2.9541
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.9902
# 	Val Target Regression Loss: : 0.8730
# 	Val Source R2 Score: : -2.0250
# 	Val Target R2 Score: : -1.5915
# 	Val Source Mve Loss: : 0.3348
# 	Val Target Mve Loss: : 0.2725
# Saving Model MVE... Done.
#
# Epoch 3: 51.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.4705
# 	Train Regression Loss: : 0.7740
# 	Train Mve Loss: : 0.2256
# 	Train R2 Score: : -1.3455
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.5851
# 	Val Target Regression Loss: : 0.5201
# 	Val Source R2 Score: : -0.7969
# 	Val Target R2 Score: : -0.5488
# 	Val Source Mve Loss: : 0.1302
# 	Val Target Mve Loss: : 0.0939
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 4: 48.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.4421
# 	Train Regression Loss: : 0.4836
# 	Train Mve Loss: : 0.0781
# 	Train R2 Score: : -0.4625
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3891
# 	Val Target Regression Loss: : 0.3587
# 	Val Source R2 Score: : -0.1913
# 	Val Target R2 Score: : -0.0644
# 	Val Source Mve Loss: : 0.0299
# 	Val Target Mve Loss: : 0.0115
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 5: 48.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.4038
# 	Train Regression Loss: : 0.3482
# 	Train Mve Loss: : 0.0094
# 	Train R2 Score: : -0.0532
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3042
# 	Val Target Regression Loss: : 0.3010
# 	Val Source R2 Score: : 0.0734
# 	Val Target R2 Score: : 0.1023
# 	Val Source Mve Loss: : -0.0134
# 	Val Target Mve Loss: : -0.0180
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 6: 50.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.3626
# 	Train Regression Loss: : 0.2892
# 	Train Mve Loss: : -0.0214
# 	Train R2 Score: : 0.1262
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2673
# 	Val Target Regression Loss: : 0.2864
# 	Val Source R2 Score: : 0.1836
# 	Val Target R2 Score: : 0.1551
# 	Val Source Mve Loss: : -0.0324
# 	Val Target Mve Loss: : -0.0255
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 7: 50.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.3239
# 	Train Regression Loss: : 0.2581
# 	Train Mve Loss: : -0.0377
# 	Train R2 Score: : 0.2206
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2402
# 	Val Target Regression Loss: : 0.2717
# 	Val Source R2 Score: : 0.2679
# 	Val Target R2 Score: : 0.1954
# 	Val Source Mve Loss: : -0.0476
# 	Val Target Mve Loss: : -0.0324
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 8: 49.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2875
# 	Train Regression Loss: : 0.2300
# 	Train Mve Loss: : -0.0533
# 	Train R2 Score: : 0.3064
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2117
# 	Val Target Regression Loss: : 0.2511
# 	Val Source R2 Score: : 0.3548
# 	Val Target R2 Score: : 0.2561
# 	Val Source Mve Loss: : -0.0628
# 	Val Target Mve Loss: : -0.0415
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 9: 48.54s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2522
# 	Train Regression Loss: : 0.1988
# 	Train Mve Loss: : -0.0696
# 	Train R2 Score: : 0.3997
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1804
# 	Val Target Regression Loss: : 0.2234
# 	Val Source R2 Score: : 0.4510
# 	Val Target R2 Score: : 0.3354
# 	Val Source Mve Loss: : -0.0779
# 	Val Target Mve Loss: : -0.0505
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 10: 48.24s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2191
# 	Train Regression Loss: : 0.1652
# 	Train Mve Loss: : -0.0835
# 	Train R2 Score: : 0.5008
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1478
# 	Val Target Regression Loss: : 0.1925
# 	Val Source R2 Score: : 0.5471
# 	Val Target R2 Score: : 0.4281
# 	Val Source Mve Loss: : -0.0880
# 	Val Target Mve Loss: : -0.0527
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 11: 49.20s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1864
# 	Train Regression Loss: : 0.1344
# 	Train Mve Loss: : -0.0893
# 	Train R2 Score: : 0.5945
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1209
# 	Val Target Regression Loss: : 0.1657
# 	Val Source R2 Score: : 0.6272
# 	Val Target R2 Score: : 0.5059
# 	Val Source Mve Loss: : -0.0886
# 	Val Target Mve Loss: : -0.0472
# Saving Model... Done.
#
# Epoch 12: 53.06s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1575
# 	Train Regression Loss: : 0.1111
# 	Train Mve Loss: : -0.0913
# 	Train R2 Score: : 0.6648
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1010
# 	Val Target Regression Loss: : 0.1430
# 	Val Source R2 Score: : 0.6911
# 	Val Target R2 Score: : 0.5766
# 	Val Source Mve Loss: : -0.0989
# 	Val Target Mve Loss: : -0.0670
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 13: 46.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1343
# 	Train Regression Loss: : 0.0946
# 	Train Mve Loss: : -0.0889
# 	Train R2 Score: : 0.7145
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0875
# 	Val Target Regression Loss: : 0.1256
# 	Val Source R2 Score: : 0.7318
# 	Val Target R2 Score: : 0.6282
# 	Val Source Mve Loss: : -0.0820
# 	Val Target Mve Loss: : -0.0435
# Saving Model... Done.
#
# Epoch 14: 47.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1154
# 	Train Regression Loss: : 0.0808
# 	Train Mve Loss: : -0.0844
# 	Train R2 Score: : 0.7560
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0755
# 	Val Target Regression Loss: : 0.1079
# 	Val Source R2 Score: : 0.7703
# 	Val Target R2 Score: : 0.6789
# 	Val Source Mve Loss: : -0.0782
# 	Val Target Mve Loss: : -0.0431
# Saving Model... Done.
#
# Epoch 15: 51.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1004
# 	Train Regression Loss: : 0.0705
# 	Train Mve Loss: : -0.0867
# 	Train R2 Score: : 0.7869
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0671
# 	Val Target Regression Loss: : 0.0956
# 	Val Source R2 Score: : 0.7949
# 	Val Target R2 Score: : 0.7172
# 	Val Source Mve Loss: : -0.0746
# 	Val Target Mve Loss: : -0.0444
# Saving Model... Done.
#
# Epoch 16: 51.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0880
# 	Train Regression Loss: : 0.0623
# 	Train Mve Loss: : -0.0856
# 	Train R2 Score: : 0.8115
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0588
# 	Val Target Regression Loss: : 0.0858
# 	Val Source R2 Score: : 0.8204
# 	Val Target R2 Score: : 0.7436
# 	Val Source Mve Loss: : -0.1064
# 	Val Target Mve Loss: : -0.0791
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 17: 47.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0793
# 	Train Regression Loss: : 0.0555
# 	Train Mve Loss: : -0.0797
# 	Train R2 Score: : 0.8322
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0536
# 	Val Target Regression Loss: : 0.0767
# 	Val Source R2 Score: : 0.8361
# 	Val Target R2 Score: : 0.7728
# 	Val Source Mve Loss: : -0.0735
# 	Val Target Mve Loss: : -0.0449
# Saving Model... Done.
#
# Epoch 18: 44.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0716
# 	Train Regression Loss: : 0.0498
# 	Train Mve Loss: : -0.0739
# 	Train R2 Score: : 0.8494
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0474
# 	Val Target Regression Loss: : 0.0696
# 	Val Source R2 Score: : 0.8550
# 	Val Target R2 Score: : 0.7929
# 	Val Source Mve Loss: : -0.0647
# 	Val Target Mve Loss: : -0.0347
# Saving Model... Done.
#
# Epoch 19: 48.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0653
# 	Train Regression Loss: : 0.0447
# 	Train Mve Loss: : -0.0730
# 	Train R2 Score: : 0.8650
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0438
# 	Val Target Regression Loss: : 0.0626
# 	Val Source R2 Score: : 0.8637
# 	Val Target R2 Score: : 0.8146
# 	Val Source Mve Loss: : -0.0639
# 	Val Target Mve Loss: : -0.0350
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 20: 53.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0594
# 	Train Regression Loss: : 0.0403
# 	Train Mve Loss: : -0.0843
# 	Train R2 Score: : 0.8781
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0392
# 	Val Target Regression Loss: : 0.0580
# 	Val Source R2 Score: : 0.8799
# 	Val Target R2 Score: : 0.8275
# 	Val Source Mve Loss: : -0.0695
# 	Val Target Mve Loss: : -0.0379
# Saving Model... Done.
#
# Epoch 21: 46.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0564
# 	Train Regression Loss: : 0.0374
# 	Train Mve Loss: : -0.1045
# 	Train R2 Score: : 0.8869
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0372
# 	Val Target Regression Loss: : 0.0552
# 	Val Source R2 Score: : 0.8860
# 	Val Target R2 Score: : 0.8365
# 	Val Source Mve Loss: : -0.1125
# 	Val Target Mve Loss: : -0.0848
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 22: 47.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0538
# 	Train Regression Loss: : 0.0358
# 	Train Mve Loss: : -0.0896
# 	Train R2 Score: : 0.8916
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0349
# 	Val Target Regression Loss: : 0.0519
# 	Val Source R2 Score: : 0.8928
# 	Val Target R2 Score: : 0.8458
# 	Val Source Mve Loss: : -0.0813
# 	Val Target Mve Loss: : -0.0503
# Saving Model... Done.
#
# Epoch 23: 49.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0522
# 	Train Regression Loss: : 0.0340
# 	Train Mve Loss: : -0.0804
# 	Train R2 Score: : 0.8971
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0336
# 	Val Target Regression Loss: : 0.0491
# 	Val Source R2 Score: : 0.8981
# 	Val Target R2 Score: : 0.8537
# 	Val Source Mve Loss: : -0.0643
# 	Val Target Mve Loss: : -0.0316
# Saving Model... Done.
#
# Epoch 24: 50.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0512
# 	Train Regression Loss: : 0.0322
# 	Train Mve Loss: : -0.0718
# 	Train R2 Score: : 0.9024
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0319
# 	Val Target Regression Loss: : 0.0465
# 	Val Source R2 Score: : 0.9021
# 	Val Target R2 Score: : 0.8612
# 	Val Source Mve Loss: : -0.0728
# 	Val Target Mve Loss: : -0.0423
# Saving Model... Done.
#
# Epoch 25: 48.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0472
# 	Train Regression Loss: : 0.0307
# 	Train Mve Loss: : -0.0697
# 	Train R2 Score: : 0.9072
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0299
# 	Val Target Regression Loss: : 0.0436
# 	Val Source R2 Score: : 0.9086
# 	Val Target R2 Score: : 0.8697
# 	Val Source Mve Loss: : -0.0719
# 	Val Target Mve Loss: : -0.0417
# Saving Model... Done.
#
# Epoch 26: 52.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0467
# 	Train Regression Loss: : 0.0291
# 	Train Mve Loss: : -0.0872
# 	Train R2 Score: : 0.9118
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0291
# 	Val Target Regression Loss: : 0.0413
# 	Val Source R2 Score: : 0.9108
# 	Val Target R2 Score: : 0.8768
# 	Val Source Mve Loss: : -0.1114
# 	Val Target Mve Loss: : -0.0894
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 27: 51.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0441
# 	Train Regression Loss: : 0.0280
# 	Train Mve Loss: : -0.0874
# 	Train R2 Score: : 0.9153
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0285
# 	Val Target Regression Loss: : 0.0387
# 	Val Source R2 Score: : 0.9129
# 	Val Target R2 Score: : 0.8845
# 	Val Source Mve Loss: : -0.0814
# 	Val Target Mve Loss: : -0.0537
# Saving Model... Done.
#
# Epoch 28: 49.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0441
# 	Train Regression Loss: : 0.0274
# 	Train Mve Loss: : -0.1183
# 	Train R2 Score: : 0.9171
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0270
# 	Val Target Regression Loss: : 0.0382
# 	Val Source R2 Score: : 0.9174
# 	Val Target R2 Score: : 0.8864
# 	Val Source Mve Loss: : -0.1200
# 	Val Target Mve Loss: : -0.1009
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 29: 50.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0425
# 	Train Regression Loss: : 0.0267
# 	Train Mve Loss: : -0.1197
# 	Train R2 Score: : 0.9190
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0263
# 	Val Target Regression Loss: : 0.0361
# 	Val Source R2 Score: : 0.9193
# 	Val Target R2 Score: : 0.8928
# 	Val Source Mve Loss: : -0.1000
# 	Val Target Mve Loss: : -0.0787
# Saving Model... Done.
#
# Epoch 30: 48.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0420
# 	Train Regression Loss: : 0.0260
# 	Train Mve Loss: : -0.0906
# 	Train R2 Score: : 0.9212
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0259
# 	Val Target Regression Loss: : 0.0343
# 	Val Source R2 Score: : 0.9205
# 	Val Target R2 Score: : 0.8979
# 	Val Source Mve Loss: : -0.0717
# 	Val Target Mve Loss: : -0.0476
# Saving Model... Done.
#
# Epoch 31: 45.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0399
# 	Train Regression Loss: : 0.0255
# 	Train Mve Loss: : -0.0854
# 	Train R2 Score: : 0.9229
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0255
# 	Val Target Regression Loss: : 0.0342
# 	Val Source R2 Score: : 0.9223
# 	Val Target R2 Score: : 0.8979
# 	Val Source Mve Loss: : -0.1145
# 	Val Target Mve Loss: : -0.0975
# Saving Model... Done.
#
# Epoch 32: 52.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0405
# 	Train Regression Loss: : 0.0252
# 	Train Mve Loss: : -0.1098
# 	Train R2 Score: : 0.9236
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0252
# 	Val Target Regression Loss: : 0.0333
# 	Val Source R2 Score: : 0.9227
# 	Val Target R2 Score: : 0.9011
# 	Val Source Mve Loss: : -0.0992
# 	Val Target Mve Loss: : -0.0797
# Saving Model... Done.
#
# Epoch 33: 50.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0406
# 	Train Regression Loss: : 0.0244
# 	Train Mve Loss: : -0.0934
# 	Train R2 Score: : 0.9258
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0243
# 	Val Target Regression Loss: : 0.0327
# 	Val Source R2 Score: : 0.9251
# 	Val Target R2 Score: : 0.9029
# 	Val Source Mve Loss: : -0.0900
# 	Val Target Mve Loss: : -0.0678
# Saving Model... Done.
#
# Epoch 34: 48.45s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0404
# 	Train Regression Loss: : 0.0238
# 	Train Mve Loss: : -0.0898
# 	Train R2 Score: : 0.9279
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0235
# 	Val Target Regression Loss: : 0.0326
# 	Val Source R2 Score: : 0.9275
# 	Val Target R2 Score: : 0.9032
# 	Val Source Mve Loss: : -0.0992
# 	Val Target Mve Loss: : -0.0784
# Saving Model... Done.
#
# Epoch 35: 49.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0404
# 	Train Regression Loss: : 0.0232
# 	Train Mve Loss: : -0.0900
# 	Train R2 Score: : 0.9296
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0229
# 	Val Target Regression Loss: : 0.0312
# 	Val Source R2 Score: : 0.9293
# 	Val Target R2 Score: : 0.9071
# 	Val Source Mve Loss: : -0.0858
# 	Val Target Mve Loss: : -0.0631
# Saving Model... Done.
#
# Epoch 36: 50.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0392
# 	Train Regression Loss: : 0.0227
# 	Train Mve Loss: : -0.1194
# 	Train R2 Score: : 0.9313
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0227
# 	Val Target Regression Loss: : 0.0308
# 	Val Source R2 Score: : 0.9300
# 	Val Target R2 Score: : 0.9082
# 	Val Source Mve Loss: : -0.1106
# 	Val Target Mve Loss: : -0.0912
# Saving Model... Done.
#
# Epoch 37: 47.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0395
# 	Train Regression Loss: : 0.0222
# 	Train Mve Loss: : -0.0989
# 	Train R2 Score: : 0.9325
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0223
# 	Val Target Regression Loss: : 0.0295
# 	Val Source R2 Score: : 0.9321
# 	Val Target R2 Score: : 0.9121
# 	Val Source Mve Loss: : -0.0806
# 	Val Target Mve Loss: : -0.0534
# Saving Model... Done.
#
# Epoch 38: 49.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0382
# 	Train Regression Loss: : 0.0217
# 	Train Mve Loss: : -0.1237
# 	Train R2 Score: : 0.9343
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0216
# 	Val Target Regression Loss: : 0.0292
# 	Val Source R2 Score: : 0.9338
# 	Val Target R2 Score: : 0.9133
# 	Val Source Mve Loss: : -0.1189
# 	Val Target Mve Loss: : -0.1028
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 39: 49.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0388
# 	Train Regression Loss: : 0.0213
# 	Train Mve Loss: : -0.0931
# 	Train R2 Score: : 0.9353
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0220
# 	Val Target Regression Loss: : 0.0288
# 	Val Source R2 Score: : 0.9333
# 	Val Target R2 Score: : 0.9143
# 	Val Source Mve Loss: : -0.0903
# 	Val Target Mve Loss: : -0.0667
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 40: 52.85s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0385
# 	Train Regression Loss: : 0.0210
# 	Train Mve Loss: : -0.1319
# 	Train R2 Score: : 0.9362
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0213
# 	Val Target Regression Loss: : 0.0284
# 	Val Source R2 Score: : 0.9350
# 	Val Target R2 Score: : 0.9156
# 	Val Source Mve Loss: : -0.1133
# 	Val Target Mve Loss: : -0.0973
# Saving Model... Done.
#
# Epoch 41: 48.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0377
# 	Train Regression Loss: : 0.0208
# 	Train Mve Loss: : -0.0979
# 	Train R2 Score: : 0.9369
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0209
# 	Val Target Regression Loss: : 0.0275
# 	Val Source R2 Score: : 0.9358
# 	Val Target R2 Score: : 0.9182
# 	Val Source Mve Loss: : -0.0927
# 	Val Target Mve Loss: : -0.0687
# Saving Model... Done.
#
# Epoch 42: 47.09s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0377
# 	Train Regression Loss: : 0.0204
# 	Train Mve Loss: : -0.0946
# 	Train R2 Score: : 0.9382
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0204
# 	Val Target Regression Loss: : 0.0273
# 	Val Source R2 Score: : 0.9369
# 	Val Target R2 Score: : 0.9187
# 	Val Source Mve Loss: : -0.0898
# 	Val Target Mve Loss: : -0.0637
# Saving Model... Done.
#
# Epoch 43: 47.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0366
# 	Train Regression Loss: : 0.0201
# 	Train Mve Loss: : -0.0956
# 	Train R2 Score: : 0.9392
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0199
# 	Val Target Regression Loss: : 0.0267
# 	Val Source R2 Score: : 0.9388
# 	Val Target R2 Score: : 0.9208
# 	Val Source Mve Loss: : -0.0815
# 	Val Target Mve Loss: : -0.0559
# Saving Model... Done.
#
# Epoch 44: 49.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0363
# 	Train Regression Loss: : 0.0197
# 	Train Mve Loss: : -0.0904
# 	Train R2 Score: : 0.9405
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0203
# 	Val Target Regression Loss: : 0.0259
# 	Val Source R2 Score: : 0.9375
# 	Val Target R2 Score: : 0.9229
# 	Val Source Mve Loss: : -0.0878
# 	Val Target Mve Loss: : -0.0624
# Saving Model... Done.
#
# Epoch 45: 50.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0374
# 	Train Regression Loss: : 0.0194
# 	Train Mve Loss: : -0.0859
# 	Train R2 Score: : 0.9414
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0193
# 	Val Target Regression Loss: : 0.0258
# 	Val Source R2 Score: : 0.9407
# 	Val Target R2 Score: : 0.9233
# 	Val Source Mve Loss: : -0.0799
# 	Val Target Mve Loss: : -0.0544
# Saving Model... Done.
#
# Epoch 46: 47.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0362
# 	Train Regression Loss: : 0.0191
# 	Train Mve Loss: : -0.1041
# 	Train R2 Score: : 0.9422
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0189
# 	Val Target Regression Loss: : 0.0255
# 	Val Source R2 Score: : 0.9420
# 	Val Target R2 Score: : 0.9232
# 	Val Source Mve Loss: : -0.0901
# 	Val Target Mve Loss: : -0.0599
#
# Epoch 47: 50.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0364
# 	Train Regression Loss: : 0.0187
# 	Train Mve Loss: : -0.0902
# 	Train R2 Score: : 0.9434
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0189
# 	Val Target Regression Loss: : 0.0251
# 	Val Source R2 Score: : 0.9423
# 	Val Target R2 Score: : 0.9251
# 	Val Source Mve Loss: : -0.1391
# 	Val Target Mve Loss: : -0.1281
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 48: 49.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0354
# 	Train Regression Loss: : 0.0184
# 	Train Mve Loss: : -0.0904
# 	Train R2 Score: : 0.9441
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0182
# 	Val Target Regression Loss: : 0.0246
# 	Val Source R2 Score: : 0.9442
# 	Val Target R2 Score: : 0.9271
# 	Val Source Mve Loss: : -0.0702
# 	Val Target Mve Loss: : -0.0459
# Saving Model... Done.
#
# Epoch 49: 49.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0348
# 	Train Regression Loss: : 0.0180
# 	Train Mve Loss: : -0.1057
# 	Train R2 Score: : 0.9455
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0178
# 	Val Target Regression Loss: : 0.0241
# 	Val Source R2 Score: : 0.9455
# 	Val Target R2 Score: : 0.9284
# 	Val Source Mve Loss: : -0.1217
# 	Val Target Mve Loss: : -0.1079
# Saving Model... Done.
#
# Epoch 50: 48.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.0177
# 	Train Mve Loss: : -0.0848
# 	Train R2 Score: : 0.9463
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0178
# 	Val Target Regression Loss: : 0.0236
# 	Val Source R2 Score: : 0.9456
# 	Val Target R2 Score: : 0.9299
# 	Val Source Mve Loss: : -0.0902
# 	Val Target Mve Loss: : -0.0719
# Saving Model... Done.
#
# Epoch 51: 48.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0348
# 	Train Regression Loss: : 0.0173
# 	Train Mve Loss: : -0.0927
# 	Train R2 Score: : 0.9474
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0174
# 	Val Target Regression Loss: : 0.0237
# 	Val Source R2 Score: : 0.9464
# 	Val Target R2 Score: : 0.9296
# 	Val Source Mve Loss: : -0.0818
# 	Val Target Mve Loss: : -0.0536
#
# Epoch 52: 50.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0346
# 	Train Regression Loss: : 0.0172
# 	Train Mve Loss: : -0.1294
# 	Train R2 Score: : 0.9480
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0172
# 	Val Target Regression Loss: : 0.0233
# 	Val Source R2 Score: : 0.9476
# 	Val Target R2 Score: : 0.9304
# 	Val Source Mve Loss: : -0.0959
# 	Val Target Mve Loss: : -0.0748
# Saving Model... Done.
#
# Epoch 53: 49.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0354
# 	Train Regression Loss: : 0.0168
# 	Train Mve Loss: : -0.0978
# 	Train R2 Score: : 0.9489
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0168
# 	Val Target Regression Loss: : 0.0228
# 	Val Source R2 Score: : 0.9483
# 	Val Target R2 Score: : 0.9323
# 	Val Source Mve Loss: : -0.1016
# 	Val Target Mve Loss: : -0.0786
# Saving Model... Done.
#
# Epoch 54: 49.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0339
# 	Train Regression Loss: : 0.0165
# 	Train Mve Loss: : -0.1064
# 	Train R2 Score: : 0.9498
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0165
# 	Val Target Regression Loss: : 0.0225
# 	Val Source R2 Score: : 0.9491
# 	Val Target R2 Score: : 0.9330
# 	Val Source Mve Loss: : -0.0806
# 	Val Target Mve Loss: : -0.0594
# Saving Model... Done.
#
# Epoch 55: 49.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0337
# 	Train Regression Loss: : 0.0163
# 	Train Mve Loss: : -0.1052
# 	Train R2 Score: : 0.9505
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0165
# 	Val Target Regression Loss: : 0.0227
# 	Val Source R2 Score: : 0.9496
# 	Val Target R2 Score: : 0.9325
# 	Val Source Mve Loss: : -0.1111
# 	Val Target Mve Loss: : -0.0927
#
# Epoch 56: 49.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0326
# 	Train Regression Loss: : 0.0162
# 	Train Mve Loss: : -0.1230
# 	Train R2 Score: : 0.9510
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0164
# 	Val Target Regression Loss: : 0.0222
# 	Val Source R2 Score: : 0.9496
# 	Val Target R2 Score: : 0.9341
# 	Val Source Mve Loss: : -0.1649
# 	Val Target Mve Loss: : -0.1540
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 57: 52.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0329
# 	Train Regression Loss: : 0.0160
# 	Train Mve Loss: : -0.1612
# 	Train R2 Score: : 0.9513
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0164
# 	Val Target Regression Loss: : 0.0225
# 	Val Source R2 Score: : 0.9492
# 	Val Target R2 Score: : 0.9331
# 	Val Source Mve Loss: : -0.1167
# 	Val Target Mve Loss: : -0.0987
#
# Epoch 58: 47.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0341
# 	Train Regression Loss: : 0.0159
# 	Train Mve Loss: : -0.1104
# 	Train R2 Score: : 0.9518
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0163
# 	Val Target Regression Loss: : 0.0228
# 	Val Source R2 Score: : 0.9501
# 	Val Target R2 Score: : 0.9320
# 	Val Source Mve Loss: : -0.0848
# 	Val Target Mve Loss: : -0.0522
#
# Epoch 59: 46.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0331
# 	Train Regression Loss: : 0.0158
# 	Train Mve Loss: : -0.0897
# 	Train R2 Score: : 0.9520
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0160
# 	Val Target Regression Loss: : 0.0224
# 	Val Source R2 Score: : 0.9512
# 	Val Target R2 Score: : 0.9332
# 	Val Source Mve Loss: : -0.0870
# 	Val Target Mve Loss: : -0.0612
# Generating Isomap...
# Epoch 60: 51.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0338
# 	Train Regression Loss: : 0.0156
# 	Train Mve Loss: : -0.1092
# 	Train R2 Score: : 0.9529
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0156
# 	Val Target Regression Loss: : 0.0216
# 	Val Source R2 Score: : 0.9522
# 	Val Target R2 Score: : 0.9356
# 	Val Source Mve Loss: : -0.1136
# 	Val Target Mve Loss: : -0.0915
# Saving Model... Done.
#
# Epoch 61: 51.91s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0347
# 	Train Regression Loss: : 0.0155
# 	Train Mve Loss: : -0.1284
# 	Train R2 Score: : 0.9530
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0157
# 	Val Target Regression Loss: : 0.0222
# 	Val Source R2 Score: : 0.9519
# 	Val Target R2 Score: : 0.9338
# 	Val Source Mve Loss: : -0.1145
# 	Val Target Mve Loss: : -0.0951
#
# Epoch 62: 49.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0322
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.1484
# 	Train R2 Score: : 0.9534
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0156
# 	Val Target Regression Loss: : 0.0222
# 	Val Source R2 Score: : 0.9523
# 	Val Target R2 Score: : 0.9327
# 	Val Source Mve Loss: : -0.1844
# 	Val Target Mve Loss: : -0.1766
# Saving Model MVE... Done.
#
# Epoch 63: 50.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0329
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.1543
# 	Train R2 Score: : 0.9534
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0159
# 	Val Target Regression Loss: : 0.0225
# 	Val Source R2 Score: : 0.9518
# 	Val Target R2 Score: : 0.9337
# 	Val Source Mve Loss: : -0.1215
# 	Val Target Mve Loss: : -0.1074
#
# Epoch 64: 51.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0333
# 	Train Regression Loss: : 0.0153
# 	Train Mve Loss: : -0.1429
# 	Train R2 Score: : 0.9538
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0157
# 	Val Target Regression Loss: : 0.0230
# 	Val Source R2 Score: : 0.9521
# 	Val Target R2 Score: : 0.9316
# 	Val Source Mve Loss: : -0.1998
# 	Val Target Mve Loss: : -0.1929
# Saving Model MVE... Done.
#
# Epoch 65: 49.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0324
# 	Train Regression Loss: : 0.0153
# 	Train Mve Loss: : -0.1876
# 	Train R2 Score: : 0.9538
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0154
# 	Val Target Regression Loss: : 0.0226
# 	Val Source R2 Score: : 0.9532
# 	Val Target R2 Score: : 0.9318
# 	Val Source Mve Loss: : -0.1675
# 	Val Target Mve Loss: : -0.1602
#
# Epoch 66: 52.00s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0325
# 	Train Regression Loss: : 0.0152
# 	Train Mve Loss: : -0.1520
# 	Train R2 Score: : 0.9540
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0153
# 	Val Target Regression Loss: : 0.0218
# 	Val Source R2 Score: : 0.9528
# 	Val Target R2 Score: : 0.9349
# 	Val Source Mve Loss: : -0.1181
# 	Val Target Mve Loss: : -0.1011
#
# Epoch 67: 49.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0333
# 	Train Regression Loss: : 0.0151
# 	Train Mve Loss: : -0.1267
# 	Train R2 Score: : 0.9543
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0150
# 	Val Target Regression Loss: : 0.0218
# 	Val Source R2 Score: : 0.9539
# 	Val Target R2 Score: : 0.9351
# 	Val Source Mve Loss: : -0.1065
# 	Val Target Mve Loss: : -0.0866
#
# Epoch 68: 49.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0322
# 	Train Regression Loss: : 0.0149
# 	Train Mve Loss: : -0.1360
# 	Train R2 Score: : 0.9548
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0151
# 	Val Target Regression Loss: : 0.0216
# 	Val Source R2 Score: : 0.9536
# 	Val Target R2 Score: : 0.9356
# 	Val Source Mve Loss: : -0.1198
# 	Val Target Mve Loss: : -0.0986
# Saving Model... Done.
#
# Epoch 69: 48.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0330
# 	Train Regression Loss: : 0.0148
# 	Train Mve Loss: : -0.1222
# 	Train R2 Score: : 0.9551
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0150
# 	Val Target Regression Loss: : 0.0218
# 	Val Source R2 Score: : 0.9534
# 	Val Target R2 Score: : 0.9352
# 	Val Source Mve Loss: : -0.1089
# 	Val Target Mve Loss: : -0.0863
#
# Epoch 70: 48.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0314
# 	Train Regression Loss: : 0.0147
# 	Train Mve Loss: : -0.1070
# 	Train R2 Score: : 0.9553
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0148
# 	Val Target Regression Loss: : 0.0216
# 	Val Source R2 Score: : 0.9547
# 	Val Target R2 Score: : 0.9357
# 	Val Source Mve Loss: : -0.1074
# 	Val Target Mve Loss: : -0.0892
# Saving Model... Done.
#
# Epoch 71: 48.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0314
# 	Train Regression Loss: : 0.0146
# 	Train Mve Loss: : -0.1198
# 	Train R2 Score: : 0.9558
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0153
# 	Val Target Regression Loss: : 0.0213
# 	Val Source R2 Score: : 0.9528
# 	Val Target R2 Score: : 0.9368
# 	Val Source Mve Loss: : -0.1093
# 	Val Target Mve Loss: : -0.0830
# Saving Model... Done.
#
# Epoch 72: 53.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0321
# 	Train Regression Loss: : 0.0145
# 	Train Mve Loss: : -0.1305
# 	Train R2 Score: : 0.9561
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0148
# 	Val Target Regression Loss: : 0.0211
# 	Val Source R2 Score: : 0.9543
# 	Val Target R2 Score: : 0.9372
# 	Val Source Mve Loss: : -0.1846
# 	Val Target Mve Loss: : -0.1774
# Saving Model... Done.
#
# Epoch 73: 52.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0320
# 	Train Regression Loss: : 0.0144
# 	Train Mve Loss: : -0.1364
# 	Train R2 Score: : 0.9563
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0146
# 	Val Target Regression Loss: : 0.0211
# 	Val Source R2 Score: : 0.9553
# 	Val Target R2 Score: : 0.9372
# 	Val Source Mve Loss: : -0.1067
# 	Val Target Mve Loss: : -0.0796
#
# Epoch 74: 47.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0332
# 	Train Regression Loss: : 0.0143
# 	Train Mve Loss: : -0.1361
# 	Train R2 Score: : 0.9566
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0146
# 	Val Target Regression Loss: : 0.0214
# 	Val Source R2 Score: : 0.9553
# 	Val Target R2 Score: : 0.9363
# 	Val Source Mve Loss: : -0.0893
# 	Val Target Mve Loss: : -0.0513
#
# Epoch 75: 48.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0317
# 	Train Regression Loss: : 0.0142
# 	Train Mve Loss: : -0.1420
# 	Train R2 Score: : 0.9571
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0146
# 	Val Target Regression Loss: : 0.0212
# 	Val Source R2 Score: : 0.9549
# 	Val Target R2 Score: : 0.9372
# 	Val Source Mve Loss: : -0.1391
# 	Val Target Mve Loss: : -0.1271
#
# Epoch 76: 49.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0327
# 	Train Regression Loss: : 0.0142
# 	Train Mve Loss: : -0.1614
# 	Train R2 Score: : 0.9569
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0144
# 	Val Target Regression Loss: : 0.0206
# 	Val Source R2 Score: : 0.9557
# 	Val Target R2 Score: : 0.9382
# 	Val Source Mve Loss: : -0.1506
# 	Val Target Mve Loss: : -0.1320
# Saving Model... Done.
#
# Epoch 77: 52.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0315
# 	Train Regression Loss: : 0.0140
# 	Train Mve Loss: : -0.1557
# 	Train R2 Score: : 0.9574
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0147
# 	Val Target Regression Loss: : 0.0220
# 	Val Source R2 Score: : 0.9548
# 	Val Target R2 Score: : 0.9345
# 	Val Source Mve Loss: : -0.1401
# 	Val Target Mve Loss: : -0.1166
#
# Epoch 78: 50.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0322
# 	Train Regression Loss: : 0.0143
# 	Train Mve Loss: : -0.1811
# 	Train R2 Score: : 0.9568
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0144
# 	Val Target Regression Loss: : 0.0208
# 	Val Source R2 Score: : 0.9559
# 	Val Target R2 Score: : 0.9381
# 	Val Source Mve Loss: : -0.1970
# 	Val Target Mve Loss: : -0.1850
#
# Epoch 79: 51.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0325
# 	Train Regression Loss: : 0.0140
# 	Train Mve Loss: : -0.1631
# 	Train R2 Score: : 0.9574
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0141
# 	Val Target Regression Loss: : 0.0204
# 	Val Source R2 Score: : 0.9568
# 	Val Target R2 Score: : 0.9394
# 	Val Source Mve Loss: : -0.1394
# 	Val Target Mve Loss: : -0.1169
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 80: 53.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0323
# 	Train Regression Loss: : 0.0139
# 	Train Mve Loss: : -0.1532
# 	Train R2 Score: : 0.9578
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0206
# 	Val Source R2 Score: : 0.9558
# 	Val Target R2 Score: : 0.9381
# 	Val Source Mve Loss: : -0.1519
# 	Val Target Mve Loss: : -0.1364
#
# Epoch 81: 53.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0328
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.1601
# 	Train R2 Score: : 0.9581
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0140
# 	Val Target Regression Loss: : 0.0199
# 	Val Source R2 Score: : 0.9566
# 	Val Target R2 Score: : 0.9412
# 	Val Source Mve Loss: : -0.1799
# 	Val Target Mve Loss: : -0.1631
# Saving Model... Done.
#
# Epoch 82: 50.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0325
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.1718
# 	Train R2 Score: : 0.9584
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0203
# 	Val Source R2 Score: : 0.9579
# 	Val Target R2 Score: : 0.9396
# 	Val Source Mve Loss: : -0.1424
# 	Val Target Mve Loss: : -0.1164
#
# Epoch 83: 51.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0319
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.1627
# 	Train R2 Score: : 0.9585
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0139
# 	Val Target Regression Loss: : 0.0207
# 	Val Source R2 Score: : 0.9572
# 	Val Target R2 Score: : 0.9378
# 	Val Source Mve Loss: : -0.2329
# 	Val Target Mve Loss: : -0.2241
# Saving Model MVE... Done.
#
# Epoch 84: 51.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0325
# 	Train Regression Loss: : 0.0136
# 	Train Mve Loss: : -0.2096
# 	Train R2 Score: : 0.9588
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0202
# 	Val Source R2 Score: : 0.9580
# 	Val Target R2 Score: : 0.9399
# 	Val Source Mve Loss: : -0.1596
# 	Val Target Mve Loss: : -0.1538
#
# Epoch 85: 48.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0312
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.1479
# 	Train R2 Score: : 0.9592
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0138
# 	Val Target Regression Loss: : 0.0207
# 	Val Source R2 Score: : 0.9578
# 	Val Target R2 Score: : 0.9389
# 	Val Source Mve Loss: : -0.1173
# 	Val Target Mve Loss: : -0.0803
#
# Epoch 86: 49.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0328
# 	Train Regression Loss: : 0.0135
# 	Train Mve Loss: : -0.1855
# 	Train R2 Score: : 0.9591
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0200
# 	Val Source R2 Score: : 0.9579
# 	Val Target R2 Score: : 0.9398
# 	Val Source Mve Loss: : -0.2305
# 	Val Target Mve Loss: : -0.2198
#
# Epoch 87: 47.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0311
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.2196
# 	Train R2 Score: : 0.9593
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0195
# 	Val Source R2 Score: : 0.9585
# 	Val Target R2 Score: : 0.9418
# 	Val Source Mve Loss: : -0.2218
# 	Val Target Mve Loss: : -0.2133
# Saving Model... Done.
#
# Epoch 88: 52.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0320
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.1923
# 	Train R2 Score: : 0.9595
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0134
# 	Val Target Regression Loss: : 0.0198
# 	Val Source R2 Score: : 0.9589
# 	Val Target R2 Score: : 0.9411
# 	Val Source Mve Loss: : -0.2041
# 	Val Target Mve Loss: : -0.1942
#
# Epoch 89: 49.09s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0325
# 	Train Regression Loss: : 0.0133
# 	Train Mve Loss: : -0.1767
# 	Train R2 Score: : 0.9596
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0194
# 	Val Source R2 Score: : 0.9579
# 	Val Target R2 Score: : 0.9419
# 	Val Source Mve Loss: : -0.1453
# 	Val Target Mve Loss: : -0.0940
# Saving Model... Done.
#
# Epoch 90: 43.73s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0315
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.1379
# 	Train R2 Score: : 0.9595
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0196
# 	Val Source R2 Score: : 0.9583
# 	Val Target R2 Score: : 0.9416
# 	Val Source Mve Loss: : -0.1477
# 	Val Target Mve Loss: : -0.1179
#
# Epoch 91: 49.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0322
# 	Train Regression Loss: : 0.0131
# 	Train Mve Loss: : -0.1333
# 	Train R2 Score: : 0.9602
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0134
# 	Val Target Regression Loss: : 0.0200
# 	Val Source R2 Score: : 0.9588
# 	Val Target R2 Score: : 0.9401
# 	Val Source Mve Loss: : -0.1419
# 	Val Target Mve Loss: : -0.0983
#
# Epoch 92: 50.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0309
# 	Train Regression Loss: : 0.0132
# 	Train Mve Loss: : -0.1599
# 	Train R2 Score: : 0.9601
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0192
# 	Val Source R2 Score: : 0.9579
# 	Val Target R2 Score: : 0.9428
# 	Val Source Mve Loss: : -0.1555
# 	Val Target Mve Loss: : -0.0967
# Saving Model... Done.
#
# Epoch 93: 50.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0310
# 	Train Regression Loss: : 0.0131
# 	Train Mve Loss: : -0.1784
# 	Train R2 Score: : 0.9604
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0197
# 	Val Source R2 Score: : 0.9574
# 	Val Target R2 Score: : 0.9402
# 	Val Source Mve Loss: : -0.2310
# 	Val Target Mve Loss: : -0.2230
#
# Epoch 94: 48.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0300
# 	Train Regression Loss: : 0.0130
# 	Train Mve Loss: : -0.1921
# 	Train R2 Score: : 0.9605
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0132
# 	Val Target Regression Loss: : 0.0198
# 	Val Source R2 Score: : 0.9597
# 	Val Target R2 Score: : 0.9411
# 	Val Source Mve Loss: : -0.1839
# 	Val Target Mve Loss: : -0.1598

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = final_mod_name # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9767

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.977')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | BNLL: -0.175')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9661

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.966')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.966')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.156')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
