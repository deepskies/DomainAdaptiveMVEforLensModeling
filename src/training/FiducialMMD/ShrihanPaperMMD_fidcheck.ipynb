# %%
# Imports we will use
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
#from torchsummary import summary
from sklearn.metrics import r2_score

# For matplotlib
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# Set Seed
torch.manual_seed(22)

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Load data function
def create_dataloader(img_path, metadata_path, batch_size):
    '''
    Creates dataloader for training, reserving the last 1000 images for validation/testing
    '''
    data = np.load(img_path).squeeze()
    length = len(data)
    data_train = torch.tensor(data[:int(.7*length)])
    data_test = torch.tensor(data[int(.7*length):int(.9*length)])
    data_val = torch.tensor(data[int(.9*length):])

    metadata = pd.read_csv(metadata_path)
    labels = metadata['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()
    labels_train = torch.tensor(labels[:int(.7*length)])
    labels_test = torch.tensor(labels[int(.7*length):int(.9*length)])
    labels_val = torch.tensor(labels[int(.9*length):])

    data_train.cuda()
    data_test.cuda()
    data_val.cuda()
    labels_train.cuda()
    labels_test.cuda()
    labels_val.cuda()

    train_dataset = TensorDataset(data_train, labels_train)
    test_dataset = TensorDataset(data_test, labels_test)
    val_dataset = TensorDataset(data_val, labels_val)

    train_dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_dataloader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=True)

    return train_dataloader, test_dataloader, val_dataloader, data

# %%
#mount to drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Load in data
source_img_path = '/content/gdrive/MyDrive/deepskies/fiducialcheck/pax_orig_source.npy'
target_img_path = '/content/gdrive/MyDrive/deepskies/fiducialcheck/pax_target.npy'
source_meta = '/content/gdrive/MyDrive/deepskies/fiducialcheck/paxnorm_orig_source_metadata.csv'
target_meta = '/content/gdrive/MyDrive/deepskies/fiducialcheck/paxnorm_target_metadata.csv'
batch_size = 32
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)

# %%
# Define data visualization function
def visualize_data(data):
    '''
    visualizes 16 random images from dataset
    '''
    #get random indices
    x = np.empty(1)
    i = 1

    while i < 16:
        example_num = int(random.randrange(0, len(data[0:])))
        if example_num != x[i-1]:
            x = np.append(x, [example_num])
            i += 1

    #plot the examples for source
    fig1=plt.figure(figsize=(8,8))

    for i in range(16):
        plt.subplot(4, 4, i + 1)
        plt.axis("off")

        example_indices = int(x[i])

        example_image = np.squeeze(data[example_indices:(example_indices + 1)]) #change band by switching 0:1 to 1:2 or 2:3

        plt.imshow(example_image, aspect='auto', cmap='viridis')

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %%
# Define and initialize model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.feature = nn.Sequential()
        self.feature.add_module('f_conv1', nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_bn1', nn.BatchNorm2d(8))
        self.feature.add_module('f_pool1', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv2', nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_bn2', nn.BatchNorm2d(16))
        self.feature.add_module('f_pool2', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv3', nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        self.feature.add_module('f_bn3', nn.BatchNorm2d(32))
        self.feature.add_module('f_pool3', nn.MaxPool2d(kernel_size=2, stride=2))

        self.regressor = nn.Sequential()
        self.regressor.add_module('r_fc1', nn.Linear(in_features=32*5*5, out_features=128))
        self.regressor.add_module('r_relu1', nn.ReLU(True))
        #self.regressor.add_module('r_fc2', nn.Linear(in_features=128, out_features=64))
        #self.regressor.add_module('r_relu2', nn.ReLU(True))
        self.regressor.add_module('r_fc3', nn.Linear(in_features=128, out_features=1))

    def forward(self, x):
        x = x.view(-1, 1, 40, 40)

        features = self.feature(x)
        features = features.view(-1, 32*5*5)
        estimate = self.regressor(features)
        estimate = F.relu(estimate)
        estimate = estimate.view(-1)

        return estimate, features

# %%
# code from https://github.com/ZongxianLee/MMD_Loss.Pytorch

class MMD_loss(nn.Module):
    def __init__(self, kernel_mul = 2.0, kernel_num = 5):
        super(MMD_loss, self).__init__()
        self.kernel_num = kernel_num
        self.kernel_mul = kernel_mul
        self.fix_sigma = None
        return
    def guassian_kernel(self, source, target, kernel_mul=2.0, kernel_num=5, fix_sigma=None):
        n_samples = int(source.size()[0])+int(target.size()[0])
        total = torch.cat([source, target], dim=0)

        total0 = total.unsqueeze(0).expand(int(total.size(0)), int(total.size(0)), int(total.size(1)))
        total1 = total.unsqueeze(1).expand(int(total.size(0)), int(total.size(0)), int(total.size(1)))
        L2_distance = ((total0-total1)**2).sum(2)
        if fix_sigma:
            bandwidth = fix_sigma
        else:
            bandwidth = torch.sum(L2_distance.data) / (n_samples**2-n_samples)
        bandwidth /= kernel_mul ** (kernel_num // 2)
        bandwidth_list = [bandwidth * (kernel_mul**i) for i in range(kernel_num)]
        kernel_val = [torch.exp(-L2_distance / bandwidth_temp) for bandwidth_temp in bandwidth_list]
        return sum(kernel_val)

    def forward(self, source, target):
        batch_size = int(source.size()[0])
        kernels = self.guassian_kernel(source, target, kernel_mul=self.kernel_mul, kernel_num=self.kernel_num, fix_sigma=self.fix_sigma)
        XX = kernels[:batch_size, :batch_size]
        YY = kernels[batch_size:, batch_size:]
        XY = kernels[:batch_size, batch_size:]
        YX = kernels[batch_size:, :batch_size]
        loss = torch.mean(XX + YY - XY -YX)
        return loss

# %%
# Define training loop
def train_loop(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, optimizer, n_epoch, epoch):

    domain_error = 0
    domain_classifier_accuracy = 0
    estimator_error = 0
    score_list = np.array([])

    len_dataloader = min(len(source_dataloader), len(target_dataloader))
    data_source_iter = iter(source_dataloader)
    data_target_iter = iter(target_dataloader)

    i = 0
    while i < len_dataloader:

        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # Source Training

        data_source = next(data_source_iter)
        X, y = data_source
        X = X.float()
        X = X.cuda()
        y = y.cuda()

        model.zero_grad()
        batch_size = len(y)

        domain_label = torch.zeros(batch_size)
        domain_label = domain_label.long()
        domain_label = domain_label.cuda()

        estimate_output, domain_output_source = model(X)

        estimate_loss = regressor_loss_fn(estimate_output, y)

        # Target Training

        data_target = next(data_target_iter)
        X_target, _ = data_target
        X_target = X_target.float()
        X_target = X_target.cuda()

        batch_size = len(X_target)

        _, domain_output_target = model(X_target)
        domain_loss = da_loss(domain_output_source, domain_output_target)

        loss = estimate_loss + domain_loss*1.4
        loss.backward()
        optimizer.step()

        # Update values

        domain_error += domain_loss.item()
        #domain_classifier_accuracy +=
        estimator_error += estimate_loss.item()
        score = r2_score(y.cpu().detach().numpy(), estimate_output.cpu().detach().numpy())
        score_list = np.append(score_list, score)

        i += 1

    score = np.mean(score_list)
    domain_error = domain_error / (len_dataloader)
    estimator_error /= len_dataloader

    return [domain_error, estimator_error, score]

# %%
# Define testing loop

def test_loop(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, n_epoch, epoch):

    with torch.no_grad():

        len_dataloader = min(len(source_dataloader), len(target_dataloader))
        data_source_iter = iter(source_dataloader)
        data_target_iter = iter(target_dataloader)

        domain_classifier_error = 0
        domain_classifier_accuracy = 0
        estimator_error = 0
        estimator_error_target = 0
        score_list = np.array([])
        score_list_target = np.array([])

        i = 0
        while i < len_dataloader:

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # Source Testing

            data_source = next(data_source_iter)
            X, y = data_source
            X = X.float()
            X = X.cuda()
            y = y.cuda()

            batch_size = len(y)

            #domain_label = torch.zeros(batch_size)
            #domain_label = domain_label.long()
            #domain_label = domain_label.cuda()

            estimate_output, domain_output = model(X)

            estimate_loss = regressor_loss_fn(estimate_output, y)
            #domain_loss_source = classifier_loss_fn(domain_output, domain_label)

            # Target Testing

            data_target = next(data_target_iter)
            X_target, y_target = data_target
            X_target = X_target.float()
            X_target = X_target.cuda()
            y_target = y_target.cuda()

            batch_size = len(X_target)

            #domain_label = torch.ones(batch_size)
            #domain_label = domain_label.long()
            #domain_label = domain_label.cuda()

            estimate_output_target, domain_output = model(X_target)

            estimate_loss_target = regressor_loss_fn(estimate_output_target, y_target)
            #domain_loss_target = classifier_loss_fn(domain_output, domain_label)

            # Update values

           # domain_classifier_error += domain_loss_source.item()
            #domain_classifier_error += domain_loss_target.item()
            #domain_classifier_accuracy +=
            estimator_error += estimate_loss.item()
            estimator_error_target += estimate_loss_target.item()
            score = r2_score(y.cpu(), estimate_output.cpu())
            score_list = np.append(score_list, score)
            score_target = r2_score(y_target.cpu(), estimate_output_target.cpu())
            score_list_target = np.append(score_list_target, score_target)

            i += 1

        score = np.mean(score_list)
        score_target = np.mean(score_list_target)
        #classifier_error = domain_classifier_error / (len_dataloader * 2)
        estimator_error /= len_dataloader
        estimator_error_target /= len_dataloader
    classifier_error = 1
    return [classifier_error, estimator_error, estimator_error_target, score, score_target]

# %%
# Initialize dictionary for training stats
import time
model = NeuralNetwork().cuda()
# Hyper parameter presets
learning_rate = 6e-5
epochs = 30
# Define loss functions and optimizer
regressor_loss_fn = nn.MSELoss().cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
da_loss = MMD_loss()

stats = {'train_domain_classifier_error':[],
             'train_estimator_error':[],
             'train_score':[],
             'val_domain_classifier_error':[],
             'val_estimator_error':[],
             'val_estimator_error_target':[],
             'val_score':[],
             'val_score_target':[]}

# Train
for i in range(epochs):
        start_time = time.time()
        print(f"Epoch {i+1}\n-------------------------------")
        vals = train_loop(source_train_dataloader, target_train_dataloader, model,
                   regressor_loss_fn, da_loss, optimizer, epochs, i)

        vals_validate = test_loop(source_val_dataloader, target_val_dataloader,
                         model, regressor_loss_fn, da_loss, epochs, i)
        print(time.time() - start_time)

        stats['train_domain_classifier_error'].append(vals[0])
        stats['train_estimator_error'].append(vals[1])
        stats['train_score'].append(vals[2])
        stats['val_domain_classifier_error'].append(vals_validate[0])
        stats['val_estimator_error'].append(vals_validate[1])
        stats['val_estimator_error_target'].append(vals_validate[2])
        stats['val_score'].append(vals_validate[3])
        stats['val_score_target'].append(vals_validate[4])

        to_print = (
            f'Train Estimator Error = {vals[1]}\n'
            f'Train Estimator R2 Score = {vals[2]:.4f}\n'
            f'Train Domain Classifier Error = {vals[0]}\n'
            f'Validation Source Estimator Error = {vals_validate[1]}\n'
            f'Validation Source R2 Score = {vals_validate[3]:.4f}\n'
            f'Validation Target Estimator Error = {vals_validate[2]}\n'
            f'Validation Target R2 Score = {vals_validate[4]:.4f}\n'
            f'Validation Domain Classifier Error = {vals_validate[0]}\n'
        )

        print(to_print)
# Out:
# Epoch 1
# -------------------------------
# 12.297868967056274
# Train Estimator Error = 0.16440890379032116
# Train Estimator R2 Score = 0.6711
# Train Domain Classifier Error = 0.19728729280709567
# Validation Source Estimator Error = 0.039871880962590506
# Validation Source R2 Score = 0.9174
# Validation Target Estimator Error = 0.1799615289375281
# Validation Target R2 Score = 0.6379
# Validation Domain Classifier Error = 1
#
# Epoch 2
# -------------------------------
# 9.530860662460327
# Train Estimator Error = 0.03405903800521761
# Train Estimator R2 Score = 0.9311
# Train Domain Classifier Error = 0.10595942914853693
# Validation Source Estimator Error = 0.02670749679065434
# Validation Source R2 Score = 0.9445
# Validation Target Estimator Error = 0.12471325918557538
# Validation Target R2 Score = 0.7481
# Validation Domain Classifier Error = 1
#
# Epoch 3
# -------------------------------
# 9.066286563873291
# Train Estimator Error = 0.025919074311825215
# Train Estimator R2 Score = 0.9476
# Train Domain Classifier Error = 0.09859661889727307
# Validation Source Estimator Error = 0.027070000417720362
# Validation Source R2 Score = 0.9439
# Validation Target Estimator Error = 0.1161786566968936
# Validation Target R2 Score = 0.7676
# Validation Domain Classifier Error = 1
#
# Epoch 4
# -------------------------------
# 9.682335138320923
# Train Estimator Error = 0.021738914248041495
# Train Estimator R2 Score = 0.9559
# Train Domain Classifier Error = 0.09348081471824123
# Validation Source Estimator Error = 0.02298749753742651
# Validation Source R2 Score = 0.9531
# Validation Target Estimator Error = 0.09481519282718373
# Validation Target R2 Score = 0.8085
# Validation Domain Classifier Error = 1
#
# Epoch 5
# -------------------------------
# 9.690858364105225
# Train Estimator Error = 0.018687165939032867
# Train Estimator R2 Score = 0.9620
# Train Domain Classifier Error = 0.09352216096271436
# Validation Source Estimator Error = 0.016457232314452622
# Validation Source R2 Score = 0.9660
# Validation Target Estimator Error = 0.07030610132748914
# Validation Target R2 Score = 0.8561
# Validation Domain Classifier Error = 1
#
# Epoch 6
# -------------------------------
# 9.152854681015015
# Train Estimator Error = 0.01697876236028629
# Train Estimator R2 Score = 0.9656
# Train Domain Classifier Error = 0.09011710994286119
# Validation Source Estimator Error = 0.015258975579124538
# Validation Source R2 Score = 0.9681
# Validation Target Estimator Error = 0.0643621764507643
# Validation Target R2 Score = 0.8709
# Validation Domain Classifier Error = 1
#
# Epoch 7
# -------------------------------
# 9.748769521713257
# Train Estimator Error = 0.015112125134296456
# Train Estimator R2 Score = 0.9692
# Train Domain Classifier Error = 0.08729008608710505
# Validation Source Estimator Error = 0.015141435344199277
# Validation Source R2 Score = 0.9684
# Validation Target Estimator Error = 0.07740885777410808
# Validation Target R2 Score = 0.8447
# Validation Domain Classifier Error = 1
#
# Epoch 8
# -------------------------------
# 9.698214769363403
# Train Estimator Error = 0.014286771592883295
# Train Estimator R2 Score = 0.9710
# Train Domain Classifier Error = 0.08916268808600344
# Validation Source Estimator Error = 0.0135181102350022
# Validation Source R2 Score = 0.9721
# Validation Target Estimator Error = 0.06326366073576509
# Validation Target R2 Score = 0.8713
# Validation Domain Classifier Error = 1
#
# Epoch 9
# -------------------------------
# 9.158239841461182
# Train Estimator Error = 0.013546406726226878
# Train Estimator R2 Score = 0.9725
# Train Domain Classifier Error = 0.08675181677384503
# Validation Source Estimator Error = 0.014229952431859294
# Validation Source R2 Score = 0.9705
# Validation Target Estimator Error = 0.06608289748928539
# Validation Target R2 Score = 0.8655
# Validation Domain Classifier Error = 1
#
# Epoch 10
# -------------------------------
# 9.572015762329102
# Train Estimator Error = 0.012600326920617747
# Train Estimator R2 Score = 0.9744
# Train Domain Classifier Error = 0.08477671146801447
# Validation Source Estimator Error = 0.011672129679566167
# Validation Source R2 Score = 0.9760
# Validation Target Estimator Error = 0.049741499897116306
# Validation Target R2 Score = 0.8999
# Validation Domain Classifier Error = 1
#
# Epoch 11
# -------------------------------
# 10.592718362808228
# Train Estimator Error = 0.011919278474831086
# Train Estimator R2 Score = 0.9757
# Train Domain Classifier Error = 0.08146076426556985
# Validation Source Estimator Error = 0.011341693295035392
# Validation Source R2 Score = 0.9761
# Validation Target Estimator Error = 0.04818050243601108
# Validation Target R2 Score = 0.9041
# Validation Domain Classifier Error = 1
#
# Epoch 12
# -------------------------------
# 9.594529867172241
# Train Estimator Error = 0.011818662270481343
# Train Estimator R2 Score = 0.9760
# Train Domain Classifier Error = 0.08270495354625272
# Validation Source Estimator Error = 0.012057864928772305
# Validation Source R2 Score = 0.9748
# Validation Target Estimator Error = 0.0479785594525658
# Validation Target R2 Score = 0.9042
# Validation Domain Classifier Error = 1
#
# Epoch 13
# -------------------------------
# 8.733057737350464
# Train Estimator Error = 0.011578161819153542
# Train Estimator R2 Score = 0.9765
# Train Domain Classifier Error = 0.08215242751977889
# Validation Source Estimator Error = 0.010390141560654542
# Validation Source R2 Score = 0.9784
# Validation Target Estimator Error = 0.047037857460083474
# Validation Target R2 Score = 0.9051
# Validation Domain Classifier Error = 1
#
# Epoch 14
# -------------------------------
# 9.67088270187378
# Train Estimator Error = 0.010922409132654205
# Train Estimator R2 Score = 0.9778
# Train Domain Classifier Error = 0.07887498286792793
# Validation Source Estimator Error = 0.014299916403047787
# Validation Source R2 Score = 0.9705
# Validation Target Estimator Error = 0.04890319029948893
# Validation Target R2 Score = 0.9014
# Validation Domain Classifier Error = 1
#
# Epoch 15
# -------------------------------
# 13.419494152069092
# Train Estimator Error = 0.011219163756422576
# Train Estimator R2 Score = 0.9772
# Train Domain Classifier Error = 0.07942310451500977
# Validation Source Estimator Error = 0.010780301736964351
# Validation Source R2 Score = 0.9779
# Validation Target Estimator Error = 0.03656794863403033
# Validation Target R2 Score = 0.9275
# Validation Domain Classifier Error = 1
#
# Epoch 16
# -------------------------------
# 9.722912549972534
# Train Estimator Error = 0.011074880928046307
# Train Estimator R2 Score = 0.9775
# Train Domain Classifier Error = 0.07269217029138991
# Validation Source Estimator Error = 0.010975649314902865
# Validation Source R2 Score = 0.9775
# Validation Target Estimator Error = 0.03694948030837402
# Validation Target R2 Score = 0.9261
# Validation Domain Classifier Error = 1
#
# Epoch 17
# -------------------------------
# 8.823599576950073
# Train Estimator Error = 0.011354720614121808
# Train Estimator R2 Score = 0.9768
# Train Domain Classifier Error = 0.06941466684533211
# Validation Source Estimator Error = 0.010814689479436085
# Validation Source R2 Score = 0.9777
# Validation Target Estimator Error = 0.04015751655219467
# Validation Target R2 Score = 0.9200
# Validation Domain Classifier Error = 1
#
# Epoch 18
# -------------------------------
# 9.702294111251831
# Train Estimator Error = 0.012192974869890558
# Train Estimator R2 Score = 0.9752
# Train Domain Classifier Error = 0.060964591906727775
# Validation Source Estimator Error = 0.010904118700463112
# Validation Source R2 Score = 0.9774
# Validation Target Estimator Error = 0.04138289431145616
# Validation Target R2 Score = 0.9168
# Validation Domain Classifier Error = 1
#
# Epoch 19
# -------------------------------
# 9.697883367538452
# Train Estimator Error = 0.012377183637930798
# Train Estimator R2 Score = 0.9748
# Train Domain Classifier Error = 0.05150529111767872
# Validation Source Estimator Error = 0.012386439199067035
# Validation Source R2 Score = 0.9741
# Validation Target Estimator Error = 0.039128029991866674
# Validation Target R2 Score = 0.9208
# Validation Domain Classifier Error = 1
#
# Epoch 20
# -------------------------------
# 8.730470657348633
# Train Estimator Error = 0.012278761115807094
# Train Estimator R2 Score = 0.9750
# Train Domain Classifier Error = 0.0433577600018661
# Validation Source Estimator Error = 0.012313082309997385
# Validation Source R2 Score = 0.9747
# Validation Target Estimator Error = 0.038125877772831614
# Validation Target R2 Score = 0.9231
# Validation Domain Classifier Error = 1
#
# Epoch 21
# -------------------------------
# 9.758416414260864
# Train Estimator Error = 0.01189021161124042
# Train Estimator R2 Score = 0.9759
# Train Domain Classifier Error = 0.03935224178265882
# Validation Source Estimator Error = 0.01203390772923068
# Validation Source R2 Score = 0.9753
# Validation Target Estimator Error = 0.0335262859429998
# Validation Target R2 Score = 0.9331
# Validation Domain Classifier Error = 1
#
# Epoch 22
# -------------------------------
# 9.716171026229858
# Train Estimator Error = 0.011208078118681335
# Train Estimator R2 Score = 0.9772
# Train Domain Classifier Error = 0.0401524494425947
# Validation Source Estimator Error = 0.011742838504160665
# Validation Source R2 Score = 0.9755
# Validation Target Estimator Error = 0.029895670937409826
# Validation Target R2 Score = 0.9399
# Validation Domain Classifier Error = 1
#
# Epoch 23
# -------------------------------
# 8.975570678710938
# Train Estimator Error = 0.010847380214755575
# Train Estimator R2 Score = 0.9781
# Train Domain Classifier Error = 0.035987597610120416
# Validation Source Estimator Error = 0.010999546943908664
# Validation Source R2 Score = 0.9773
# Validation Target Estimator Error = 0.035138511187901164
# Validation Target R2 Score = 0.9307
# Validation Domain Classifier Error = 1
#
# Epoch 24
# -------------------------------
# 10.384584188461304
# Train Estimator Error = 0.010592709611071243
# Train Estimator R2 Score = 0.9786
# Train Domain Classifier Error = 0.033037237487597154
# Validation Source Estimator Error = 0.011742009502497448
# Validation Source R2 Score = 0.9758
# Validation Target Estimator Error = 0.03395961031649902
# Validation Target R2 Score = 0.9322
# Validation Domain Classifier Error = 1
#
# Epoch 25
# -------------------------------
# 9.784534215927124
# Train Estimator Error = 0.010143085682536501
# Train Estimator R2 Score = 0.9794
# Train Domain Classifier Error = 0.032503849288731325
# Validation Source Estimator Error = 0.010280083556463765
# Validation Source R2 Score = 0.9788
# Validation Target Estimator Error = 0.033179433067228384
# Validation Target R2 Score = 0.9338
# Validation Domain Classifier Error = 1
#
# Epoch 26
# -------------------------------
# 9.405085802078247
# Train Estimator Error = 0.010003908833155111
# Train Estimator R2 Score = 0.9797
# Train Domain Classifier Error = 0.029876068154421433
# Validation Source Estimator Error = 0.013208341001752456
# Validation Source R2 Score = 0.9732
# Validation Target Estimator Error = 0.03495059235934998
# Validation Target R2 Score = 0.9310
# Validation Domain Classifier Error = 1
#
# Epoch 27
# -------------------------------
# 8.996155261993408
# Train Estimator Error = 0.01033423473769918
# Train Estimator R2 Score = 0.9788
# Train Domain Classifier Error = 0.032185634939507386
# Validation Source Estimator Error = 0.01055313355087712
# Validation Source R2 Score = 0.9783
# Validation Target Estimator Error = 0.029229580015418637
# Validation Target R2 Score = 0.9417
# Validation Domain Classifier Error = 1
#
# Epoch 28
# -------------------------------
# 9.68241572380066
# Train Estimator Error = 0.009622836384626014
# Train Estimator R2 Score = 0.9804
# Train Domain Classifier Error = 0.02733555708890968
# Validation Source Estimator Error = 0.008882282402627407
# Validation Source R2 Score = 0.9811
# Validation Target Estimator Error = 0.03039658988772589
# Validation Target R2 Score = 0.9393
# Validation Domain Classifier Error = 1
#
# Epoch 29
# -------------------------------
# 9.721857070922852
# Train Estimator Error = 0.010094045646917722
# Train Estimator R2 Score = 0.9796
# Train Domain Classifier Error = 0.028681774351275925
# Validation Source Estimator Error = 0.009276959001068856
# Validation Source R2 Score = 0.9809
# Validation Target Estimator Error = 0.030769670156726412
# Validation Target R2 Score = 0.9384
# Validation Domain Classifier Error = 1
#
# Epoch 30
# -------------------------------
# 8.808199167251587
# Train Estimator Error = 0.010016896677462271
# Train Estimator R2 Score = 0.9796
# Train Domain Classifier Error = 0.028641486759220933
# Validation Source Estimator Error = 0.010895177194030043
# Validation Source R2 Score = 0.9774
# Validation Target Estimator Error = 0.02824437698930692
# Validation Target R2 Score = 0.9440
# Validation Domain Classifier Error = 1

# %%
# Classifier
eps = np.arange(epochs)
plt.title("Classifier Error")
plt.plot(eps, stats['train_domain_classifier_error'])
plt.plot(eps, stats['val_domain_classifier_error'])

# %%
# Estimator
plt.title("Estimator Error")
plt.plot(eps, stats['train_estimator_error'])
plt.plot(eps, stats['val_estimator_error'])
plt.plot(eps, stats['val_estimator_error_target'])

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_score'])
plt.plot(eps, stats['val_score'])
plt.plot(eps, stats['val_score_target'])

# %%
# Test Source
preds = np.array([])
true = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds = np.append(preds, pred.cpu())
        true = np.append(true, y.cpu())
        score = r2_score(y.cpu(), pred.cpu())
        score_list = np.append(score_list, score)

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true, preds,  color='black')
line = np.linspace(0, 4, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD - Source')
# Out:
# Source R2 Score is 0.9771
# Text(0.5, 1.0, 'MMD - Source')

# %%
# Test target
preds = np.array([])
true = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds = np.append(preds, pred.cpu())
        true = np.append(true, y.cpu())
        score = r2_score(y.cpu(), pred.cpu())
        score_list = np.append(score_list, score)

score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true, preds,  color='black')
line = np.linspace(0, 4, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD - Target')
# Out:
# Target R2 Score is 0.9424
# Text(0.5, 1.0, 'MMD - Target')
