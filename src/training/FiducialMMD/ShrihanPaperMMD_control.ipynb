# %%
# Imports we will use
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score

# For matplotlib
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# Set Seed
torch.manual_seed(22)

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Load data function
def create_dataloader(img_path, metadata_path, batch_size):
    '''
    Creates dataloader for training, reserving the last 1000 images for validation/testing
    '''
    data = np.load(img_path).squeeze()
    length = len(data)
    data_train = torch.tensor(data[:int(.7*length)])
    data_test = torch.tensor(data[int(.7*length):int(.9*length)])
    data_val = torch.tensor(data[int(.9*length):])

    metadata = pd.read_csv(metadata_path)
    labels = metadata['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()
    labels_train = torch.tensor(labels[:int(.7*length)])
    labels_test = torch.tensor(labels[int(.7*length):int(.9*length)])
    labels_val = torch.tensor(labels[int(.9*length):])

    data_train.cuda()
    data_test.cuda()
    data_val.cuda()
    labels_train.cuda()
    labels_test.cuda()
    labels_val.cuda()

    train_dataset = TensorDataset(data_train, labels_train)
    test_dataset = TensorDataset(data_test, labels_test)
    val_dataset = TensorDataset(data_val, labels_val)

    train_dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_dataloader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=True)

    return train_dataloader, test_dataloader, val_dataloader, data

# %%
# Load in data
head = Path.cwd().parents[1]
source_img_path = head / 'data/fid_source/fid_source.npy'
target_img_path = head / 'data/fid_target/fid_target.npy'
source_meta = head / 'data/fid_source/fid_source_metadata.csv'
target_meta = head / 'data/fid_target/fid_target_metadata.csv'
batch_size = 32
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)

# %%
# Define data visualization function
def visualize_data(data):
    '''
    visualizes 16 random images from dataset
    '''
    #get random indices
    x = np.empty(1)
    i = 1

    while i < 16:
        example_num = int(random.randrange(0, len(data[0:])))
        if example_num != x[i-1]:
            x = np.append(x, [example_num])
            i += 1

    #plot the examples for source
    fig1=plt.figure(figsize=(8,8))

    for i in range(16):
        plt.subplot(4, 4, i + 1)
        plt.axis("off")

        example_indices = int(x[i])

        example_image = np.squeeze(data[example_indices:(example_indices + 1)]) #change band by switching 0:1 to 1:2 or 2:3

        plt.imshow(example_image, aspect='auto', cmap='viridis')

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %%
# Define and initialize model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.feature = nn.Sequential()
        self.feature.add_module('f_conv1', nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_bn1', nn.BatchNorm2d(8))
        self.feature.add_module('f_pool1', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv2', nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_bn2', nn.BatchNorm2d(16))
        self.feature.add_module('f_pool2', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv3', nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        self.feature.add_module('f_bn3', nn.BatchNorm2d(32))
        self.feature.add_module('f_pool3', nn.MaxPool2d(kernel_size=2, stride=2))

        self.regressor = nn.Sequential()
        self.regressor.add_module('r_fc1', nn.Linear(in_features=32*5*5, out_features=128))
        self.regressor.add_module('r_relu1', nn.ReLU(True))
        #self.regressor.add_module('r_fc2', nn.Linear(in_features=128, out_features=64))
        #self.regressor.add_module('r_relu2', nn.ReLU(True))
        self.regressor.add_module('r_fc3', nn.Linear(in_features=128, out_features=1))

    def forward(self, x):
        x = x.view(-1, 1, 40, 40)

        features = self.feature(x)
        features = features.view(-1, 32*5*5)
        estimate = self.regressor(features)
        estimate = F.relu(estimate)
        estimate = estimate.view(-1)

        return estimate, features

# %%
# code from https://github.com/ZongxianLee/MMD_Loss.Pytorch

class MMD_loss(nn.Module):
    def __init__(self, kernel_mul = 2.0, kernel_num = 5):
        super(MMD_loss, self).__init__()
        self.kernel_num = kernel_num
        self.kernel_mul = kernel_mul
        self.fix_sigma = None
        return
    def guassian_kernel(self, source, target, kernel_mul=2.0, kernel_num=5, fix_sigma=None):
        n_samples = int(source.size()[0])+int(target.size()[0])
        total = torch.cat([source, target], dim=0)

        total0 = total.unsqueeze(0).expand(int(total.size(0)), int(total.size(0)), int(total.size(1)))
        total1 = total.unsqueeze(1).expand(int(total.size(0)), int(total.size(0)), int(total.size(1)))
        L2_distance = ((total0-total1)**2).sum(2)
        if fix_sigma:
            bandwidth = fix_sigma
        else:
            bandwidth = torch.sum(L2_distance.data) / (n_samples**2-n_samples)
        bandwidth /= kernel_mul ** (kernel_num // 2)
        bandwidth_list = [bandwidth * (kernel_mul**i) for i in range(kernel_num)]
        kernel_val = [torch.exp(-L2_distance / bandwidth_temp) for bandwidth_temp in bandwidth_list]
        return sum(kernel_val)

    def forward(self, source, target):
        batch_size = int(source.size()[0])
        kernels = self.guassian_kernel(source, target, kernel_mul=self.kernel_mul, kernel_num=self.kernel_num, fix_sigma=self.fix_sigma)
        XX = kernels[:batch_size, :batch_size]
        YY = kernels[batch_size:, batch_size:]
        XY = kernels[:batch_size, batch_size:]
        YX = kernels[batch_size:, :batch_size]
        loss = torch.mean(XX + YY - XY -YX)
        return loss

# %%
# Define training loop
def train_loop(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, optimizer, n_epoch, epoch):

    domain_error = 0
    domain_classifier_accuracy = 0
    estimator_error = 0
    score_list = np.array([])

    len_dataloader = min(len(source_dataloader), len(target_dataloader))
    data_source_iter = iter(source_dataloader)
    data_target_iter = iter(target_dataloader)

    i = 0
    while i < len_dataloader:

        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # Source Training

        data_source = next(data_source_iter)
        X, y = data_source
        X = X.float()
        X = X.cuda()
        y = y.cuda()

        model.zero_grad()
        batch_size = len(y)

        domain_label = torch.zeros(batch_size)
        domain_label = domain_label.long()
        domain_label = domain_label.cuda()

        estimate_output, domain_output_source = model(X)

        estimate_loss = regressor_loss_fn(estimate_output, y)

        # Target Training

        data_target = next(data_target_iter)
        X_target, _ = data_target
        X_target = X_target.float()
        X_target = X_target.cuda()

        batch_size = len(X_target)

        # _, domain_output_target = model(X_target)
        # domain_loss = da_loss(domain_output_source, domain_output_target)

        loss = estimate_loss
        loss.backward()
        optimizer.step()

        # Update values

        domain_error += 0#domain_loss.item()
        #domain_classifier_accuracy +=
        estimator_error += estimate_loss.item()
        score = r2_score(y.cpu().detach().numpy(), estimate_output.cpu().detach().numpy())
        score_list = np.append(score_list, score)

        i += 1

    score = np.mean(score_list)
    domain_error = domain_error / (len_dataloader)
    estimator_error /= len_dataloader

    return [domain_error, estimator_error, score]

# %%
# Define testing loop

def test_loop(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, n_epoch, epoch):

    with torch.no_grad():

        len_dataloader = min(len(source_dataloader), len(target_dataloader))
        data_source_iter = iter(source_dataloader)
        data_target_iter = iter(target_dataloader)

        domain_classifier_error = 0
        domain_classifier_accuracy = 0
        estimator_error = 0
        estimator_error_target = 0
        score_list = np.array([])
        score_list_target = np.array([])

        i = 0
        while i < len_dataloader:

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # Source Testing

            data_source = next(data_source_iter)
            X, y = data_source
            X = X.float()
            X = X.cuda()
            y = y.cuda()

            batch_size = len(y)

            #domain_label = torch.zeros(batch_size)
            #domain_label = domain_label.long()
            #domain_label = domain_label.cuda()

            estimate_output, domain_output = model(X)

            estimate_loss = regressor_loss_fn(estimate_output, y)
            #domain_loss_source = classifier_loss_fn(domain_output, domain_label)

            # Target Testing

            data_target = next(data_target_iter)
            X_target, y_target = data_target
            X_target = X_target.float()
            X_target = X_target.cuda()
            y_target = y_target.cuda()

            batch_size = len(X_target)

            #domain_label = torch.ones(batch_size)
            #domain_label = domain_label.long()
            #domain_label = domain_label.cuda()

            estimate_output_target, domain_output = model(X_target)

            estimate_loss_target = regressor_loss_fn(estimate_output_target, y_target)
            #domain_loss_target = classifier_loss_fn(domain_output, domain_label)

            # Update values

           # domain_classifier_error += domain_loss_source.item()
            #domain_classifier_error += domain_loss_target.item()
            #domain_classifier_accuracy +=
            estimator_error += estimate_loss.item()
            estimator_error_target += estimate_loss_target.item()
            score = r2_score(y.cpu(), estimate_output.cpu())
            score_list = np.append(score_list, score)
            score_target = r2_score(y_target.cpu(), estimate_output_target.cpu())
            score_list_target = np.append(score_list_target, score_target)

            i += 1

        score = np.mean(score_list)
        score_target = np.mean(score_list_target)
        #classifier_error = domain_classifier_error / (len_dataloader * 2)
        estimator_error /= len_dataloader
        estimator_error_target /= len_dataloader
    classifier_error = 1
    return [classifier_error, estimator_error, estimator_error_target, score, score_target]

# %%
# Initialize dictionary for training stats
import time
model = NeuralNetwork().cuda()
# Hyper parameter presets
learning_rate = 6e-5
epochs = 30
# Define loss functions and optimizer
regressor_loss_fn = nn.MSELoss().cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
da_loss = MMD_loss()

stats = {'train_domain_classifier_error':[],
             'train_estimator_error':[],
             'train_score':[],
             'val_domain_classifier_error':[],
             'val_estimator_error':[],
             'val_estimator_error_target':[],
             'val_score':[],
             'val_score_target':[]}

# Train
for i in range(epochs):
        start_time = time.time()
        print(f"Epoch {i+1}\n-------------------------------")
        vals = train_loop(source_train_dataloader, target_train_dataloader, model,
                   regressor_loss_fn, da_loss, optimizer, epochs, i)

        vals_validate = test_loop(source_val_dataloader, target_val_dataloader,
                         model, regressor_loss_fn, da_loss, epochs, i)
        print(time.time() - start_time)

        stats['train_domain_classifier_error'].append(vals[0])
        stats['train_estimator_error'].append(vals[1])
        stats['train_score'].append(vals[2])
        stats['val_domain_classifier_error'].append(vals_validate[0])
        stats['val_estimator_error'].append(vals_validate[1])
        stats['val_estimator_error_target'].append(vals_validate[2])
        stats['val_score'].append(vals_validate[3])
        stats['val_score_target'].append(vals_validate[4])

        to_print = (
            f'Train Estimator Error = {vals[1]}\n'
            f'Train Estimator R2 Score = {vals[2]:.4f}\n'
            f'Train Domain Classifier Error = {vals[0]}\n'
            f'Validation Source Estimator Error = {vals_validate[1]}\n'
            f'Validation Source R2 Score = {vals_validate[3]:.4f}\n'
            f'Validation Target Estimator Error = {vals_validate[2]}\n'
            f'Validation Target R2 Score = {vals_validate[4]:.4f}\n'
            f'Validation Domain Classifier Error = {vals_validate[0]}\n'
        )

        print(to_print)
# Out:
# Epoch 1
# -------------------------------
# 9.56321096420288
# Train Estimator Error = 0.16423636786912107
# Train Estimator R2 Score = 0.6713
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.04234646640385792
# Validation Source R2 Score = 0.9124
# Validation Target Estimator Error = 0.5941320162290221
# Validation Target R2 Score = -0.1935
# Validation Domain Classifier Error = 1
#
# Epoch 2
# -------------------------------
# 9.506195306777954
# Train Estimator Error = 0.03184297876568746
# Train Estimator R2 Score = 0.9354
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.026206694484041754
# Validation Source R2 Score = 0.9448
# Validation Target Estimator Error = 0.5024936034990723
# Validation Target R2 Score = -0.0106
# Validation Domain Classifier Error = 1
#
# Epoch 3
# -------------------------------
# 8.12877082824707
# Train Estimator Error = 0.021467947799514917
# Train Estimator R2 Score = 0.9564
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.0179045920639898
# Validation Source R2 Score = 0.9628
# Validation Target Estimator Error = 0.41426327634768884
# Validation Target R2 Score = 0.1750
# Validation Domain Classifier Error = 1
#
# Epoch 4
# -------------------------------
# 6.747941017150879
# Train Estimator Error = 0.016241814996502353
# Train Estimator R2 Score = 0.9670
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.01609290926568922
# Validation Source R2 Score = 0.9670
# Validation Target Estimator Error = 0.352713745870408
# Validation Target R2 Score = 0.2835
# Validation Domain Classifier Error = 1
#
# Epoch 5
# -------------------------------
# 7.275954246520996
# Train Estimator Error = 0.013063638773278574
# Train Estimator R2 Score = 0.9734
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.0131212021046241
# Validation Source R2 Score = 0.9726
# Validation Target Estimator Error = 0.27573069075869905
# Validation Target R2 Score = 0.4390
# Validation Domain Classifier Error = 1
#
# Epoch 6
# -------------------------------
# 7.372082948684692
# Train Estimator Error = 0.011172419898101287
# Train Estimator R2 Score = 0.9773
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.010529468165247873
# Validation Source R2 Score = 0.9778
# Validation Target Estimator Error = 0.23693192949530426
# Validation Target R2 Score = 0.5244
# Validation Domain Classifier Error = 1
#
# Epoch 7
# -------------------------------
# 7.299907922744751
# Train Estimator Error = 0.009806580399716413
# Train Estimator R2 Score = 0.9800
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.0102640904714561
# Validation Source R2 Score = 0.9785
# Validation Target Estimator Error = 0.26018699818545843
# Validation Target R2 Score = 0.4801
# Validation Domain Classifier Error = 1
#
# Epoch 8
# -------------------------------
# 8.174566984176636
# Train Estimator Error = 0.008628840891727786
# Train Estimator R2 Score = 0.9824
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.01013209857788103
# Validation Source R2 Score = 0.9792
# Validation Target Estimator Error = 0.19123146423156473
# Validation Target R2 Score = 0.6178
# Validation Domain Classifier Error = 1
#
# Epoch 9
# -------------------------------
# 7.3930823802948
# Train Estimator Error = 0.007773837831443417
# Train Estimator R2 Score = 0.9842
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.009583234291666062
# Validation Source R2 Score = 0.9802
# Validation Target Estimator Error = 0.21521569036279514
# Validation Target R2 Score = 0.5629
# Validation Domain Classifier Error = 1
#
# Epoch 10
# -------------------------------
# 8.363378286361694
# Train Estimator Error = 0.006925365418515813
# Train Estimator R2 Score = 0.9859
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.008842081847381155
# Validation Source R2 Score = 0.9818
# Validation Target Estimator Error = 0.18059236651203434
# Validation Target R2 Score = 0.6396
# Validation Domain Classifier Error = 1
#
# Epoch 11
# -------------------------------
# 10.022984743118286
# Train Estimator Error = 0.006314252173443797
# Train Estimator R2 Score = 0.9871
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.0065725547288230084
# Validation Source R2 Score = 0.9862
# Validation Target Estimator Error = 0.15650818250171697
# Validation Target R2 Score = 0.6911
# Validation Domain Classifier Error = 1
#
# Epoch 12
# -------------------------------
# 7.511659145355225
# Train Estimator Error = 0.006018820656203857
# Train Estimator R2 Score = 0.9877
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.007721489746194736
# Validation Source R2 Score = 0.9838
# Validation Target Estimator Error = 0.1502657006405721
# Validation Target R2 Score = 0.7017
# Validation Domain Classifier Error = 1
#
# Epoch 13
# -------------------------------
# 7.454715251922607
# Train Estimator Error = 0.005565542488387008
# Train Estimator R2 Score = 0.9887
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.005642690462991595
# Validation Source R2 Score = 0.9883
# Validation Target Estimator Error = 0.13445885781981762
# Validation Target R2 Score = 0.7268
# Validation Domain Classifier Error = 1
#
# Epoch 14
# -------------------------------
# 7.929354667663574
# Train Estimator Error = 0.00522825235262142
# Train Estimator R2 Score = 0.9894
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.006032673266840873
# Validation Source R2 Score = 0.9875
# Validation Target Estimator Error = 0.12339466187367394
# Validation Target R2 Score = 0.7521
# Validation Domain Classifier Error = 1
#
# Epoch 15
# -------------------------------
# 7.584348440170288
# Train Estimator Error = 0.004869981998449168
# Train Estimator R2 Score = 0.9901
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.005080949653023083
# Validation Source R2 Score = 0.9895
# Validation Target Estimator Error = 0.11556651650862709
# Validation Target R2 Score = 0.7724
# Validation Domain Classifier Error = 1
#
# Epoch 16
# -------------------------------
# 7.006015062332153
# Train Estimator Error = 0.004746615478383306
# Train Estimator R2 Score = 0.9904
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.004875422879507777
# Validation Source R2 Score = 0.9900
# Validation Target Estimator Error = 0.11345981723468775
# Validation Target R2 Score = 0.7735
# Validation Domain Classifier Error = 1
#
# Epoch 17
# -------------------------------
# 7.350466728210449
# Train Estimator Error = 0.004366243750383052
# Train Estimator R2 Score = 0.9911
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.004208994204783515
# Validation Source R2 Score = 0.9913
# Validation Target Estimator Error = 0.11342682428420729
# Validation Target R2 Score = 0.7739
# Validation Domain Classifier Error = 1
#
# Epoch 18
# -------------------------------
# 6.753988742828369
# Train Estimator Error = 0.004236587067539046
# Train Estimator R2 Score = 0.9914
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.00561363936793415
# Validation Source R2 Score = 0.9884
# Validation Target Estimator Error = 0.11366924313697846
# Validation Target R2 Score = 0.7715
# Validation Domain Classifier Error = 1
#
# Epoch 19
# -------------------------------
# 7.384313106536865
# Train Estimator Error = 0.004072628266619045
# Train Estimator R2 Score = 0.9917
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.00439261368128833
# Validation Source R2 Score = 0.9904
# Validation Target Estimator Error = 0.10983705538425856
# Validation Target R2 Score = 0.7787
# Validation Domain Classifier Error = 1
#
# Epoch 20
# -------------------------------
# 6.997509717941284
# Train Estimator Error = 0.0038793483178447964
# Train Estimator R2 Score = 0.9921
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.0038735538885697344
# Validation Source R2 Score = 0.9920
# Validation Target Estimator Error = 0.10669347076753902
# Validation Target R2 Score = 0.7872
# Validation Domain Classifier Error = 1
#
# Epoch 21
# -------------------------------
# 6.682438135147095
# Train Estimator Error = 0.00375079043006092
# Train Estimator R2 Score = 0.9924
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.004123269428297356
# Validation Source R2 Score = 0.9915
# Validation Target Estimator Error = 0.11590857234943634
# Validation Target R2 Score = 0.7679
# Validation Domain Classifier Error = 1
#
# Epoch 22
# -------------------------------
# 6.9546709060668945
# Train Estimator Error = 0.0036060918717163272
# Train Estimator R2 Score = 0.9927
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.004179092677262653
# Validation Source R2 Score = 0.9912
# Validation Target Estimator Error = 0.09674678182905647
# Validation Target R2 Score = 0.8055
# Validation Domain Classifier Error = 1
#
# Epoch 23
# -------------------------------
# 6.84088659286499
# Train Estimator Error = 0.0034866795978990726
# Train Estimator R2 Score = 0.9929
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.003920135467912361
# Validation Source R2 Score = 0.9919
# Validation Target Estimator Error = 0.09843667840976623
# Validation Target R2 Score = 0.8047
# Validation Domain Classifier Error = 1
#
# Epoch 24
# -------------------------------
# 6.979669094085693
# Train Estimator Error = 0.003378514413167663
# Train Estimator R2 Score = 0.9931
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.0036708645546322414
# Validation Source R2 Score = 0.9924
# Validation Target Estimator Error = 0.10035695658795013
# Validation Target R2 Score = 0.7995
# Validation Domain Classifier Error = 1
#
# Epoch 25
# -------------------------------
# 7.295955657958984
# Train Estimator Error = 0.0032565419483841338
# Train Estimator R2 Score = 0.9934
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.0038361810844771234
# Validation Source R2 Score = 0.9920
# Validation Target Estimator Error = 0.09577888113321961
# Validation Target R2 Score = 0.8092
# Validation Domain Classifier Error = 1
#
# Epoch 26
# -------------------------------
# 8.019706726074219
# Train Estimator Error = 0.0032011994020885682
# Train Estimator R2 Score = 0.9935
# Train Domain Classifier Error = 0.0
# Validation Source Estimator Error = 0.00405035661474155
# Validation Source R2 Score = 0.9915
# Validation Target Estimator Error = 0.10485605342657703
# Validation Target R2 Score = 0.7908
# Validation Domain Classifier Error = 1
#
# Epoch 27
# -------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 25
#      23 start_time = time.time()
#      24 print(f"Epoch {i+1}\n-------------------------------")
# ---> 25 vals = train_loop(source_train_dataloader, target_train_dataloader, model,
#      26            regressor_loss_fn, da_loss, optimizer, epochs, i)
#      28 vals_validate = test_loop(source_val_dataloader, target_val_dataloader,
#      29                  model, regressor_loss_fn, da_loss, epochs, i)
#      30 print(time.time() - start_time)
#
# Cell In[9], line 21, in train_loop(source_dataloader, target_dataloader, model, regressor_loss_fn, da_loss, optimizer, n_epoch, epoch)
#      17 alpha = 2. / (1. + np.exp(-10 * p)) - 1
#      19 # Source Training
# ---> 21 data_source = next(data_source_iter)
#      22 X, y = data_source
#      23 X = X.float()
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:264, in default_collate(batch)
#     203 def default_collate(batch):
#     204     r"""
#     205         Function that takes in a batch of data and puts the elements within the batch
#     206         into a tensor with an additional outer dimension - batch size. The exact output type can be
#    (...)
#     262             >>> default_collate(batch)  # Handle `CustomType` automatically
#     263     """
# --> 264     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:142, in collate(batch, collate_fn_map)
#     139 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     141 if isinstance(elem, tuple):
# --> 142     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143 else:
#     144     try:
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:142, in <listcomp>(.0)
#     139 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     141 if isinstance(elem, tuple):
# --> 142     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143 else:
#     144     try:
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:119, in collate(batch, collate_fn_map)
#     117 if collate_fn_map is not None:
#     118     if elem_type in collate_fn_map:
# --> 119         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     121     for collate_type in collate_fn_map:
#     122         if isinstance(elem, collate_type):
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:162, in collate_tensor_fn(batch, collate_fn_map)
#     160     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     161     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 162 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
# Classifier
eps = np.arange(26)
plt.title("Classifier Error")
plt.plot(eps, stats['train_domain_classifier_error'])
plt.plot(eps, stats['val_domain_classifier_error'])

# %%
# Estimator
plt.title("Estimator Error")
plt.plot(eps, stats['train_estimator_error'])
plt.plot(eps, stats['val_estimator_error'])
plt.plot(eps, stats['val_estimator_error_target'])

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_score'])
plt.plot(eps, stats['val_score'])
plt.plot(eps, stats['val_score_target'])

# %%
# Test Source
preds = np.array([])
true = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds = np.append(preds, pred.cpu())
        true = np.append(true, y.cpu())
        score = r2_score(y.cpu(), pred.cpu())
        score_list = np.append(score_list, score)

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true, preds,  color='black', alpha = 0.05)
line = np.linspace(0, 4, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD - Source')
# Out:
# Source R2 Score is 0.9907
# Text(0.5, 1.0, 'MMD - Source')

# %%
# Test target
preds = np.array([])
true = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds = np.append(preds, pred.cpu())
        true = np.append(true, y.cpu())
        score = r2_score(y.cpu(), pred.cpu())
        score_list = np.append(score_list, score)

score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true, preds,  color='black', alpha = 0.05)
line = np.linspace(0, 4, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD - Target')
# Out:
# Target R2 Score is 0.7840
# Text(0.5, 1.0, 'MMD - Target')
