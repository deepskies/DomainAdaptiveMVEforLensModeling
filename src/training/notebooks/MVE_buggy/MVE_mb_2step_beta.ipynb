# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# Set Seed
torch.manual_seed(22)

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Load in data
head = Path.cwd().parents[3]
source_img_path = head / 'data/mb_lenscolor_source/mb_lenscolor_source.npy'
target_img_path = head / 'data/mb_lenscolor_target/mb_lenscolor_target.npy'
source_meta = head / 'data/mb_lenscolor_source/mb_lenscolor_source_metadata.csv'
target_meta = head / 'data/mb_lenscolor_target/mb_lenscolor_target_metadata.csv'
batch_size = 32
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %%
# Define and initialize model
class NeuralNetwork(nn.Module):
    def __init__(self, npix):
        super(NeuralNetwork, self).__init__()
        self.feature = nn.Sequential()
        self.feature.add_module('f_conv1', nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_bn1', nn.BatchNorm2d(8))
        self.feature.add_module('f_pool1', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv2', nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_bn2', nn.BatchNorm2d(16))
        self.feature.add_module('f_pool2', nn.MaxPool2d(kernel_size=2, stride=2))
        self.feature.add_module('f_conv3', nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding='same'))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        self.feature.add_module('f_bn3', nn.BatchNorm2d(32))
        self.feature.add_module('f_pool3', nn.MaxPool2d(kernel_size=2, stride=2))

        self.regressor = nn.Sequential()
        self.regressor.add_module('r_fc1', nn.Linear(in_features=32*5*5, out_features=128))
        self.regressor.add_module('r_relu1', nn.ReLU(True))
        self.regressor.add_module('r_fc3', nn.Linear(in_features=128, out_features=2))

        self.npix = npix

    def forward(self, x):
        x = x.view(-1, 3, self.npix, self.npix)

        features = self.feature(x)
        features = features.view(-1, 32*5*5)
        estimate = self.regressor(features)
        estimate = F.relu(estimate)
        estimate = estimate.view(-1, 2)

        return estimate, features


    def get_feature(self, x):
        x = x.view(-1, 3, self.npix, self.npix)
        features = self.feature(x)
        features = features.view(-1, 32*5*5)
        return features

# %%
def loss_bnll(mean, variance, truth, beta, epsilon = 1e-7):  # beta=0.5):
    """Compute beta-NLL loss

    :param mean: Predicted mean of shape B x D
    :param variance: Predicted variance of shape B x D
    :param truth: truth of shape B x D
    :param beta: Parameter from range [0, 1] controlling relative
        weighting between data points, where `0` corresponds to
        high weight on low error points and `1` to an equal weighting.
    :returns: Loss per batch element of shape B
    """
    variance = variance + epsilon
    loss = 0.5 * ((truth - mean) ** 2 / variance + variance.log())
    if beta > 0:
        loss = loss * (variance.detach() ** beta)
    return loss.sum(axis=-1) / len(mean)

# %%
# Define training loop
def train_loop(source_dataloader, 
               target_dataloader, 
               model, 
               regressor_loss_fn,
               da_loss,
               optimizer,
               n_epoch,
               epoch,
               init_wt_da,
               final_wt_da,
               beta_init,
               beta_final):
               # init_wt_mve,
               # final_wt_mve):
    """
    Trains the Neural Network on Source/Target Domains with the following loss:
        Loss = Source Regression Loss + 1.4 * DA MMD Loss
    
    source_dataloader: DataLoader for the source domain data.
	target_dataloader: DataLoader for the target domain data.
	model: The neural network model to be trained.
	regressor_loss_fn: Loss function for the regression task (e.g., MSELoss).
	da_loss: Loss function for domain adaptation (e.g., MMD loss).
	optimizer: Optimizer for the model parameters.
	n_epoch: Total number of epochs for training.
	epoch: Current epoch number.
    """

    domain_error = 0
    domain_classifier_accuracy = 0
    estimator_error = 0
    mve_error = 0
    score_list = np.array([])

    # Iteration length is shorter of the two datasets
    len_dataloader = min(len(source_dataloader), len(target_dataloader))
    data_source_iter = iter(source_dataloader)
    data_target_iter = iter(target_dataloader)

    # Iterate over the two datasets
    i = 0
    while i < len_dataloader:

        # Time-varying hyperparameter, p 0 -> infty, alpha 0 -> 1
        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader # UNUSED
        alpha = 2. / (1. + np.exp(-10 * p)) - 1 # UNUSED

        # Source Training

        # Load a batch of source data, move to GPU
        data_source = next(data_source_iter)
        X, y = data_source
        X = X.float()
        X = X.cuda()
        y = y.cuda()

        # Zero model gradients and labels
        model.zero_grad()
        batch_size = len(y)

        domain_label = torch.zeros(batch_size)
        domain_label = domain_label.long()
        domain_label = domain_label.cuda()

        # Apply data to model and get predictions, embeddings, apply gradients
        estimate_output, domain_output_source = model(X)
        mean = estimate_output[:, 0]
        variance = estimate_output[:, 1]

        # print(y.shape)
        # print(mean.shape)
        # Calculate source regression loss based on predictions
        estimate_loss = regressor_loss_fn(mean, y)

        
        # Target Training

        data_target = next(data_target_iter)
        X_target, _ = data_target
        X_target = X_target.float()
        X_target = X_target.cuda()

        batch_size = len(X_target)

        _, domain_output_target = model(X_target)

        # Calculate the DA Loss between source and target, MMD loss
        domain_loss = da_loss(domain_output_source, domain_output_target)
        beta_val = beta_init - (beta_init - beta_final) * (epoch / n_epoch)
        mve_loss = loss_bnll(mean.flatten(), variance.flatten(), y, beta = beta_val)
        
        # Hyperparameter of da_weight set to weight domain loss vs source loss
        # Perhaps this is where alpha was initially used
        da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
        # mve_weight_power = (init_wt_mve - ((init_wt_mve - final_wt_mve) * (epoch / n_epoch)))
        # mve_weight = 10 ** (-mve_weight_power)

        # Calculate the R2 score of the predictions vs. labels
        score = r2_score(y.cpu().detach().numpy(), mean.cpu().detach().numpy())

        loss = mve_loss + domain_loss * da_weight 

        
        
        # Backpropagation, update optimizer lr
        loss.backward()
        optimizer.step()

        # Update values
        
        # Domain loss is the DA loss or MMD loss between embedding outputs
        domain_error += domain_loss.item()

        # Estimator loss is the source data loss on regression
        estimator_error += estimate_loss.item()

        mve_error += mve_loss.item()

        score_list = np.append(score_list, score)

        i += 1

    # Calculate average scores/errors of batches for this epoch
    score = np.mean(score_list)
    domain_error = domain_error / (len_dataloader)
    estimator_error /= len_dataloader
    mve_error /= len_dataloader

    return [domain_error, estimator_error, mve_error, score]

# %%
def test_loop(source_dataloader, 
              target_dataloader, 
              model, 
              regressor_loss_fn, 
              da_loss, 
              n_epoch, 
              epoch,
              beta_init,
              beta_final):
    """
    Tests the model accuracy.
    
    source_dataloader: DataLoader for the source domain data.
	target_dataloader: DataLoader for the target domain data.
	model: The neural network model to be trained.
	regressor_loss_fn: Loss function for the regression task (e.g., MSELoss).
	da_loss: Loss function for domain adaptation (e.g., MMD loss). UNUSED
	n_epoch: Total number of epochs for training.
	epoch: Current epoch number.
    """

    
    # Evaluating without gradient computation in bg for validation
    with torch.no_grad():
        
        len_dataloader = min(len(source_dataloader), len(target_dataloader))
        data_source_iter = iter(source_dataloader)
        data_target_iter = iter(target_dataloader)

        
        domain_classifier_error = 0
        domain_classifier_accuracy = 0
        estimator_error = 0
        estimator_error_target = 0
        mve_error = 0
        mve_error_target = 0
        score_list = np.array([])
        score_list_target = np.array([])

        i = 0
        while i < len_dataloader:

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # Source Testing

            data_source = next(data_source_iter)
            X, y = data_source
            X = X.float()
            X = X.cuda()
            y = y.cuda()

            batch_size = len(y)

            estimate_output, domain_output = model(X)
            source_mean = estimate_output[:, 0]
            source_variance = estimate_output[:, 1]
            beta_val = beta_init - (beta_init - beta_final) * (epoch / n_epoch)
            
            estimate_loss = regressor_loss_fn(source_mean, y)
            mve_loss = loss_bnll(source_mean.flatten(), source_variance.flatten(), y, beta = beta_val)

            # Target Testing

            data_target = next(data_target_iter)
            X_target, y_target = data_target
            X_target = X_target.float()
            X_target = X_target.cuda()
            y_target = y_target.cuda()

            batch_size = len(X_target)

            estimate_output_target, domain_output = model(X_target)
            target_mean = estimate_output_target[:, 0]
            target_variance = estimate_output_target[:, 1]
            
            estimate_loss_target = regressor_loss_fn(target_mean, y_target)
            mve_loss_target = loss_bnll(target_mean.flatten(), target_variance.flatten(), y_target, beta = beta_val)
            
            # Update values

            # Regression loss on validation testing
            estimator_error += estimate_loss.item()
            estimator_error_target += estimate_loss_target.item()

            # MVE loss on validation testing
            mve_error += mve_loss.item()
            mve_error_target += mve_loss_target.item()

            # R2 Scores on validation testing
            score = r2_score(y.cpu(), source_mean.cpu())
            score_list = np.append(score_list, score)
            score_target = r2_score(y_target.cpu(), target_mean.cpu())
            score_list_target = np.append(score_list_target, score_target)

            i += 1

        score = np.mean(score_list)
        score_target = np.mean(score_list_target)
        estimator_error /= len_dataloader
        estimator_error_target /= len_dataloader
        mve_error /= len_dataloader
        mve_error_target /= len_dataloader
        
    classifier_error = 1 # UNUSED, legacy
    return [classifier_error, estimator_error, estimator_error_target, score, score_target, mve_error, mve_error_target]

# %%
model = NeuralNetwork(npix=40).cuda()
learning_rate = 2e-5
epochs = 75
# Define loss functions and optimizer
regressor_loss_fn = nn.MSELoss().cuda()

# Try to adjust momentum -> see if that helps
# Try SGD, Adadelta, see if that helps
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
da_loss = MMD_loss()

source_labels = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
target_labels = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
mod_name = None#"models/mb_lenscolor_jul25_1700" #
stats = {'train_DA_loss':[],
             'train_regression_loss':[],
             'train_mve_loss':[],
             'train_r2_score':[],
             'val_source_regression_loss':[],
             'val_target_regression_loss':[],
             'val_source_r2_score':[],
             'val_target_r2_score':[],
             'val_source_mve_loss': [],
             'val_target_mve_loss': [],
            'epoch_no': 0}
if mod_name is not None:
    state = torch.load(mod_name)
    model.load_state_dict(state['state_dict'])
    optimizer.load_state_dict(state['optimizer'])
    
    stat_file = Path(mod_name+'.json')
    if stat_file.is_file():
        stats = json.load(open(mod_name+'.json', 'r'))

# %%
print("Beginning Training...")
mod_name = "models/mb_mvebeta_75epoch_aug2_0000"
# Train
best_target_R2 = -1.0
for i in range(stats['epoch_no'], stats['epoch_no'] + epochs):
        # if (i % 5 == 0):
        #     print("Generating Isomap...")
        #     source_iso, target_iso, trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
        #     show_isomaps(source_iso, target_iso, trained_source_iso, trained_target_iso, source_labels, target_labels, mod_name, stats["epoch_no"], 15000, 50, save = True)
        if (len(stats['val_target_r2_score']) > 0) and (stats['val_target_r2_score'][-1] > best_target_R2):
            print("Saving Model...", end = ' ')
            state = {
                    'epoch': stats['epoch_no'],
                    'state_dict': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    }
            json.dump(stats, open(mod_name+'.json', 'w'))
            torch.save(state, mod_name)
            best_target_R2 = stats['val_target_r2_score'][-1]
            print("Done.")
            
        start_time = time.time()
        vals = train_loop(source_train_dataloader, target_train_dataloader, model,
                   regressor_loss_fn, da_loss, optimizer, epochs, i, init_wt_da = 1.4, final_wt_da = 1.4, beta_init = 1, beta_final = 0.0)
#                         init_wt_mve = 6, final_wt_mve = 2)

        vals_validate = test_loop(source_val_dataloader, target_val_dataloader,
                         model, regressor_loss_fn, da_loss, epochs, i, beta_init = 1, beta_final = 0.0)

        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])
        stats['val_source_regression_loss'].append(vals_validate[1])
        stats['val_target_regression_loss'].append(vals_validate[2])
        stats['val_source_r2_score'].append(vals_validate[3])
        stats['val_target_r2_score'].append(vals_validate[4])
        stats['val_source_mve_loss'].append(vals_validate[5])
        stats['val_target_mve_loss'].append(vals_validate[6])
        stats['epoch_no'] += 1

        
        print_epoch_scores(stats, i, time.time() - start_time)
# Out:
# Beginning Training...
#
# Epoch 0: 22.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.3768
# 	Train Regression Loss: : 0.9861
# 	Train Mve Loss: : 0.4409
# 	Train R2 Score: : -2.1079
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1725
# 	Val Target Regression Loss: : 0.2009
# 	Val Source R2 Score: : 0.4594
# 	Val Target R2 Score: : 0.3623
# 	Val Source Mve Loss: : -0.0676
# 	Val Target Mve Loss: : -0.0495
# Saving Model... Done.
#
# Epoch 1: 20.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2238
# 	Train Regression Loss: : 0.1100
# 	Train Mve Loss: : -0.0828
# 	Train R2 Score: : 0.6540
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0837
# 	Val Target Regression Loss: : 0.1086
# 	Val Source R2 Score: : 0.7324
# 	Val Target R2 Score: : 0.6562
# 	Val Source Mve Loss: : -0.0819
# 	Val Target Mve Loss: : -0.0811
# Saving Model... Done.
#
# Epoch 2: 19.73s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1867
# 	Train Regression Loss: : 0.0704
# 	Train Mve Loss: : -0.0931
# 	Train R2 Score: : 0.7778
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0644
# 	Val Target Regression Loss: : 0.0844
# 	Val Source R2 Score: : 0.7971
# 	Val Target R2 Score: : 0.7359
# 	Val Source Mve Loss: : -0.0851
# 	Val Target Mve Loss: : -0.0864
# Saving Model... Done.
#
# Epoch 3: 16.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1698
# 	Train Regression Loss: : 0.0552
# 	Train Mve Loss: : -0.0892
# 	Train R2 Score: : 0.8267
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0542
# 	Val Target Regression Loss: : 0.0688
# 	Val Source R2 Score: : 0.8318
# 	Val Target R2 Score: : 0.7811
# 	Val Source Mve Loss: : -0.1305
# 	Val Target Mve Loss: : -0.1245
# Saving Model... Done.
#
# Epoch 4: 15.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1584
# 	Train Regression Loss: : 0.0485
# 	Train Mve Loss: : -0.1046
# 	Train R2 Score: : 0.8473
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0507
# 	Val Target Regression Loss: : 0.0616
# 	Val Source R2 Score: : 0.8407
# 	Val Target R2 Score: : 0.8040
# 	Val Source Mve Loss: : -0.1123
# 	Val Target Mve Loss: : -0.1141
# Saving Model... Done.
#
# Epoch 5: 16.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1529
# 	Train Regression Loss: : 0.0453
# 	Train Mve Loss: : -0.1147
# 	Train R2 Score: : 0.8579
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0495
# 	Val Target Regression Loss: : 0.0583
# 	Val Source R2 Score: : 0.8466
# 	Val Target R2 Score: : 0.8169
# 	Val Source Mve Loss: : -0.0727
# 	Val Target Mve Loss: : -0.0693
# Saving Model... Done.
#
# Epoch 6: 17.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1488
# 	Train Regression Loss: : 0.0435
# 	Train Mve Loss: : -0.0988
# 	Train R2 Score: : 0.8633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0474
# 	Val Target Regression Loss: : 0.0550
# 	Val Source R2 Score: : 0.8494
# 	Val Target R2 Score: : 0.8268
# 	Val Source Mve Loss: : -0.0567
# 	Val Target Mve Loss: : -0.0539
# Saving Model... Done.
#
# Epoch 7: 15.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1428
# 	Train Regression Loss: : 0.0422
# 	Train Mve Loss: : -0.1035
# 	Train R2 Score: : 0.8675
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0446
# 	Val Target Regression Loss: : 0.0528
# 	Val Source R2 Score: : 0.8604
# 	Val Target R2 Score: : 0.8326
# 	Val Source Mve Loss: : -0.1045
# 	Val Target Mve Loss: : -0.0931
# Saving Model... Done.
#
# Epoch 8: 17.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1358
# 	Train Regression Loss: : 0.0401
# 	Train Mve Loss: : -0.1058
# 	Train R2 Score: : 0.8744
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0429
# 	Val Target Regression Loss: : 0.0495
# 	Val Source R2 Score: : 0.8663
# 	Val Target R2 Score: : 0.8452
# 	Val Source Mve Loss: : -0.0827
# 	Val Target Mve Loss: : -0.0751
# Saving Model... Done.
#
# Epoch 9: 22.57s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1324
# 	Train Regression Loss: : 0.0384
# 	Train Mve Loss: : -0.1218
# 	Train R2 Score: : 0.8793
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0422
# 	Val Target Regression Loss: : 0.0482
# 	Val Source R2 Score: : 0.8685
# 	Val Target R2 Score: : 0.8473
# 	Val Source Mve Loss: : -0.1511
# 	Val Target Mve Loss: : -0.1496
# Saving Model... Done.
#
# Epoch 10: 17.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1318
# 	Train Regression Loss: : 0.0379
# 	Train Mve Loss: : -0.1104
# 	Train R2 Score: : 0.8807
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0417
# 	Val Target Regression Loss: : 0.0449
# 	Val Source R2 Score: : 0.8715
# 	Val Target R2 Score: : 0.8586
# 	Val Source Mve Loss: : -0.0526
# 	Val Target Mve Loss: : -0.0318
# Saving Model... Done.
#
# Epoch 11: 15.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1273
# 	Train Regression Loss: : 0.0355
# 	Train Mve Loss: : -0.1304
# 	Train R2 Score: : 0.8883
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0387
# 	Val Target Regression Loss: : 0.0431
# 	Val Source R2 Score: : 0.8787
# 	Val Target R2 Score: : 0.8648
# 	Val Source Mve Loss: : -0.1041
# 	Val Target Mve Loss: : -0.0929
# Saving Model... Done.
#
# Epoch 12: 16.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1235
# 	Train Regression Loss: : 0.0342
# 	Train Mve Loss: : -0.1020
# 	Train R2 Score: : 0.8928
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0379
# 	Val Target Regression Loss: : 0.0412
# 	Val Source R2 Score: : 0.8745
# 	Val Target R2 Score: : 0.8703
# 	Val Source Mve Loss: : -0.1026
# 	Val Target Mve Loss: : -0.0988
# Saving Model... Done.
#
# Epoch 13: 18.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1233
# 	Train Regression Loss: : 0.0323
# 	Train Mve Loss: : -0.1180
# 	Train R2 Score: : 0.8987
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0344
# 	Val Target Regression Loss: : 0.0384
# 	Val Source R2 Score: : 0.8920
# 	Val Target R2 Score: : 0.8790
# 	Val Source Mve Loss: : -0.1217
# 	Val Target Mve Loss: : -0.1091
# Saving Model... Done.
#
# Epoch 14: 15.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1214
# 	Train Regression Loss: : 0.0314
# 	Train Mve Loss: : -0.0919
# 	Train R2 Score: : 0.9013
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0329
# 	Val Target Regression Loss: : 0.0377
# 	Val Source R2 Score: : 0.8973
# 	Val Target R2 Score: : 0.8804
# 	Val Source Mve Loss: : -0.0888
# 	Val Target Mve Loss: : -0.0610
# Saving Model... Done.
#
# Epoch 15: 15.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1194
# 	Train Regression Loss: : 0.0317
# 	Train Mve Loss: : -0.1001
# 	Train R2 Score: : 0.9005
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0330
# 	Val Target Regression Loss: : 0.0410
# 	Val Source R2 Score: : 0.8953
# 	Val Target R2 Score: : 0.8600
# 	Val Source Mve Loss: : -0.0851
# 	Val Target Mve Loss: : -0.0396
#
# Epoch 16: 14.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1183
# 	Train Regression Loss: : 0.0352
# 	Train Mve Loss: : -0.0964
# 	Train R2 Score: : 0.8895
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0356
# 	Val Target Regression Loss: : 0.0407
# 	Val Source R2 Score: : 0.8896
# 	Val Target R2 Score: : 0.8710
# 	Val Source Mve Loss: : -0.0917
# 	Val Target Mve Loss: : -0.0563
#
# Epoch 17: 17.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1169
# 	Train Regression Loss: : 0.0318
# 	Train Mve Loss: : -0.0725
# 	Train R2 Score: : 0.9000
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0343
# 	Val Target Regression Loss: : 0.0378
# 	Val Source R2 Score: : 0.8941
# 	Val Target R2 Score: : 0.8810
# 	Val Source Mve Loss: : -0.0849
# 	Val Target Mve Loss: : -0.0659
# Saving Model... Done.
#
# Epoch 18: 16.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1148
# 	Train Regression Loss: : 0.0321
# 	Train Mve Loss: : -0.1168
# 	Train R2 Score: : 0.8993
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0359
# 	Val Target Regression Loss: : 0.0412
# 	Val Source R2 Score: : 0.8869
# 	Val Target R2 Score: : 0.8694
# 	Val Source Mve Loss: : -0.1482
# 	Val Target Mve Loss: : -0.1212
#
# Epoch 19: 18.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1154
# 	Train Regression Loss: : 0.0356
# 	Train Mve Loss: : -0.0873
# 	Train R2 Score: : 0.8881
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0356
# 	Val Target Regression Loss: : 0.0405
# 	Val Source R2 Score: : 0.8874
# 	Val Target R2 Score: : 0.8725
# 	Val Source Mve Loss: : -0.0880
# 	Val Target Mve Loss: : -0.0620
#
# Epoch 20: 19.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1154
# 	Train Regression Loss: : 0.0335
# 	Train Mve Loss: : -0.0884
# 	Train R2 Score: : 0.8945
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0348
# 	Val Target Regression Loss: : 0.0412
# 	Val Source R2 Score: : 0.8903
# 	Val Target R2 Score: : 0.8700
# 	Val Source Mve Loss: : -0.0373
# 	Val Target Mve Loss: : 0.0362
#
# Epoch 21: 17.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1148
# 	Train Regression Loss: : 0.0315
# 	Train Mve Loss: : -0.0575
# 	Train R2 Score: : 0.9012
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0337
# 	Val Target Regression Loss: : 0.0376
# 	Val Source R2 Score: : 0.8943
# 	Val Target R2 Score: : 0.8813
# 	Val Source Mve Loss: : -0.0738
# 	Val Target Mve Loss: : -0.0182
# Saving Model... Done.
#
# Epoch 22: 19.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1142
# 	Train Regression Loss: : 0.0304
# 	Train Mve Loss: : -0.1045
# 	Train R2 Score: : 0.9044
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0339
# 	Val Target Regression Loss: : 0.0361
# 	Val Source R2 Score: : 0.8945
# 	Val Target R2 Score: : 0.8843
# 	Val Source Mve Loss: : 0.0452
# 	Val Target Mve Loss: : 0.0731
# Saving Model... Done.
#
# Epoch 23: 24.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1163
# 	Train Regression Loss: : 0.0347
# 	Train Mve Loss: : -0.0163
# 	Train R2 Score: : 0.8908
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0354
# 	Val Target Regression Loss: : 0.0411
# 	Val Source R2 Score: : 0.8898
# 	Val Target R2 Score: : 0.8689
# 	Val Source Mve Loss: : -0.0217
# 	Val Target Mve Loss: : -0.0264
#
# Epoch 24: 19.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1165
# 	Train Regression Loss: : 0.0332
# 	Train Mve Loss: : -0.0611
# 	Train R2 Score: : 0.8960
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0362
# 	Val Target Regression Loss: : 0.0405
# 	Val Source R2 Score: : 0.8853
# 	Val Target R2 Score: : 0.8725
# 	Val Source Mve Loss: : -0.1151
# 	Val Target Mve Loss: : -0.1192
#
# Epoch 25: 22.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1165
# 	Train Regression Loss: : 0.0335
# 	Train Mve Loss: : -0.1299
# 	Train R2 Score: : 0.8944
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0354
# 	Val Target Regression Loss: : 0.0398
# 	Val Source R2 Score: : 0.8894
# 	Val Target R2 Score: : 0.8734
# 	Val Source Mve Loss: : -0.1073
# 	Val Target Mve Loss: : -0.0493
#
# Epoch 26: 19.84s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1161
# 	Train Regression Loss: : 0.0308
# 	Train Mve Loss: : -0.0310
# 	Train R2 Score: : 0.9034
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0335
# 	Val Target Regression Loss: : 0.0376
# 	Val Source R2 Score: : 0.8914
# 	Val Target R2 Score: : 0.8799
# 	Val Source Mve Loss: : -0.1361
# 	Val Target Mve Loss: : -0.0561
#
# Epoch 27: 19.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1163
# 	Train Regression Loss: : 0.0305
# 	Train Mve Loss: : -0.1086
# 	Train R2 Score: : 0.9034
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0331
# 	Val Target Regression Loss: : 0.0380
# 	Val Source R2 Score: : 0.8957
# 	Val Target R2 Score: : 0.8787
# 	Val Source Mve Loss: : -0.0483
# 	Val Target Mve Loss: : 0.1098
#
# Epoch 28: 15.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1162
# 	Train Regression Loss: : 0.0303
# 	Train Mve Loss: : 0.0161
# 	Train R2 Score: : 0.9049
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0348
# 	Val Target Regression Loss: : 0.0359
# 	Val Source R2 Score: : 0.8880
# 	Val Target R2 Score: : 0.8854
# 	Val Source Mve Loss: : 0.0500
# 	Val Target Mve Loss: : 0.0353
# Saving Model... Done.
#
# Epoch 29: 21.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1160
# 	Train Regression Loss: : 0.0298
# 	Train Mve Loss: : 0.0842
# 	Train R2 Score: : 0.9061
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0318
# 	Val Target Regression Loss: : 0.0365
# 	Val Source R2 Score: : 0.9018
# 	Val Target R2 Score: : 0.8843
# 	Val Source Mve Loss: : 0.5000
# 	Val Target Mve Loss: : 0.6938
#
# Epoch 30: 15.89s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1139
# 	Train Regression Loss: : 0.0307
# 	Train Mve Loss: : -0.0125
# 	Train R2 Score: : 0.9035
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0360
# 	Val Target Regression Loss: : 0.0417
# 	Val Source R2 Score: : 0.8880
# 	Val Target R2 Score: : 0.8667
# 	Val Source Mve Loss: : 0.3126
# 	Val Target Mve Loss: : 0.7794
#
# Epoch 31: 15.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1152
# 	Train Regression Loss: : 0.0309
# 	Train Mve Loss: : 0.1513
# 	Train R2 Score: : 0.9033
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0310
# 	Val Target Regression Loss: : 0.0358
# 	Val Source R2 Score: : 0.9025
# 	Val Target R2 Score: : 0.8862
# 	Val Source Mve Loss: : 0.8053
# 	Val Target Mve Loss: : 1.0596
# Saving Model... Done.
#
# Epoch 32: 17.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1164
# 	Train Regression Loss: : 0.0307
# 	Train Mve Loss: : 0.1057
# 	Train R2 Score: : 0.9037
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0330
# 	Val Target Regression Loss: : 0.0382
# 	Val Source R2 Score: : 0.8976
# 	Val Target R2 Score: : 0.8796
# 	Val Source Mve Loss: : 0.0109
# 	Val Target Mve Loss: : -0.0262
#
# Epoch 33: 11.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1154
# 	Train Regression Loss: : 0.0305
# 	Train Mve Loss: : -0.0619
# 	Train R2 Score: : 0.9040
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0402
# 	Val Target Regression Loss: : 0.0437
# 	Val Source R2 Score: : 0.8744
# 	Val Target R2 Score: : 0.8602
# 	Val Source Mve Loss: : -0.1209
# 	Val Target Mve Loss: : -0.1463
#
# Epoch 34: 12.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1159
# 	Train Regression Loss: : 0.0324
# 	Train Mve Loss: : 0.1381
# 	Train R2 Score: : 0.8979
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0306
# 	Val Target Regression Loss: : 0.0353
# 	Val Source R2 Score: : 0.9046
# 	Val Target R2 Score: : 0.8885
# 	Val Source Mve Loss: : 1.3465
# 	Val Target Mve Loss: : 2.2060
# Saving Model... Done.
#
# Epoch 35: 14.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1150
# 	Train Regression Loss: : 0.0331
# 	Train Mve Loss: : 0.5407
# 	Train R2 Score: : 0.8960
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0335
# 	Val Target Regression Loss: : 0.0357
# 	Val Source R2 Score: : 0.8950
# 	Val Target R2 Score: : 0.8862
# 	Val Source Mve Loss: : 1.2530
# 	Val Target Mve Loss: : 1.6772
#
# Epoch 36: 15.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1163
# 	Train Regression Loss: : 0.0300
# 	Train Mve Loss: : 0.9384
# 	Train R2 Score: : 0.9058
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0316
# 	Val Target Regression Loss: : 0.0344
# 	Val Source R2 Score: : 0.9012
# 	Val Target R2 Score: : 0.8911
# 	Val Source Mve Loss: : 1.3359
# 	Val Target Mve Loss: : 2.0725
# Saving Model... Done.
#
# Epoch 37: 13.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1183
# 	Train Regression Loss: : 0.0281
# 	Train Mve Loss: : 0.8683
# 	Train R2 Score: : 0.9113
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0304
# 	Val Target Regression Loss: : 0.0326
# 	Val Source R2 Score: : 0.9050
# 	Val Target R2 Score: : 0.8968
# 	Val Source Mve Loss: : 0.2097
# 	Val Target Mve Loss: : 0.0985
# Saving Model... Done.
#
# Epoch 38: 14.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1166
# 	Train Regression Loss: : 0.0280
# 	Train Mve Loss: : 0.4710
# 	Train R2 Score: : 0.9122
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0298
# 	Val Target Regression Loss: : 0.0328
# 	Val Source R2 Score: : 0.9073
# 	Val Target R2 Score: : 0.8965
# 	Val Source Mve Loss: : -0.0688
# 	Val Target Mve Loss: : -0.0751
#
# Epoch 39: 12.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1176
# 	Train Regression Loss: : 0.0281
# 	Train Mve Loss: : -0.0224
# 	Train R2 Score: : 0.9117
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0284
# 	Val Target Regression Loss: : 0.0320
# 	Val Source R2 Score: : 0.9119
# 	Val Target R2 Score: : 0.8975
# 	Val Source Mve Loss: : -0.0871
# 	Val Target Mve Loss: : 0.1016
# Saving Model... Done.
#
# Epoch 40: 15.73s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1158
# 	Train Regression Loss: : 0.0345
# 	Train Mve Loss: : 1.3792
# 	Train R2 Score: : 0.8916
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0305
# 	Val Target Regression Loss: : 0.0323
# 	Val Source R2 Score: : 0.9045
# 	Val Target R2 Score: : 0.8968
# 	Val Source Mve Loss: : 1.5813
# 	Val Target Mve Loss: : 1.9848
#
# Epoch 41: 14.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1181
# 	Train Regression Loss: : 0.0461
# 	Train Mve Loss: : 0.9291
# 	Train R2 Score: : 0.8553
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0506
# 	Val Target Regression Loss: : 0.0509
# 	Val Source R2 Score: : 0.8427
# 	Val Target R2 Score: : 0.8356
# 	Val Source Mve Loss: : 0.5071
# 	Val Target Mve Loss: : 0.4789
#
# Epoch 42: 12.24s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1203
# 	Train Regression Loss: : 0.0411
# 	Train Mve Loss: : 0.9958
# 	Train R2 Score: : 0.8711
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0340
# 	Val Target Regression Loss: : 0.0337
# 	Val Source R2 Score: : 0.8932
# 	Val Target R2 Score: : 0.8914
# 	Val Source Mve Loss: : 0.4058
# 	Val Target Mve Loss: : 1.4621
#
# Epoch 43: 12.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1238
# 	Train Regression Loss: : 0.0311
# 	Train Mve Loss: : 0.3373
# 	Train R2 Score: : 0.9020
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0304
# 	Val Target Regression Loss: : 0.0314
# 	Val Source R2 Score: : 0.9044
# 	Val Target R2 Score: : 0.9000
# 	Val Source Mve Loss: : 0.3716
# 	Val Target Mve Loss: : 0.7534
# Saving Model... Done.
#
# Epoch 44: 11.51s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1237
# 	Train Regression Loss: : 0.0428
# 	Train Mve Loss: : 0.7233
# 	Train R2 Score: : 0.8654
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0367
# 	Val Target Regression Loss: : 0.0379
# 	Val Source R2 Score: : 0.8848
# 	Val Target R2 Score: : 0.8793
# 	Val Source Mve Loss: : 0.0497
# 	Val Target Mve Loss: : 1.4870
#
# Epoch 45: 12.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1256
# 	Train Regression Loss: : 0.0574
# 	Train Mve Loss: : 1.2108
# 	Train R2 Score: : 0.8196
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0475
# 	Val Target Regression Loss: : 0.0552
# 	Val Source R2 Score: : 0.8520
# 	Val Target R2 Score: : 0.8242
# 	Val Source Mve Loss: : -0.0096
# 	Val Target Mve Loss: : -0.0165
#
# Epoch 46: 16.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1238
# 	Train Regression Loss: : 0.0382
# 	Train Mve Loss: : 0.0070
# 	Train R2 Score: : 0.8792
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0357
# 	Val Target Regression Loss: : 0.0393
# 	Val Source R2 Score: : 0.8896
# 	Val Target R2 Score: : 0.8737
# 	Val Source Mve Loss: : 3.2800
# 	Val Target Mve Loss: : 2.6416
#
# Epoch 47: 14.99s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1243
# 	Train Regression Loss: : 0.0445
# 	Train Mve Loss: : 3.1781
# 	Train R2 Score: : 0.8592
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0653
# 	Val Target Regression Loss: : 0.0638
# 	Val Source R2 Score: : 0.7968
# 	Val Target R2 Score: : 0.7957
# 	Val Source Mve Loss: : 6.0322
# 	Val Target Mve Loss: : -0.2052
#
# Epoch 48: 17.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1241
# 	Train Regression Loss: : 0.0875
# 	Train Mve Loss: : 4.5073
# 	Train R2 Score: : 0.7223
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0547
# 	Val Target Regression Loss: : 0.0556
# 	Val Source R2 Score: : 0.8288
# 	Val Target R2 Score: : 0.8229
# 	Val Source Mve Loss: : 4.3920
# 	Val Target Mve Loss: : -0.1549
#
# Epoch 49: 17.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1253
# 	Train Regression Loss: : 0.0886
# 	Train Mve Loss: : 1.2643
# 	Train R2 Score: : 0.7195
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1028
# 	Val Target Regression Loss: : 0.1006
# 	Val Source R2 Score: : 0.6738
# 	Val Target R2 Score: : 0.6766
# 	Val Source Mve Loss: : 4.9365
# 	Val Target Mve Loss: : 9.2627
#
# Epoch 50: 19.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1257
# 	Train Regression Loss: : 0.0612
# 	Train Mve Loss: : 2.4051
# 	Train R2 Score: : 0.8063
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0570
# 	Val Target Regression Loss: : 0.0662
# 	Val Source R2 Score: : 0.8214
# 	Val Target R2 Score: : 0.7895
# 	Val Source Mve Loss: : 0.0074
# 	Val Target Mve Loss: : -0.0000
#
# Epoch 51: 25.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1267
# 	Train Regression Loss: : 0.0503
# 	Train Mve Loss: : -0.0479
# 	Train R2 Score: : 0.8407
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0499
# 	Val Target Regression Loss: : 0.0578
# 	Val Source R2 Score: : 0.8431
# 	Val Target R2 Score: : 0.8151
# 	Val Source Mve Loss: : 6.5448
# 	Val Target Mve Loss: : 0.8278
#
# Epoch 52: 21.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1285
# 	Train Regression Loss: : 0.0665
# 	Train Mve Loss: : 7.0820
# 	Train R2 Score: : 0.7904
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0460
# 	Val Target Regression Loss: : 0.0520
# 	Val Source R2 Score: : 0.8558
# 	Val Target R2 Score: : 0.8317
# 	Val Source Mve Loss: : 8.1524
# 	Val Target Mve Loss: : 1.6947
#
# Epoch 53: 18.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1286
# 	Train Regression Loss: : 0.1045
# 	Train Mve Loss: : 5.4646
# 	Train R2 Score: : 0.6682
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.4587
# 	Val Target Regression Loss: : 0.4573
# 	Val Source R2 Score: : -0.4595
# 	Val Target R2 Score: : -0.4554
# 	Val Source Mve Loss: : 20.6800
# 	Val Target Mve Loss: : 27.0312
#
# Epoch 54: 21.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1290
# 	Train Regression Loss: : 0.2130
# 	Train Mve Loss: : 0.7167
# 	Train R2 Score: : 0.3208
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1083
# 	Val Target Regression Loss: : 0.1198
# 	Val Source R2 Score: : 0.6565
# 	Val Target R2 Score: : 0.6158
# 	Val Source Mve Loss: : 8.8968
# 	Val Target Mve Loss: : 8.3495
#
# Epoch 55: 18.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1270
# 	Train Regression Loss: : 0.0820
# 	Train Mve Loss: : 5.6119
# 	Train R2 Score: : 0.7397
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0705
# 	Val Target Regression Loss: : 0.0842
# 	Val Source R2 Score: : 0.7768
# 	Val Target R2 Score: : 0.7323
# 	Val Source Mve Loss: : 4.8858
# 	Val Target Mve Loss: : 9.6942
#
# Epoch 56: 23.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1274
# 	Train Regression Loss: : 0.0789
# 	Train Mve Loss: : 3.2058
# 	Train R2 Score: : 0.7504
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0642
# 	Val Target Regression Loss: : 0.0762
# 	Val Source R2 Score: : 0.7987
# 	Val Target R2 Score: : 0.7543
# 	Val Source Mve Loss: : 0.1561
# 	Val Target Mve Loss: : 3.3367
#
# Epoch 57: 16.28s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1274
# 	Train Regression Loss: : 0.0608
# 	Train Mve Loss: : 0.1474
# 	Train R2 Score: : 0.8079
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0618
# 	Val Target Regression Loss: : 0.0729
# 	Val Source R2 Score: : 0.8089
# 	Val Target R2 Score: : 0.7696
# 	Val Source Mve Loss: : 0.1424
# 	Val Target Mve Loss: : 0.1428
#
# Epoch 58: 14.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1284
# 	Train Regression Loss: : 0.0574
# 	Train Mve Loss: : 0.1247
# 	Train R2 Score: : 0.8185
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0540
# 	Val Target Regression Loss: : 0.0627
# 	Val Source R2 Score: : 0.8310
# 	Val Target R2 Score: : 0.8025
# 	Val Source Mve Loss: : 8.4094
# 	Val Target Mve Loss: : 0.7955
#
# Epoch 59: 20.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1280
# 	Train Regression Loss: : 0.0952
# 	Train Mve Loss: : 12.1482
# 	Train R2 Score: : 0.7003
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1674
# 	Val Target Regression Loss: : 0.1515
# 	Val Source R2 Score: : 0.4687
# 	Val Target R2 Score: : 0.5180
# 	Val Source Mve Loss: : 163.2981
# 	Val Target Mve Loss: : 80.0040
#
# Epoch 60: 19.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1307
# 	Train Regression Loss: : 0.2036
# 	Train Mve Loss: : 54.1448
# 	Train R2 Score: : 0.3566
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.7648
# 	Val Target Regression Loss: : 0.7357
# 	Val Source R2 Score: : -1.4006
# 	Val Target R2 Score: : -1.3579
# 	Val Source Mve Loss: : 81.8374
# 	Val Target Mve Loss: : 108.2387
#
# Epoch 61: 18.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1341
# 	Train Regression Loss: : 0.2266
# 	Train Mve Loss: : 11.3345
# 	Train R2 Score: : 0.2789
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1415
# 	Val Target Regression Loss: : 0.1374
# 	Val Source R2 Score: : 0.5528
# 	Val Target R2 Score: : 0.5573
# 	Val Source Mve Loss: : 17.0722
# 	Val Target Mve Loss: : 59.3238
#
# Epoch 62: 12.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1350
# 	Train Regression Loss: : 0.2077
# 	Train Mve Loss: : 13.7883
# 	Train R2 Score: : 0.3392
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.3725
# 	Val Target Regression Loss: : 0.3742
# 	Val Source R2 Score: : -0.1669
# 	Val Target R2 Score: : -0.2166
# 	Val Source Mve Loss: : 2.4901
# 	Val Target Mve Loss: : 432.4814
#
# Epoch 63: 14.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1330
# 	Train Regression Loss: : 0.2311
# 	Train Mve Loss: : 42.7999
# 	Train R2 Score: : 0.2624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1007
# 	Val Target Regression Loss: : 0.1060
# 	Val Source R2 Score: : 0.6829
# 	Val Target R2 Score: : 0.6618
# 	Val Source Mve Loss: : 99.5845
# 	Val Target Mve Loss: : 108.4255
#
# Epoch 64: 15.93s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1371
# 	Train Regression Loss: : 0.1166
# 	Train Mve Loss: : 32.4718
# 	Train R2 Score: : 0.6305
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2091
# 	Val Target Regression Loss: : 0.2256
# 	Val Source R2 Score: : 0.3429
# 	Val Target R2 Score: : 0.2779
# 	Val Source Mve Loss: : 0.0819
# 	Val Target Mve Loss: : 222.7890
#
# Epoch 65: 14.62s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1390
# 	Train Regression Loss: : 0.1961
# 	Train Mve Loss: : 40.1569
# 	Train R2 Score: : 0.3785
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1544
# 	Val Target Regression Loss: : 0.1730
# 	Val Source R2 Score: : 0.5144
# 	Val Target R2 Score: : 0.4410
# 	Val Source Mve Loss: : 208.5407
# 	Val Target Mve Loss: : 226.6717
#
# Epoch 66: 14.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1416
# 	Train Regression Loss: : 0.1724
# 	Train Mve Loss: : 178.5760
# 	Train R2 Score: : 0.4502
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1186
# 	Val Target Regression Loss: : 0.1383
# 	Val Source R2 Score: : 0.6216
# 	Val Target R2 Score: : 0.5430
# 	Val Source Mve Loss: : 29.6834
# 	Val Target Mve Loss: : 66.1640
#
# Epoch 67: 17.20s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1444
# 	Train Regression Loss: : 0.0987
# 	Train Mve Loss: : 136.7439
# 	Train R2 Score: : 0.6874
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1361
# 	Val Target Regression Loss: : 0.1289
# 	Val Source R2 Score: : 0.5689
# 	Val Target R2 Score: : 0.5871
# 	Val Source Mve Loss: : 17.0042
# 	Val Target Mve Loss: : 166.2610
#
# Epoch 68: 16.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1465
# 	Train Regression Loss: : 0.1177
# 	Train Mve Loss: : 294.9470
# 	Train R2 Score: : 0.6313
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0641
# 	Val Target Regression Loss: : 0.0696
# 	Val Source R2 Score: : 0.7967
# 	Val Target R2 Score: : 0.7548
# 	Val Source Mve Loss: : 36.8804
# 	Val Target Mve Loss: : 4.6510
#
# Epoch 69: 16.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1458
# 	Train Regression Loss: : 0.0793
# 	Train Mve Loss: : 36.8724
# 	Train R2 Score: : 0.7483
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0485
# 	Val Target Regression Loss: : 0.0531
# 	Val Source R2 Score: : 0.8488
# 	Val Target R2 Score: : 0.8322
# 	Val Source Mve Loss: : 21.9729
# 	Val Target Mve Loss: : -0.0432
#
# Epoch 70: 20.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1446
# 	Train Regression Loss: : 0.2005
# 	Train Mve Loss: : 18.5576
# 	Train R2 Score: : 0.3658
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2280
# 	Val Target Regression Loss: : 0.2402
# 	Val Source R2 Score: : 0.2843
# 	Val Target R2 Score: : 0.2307
# 	Val Source Mve Loss: : 0.0835
# 	Val Target Mve Loss: : 0.0615
#
# Epoch 71: 24.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1456
# 	Train Regression Loss: : 0.1992
# 	Train Mve Loss: : 35.7211
# 	Train R2 Score: : 0.3678
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1224
# 	Val Target Regression Loss: : 0.1262
# 	Val Source R2 Score: : 0.6145
# 	Val Target R2 Score: : 0.5892
# 	Val Source Mve Loss: : 30.4629
# 	Val Target Mve Loss: : -0.0241
#
# Epoch 72: 26.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1457
# 	Train Regression Loss: : 0.2719
# 	Train Mve Loss: : 315.6865
# 	Train R2 Score: : 0.1426
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2921
# 	Val Target Regression Loss: : 0.3046
# 	Val Source R2 Score: : 0.0713
# 	Val Target R2 Score: : 0.0208
# 	Val Source Mve Loss: : 367.6517
# 	Val Target Mve Loss: : 0.0430
#
# Epoch 73: 21.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1460
# 	Train Regression Loss: : 0.1687
# 	Train Mve Loss: : 98.3957
# 	Train R2 Score: : 0.4650
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0753
# 	Val Target Regression Loss: : 0.0802
# 	Val Source R2 Score: : 0.7608
# 	Val Target R2 Score: : 0.7455
# 	Val Source Mve Loss: : 750.7222
# 	Val Target Mve Loss: : -0.1562
#
# Epoch 74: 24.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1451
# 	Train Regression Loss: : 0.2821
# 	Train Mve Loss: : 512.2986
# 	Train R2 Score: : 0.1123
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.9761
# 	Val Target Regression Loss: : 0.9690
# 	Val Source R2 Score: : -2.0961
# 	Val Target R2 Score: : -2.1113
# 	Val Source Mve Loss: : 4706.8716
# 	Val Target Mve Loss: : 2642.1094

# %%
state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
mod_name = "models/mb_mvebetaFinal_75epoch_aug2_0000"
torch.save(state, mod_name)
json.dump(stats, open(mod_name+'.json', 'w'))

# %% [markdown]
# mod_name = "models/mb_lenscolor_jul25_1740"
# model.load_state_dict(torch.load(mod_name)['state_dict'])
# stats = json.load(open(mod_name+'.json', 'r'))

# %% [markdown]
# def generate_isomaps(source_data, target_data, model, n_neighbors = 5, n_components = 2, n_points = 1000):
#     device = "cuda" if torch.cuda.is_available() else "cpu"
#     gc.collect()
#     torch.cuda.empty_cache()
#
#     isomap = Isomap(n_neighbors=n_neighbors, n_components=n_components)
#     train_isomap = Isomap(n_neighbors=n_neighbors, n_components=n_components)
#
#     sdata = source_data.reshape([-1, np.prod(source_data.shape[1:])])[:n_points]
#     tdata = target_data.reshape([-1, np.prod(target_data.shape[1:])])[:n_points]
#     catdata = np.concatenate((sdata, tdata), axis=0)
#     print(catdata.shape)
#     isomap = isomap.fit(catdata)
#
#     with torch.no_grad():
#         source_tensor = torch.FloatTensor(source_data[:n_points]).to(device)
#         target_tensor = torch.FloatTensor(target_data[:n_points]).to(device)
#         sfeat = model.get_feature(source_tensor).cpu().detach().numpy()
#         tfeat = model.get_feature(target_tensor).cpu().detach().numpy()
#         catfeat = np.concatenate((sfeat, tfeat), axis=0)
#
#     train_isomap = train_isomap.fit(catfeat)
#     trained_source_iso = train_isomap.transform(sfeat)
#     trained_target_iso = train_isomap.transform(tfeat)
#
#     del sfeat
#     del tfeat
#
#     source_iso = isomap.transform(sdata)
#     target_iso = isomap.transform(tdata)
#
#     return source_iso, target_iso, trained_source_iso, trained_target_iso

# %%
source_iso, target_iso, trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
# Out:
# (2000, 6075)

# %% [markdown]
# def show_isomaps(source_iso,
#                  target_iso,
#                  trained_source_iso,
#                  trained_target_iso,
#                  source_labels,
#                  target_labels,
#                  mod_name,
#                  epoch_no,
#                  pretrain_lim = 500,
#                  posttrain_lim = 50,
#                  save = False):
#
#     fig0, axes = plt.subplots(1, 2, figsize=(8, 4))
#
#     (ax1, ax2) = axes
#     ax1.scatter(source_iso[:, 0], source_iso[:, 1], s=3, marker='o')
#     ax1.scatter(target_iso[:, 0], target_iso[:, 1], s=3, marker='^')
#     lval1 = pretrain_lim
#     ax1.set_xlim(-lval1, lval1)
#     ax1.set_ylim(-lval1, lval1)
#     ax1.set_title('Source and Target')
#
#     ax2.scatter(trained_source_iso[:, 0], trained_source_iso[:, 1], s=3, marker='o')
#     ax2.scatter(trained_target_iso[:, 0], trained_target_iso[:, 1], s=3, marker='^')
#     lval2 = posttrain_lim
#     ax2.set_xlim(-lval2, lval2)
#     ax2.set_ylim(-lval2, lval2)
#     ax2.set_title('Trained Source and Target')
#
#     ax1.set_xlabel('Component 1')
#     ax1.set_ylabel('Component 2')
#     ax2.set_xlabel('Component 1')
#     ax2.set_ylabel('Component 2')
#
#     if save:
#         plt.savefig(mod_name + "_" + str(epoch_no) + "_compare.png", bbox_inches = 'tight', dpi = 400)
#
#     plt.show()
#
#     fig1, ax = plt.subplots(2, 2, figsize=(14, 10))
#
#     ax1 = ax[0][1]
#     scatter1 = ax1.scatter(trained_source_iso[:, 0], trained_source_iso[:, 1], s=3, marker='o', c = source_labels)
#     lval1 = posttrain_lim
#     ax1.set_xlim(-lval1, lval1)
#     ax1.set_ylim(-lval1, lval1)
#     ax1.set_title('Trained Source')
#
#     ax2 = ax[0][0]
#     ax2.scatter(source_iso[:, 0], source_iso[:, 1], s=3, c = source_labels)
#     lval2 = pretrain_lim
#     ax2.set_xlim(-lval2, lval2)
#     ax2.set_ylim(-lval2, lval2)
#     ax2.set_title('Source')
#
#     ax1 = ax[1][1]
#     ax1.scatter(trained_target_iso[:, 0], trained_target_iso[:, 1], s=3, marker='o', c = target_labels)
#     lval1 = posttrain_lim
#     ax1.set_xlim(-lval1, lval1)
#     ax1.set_ylim(-lval1, lval1)
#     ax1.set_title('Trained Target')
#
#     ax2 = ax[1][0]
#     ax2.scatter(target_iso[:, 0], target_iso[:, 1], s=3, c = target_labels)
#     lval2 = pretrain_lim
#     ax2.set_xlim(-lval2, lval2)
#     ax2.set_ylim(-lval2, lval2)
#     ax2.set_title('Target')
#
#     for i in ax.ravel():
#         i.set_xlabel('Component 1')
#         i.set_ylabel('Component 2')
#
#     cbar = fig.colorbar(scatter1, ax=ax.ravel().tolist(), orientation='vertical')
#     cbar.set_label('$\\theta_E$')
#
#     plt.suptitle("Isomap of Regression Inputs: Before and After", x = 0.44, y = 0.94, fontsize = 20)
#
#     if save:
#         plt.savefig(mod_name + "_" + str(epoch_no) + "_thetaE.png", bbox_inches = 'tight', dpi = 400)
#
#     plt.show()
#
#     return fig0, axes, fig1, ax

# %%
source_labels = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
target_labels = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
show_isomaps(source_iso, target_iso, trained_source_iso, trained_target_iso, source_labels, target_labels, mod_name, stats["epoch_no"], 100000, 50)
# Out:
# (<Figure size 800x400 with 2 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Trained Source and Target'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object),
#  <Figure size 1400x1000 with 5 Axes>,
#  array([[<Axes: title={'center': 'Source'}, xlabel='Component 1', ylabel='Component 2'>,
#          <Axes: title={'center': 'Trained Source'}, xlabel='Component 1', ylabel='Component 2'>],
#         [<Axes: title={'center': 'Target'}, xlabel='Component 1', ylabel='Component 2'>,
#          <Axes: title={'center': 'Trained Target'}, xlabel='Component 1', ylabel='Component 2'>]],
#        dtype=object))

# %%
# Classifier
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# Estimator
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 10)
# Out:
# (-1.0, 10.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Source R2 Score is -2.1589
# Text(0.5, 1.0, 'MMD | Source | R2: -2.159')

# %%
plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | BNLL: 0.413')

# %%
beta_val = 1 - ((46 / 100) * 0.7 )

# %%
beta_val
# Out:
# 0.6779999999999999

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')

plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Target R2 Score is -2.0736
# Text(0.5, 1.0, 'MMD | Target | R2: -2.074')

# %%
plt.figure(figsize=(8,8),dpi=50)
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: 1.022')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
idx = (np.abs(true - preds) > 0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 idx = (np.abs(true - preds) > 0.7)
#
# NameError: name 'true' is not defined

# %%
preds
# Out:
# array([1.30214167, 2.98077202, 2.00425458, ..., 0.95970899, 3.07219529,
#        2.18891573])

# %%
true
# Out:
# array([1.69164467, 3.9343679 , 2.13911223, ..., 1.52133608, 2.09088802,
#        2.36884522])

# %%
i = 0
b = 0
plt.imshow(imgs[idx][i, b, :, :])
print(true[idx][0])
print(preds[idx][0])
# Out:
# 3.9343678951263428
# 2.980772018432617

# %%
i = 134
# Create a figure with 3 subplots arranged horizontally
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# First subplot
axs[0].imshow(imgs[idx][i, 0, :, :])
axs[0].set_title('g')

# Second subplot
axs[1].imshow(imgs[idx][i, 1, :, :])
axs[1].set_title('r')

# Third subplot
axs[2].imshow(imgs[idx][i, 2, :, :])
axs[2].set_title('z')

# Adjust layout to prevent overlap
plt.tight_layout()

print(true[idx][i])
print(preds[idx][i])
# Show the plot
plt.show()
# Out:
# 1.154159426689148
# 2.234156370162964

# %%
i = 16
# Create a figure with 3 subplots arranged horizontally
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# First subplot
axs[0].imshow(source_data[i, 0, :, :])
axs[0].set_title('g')

# Second subplot
axs[1].imshow(source_data[i, 1, :, :])
axs[1].set_title('r')

# Third subplot
axs[2].imshow(source_data[i, 2, :, :])
axs[2].set_title('z')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
