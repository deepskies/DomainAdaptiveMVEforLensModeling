# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 56
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    # if epoch < evolv_epoch:
    #     da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    # else:
    #     da_weight = final_wt_da
    return 1.4

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    # if epoch < evolv_epoch:
    #     beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    # else:
    #     beta_val = beta_final
    return 0.5

# Initialize hyperparameters
n_epoch = 150

# %%
s = np.arange(250)
plt.plot(s, [da_weight_function(i) for i in s])
plt.plot(s, [beta_function(i) for i in s])

# %%
# Initialize model
model = NeuralNetworkMVEv3(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.AdamW(model.parameters())

# %%
from torchsummary import summary
summary(model, (3, 40, 40))
# Out:
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 40, 40]             224
#               ReLU-2            [-1, 8, 40, 40]               0
#        BatchNorm2d-3            [-1, 8, 40, 40]              16
#          MaxPool2d-4            [-1, 8, 20, 20]               0
#             Conv2d-5           [-1, 16, 20, 20]           1,168
#               ReLU-6           [-1, 16, 20, 20]               0
#        BatchNorm2d-7           [-1, 16, 20, 20]              32
#          MaxPool2d-8           [-1, 16, 10, 10]               0
#             Conv2d-9           [-1, 32, 10, 10]           4,640
#              ReLU-10           [-1, 32, 10, 10]               0
#       BatchNorm2d-11           [-1, 32, 10, 10]              64
#         MaxPool2d-12             [-1, 32, 5, 5]               0
#            Linear-13                  [-1, 128]         102,528
#           Sigmoid-14                  [-1, 128]               0
#            Linear-15                   [-1, 32]           4,128
#           Sigmoid-16                   [-1, 32]               0
#            Linear-17                    [-1, 2]              66
# ================================================================
# Total params: 112,866
# Trainable params: 112,866
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.56
# Params size (MB): 0.43
# Estimated Total Size (MB): 1.01
# ----------------------------------------------------------------

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None 
stats, model, optimizer, best_target_R2, best_mve_loss, best_nll_loss, best_snll_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/RunA"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")

for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)
            
            print("Saving Model...", end = ' ')
            save_model(save_mod_name + "_{}".format(curr_epoch), model, optimizer, stats)
            print("Done.")

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_nll_loss'][-1] < best_nll_loss):
                print("Saving Model NLL...", end = ' ')
                nll_name = save_mod_name + "_nll"
                save_model(nll_name, model, optimizer, stats)
                best_nll_loss = stats['val_target_nll_loss'][-1]
                print("Done.")

            # Save and overwrite model every best target MVE Loss
            if (stats['val_source_nll_loss'][-1] < best_snll_loss):
                print("Saving Model SNLL...", end = ' ')
                snll_name = save_mod_name + "_snll"
                save_model(snll_name, model, optimizer, stats)
                best_snll_loss = stats['val_source_nll_loss'][-1]
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)


        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        stats['val_source_nll_loss'].append(vals_validate[6])
        stats['val_target_nll_loss'].append(vals_validate[7])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        #stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 0: 33.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0350
# 	Train Regression Loss: : 0.1467
# 	Train Mve Loss: : -0.1505
# 	Train R2 Score: : 0.5523
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0220
# 	Val Target Regression Loss: : 0.0240
# 	Val Source R2 Score: : 0.9323
# 	Val Target R2 Score: : 0.9286
# 	Val Source Mve Loss: : -0.3336
# 	Val Target Mve Loss: : -0.3311
# 	Val Source Nll Loss: : -0.7653
# 	Val Target Nll Loss: : -0.7592
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 1: 31.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0362
# 	Train Regression Loss: : 0.0209
# 	Train Mve Loss: : -0.1946
# 	Train R2 Score: : 0.9366
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0156
# 	Val Target Regression Loss: : 0.0171
# 	Val Source R2 Score: : 0.9520
# 	Val Target R2 Score: : 0.9491
# 	Val Source Mve Loss: : -0.2517
# 	Val Target Mve Loss: : -0.2469
# 	Val Source Nll Loss: : -1.5458
# 	Val Target Nll Loss: : -1.5193
# Saving Model... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 2: 31.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0334
# 	Train Regression Loss: : 0.0210
# 	Train Mve Loss: : -0.2428
# 	Train R2 Score: : 0.9364
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0323
# 	Val Target Regression Loss: : 0.0321
# 	Val Source R2 Score: : 0.8994
# 	Val Target R2 Score: : 0.9045
# 	Val Source Mve Loss: : -0.3251
# 	Val Target Mve Loss: : -0.3253
# 	Val Source Nll Loss: : -0.7449
# 	Val Target Nll Loss: : -0.7458
#
# Epoch 3: 32.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0308
# 	Train Regression Loss: : 0.0278
# 	Train Mve Loss: : -0.2349
# 	Train R2 Score: : 0.9156
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0226
# 	Val Target Regression Loss: : 0.0249
# 	Val Source R2 Score: : 0.9305
# 	Val Target R2 Score: : 0.9260
# 	Val Source Mve Loss: : -0.3138
# 	Val Target Mve Loss: : -0.3097
# 	Val Source Nll Loss: : -1.1223
# 	Val Target Nll Loss: : -1.1015
#
# Epoch 4: 32.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0263
# 	Train Regression Loss: : 0.0167
# 	Train Mve Loss: : -0.2553
# 	Train R2 Score: : 0.9492
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0126
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9615
# 	Val Target R2 Score: : 0.9585
# 	Val Source Mve Loss: : -0.3491
# 	Val Target Mve Loss: : -0.3475
# 	Val Source Nll Loss: : -0.8785
# 	Val Target Nll Loss: : -0.8775
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 5: 32.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0295
# 	Train Regression Loss: : 0.0181
# 	Train Mve Loss: : -0.1904
# 	Train R2 Score: : 0.9449
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0160
# 	Val Target Regression Loss: : 0.0166
# 	Val Source R2 Score: : 0.9512
# 	Val Target R2 Score: : 0.9503
# 	Val Source Mve Loss: : -0.2799
# 	Val Target Mve Loss: : -0.2788
# 	Val Source Nll Loss: : -1.4021
# 	Val Target Nll Loss: : -1.3995
#
# Epoch 6: 32.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0267
# 	Train Regression Loss: : 0.0157
# 	Train Mve Loss: : -0.2689
# 	Train R2 Score: : 0.9522
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0255
# 	Val Target Regression Loss: : 0.0264
# 	Val Source R2 Score: : 0.9216
# 	Val Target R2 Score: : 0.9212
# 	Val Source Mve Loss: : -0.2531
# 	Val Target Mve Loss: : -0.2526
# 	Val Source Nll Loss: : -0.3853
# 	Val Target Nll Loss: : -0.3847
#
# Epoch 7: 31.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0275
# 	Train Regression Loss: : 0.0217
# 	Train Mve Loss: : -0.2759
# 	Train R2 Score: : 0.9336
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0125
# 	Val Target Regression Loss: : 0.0175
# 	Val Source R2 Score: : 0.9618
# 	Val Target R2 Score: : 0.9478
# 	Val Source Mve Loss: : -0.2185
# 	Val Target Mve Loss: : -0.2050
# 	Val Source Nll Loss: : -1.7013
# 	Val Target Nll Loss: : -1.6101
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 8: 30.96s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0228
# 	Train Regression Loss: : 0.0090
# 	Train Mve Loss: : -0.1983
# 	Train R2 Score: : 0.9727
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0097
# 	Val Target Regression Loss: : 0.0113
# 	Val Source R2 Score: : 0.9703
# 	Val Target R2 Score: : 0.9663
# 	Val Source Mve Loss: : -0.3296
# 	Val Target Mve Loss: : -0.3283
# 	Val Source Nll Loss: : -0.6799
# 	Val Target Nll Loss: : -0.6787
# Saving Model... Done.
#
# Epoch 9: 31.40s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0237
# 	Train Regression Loss: : 0.0188
# 	Train Mve Loss: : -0.2384
# 	Train R2 Score: : 0.9431
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0145
# 	Val Source R2 Score: : 0.9579
# 	Val Target R2 Score: : 0.9566
# 	Val Source Mve Loss: : -0.2960
# 	Val Target Mve Loss: : -0.2955
# 	Val Source Nll Loss: : -0.5255
# 	Val Target Nll Loss: : -0.5257
#
# Epoch 10: 31.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0230
# 	Train Regression Loss: : 0.0145
# 	Train Mve Loss: : -0.2771
# 	Train R2 Score: : 0.9560
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0101
# 	Val Target Regression Loss: : 0.0109
# 	Val Source R2 Score: : 0.9689
# 	Val Target R2 Score: : 0.9676
# 	Val Source Mve Loss: : -0.2043
# 	Val Target Mve Loss: : -0.2138
# 	Val Source Nll Loss: : 39.6436
# 	Val Target Nll Loss: : -1.6620
# Saving Model... Done.
# Saving Model NLL... Done.
#
# Epoch 11: 32.66s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0212
# 	Train Regression Loss: : 0.0131
# 	Train Mve Loss: : -0.2404
# 	Train R2 Score: : 0.9602
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0082
# 	Val Target Regression Loss: : 0.0087
# 	Val Source R2 Score: : 0.9750
# 	Val Target R2 Score: : 0.9741
# 	Val Source Mve Loss: : -0.2808
# 	Val Target Mve Loss: : -0.2786
# 	Val Source Nll Loss: : -1.6188
# 	Val Target Nll Loss: : -1.6075
# Saving Model... Done.
#
# Epoch 12: 32.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0174
# 	Train Regression Loss: : 0.0109
# 	Train Mve Loss: : -0.2135
# 	Train R2 Score: : 0.9669
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0089
# 	Val Target Regression Loss: : 0.0130
# 	Val Source R2 Score: : 0.9725
# 	Val Target R2 Score: : 0.9569
# 	Val Source Mve Loss: : -0.3009
# 	Val Target Mve Loss: : -0.2958
# 	Val Source Nll Loss: : -1.5014
# 	Val Target Nll Loss: : -1.4815
#
# Epoch 13: 32.00s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0137
# 	Train Regression Loss: : 0.0120
# 	Train Mve Loss: : -0.2864
# 	Train R2 Score: : 0.9636
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0103
# 	Val Target Regression Loss: : 0.0098
# 	Val Source R2 Score: : 0.9684
# 	Val Target R2 Score: : 0.9705
# 	Val Source Mve Loss: : -0.2233
# 	Val Target Mve Loss: : -0.2242
# 	Val Source Nll Loss: : -1.7835
# 	Val Target Nll Loss: : -1.7821
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 14: 33.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0148
# 	Train Regression Loss: : 0.0096
# 	Train Mve Loss: : -0.2319
# 	Train R2 Score: : 0.9708
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0063
# 	Val Target Regression Loss: : 0.0073
# 	Val Source R2 Score: : 0.9806
# 	Val Target R2 Score: : 0.9783
# 	Val Source Mve Loss: : -0.3509
# 	Val Target Mve Loss: : -0.3492
# 	Val Source Nll Loss: : -1.0840
# 	Val Target Nll Loss: : -1.0806
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 15: 33.23s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0171
# 	Train Regression Loss: : 0.0156
# 	Train Mve Loss: : -0.2803
# 	Train R2 Score: : 0.9528
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0194
# 	Val Target Regression Loss: : 0.0233
# 	Val Source R2 Score: : 0.9393
# 	Val Target R2 Score: : 0.9307
# 	Val Source Mve Loss: : -0.3054
# 	Val Target Mve Loss: : -0.3024
# 	Val Source Nll Loss: : -0.5655
# 	Val Target Nll Loss: : -0.5604
#
# Epoch 16: 33.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0217
# 	Train Regression Loss: : 0.0169
# 	Train Mve Loss: : -0.3135
# 	Train R2 Score: : 0.9490
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0113
# 	Val Target Regression Loss: : 0.0176
# 	Val Source R2 Score: : 0.9654
# 	Val Target R2 Score: : 0.9479
# 	Val Source Mve Loss: : -0.2924
# 	Val Target Mve Loss: : -0.2848
# 	Val Source Nll Loss: : -1.4210
# 	Val Target Nll Loss: : -1.3825
#
# Epoch 17: 32.72s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0176
# 	Train Regression Loss: : 0.0089
# 	Train Mve Loss: : -0.2653
# 	Train R2 Score: : 0.9730
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0077
# 	Val Target Regression Loss: : 0.0156
# 	Val Source R2 Score: : 0.9763
# 	Val Target R2 Score: : 0.9514
# 	Val Source Mve Loss: : -0.2370
# 	Val Target Mve Loss: : -0.2259
# 	Val Source Nll Loss: : -1.7463
# 	Val Target Nll Loss: : -1.6646
#
# Epoch 18: 33.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0166
# 	Train Regression Loss: : 0.0068
# 	Train Mve Loss: : -0.2206
# 	Train R2 Score: : 0.9795
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0061
# 	Val Target Regression Loss: : 0.0100
# 	Val Source R2 Score: : 0.9815
# 	Val Target R2 Score: : 0.9701
# 	Val Source Mve Loss: : -0.2033
# 	Val Target Mve Loss: : -0.1961
# 	Val Source Nll Loss: : -1.9546
# 	Val Target Nll Loss: : -1.8615
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 19: 33.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0155
# 	Train Regression Loss: : 0.0055
# 	Train Mve Loss: : -0.1912
# 	Train R2 Score: : 0.9832
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0049
# 	Val Target Regression Loss: : 0.0112
# 	Val Source R2 Score: : 0.9851
# 	Val Target R2 Score: : 0.9642
# 	Val Source Mve Loss: : -0.1792
# 	Val Target Mve Loss: : -0.1690
# 	Val Source Nll Loss: : -2.1529
# 	Val Target Nll Loss: : -2.0323
# Generating Isomap...
# Saving Model... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 20: 35.22s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0145
# 	Train Regression Loss: : 0.0046
# 	Train Mve Loss: : -0.1680
# 	Train R2 Score: : 0.9861
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0043
# 	Val Target Regression Loss: : 0.0072
# 	Val Source R2 Score: : 0.9868
# 	Val Target R2 Score: : 0.9783
# 	Val Source Mve Loss: : -0.1574
# 	Val Target Mve Loss: : -0.1462
# 	Val Source Nll Loss: : -2.2472
# 	Val Target Nll Loss: : -2.0648
# Saving Model... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 21: 34.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0134
# 	Train Regression Loss: : 0.0039
# 	Train Mve Loss: : -0.1485
# 	Train R2 Score: : 0.9881
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0037
# 	Val Target Regression Loss: : 0.0050
# 	Val Source R2 Score: : 0.9888
# 	Val Target R2 Score: : 0.9853
# 	Val Source Mve Loss: : -0.1348
# 	Val Target Mve Loss: : -0.1266
# 	Val Source Nll Loss: : -2.4210
# 	Val Target Nll Loss: : -2.2588
# Saving Model... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 22: 35.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0128
# 	Train Regression Loss: : 0.0035
# 	Train Mve Loss: : -0.1340
# 	Train R2 Score: : 0.9895
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0032
# 	Val Target Regression Loss: : 0.0056
# 	Val Source R2 Score: : 0.9900
# 	Val Target R2 Score: : 0.9833
# 	Val Source Mve Loss: : -0.1291
# 	Val Target Mve Loss: : -0.1102
# 	Val Source Nll Loss: : -2.5024
# 	Val Target Nll Loss: : 23.1697
# Saving Model SNLL... Done.
#
# Epoch 23: 33.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0120
# 	Train Regression Loss: : 0.0031
# 	Train Mve Loss: : -0.1258
# 	Train R2 Score: : 0.9907
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0086
# 	Val Target Regression Loss: : 0.0045
# 	Val Source R2 Score: : 0.9767
# 	Val Target R2 Score: : 0.9865
# 	Val Source Mve Loss: : -0.1135
# 	Val Target Mve Loss: : -0.1062
# 	Val Source Nll Loss: : 13.0319
# 	Val Target Nll Loss: : 21.6486
# Saving Model... Done.
#
# Epoch 24: 32.91s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0123
# 	Train Regression Loss: : 0.0028
# 	Train Mve Loss: : -0.1201
# 	Train R2 Score: : 0.9916
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0055
# 	Val Target Regression Loss: : 0.0067
# 	Val Source R2 Score: : 0.9860
# 	Val Target R2 Score: : 0.9793
# 	Val Source Mve Loss: : -0.1164
# 	Val Target Mve Loss: : -0.1005
# 	Val Source Nll Loss: : -2.5048
# 	Val Target Nll Loss: : 26.5249
# Saving Model SNLL... Done.
#
# Epoch 25: 32.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0112
# 	Train Regression Loss: : 0.0026
# 	Train Mve Loss: : -0.1209
# 	Train R2 Score: : 0.9920
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0026
# 	Val Target Regression Loss: : 0.0140
# 	Val Source R2 Score: : 0.9919
# 	Val Target R2 Score: : 0.9442
# 	Val Source Mve Loss: : -0.1106
# 	Val Target Mve Loss: : -0.0931
# 	Val Source Nll Loss: : -2.6395
# 	Val Target Nll Loss: : -2.4031
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 26: 33.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0101
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.1841
# 	Train R2 Score: : 0.9852
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0061
# 	Val Target Regression Loss: : 0.0100
# 	Val Source R2 Score: : 0.9813
# 	Val Target R2 Score: : 0.9706
# 	Val Source Mve Loss: : -0.3590
# 	Val Target Mve Loss: : -0.3555
# 	Val Source Nll Loss: : -0.9577
# 	Val Target Nll Loss: : -0.9489
# Saving Model MVE... Done.
#
# Epoch 27: 33.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0163
# 	Train Regression Loss: : 0.0055
# 	Train Mve Loss: : -0.3586
# 	Train R2 Score: : 0.9832
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0046
# 	Val Target Regression Loss: : 0.0057
# 	Val Source R2 Score: : 0.9857
# 	Val Target R2 Score: : 0.9831
# 	Val Source Mve Loss: : -0.3571
# 	Val Target Mve Loss: : -0.3558
# 	Val Source Nll Loss: : -1.1050
# 	Val Target Nll Loss: : -1.1016
# Saving Model MVE... Done.
#
# Epoch 28: 32.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0093
# 	Train Regression Loss: : 0.0046
# 	Train Mve Loss: : -0.3487
# 	Train R2 Score: : 0.9862
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0052
# 	Val Target Regression Loss: : 0.0067
# 	Val Source R2 Score: : 0.9839
# 	Val Target R2 Score: : 0.9801
# 	Val Source Mve Loss: : -0.3276
# 	Val Target Mve Loss: : -0.3247
# 	Val Source Nll Loss: : -1.3824
# 	Val Target Nll Loss: : -1.3713
#
# Epoch 29: 33.16s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0116
# 	Train Regression Loss: : 0.0073
# 	Train Mve Loss: : -0.2604
# 	Train R2 Score: : 0.9779
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0056
# 	Val Target Regression Loss: : 0.0065
# 	Val Source R2 Score: : 0.9826
# 	Val Target R2 Score: : 0.9804
# 	Val Source Mve Loss: : -0.2097
# 	Val Target Mve Loss: : -0.2051
# 	Val Source Nll Loss: : -1.9496
# 	Val Target Nll Loss: : -1.8864
#
# Epoch 30: 33.11s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0153
# 	Train Regression Loss: : 0.0251
# 	Train Mve Loss: : -0.2350
# 	Train R2 Score: : 0.9242
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0162
# 	Val Target Regression Loss: : 0.0192
# 	Val Source R2 Score: : 0.9502
# 	Val Target R2 Score: : 0.9442
# 	Val Source Mve Loss: : -0.3355
# 	Val Target Mve Loss: : -0.3325
# 	Val Source Nll Loss: : -0.7024
# 	Val Target Nll Loss: : -0.6965
#
# Epoch 31: 32.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0155
# 	Train Regression Loss: : 0.0106
# 	Train Mve Loss: : -0.3440
# 	Train R2 Score: : 0.9678
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0079
# 	Val Target Regression Loss: : 0.0114
# 	Val Source R2 Score: : 0.9759
# 	Val Target R2 Score: : 0.9669
# 	Val Source Mve Loss: : -0.3494
# 	Val Target Mve Loss: : -0.3465
# 	Val Source Nll Loss: : -0.7719
# 	Val Target Nll Loss: : -0.7671
#
# Epoch 32: 32.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0120
# 	Train Regression Loss: : 0.0071
# 	Train Mve Loss: : -0.3530
# 	Train R2 Score: : 0.9785
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0065
# 	Val Target Regression Loss: : 0.0130
# 	Val Source R2 Score: : 0.9802
# 	Val Target R2 Score: : 0.9603
# 	Val Source Mve Loss: : -0.3562
# 	Val Target Mve Loss: : -0.3509
# 	Val Source Nll Loss: : -0.8544
# 	Val Target Nll Loss: : -0.8455
#
# Epoch 33: 34.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0115
# 	Train Regression Loss: : 0.0059
# 	Train Mve Loss: : -0.3583
# 	Train R2 Score: : 0.9820
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0056
# 	Val Target Regression Loss: : 0.0119
# 	Val Source R2 Score: : 0.9828
# 	Val Target R2 Score: : 0.9671
# 	Val Source Mve Loss: : -0.3597
# 	Val Target Mve Loss: : -0.3543
# 	Val Source Nll Loss: : -0.9483
# 	Val Target Nll Loss: : -0.9384
#
# Epoch 34: 33.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0089
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.3596
# 	Train R2 Score: : 0.9843
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0049
# 	Val Target Regression Loss: : 0.0113
# 	Val Source R2 Score: : 0.9846
# 	Val Target R2 Score: : 0.9653
# 	Val Source Mve Loss: : -0.3577
# 	Val Target Mve Loss: : -0.3501
# 	Val Source Nll Loss: : -1.0902
# 	Val Target Nll Loss: : -1.0716
#
# Epoch 35: 33.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0093
# 	Train Regression Loss: : 0.0045
# 	Train Mve Loss: : -0.3489
# 	Train R2 Score: : 0.9862
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0042
# 	Val Target Regression Loss: : 0.0052
# 	Val Source R2 Score: : 0.9872
# 	Val Target R2 Score: : 0.9846
# 	Val Source Mve Loss: : -0.3308
# 	Val Target Mve Loss: : -0.3286
# 	Val Source Nll Loss: : -1.4134
# 	Val Target Nll Loss: : -1.4038
#
# Epoch 36: 33.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0085
# 	Train Regression Loss: : 0.0037
# 	Train Mve Loss: : -0.2158
# 	Train R2 Score: : 0.9889
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0028
# 	Val Target Regression Loss: : 0.0074
# 	Val Source R2 Score: : 0.9912
# 	Val Target R2 Score: : 0.9786
# 	Val Source Mve Loss: : -0.1263
# 	Val Target Mve Loss: : -0.1149
# 	Val Source Nll Loss: : -2.5420
# 	Val Target Nll Loss: : -2.3610
#
# Epoch 37: 32.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0075
# 	Train Regression Loss: : 0.0026
# 	Train Mve Loss: : -0.1244
# 	Train R2 Score: : 0.9922
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0120
# 	Val Target Regression Loss: : 0.0206
# 	Val Source R2 Score: : 0.9607
# 	Val Target R2 Score: : 0.9391
# 	Val Source Mve Loss: : -0.1021
# 	Val Target Mve Loss: : -0.0875
# 	Val Source Nll Loss: : -2.5801
# 	Val Target Nll Loss: : -2.3587
#
# Epoch 38: 34.65s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0112
# 	Train Regression Loss: : 0.0044
# 	Train Mve Loss: : -0.1865
# 	Train R2 Score: : 0.9867
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0026
# 	Val Target Regression Loss: : 0.0034
# 	Val Source R2 Score: : 0.9921
# 	Val Target R2 Score: : 0.9898
# 	Val Source Mve Loss: : -0.2733
# 	Val Target Mve Loss: : -0.2706
# 	Val Source Nll Loss: : -1.8571
# 	Val Target Nll Loss: : -1.8389
# Saving Model... Done.
#
# Epoch 39: 34.24s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0106
# 	Train Regression Loss: : 0.0021
# 	Train Mve Loss: : -0.1297
# 	Train R2 Score: : 0.9935
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0018
# 	Val Target Regression Loss: : 0.0026
# 	Val Source R2 Score: : 0.9945
# 	Val Target R2 Score: : 0.9924
# 	Val Source Mve Loss: : -0.1989
# 	Val Target Mve Loss: : -0.1950
# 	Val Source Nll Loss: : -2.3642
# 	Val Target Nll Loss: : -2.3169
# Generating Isomap...
# Saving Model... Done.
# Saving Model... Done.
#
# Epoch 40: 33.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0079
# 	Train Regression Loss: : 0.0038
# 	Train Mve Loss: : -0.3119
# 	Train R2 Score: : 0.9884
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0042
# 	Val Target Regression Loss: : 0.0056
# 	Val Source R2 Score: : 0.9870
# 	Val Target R2 Score: : 0.9832
# 	Val Source Mve Loss: : -0.2131
# 	Val Target Mve Loss: : -0.2065
# 	Val Source Nll Loss: : -2.0829
# 	Val Target Nll Loss: : -2.0139
#
# Epoch 41: 33.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0072
# 	Train Regression Loss: : 0.0030
# 	Train Mve Loss: : -0.1903
# 	Train R2 Score: : 0.9909
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0024
# 	Val Target Regression Loss: : 0.0047
# 	Val Source R2 Score: : 0.9926
# 	Val Target R2 Score: : 0.9849
# 	Val Source Mve Loss: : -0.2738
# 	Val Target Mve Loss: : -0.2683
# 	Val Source Nll Loss: : -1.8612
# 	Val Target Nll Loss: : -1.8292
#
# Epoch 42: 33.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0074
# 	Train Regression Loss: : 0.0082
# 	Train Mve Loss: : -0.1944
# 	Train R2 Score: : 0.9750
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0100
# 	Val Target Regression Loss: : 0.0096
# 	Val Source R2 Score: : 0.9693
# 	Val Target R2 Score: : 0.9717
# 	Val Source Mve Loss: : -0.3484
# 	Val Target Mve Loss: : -0.3491
# 	Val Source Nll Loss: : -0.7878
# 	Val Target Nll Loss: : -0.7895
#
# Epoch 43: 33.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0080
# 	Train Regression Loss: : 0.0059
# 	Train Mve Loss: : -0.3553
# 	Train R2 Score: : 0.9820
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0053
# 	Val Target Regression Loss: : 0.0066
# 	Val Source R2 Score: : 0.9837
# 	Val Target R2 Score: : 0.9800
# 	Val Source Mve Loss: : -0.3578
# 	Val Target Mve Loss: : -0.3562
# 	Val Source Nll Loss: : -0.8631
# 	Val Target Nll Loss: : -0.8599
# Saving Model MVE... Done.

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = save_mod_name#"models/papermve_v3_aug22_1315_C_mve" # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['val_source_nll_loss'], label = "Source Val NLL Loss")
plt.plot(eps, stats['val_target_nll_loss'], label = "Target Val NLL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-2, 1)
# Out:
# (-2.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.0))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9687

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.969')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | NLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | NLL: 131.683')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9579

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.273')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
