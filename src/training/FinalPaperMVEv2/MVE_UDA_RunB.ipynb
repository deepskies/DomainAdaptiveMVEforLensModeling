# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 11
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    # if epoch < evolv_epoch:
    #     da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    # else:
    #     da_weight = final_wt_da
    return 1.4

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    # if epoch < evolv_epoch:
    #     beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    # else:
    #     beta_val = beta_final
    return 0.5

# Initialize hyperparameters
n_epoch = 150

# %%
s = np.arange(250)
plt.plot(s, [da_weight_function(i) for i in s])
plt.plot(s, [beta_function(i) for i in s])

# %%
# Initialize model
model = NeuralNetworkMVEv3(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.AdamW(model.parameters())

# %%
from torchsummary import summary
summary(model, (3, 40, 40))
# Out:
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 40, 40]             224
#               ReLU-2            [-1, 8, 40, 40]               0
#        BatchNorm2d-3            [-1, 8, 40, 40]              16
#          MaxPool2d-4            [-1, 8, 20, 20]               0
#             Conv2d-5           [-1, 16, 20, 20]           1,168
#               ReLU-6           [-1, 16, 20, 20]               0
#        BatchNorm2d-7           [-1, 16, 20, 20]              32
#          MaxPool2d-8           [-1, 16, 10, 10]               0
#             Conv2d-9           [-1, 32, 10, 10]           4,640
#              ReLU-10           [-1, 32, 10, 10]               0
#       BatchNorm2d-11           [-1, 32, 10, 10]              64
#         MaxPool2d-12             [-1, 32, 5, 5]               0
#            Linear-13                  [-1, 128]         102,528
#           Sigmoid-14                  [-1, 128]               0
#            Linear-15                   [-1, 32]           4,128
#           Sigmoid-16                   [-1, 32]               0
#            Linear-17                    [-1, 2]              66
# ================================================================
# Total params: 112,866
# Trainable params: 112,866
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.56
# Params size (MB): 0.43
# Estimated Total Size (MB): 1.01
# ----------------------------------------------------------------

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None 
stats, model, optimizer, best_target_R2, best_mve_loss, best_nll_loss, best_snll_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/RunB"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")

for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)
            
            print("Saving Model...", end = ' ')
            save_model(save_mod_name + "_{}".format(curr_epoch), model, optimizer, stats)
            print("Done.")

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_nll_loss'][-1] < best_nll_loss):
                print("Saving Model NLL...", end = ' ')
                nll_name = save_mod_name + "_nll"
                save_model(nll_name, model, optimizer, stats)
                best_nll_loss = stats['val_target_nll_loss'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_source_nll_loss'][-1] < best_snll_loss):
                print("Saving Model SNLL...", end = ' ')
                snll_name = save_mod_name + "_snll"
                save_model(snll_name, model, optimizer, stats)
                best_snll_loss = stats['val_source_nll_loss'][-1]
                print("Done.")
        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)


        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        stats['val_source_nll_loss'].append(vals_validate[6])
        stats['val_target_nll_loss'].append(vals_validate[7])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        #stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 0: 34.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0365
# 	Train Regression Loss: : 0.3124
# 	Train Mve Loss: : -0.0192
# 	Train R2 Score: : 0.0633
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0132
# 	Val Target Regression Loss: : 0.0147
# 	Val Source R2 Score: : 0.9592
# 	Val Target R2 Score: : 0.9558
# 	Val Source Mve Loss: : -0.2406
# 	Val Target Mve Loss: : -0.2359
# 	Val Source Nll Loss: : -1.5918
# 	Val Target Nll Loss: : -1.5551
# Saving Model... Done.
# Saving Model MVE... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 1: 34.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0354
# 	Train Regression Loss: : 0.0224
# 	Train Mve Loss: : -0.2555
# 	Train R2 Score: : 0.9323
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0189
# 	Val Target Regression Loss: : 0.0194
# 	Val Source R2 Score: : 0.9417
# 	Val Target R2 Score: : 0.9424
# 	Val Source Mve Loss: : -0.3026
# 	Val Target Mve Loss: : -0.3021
# 	Val Source Nll Loss: : -0.5382
# 	Val Target Nll Loss: : -0.5372
# Saving Model MVE... Done.
#
# Epoch 2: 33.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0344
# 	Train Regression Loss: : 0.0247
# 	Train Mve Loss: : -0.2723
# 	Train R2 Score: : 0.9249
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2653
# 	Val Target Regression Loss: : 0.2817
# 	Val Source R2 Score: : 0.1789
# 	Val Target R2 Score: : 0.1572
# 	Val Source Mve Loss: : -0.0734
# 	Val Target Mve Loss: : -0.0559
# 	Val Source Nll Loss: : -0.1787
# 	Val Target Nll Loss: : -0.1409
#
# Epoch 3: 33.33s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0380
# 	Train Regression Loss: : 0.0224
# 	Train Mve Loss: : -0.1858
# 	Train R2 Score: : 0.9325
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0203
# 	Val Target Regression Loss: : 0.0220
# 	Val Source R2 Score: : 0.9374
# 	Val Target R2 Score: : 0.9348
# 	Val Source Mve Loss: : -0.2841
# 	Val Target Mve Loss: : -0.2828
# 	Val Source Nll Loss: : -0.4935
# 	Val Target Nll Loss: : -0.4916
#
# Epoch 4: 33.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0363
# 	Train Regression Loss: : 0.0211
# 	Train Mve Loss: : -0.2608
# 	Train R2 Score: : 0.9358
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0162
# 	Val Target Regression Loss: : 0.0195
# 	Val Source R2 Score: : 0.9504
# 	Val Target R2 Score: : 0.9419
# 	Val Source Mve Loss: : -0.3331
# 	Val Target Mve Loss: : -0.3276
# 	Val Source Nll Loss: : -1.1068
# 	Val Target Nll Loss: : -1.0871
# Saving Model MVE... Done.
#
# Epoch 5: 32.96s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0373
# 	Train Regression Loss: : 0.0371
# 	Train Mve Loss: : -0.2281
# 	Train R2 Score: : 0.8878
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0209
# 	Val Target Regression Loss: : 0.0250
# 	Val Source R2 Score: : 0.9359
# 	Val Target R2 Score: : 0.9254
# 	Val Source Mve Loss: : -0.2550
# 	Val Target Mve Loss: : -0.2303
# 	Val Source Nll Loss: : 39.7589
# 	Val Target Nll Loss: : 79.9101
#
# Epoch 6: 33.36s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0369
# 	Train Regression Loss: : 0.0195
# 	Train Mve Loss: : -0.2897
# 	Train R2 Score: : 0.9407
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0135
# 	Val Target Regression Loss: : 0.0166
# 	Val Source R2 Score: : 0.9586
# 	Val Target R2 Score: : 0.9507
# 	Val Source Mve Loss: : -0.2681
# 	Val Target Mve Loss: : -0.2531
# 	Val Source Nll Loss: : 2.6124
# 	Val Target Nll Loss: : 20.9549
#
# Epoch 7: 33.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0358
# 	Train Regression Loss: : 0.0131
# 	Train Mve Loss: : -0.2210
# 	Train R2 Score: : 0.9602
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0112
# 	Val Target Regression Loss: : 0.0139
# 	Val Source R2 Score: : 0.9655
# 	Val Target R2 Score: : 0.9585
# 	Val Source Mve Loss: : -0.2130
# 	Val Target Mve Loss: : -0.2050
# 	Val Source Nll Loss: : 9.6728
# 	Val Target Nll Loss: : -0.7003
# Saving Model... Done.
#
# Epoch 8: 33.08s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0352
# 	Train Regression Loss: : 0.0165
# 	Train Mve Loss: : -0.2575
# 	Train R2 Score: : 0.9501
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0180
# 	Val Target Regression Loss: : 0.0206
# 	Val Source R2 Score: : 0.9451
# 	Val Target R2 Score: : 0.9385
# 	Val Source Mve Loss: : -0.3313
# 	Val Target Mve Loss: : -0.3268
# 	Val Source Nll Loss: : -1.0896
# 	Val Target Nll Loss: : -1.0725
#
# Epoch 9: 33.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0380
# 	Train Regression Loss: : 0.0124
# 	Train Mve Loss: : -0.2366
# 	Train R2 Score: : 0.9624
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0100
# 	Val Target Regression Loss: : 0.0117
# 	Val Source R2 Score: : 0.9686
# 	Val Target R2 Score: : 0.9651
# 	Val Source Mve Loss: : -0.2108
# 	Val Target Mve Loss: : -0.2056
# 	Val Source Nll Loss: : -1.7712
# 	Val Target Nll Loss: : -1.7048
# Saving Model... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 10: 33.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0382
# 	Train Regression Loss: : 0.0088
# 	Train Mve Loss: : -0.1900
# 	Train R2 Score: : 0.9733
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0071
# 	Val Target Regression Loss: : 0.0088
# 	Val Source R2 Score: : 0.9785
# 	Val Target R2 Score: : 0.9736
# 	Val Source Mve Loss: : -0.1637
# 	Val Target Mve Loss: : -0.1455
# 	Val Source Nll Loss: : 15.6513
# 	Val Target Nll Loss: : 44.9990
# Saving Model... Done.
#
# Epoch 11: 34.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0383
# 	Train Regression Loss: : 0.0084
# 	Train Mve Loss: : -0.2543
# 	Train R2 Score: : 0.9745
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0087
# 	Val Target Regression Loss: : 0.0101
# 	Val Source R2 Score: : 0.9727
# 	Val Target R2 Score: : 0.9698
# 	Val Source Mve Loss: : -0.2402
# 	Val Target Mve Loss: : -0.2357
# 	Val Source Nll Loss: : -1.7492
# 	Val Target Nll Loss: : 0.2923
#
# Epoch 12: 33.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0384
# 	Train Regression Loss: : 0.0068
# 	Train Mve Loss: : -0.1973
# 	Train R2 Score: : 0.9793
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0049
# 	Val Target Regression Loss: : 0.0056
# 	Val Source R2 Score: : 0.9850
# 	Val Target R2 Score: : 0.9830
# 	Val Source Mve Loss: : -0.0875
# 	Val Target Mve Loss: : -0.1324
# 	Val Source Nll Loss: : 173.7305
# 	Val Target Nll Loss: : 17.2311
# Saving Model... Done.
#
# Epoch 13: 37.55s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0383
# 	Train Regression Loss: : 0.0064
# 	Train Mve Loss: : -0.1887
# 	Train R2 Score: : 0.9805
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0054
# 	Val Target Regression Loss: : 0.0065
# 	Val Source R2 Score: : 0.9834
# 	Val Target R2 Score: : 0.9805
# 	Val Source Mve Loss: : -0.1658
# 	Val Target Mve Loss: : -0.1611
# 	Val Source Nll Loss: : -1.8882
# 	Val Target Nll Loss: : -1.1490
# Saving Model SNLL... Done.
#
# Epoch 14: 49.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0378
# 	Train Regression Loss: : 0.0071
# 	Train Mve Loss: : -0.1951
# 	Train R2 Score: : 0.9782
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0263
# 	Val Target Regression Loss: : 0.0298
# 	Val Source R2 Score: : 0.9190
# 	Val Target R2 Score: : 0.9114
# 	Val Source Mve Loss: : -0.2388
# 	Val Target Mve Loss: : -0.2298
# 	Val Source Nll Loss: : -1.3217
# 	Val Target Nll Loss: : -1.2685
#
# Epoch 15: 49.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0371
# 	Train Regression Loss: : 0.0074
# 	Train Mve Loss: : -0.3415
# 	Train R2 Score: : 0.9776
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0068
# 	Val Target Regression Loss: : 0.0079
# 	Val Source R2 Score: : 0.9791
# 	Val Target R2 Score: : 0.9766
# 	Val Source Mve Loss: : -0.3131
# 	Val Target Mve Loss: : -0.3109
# 	Val Source Nll Loss: : -1.4731
# 	Val Target Nll Loss: : -1.4617
#
# Epoch 16: 53.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0377
# 	Train Regression Loss: : 0.0078
# 	Train Mve Loss: : -0.2212
# 	Train R2 Score: : 0.9763
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0101
# 	Val Target Regression Loss: : 0.0107
# 	Val Source R2 Score: : 0.9687
# 	Val Target R2 Score: : 0.9681
# 	Val Source Mve Loss: : -0.3456
# 	Val Target Mve Loss: : -0.3448
# 	Val Source Nll Loss: : -0.7673
# 	Val Target Nll Loss: : -0.7652
# Saving Model MVE... Done.
#
# Epoch 17: 65.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0378
# 	Train Regression Loss: : 0.0080
# 	Train Mve Loss: : -0.3436
# 	Train R2 Score: : 0.9758
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0060
# 	Val Target Regression Loss: : 0.0072
# 	Val Source R2 Score: : 0.9816
# 	Val Target R2 Score: : 0.9788
# 	Val Source Mve Loss: : -0.2784
# 	Val Target Mve Loss: : -0.2749
# 	Val Source Nll Loss: : -1.6838
# 	Val Target Nll Loss: : -1.6580
#
# Epoch 18: 65.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0384
# 	Train Regression Loss: : 0.0046
# 	Train Mve Loss: : -0.2137
# 	Train R2 Score: : 0.9862
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0037
# 	Val Target Regression Loss: : 0.0049
# 	Val Source R2 Score: : 0.9886
# 	Val Target R2 Score: : 0.9855
# 	Val Source Mve Loss: : -0.1906
# 	Val Target Mve Loss: : -0.1846
# 	Val Source Nll Loss: : -2.2198
# 	Val Target Nll Loss: : -2.1391
# Saving Model... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 19: 67.21s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0396
# 	Train Regression Loss: : 0.0031
# 	Train Mve Loss: : -0.1385
# 	Train R2 Score: : 0.9907
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0059
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9819
# 	Val Target R2 Score: : 0.9839
# 	Val Source Mve Loss: : -0.2091
# 	Val Target Mve Loss: : -0.2117
# 	Val Source Nll Loss: : -2.0050
# 	Val Target Nll Loss: : -2.0287
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 20: 65.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0396
# 	Train Regression Loss: : 0.0033
# 	Train Mve Loss: : -0.1916
# 	Train R2 Score: : 0.9899
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0027
# 	Val Target Regression Loss: : 0.0034
# 	Val Source R2 Score: : 0.9917
# 	Val Target R2 Score: : 0.9899
# 	Val Source Mve Loss: : -0.1435
# 	Val Target Mve Loss: : -0.1392
# 	Val Source Nll Loss: : -2.5184
# 	Val Target Nll Loss: : -2.4420
# Saving Model... Done.
# Saving Model NLL... Done.
# Saving Model SNLL... Done.
#
# Epoch 21: 72.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0398
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.1804
# 	Train R2 Score: : 0.9853
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0032
# 	Val Target Regression Loss: : 0.0038
# 	Val Source R2 Score: : 0.9901
# 	Val Target R2 Score: : 0.9887
# 	Val Source Mve Loss: : -0.1730
# 	Val Target Mve Loss: : -0.1702
# 	Val Source Nll Loss: : -2.3482
# 	Val Target Nll Loss: : -2.3056
#
# Epoch 22: 76.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0404
# 	Train Regression Loss: : 0.0053
# 	Train Mve Loss: : -0.2200
# 	Train R2 Score: : 0.9839
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0044
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9865
# 	Val Target R2 Score: : 0.9837
# 	Val Source Mve Loss: : -0.3536
# 	Val Target Mve Loss: : -0.3519
# 	Val Source Nll Loss: : -1.1733
# 	Val Target Nll Loss: : -1.1672
# Saving Model MVE... Done.
#
# Epoch 23: 90.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0421
# 	Train Regression Loss: : 0.0054
# 	Train Mve Loss: : -0.2282
# 	Train R2 Score: : 0.9835
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0062
# 	Val Target Regression Loss: : 0.0074
# 	Val Source R2 Score: : 0.9808
# 	Val Target R2 Score: : 0.9780
# 	Val Source Mve Loss: : -0.3492
# 	Val Target Mve Loss: : -0.3472
# 	Val Source Nll Loss: : -1.1842
# 	Val Target Nll Loss: : -1.1775
#
# Epoch 24: 75.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0441
# 	Train Regression Loss: : 0.0058
# 	Train Mve Loss: : -0.2027
# 	Train R2 Score: : 0.9825
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0078
# 	Val Target Regression Loss: : 0.0089
# 	Val Source R2 Score: : 0.9762
# 	Val Target R2 Score: : 0.9732
# 	Val Source Mve Loss: : -0.1431
# 	Val Target Mve Loss: : -0.1371
# 	Val Source Nll Loss: : -1.9378
# 	Val Target Nll Loss: : -1.8483
#
# Epoch 25: 87.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0442
# 	Train Regression Loss: : 0.0068
# 	Train Mve Loss: : -0.1796
# 	Train R2 Score: : 0.9795
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0081
# 	Val Target Regression Loss: : 0.0093
# 	Val Source R2 Score: : 0.9752
# 	Val Target R2 Score: : 0.9718
# 	Val Source Mve Loss: : -0.1764
# 	Val Target Mve Loss: : -0.1713
# 	Val Source Nll Loss: : -1.9182
# 	Val Target Nll Loss: : -1.8566
#
# Epoch 26: 86.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0073
# 	Train Mve Loss: : -0.2091
# 	Train R2 Score: : 0.9779
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0096
# 	Val Target Regression Loss: : 0.0105
# 	Val Source R2 Score: : 0.9705
# 	Val Target R2 Score: : 0.9689
# 	Val Source Mve Loss: : -0.2005
# 	Val Target Mve Loss: : -0.1972
# 	Val Source Nll Loss: : -1.8207
# 	Val Target Nll Loss: : -1.7876
#
# Epoch 27: 82.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0440
# 	Train Regression Loss: : 0.0058
# 	Train Mve Loss: : -0.1731
# 	Train R2 Score: : 0.9825
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0053
# 	Val Target Regression Loss: : 0.0066
# 	Val Source R2 Score: : 0.9837
# 	Val Target R2 Score: : 0.9805
# 	Val Source Mve Loss: : -0.2852
# 	Val Target Mve Loss: : -0.2817
# 	Val Source Nll Loss: : -1.6843
# 	Val Target Nll Loss: : -1.6623
#
# Epoch 28: 77.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0433
# 	Train Regression Loss: : 0.0080
# 	Train Mve Loss: : -0.1959
# 	Train R2 Score: : 0.9755
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0048
# 	Val Target Regression Loss: : 0.0056
# 	Val Source R2 Score: : 0.9854
# 	Val Target R2 Score: : 0.9835
# 	Val Source Mve Loss: : -0.1307
# 	Val Target Mve Loss: : -0.1256
# 	Val Source Nll Loss: : -2.2001
# 	Val Target Nll Loss: : -2.1031
#
# Epoch 29: 77.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0443
# 	Train Regression Loss: : 0.0079
# 	Train Mve Loss: : -0.1962
# 	Train R2 Score: : 0.9759
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0057
# 	Val Target Regression Loss: : 0.0063
# 	Val Source R2 Score: : 0.9823
# 	Val Target R2 Score: : 0.9812
# 	Val Source Mve Loss: : -0.1454
# 	Val Target Mve Loss: : -0.1427
# 	Val Source Nll Loss: : -2.0827
# 	Val Target Nll Loss: : -2.0373
#
# Epoch 30: 74.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0444
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1544
# 	Train R2 Score: : 0.9850
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0044
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9867
# 	Val Target R2 Score: : 0.9837
# 	Val Source Mve Loss: : -0.1654
# 	Val Target Mve Loss: : -0.1588
# 	Val Source Nll Loss: : -2.2379
# 	Val Target Nll Loss: : -2.1420
#
# Epoch 31: 69.27s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0446
# 	Train Regression Loss: : 0.0138
# 	Train Mve Loss: : -0.2559
# 	Train R2 Score: : 0.9588
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0064
# 	Val Target Regression Loss: : 0.0079
# 	Val Source R2 Score: : 0.9803
# 	Val Target R2 Score: : 0.9764
# 	Val Source Mve Loss: : -0.3176
# 	Val Target Mve Loss: : -0.3140
# 	Val Source Nll Loss: : -1.4491
# 	Val Target Nll Loss: : -1.4347
#
# Epoch 32: 80.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0432
# 	Train Regression Loss: : 0.0057
# 	Train Mve Loss: : -0.1757
# 	Train R2 Score: : 0.9827
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0051
# 	Val Target Regression Loss: : 0.0066
# 	Val Source R2 Score: : 0.9845
# 	Val Target R2 Score: : 0.9806
# 	Val Source Mve Loss: : -0.1251
# 	Val Target Mve Loss: : -0.1138
# 	Val Source Nll Loss: : -2.1936
# 	Val Target Nll Loss: : -1.9929
#
# Epoch 33: 86.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0447
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1586
# 	Train R2 Score: : 0.9842
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0037
# 	Val Target Regression Loss: : 0.0051
# 	Val Source R2 Score: : 0.9886
# 	Val Target R2 Score: : 0.9848
# 	Val Source Mve Loss: : -0.1609
# 	Val Target Mve Loss: : -0.1519
# 	Val Source Nll Loss: : -2.3029
# 	Val Target Nll Loss: : -2.1690
#
# Epoch 34: 84.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0430
# 	Train Regression Loss: : 0.0531
# 	Train Mve Loss: : -0.1488
# 	Train R2 Score: : 0.8397
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0172
# 	Val Target Regression Loss: : 0.0189
# 	Val Source R2 Score: : 0.9471
# 	Val Target R2 Score: : 0.9439
# 	Val Source Mve Loss: : -0.3261
# 	Val Target Mve Loss: : -0.3244
# 	Val Source Nll Loss: : -0.6396
# 	Val Target Nll Loss: : -0.6364
#
# Epoch 35: 64.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0420
# 	Train Regression Loss: : 0.0434
# 	Train Mve Loss: : -0.2884
# 	Train R2 Score: : 0.8688
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0110
# 	Val Target Regression Loss: : 0.0131
# 	Val Source R2 Score: : 0.9665
# 	Val Target R2 Score: : 0.9612
# 	Val Source Mve Loss: : -0.3424
# 	Val Target Mve Loss: : -0.3389
# 	Val Source Nll Loss: : -1.1284
# 	Val Target Nll Loss: : -1.1171
#
# Epoch 36: 74.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0438
# 	Train Regression Loss: : 0.0074
# 	Train Mve Loss: : -0.1977
# 	Train R2 Score: : 0.9774
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0058
# 	Val Target Regression Loss: : 0.0070
# 	Val Source R2 Score: : 0.9823
# 	Val Target R2 Score: : 0.9792
# 	Val Source Mve Loss: : -0.1596
# 	Val Target Mve Loss: : -0.1525
# 	Val Source Nll Loss: : -2.0984
# 	Val Target Nll Loss: : -2.0016
#
# Epoch 37: 69.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0440
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1593
# 	Train R2 Score: : 0.9844
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0048
# 	Val Target Regression Loss: : 0.0058
# 	Val Source R2 Score: : 0.9854
# 	Val Target R2 Score: : 0.9828
# 	Val Source Mve Loss: : -0.1289
# 	Val Target Mve Loss: : -0.1208
# 	Val Source Nll Loss: : -2.1989
# 	Val Target Nll Loss: : -2.0531
#
# Epoch 38: 81.50s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0435
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1656
# 	Train R2 Score: : 0.9849
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0050
# 	Val Target Regression Loss: : 0.0068
# 	Val Source R2 Score: : 0.9847
# 	Val Target R2 Score: : 0.9795
# 	Val Source Mve Loss: : -0.2595
# 	Val Target Mve Loss: : -0.2530
# 	Val Source Nll Loss: : -1.8309
# 	Val Target Nll Loss: : -1.7848
#
# Epoch 39: 90.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0436
# 	Train Regression Loss: : 0.0203
# 	Train Mve Loss: : -0.2924
# 	Train R2 Score: : 0.9382
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0075
# 	Val Target Regression Loss: : 0.0089
# 	Val Source R2 Score: : 0.9771
# 	Val Target R2 Score: : 0.9732
# 	Val Source Mve Loss: : -0.1595
# 	Val Target Mve Loss: : -0.1504
# 	Val Source Nll Loss: : -1.8766
# 	Val Target Nll Loss: : -1.7640
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 40: 68.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0438
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1601
# 	Train R2 Score: : 0.9844
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0034
# 	Val Target Regression Loss: : 0.0048
# 	Val Source R2 Score: : 0.9895
# 	Val Target R2 Score: : 0.9856
# 	Val Source Mve Loss: : -0.1583
# 	Val Target Mve Loss: : -0.1484
# 	Val Source Nll Loss: : -2.3167
# 	Val Target Nll Loss: : -2.1677
#
# Epoch 41: 79.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0053
# 	Train Mve Loss: : -0.1891
# 	Train R2 Score: : 0.9839
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0050
# 	Val Target Regression Loss: : 0.0064
# 	Val Source R2 Score: : 0.9846
# 	Val Target R2 Score: : 0.9808
# 	Val Source Mve Loss: : -0.2441
# 	Val Target Mve Loss: : -0.2385
# 	Val Source Nll Loss: : -1.9005
# 	Val Target Nll Loss: : -1.8568
#
# Epoch 42: 84.63s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1632
# 	Train R2 Score: : 0.9844
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0039
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9879
# 	Val Target R2 Score: : 0.9837
# 	Val Source Mve Loss: : -0.1208
# 	Val Target Mve Loss: : -0.1063
# 	Val Source Nll Loss: : -2.2256
# 	Val Target Nll Loss: : -1.9551
#
# Epoch 43: 68.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1721
# 	Train R2 Score: : 0.9847
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0073
# 	Val Target Regression Loss: : 0.0091
# 	Val Source R2 Score: : 0.9775
# 	Val Target R2 Score: : 0.9730
# 	Val Source Mve Loss: : -0.1805
# 	Val Target Mve Loss: : -0.1709
# 	Val Source Nll Loss: : -1.9539
# 	Val Target Nll Loss: : -1.8493
#
# Epoch 44: 80.01s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.1649
# 	Train R2 Score: : 0.9853
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0057
# 	Val Target Regression Loss: : 0.0075
# 	Val Source R2 Score: : 0.9825
# 	Val Target R2 Score: : 0.9777
# 	Val Source Mve Loss: : -0.1067
# 	Val Target Mve Loss: : -0.0904
# 	Val Source Nll Loss: : -1.9476
# 	Val Target Nll Loss: : -1.6446
#
# Epoch 45: 75.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0048
# 	Train Mve Loss: : -0.1621
# 	Train R2 Score: : 0.9854
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0031
# 	Val Target Regression Loss: : 0.0047
# 	Val Source R2 Score: : 0.9905
# 	Val Target R2 Score: : 0.9861
# 	Val Source Mve Loss: : -0.1675
# 	Val Target Mve Loss: : -0.1568
# 	Val Source Nll Loss: : -2.3362
# 	Val Target Nll Loss: : -2.1864
#
# Epoch 46: 66.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0422
# 	Train Regression Loss: : 0.0123
# 	Train Mve Loss: : -0.3051
# 	Train R2 Score: : 0.9628
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0085
# 	Val Target Regression Loss: : 0.0104
# 	Val Source R2 Score: : 0.9741
# 	Val Target R2 Score: : 0.9691
# 	Val Source Mve Loss: : -0.3540
# 	Val Target Mve Loss: : -0.3518
# 	Val Source Nll Loss: : -0.8441
# 	Val Target Nll Loss: : -0.8391
#
# Epoch 47: 78.45s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0411
# 	Train Regression Loss: : 0.0079
# 	Train Mve Loss: : -0.3518
# 	Train R2 Score: : 0.9761
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0071
# 	Val Target Regression Loss: : 0.0093
# 	Val Source R2 Score: : 0.9782
# 	Val Target R2 Score: : 0.9718
# 	Val Source Mve Loss: : -0.3360
# 	Val Target Mve Loss: : -0.3318
# 	Val Source Nll Loss: : -1.2977
# 	Val Target Nll Loss: : -1.2820
#
# Epoch 48: 76.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0074
# 	Train Mve Loss: : -0.2338
# 	Train R2 Score: : 0.9776
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0062
# 	Val Target Regression Loss: : 0.0082
# 	Val Source R2 Score: : 0.9808
# 	Val Target R2 Score: : 0.9757
# 	Val Source Mve Loss: : -0.1417
# 	Val Target Mve Loss: : -0.1280
# 	Val Source Nll Loss: : -2.0502
# 	Val Target Nll Loss: : -1.8494
#
# Epoch 49: 82.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0060
# 	Train Mve Loss: : -0.1627
# 	Train R2 Score: : 0.9817
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0046
# 	Val Target Regression Loss: : 0.0062
# 	Val Source R2 Score: : 0.9858
# 	Val Target R2 Score: : 0.9815
# 	Val Source Mve Loss: : -0.1827
# 	Val Target Mve Loss: : -0.1740
# 	Val Source Nll Loss: : -2.1510
# 	Val Target Nll Loss: : -2.0441
#
# Epoch 50: 79.59s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0432
# 	Train Regression Loss: : 0.0057
# 	Train Mve Loss: : -0.1635
# 	Train R2 Score: : 0.9827
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0039
# 	Val Target Regression Loss: : 0.0049
# 	Val Source R2 Score: : 0.9881
# 	Val Target R2 Score: : 0.9853
# 	Val Source Mve Loss: : -0.1538
# 	Val Target Mve Loss: : -0.1468
# 	Val Source Nll Loss: : -2.2678
# 	Val Target Nll Loss: : -2.1614
#
# Epoch 51: 64.31s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0430
# 	Train Regression Loss: : 0.0055
# 	Train Mve Loss: : -0.1597
# 	Train R2 Score: : 0.9834
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0033
# 	Val Target Regression Loss: : 0.0050
# 	Val Source R2 Score: : 0.9897
# 	Val Target R2 Score: : 0.9850
# 	Val Source Mve Loss: : -0.1770
# 	Val Target Mve Loss: : -0.1663
# 	Val Source Nll Loss: : -2.2851
# 	Val Target Nll Loss: : -2.1452
#
# Epoch 52: 81.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.1573
# 	Train R2 Score: : 0.9852
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0065
# 	Val Target Regression Loss: : 0.0087
# 	Val Source R2 Score: : 0.9800
# 	Val Target R2 Score: : 0.9740
# 	Val Source Mve Loss: : -0.1948
# 	Val Target Mve Loss: : -0.1838
# 	Val Source Nll Loss: : -1.9822
# 	Val Target Nll Loss: : -1.8689
#
# Epoch 53: 62.69s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0433
# 	Train Regression Loss: : 0.0053
# 	Train Mve Loss: : -0.1738
# 	Train R2 Score: : 0.9839
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0037
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9886
# 	Val Target R2 Score: : 0.9836
# 	Val Source Mve Loss: : -0.1418
# 	Val Target Mve Loss: : -0.1271
# 	Val Source Nll Loss: : -2.3067
# 	Val Target Nll Loss: : -2.0605
#
# Epoch 54: 82.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0432
# 	Train Regression Loss: : 0.0054
# 	Train Mve Loss: : -0.1622
# 	Train R2 Score: : 0.9835
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0034
# 	Val Target Regression Loss: : 0.0053
# 	Val Source R2 Score: : 0.9896
# 	Val Target R2 Score: : 0.9840
# 	Val Source Mve Loss: : -0.2236
# 	Val Target Mve Loss: : -0.2146
# 	Val Source Nll Loss: : -2.0861
# 	Val Target Nll Loss: : -2.0015
#
# Epoch 55: 71.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0433
# 	Train Regression Loss: : 0.0046
# 	Train Mve Loss: : -0.1609
# 	Train R2 Score: : 0.9861
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0036
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9890
# 	Val Target R2 Score: : 0.9841
# 	Val Source Mve Loss: : -0.0764
# 	Val Target Mve Loss: : -0.0540
# 	Val Source Nll Loss: : -2.0532
# 	Val Target Nll Loss: : -1.4651
#
# Epoch 56: 75.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0427
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1993
# 	Train R2 Score: : 0.9842
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0038
# 	Val Target Regression Loss: : 0.0057
# 	Val Source R2 Score: : 0.9881
# 	Val Target R2 Score: : 0.9829
# 	Val Source Mve Loss: : -0.1618
# 	Val Target Mve Loss: : -0.1484
# 	Val Source Nll Loss: : -2.2699
# 	Val Target Nll Loss: : -2.0808
#
# Epoch 57: 69.46s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1618
# 	Train R2 Score: : 0.9844
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0047
# 	Val Target Regression Loss: : 0.0067
# 	Val Source R2 Score: : 0.9857
# 	Val Target R2 Score: : 0.9800
# 	Val Source Mve Loss: : -0.1616
# 	Val Target Mve Loss: : -0.1478
# 	Val Source Nll Loss: : -2.1789
# 	Val Target Nll Loss: : -1.9922
#
# Epoch 58: 54.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0428
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.1604
# 	Train R2 Score: : 0.9852
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0057
# 	Val Target Regression Loss: : 0.0078
# 	Val Source R2 Score: : 0.9825
# 	Val Target R2 Score: : 0.9768
# 	Val Source Mve Loss: : -0.1670
# 	Val Target Mve Loss: : -0.1540
# 	Val Source Nll Loss: : -2.0830
# 	Val Target Nll Loss: : -1.9211
#
# Epoch 59: 63.79s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0450
# 	Train Regression Loss: : 0.0212
# 	Train Mve Loss: : -0.1561
# 	Train R2 Score: : 0.9359
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0562
# 	Val Target Regression Loss: : 0.0566
# 	Val Source R2 Score: : 0.8269
# 	Val Target R2 Score: : 0.8325
# 	Val Source Mve Loss: : -0.2699
# 	Val Target Mve Loss: : -0.2695
# 	Val Source Nll Loss: : -0.4720
# 	Val Target Nll Loss: : -0.4714
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 60: 68.78s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0417
# 	Train Regression Loss: : 0.0203
# 	Train Mve Loss: : -0.3228
# 	Train R2 Score: : 0.9387
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0115
# 	Val Target Regression Loss: : 0.0134
# 	Val Source R2 Score: : 0.9650
# 	Val Target R2 Score: : 0.9603
# 	Val Source Mve Loss: : -0.3279
# 	Val Target Mve Loss: : -0.3241
# 	Val Source Nll Loss: : -1.2616
# 	Val Target Nll Loss: : -1.2471
#
# Epoch 61: 94.51s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0437
# 	Train Regression Loss: : 0.0089
# 	Train Mve Loss: : -0.2021
# 	Train R2 Score: : 0.9731
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0074
# 	Val Target Regression Loss: : 0.0095
# 	Val Source R2 Score: : 0.9773
# 	Val Target R2 Score: : 0.9718
# 	Val Source Mve Loss: : -0.1435
# 	Val Target Mve Loss: : -0.1294
# 	Val Source Nll Loss: : -1.8965
# 	Val Target Nll Loss: : -1.6984
#
# Epoch 62: 64.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0060
# 	Train Mve Loss: : -0.1652
# 	Train R2 Score: : 0.9818
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0038
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9882
# 	Val Target R2 Score: : 0.9836
# 	Val Source Mve Loss: : -0.1646
# 	Val Target Mve Loss: : -0.1542
# 	Val Source Nll Loss: : -2.2640
# 	Val Target Nll Loss: : -2.1204
#
# Epoch 63: 87.09s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0427
# 	Train Regression Loss: : 0.0057
# 	Train Mve Loss: : -0.1619
# 	Train R2 Score: : 0.9826
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0042
# 	Val Target Regression Loss: : 0.0058
# 	Val Source R2 Score: : 0.9870
# 	Val Target R2 Score: : 0.9828
# 	Val Source Mve Loss: : -0.1534
# 	Val Target Mve Loss: : -0.1421
# 	Val Source Nll Loss: : -2.2371
# 	Val Target Nll Loss: : -2.0736
#
# Epoch 64: 73.70s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0432
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.1590
# 	Train R2 Score: : 0.9851
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0042
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9872
# 	Val Target R2 Score: : 0.9839
# 	Val Source Mve Loss: : -0.1801
# 	Val Target Mve Loss: : -0.1725
# 	Val Source Nll Loss: : -2.1925
# 	Val Target Nll Loss: : -2.1001
#
# Epoch 65: 98.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0427
# 	Train Regression Loss: : 0.0054
# 	Train Mve Loss: : -0.1800
# 	Train R2 Score: : 0.9836
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0071
# 	Val Target Regression Loss: : 0.0085
# 	Val Source R2 Score: : 0.9781
# 	Val Target R2 Score: : 0.9746
# 	Val Source Mve Loss: : -0.1460
# 	Val Target Mve Loss: : -0.1367
# 	Val Source Nll Loss: : -1.9659
# 	Val Target Nll Loss: : -1.8415
#
# Epoch 66: 61.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0431
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1619
# 	Train R2 Score: : 0.9848
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0042
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9871
# 	Val Target R2 Score: : 0.9838
# 	Val Source Mve Loss: : -0.1590
# 	Val Target Mve Loss: : -0.1509
# 	Val Source Nll Loss: : -2.2285
# 	Val Target Nll Loss: : -2.1139
#
# Epoch 67: 69.29s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0437
# 	Train Regression Loss: : 0.0053
# 	Train Mve Loss: : -0.1710
# 	Train R2 Score: : 0.9839
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0059
# 	Val Target Regression Loss: : 0.0078
# 	Val Source R2 Score: : 0.9818
# 	Val Target R2 Score: : 0.9765
# 	Val Source Mve Loss: : -0.2042
# 	Val Target Mve Loss: : -0.1948
# 	Val Source Nll Loss: : -1.9956
# 	Val Target Nll Loss: : -1.9047
#
# Epoch 68: 64.43s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0431
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1631
# 	Train R2 Score: : 0.9849
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0047
# 	Val Target Regression Loss: : 0.0061
# 	Val Source R2 Score: : 0.9856
# 	Val Target R2 Score: : 0.9818
# 	Val Source Mve Loss: : -0.1102
# 	Val Target Mve Loss: : -0.0974
# 	Val Source Nll Loss: : -2.1186
# 	Val Target Nll Loss: : -1.8766
#
# Epoch 69: 85.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0436
# 	Train Regression Loss: : 0.0054
# 	Train Mve Loss: : -0.1813
# 	Train R2 Score: : 0.9836
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0035
# 	Val Target Regression Loss: : 0.0052
# 	Val Source R2 Score: : 0.9893
# 	Val Target R2 Score: : 0.9845
# 	Val Source Mve Loss: : -0.3318
# 	Val Target Mve Loss: : -0.3281
# 	Val Source Nll Loss: : -1.4250
# 	Val Target Nll Loss: : -1.4095
#
# Epoch 70: 82.85s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0428
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1820
# 	Train R2 Score: : 0.9843
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0070
# 	Val Target Regression Loss: : 0.0093
# 	Val Source R2 Score: : 0.9786
# 	Val Target R2 Score: : 0.9725
# 	Val Source Mve Loss: : -0.1826
# 	Val Target Mve Loss: : -0.1704
# 	Val Source Nll Loss: : -1.9775
# 	Val Target Nll Loss: : -1.8466
#
# Epoch 71: 84.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0060
# 	Train Mve Loss: : -0.2390
# 	Train R2 Score: : 0.9816
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0051
# 	Val Target Regression Loss: : 0.0069
# 	Val Source R2 Score: : 0.9844
# 	Val Target R2 Score: : 0.9795
# 	Val Source Mve Loss: : -0.2263
# 	Val Target Mve Loss: : -0.2185
# 	Val Source Nll Loss: : -1.9655
# 	Val Target Nll Loss: : -1.8983
#
# Epoch 72: 73.00s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0437
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1600
# 	Train R2 Score: : 0.9842
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0046
# 	Val Target Regression Loss: : 0.0065
# 	Val Source R2 Score: : 0.9859
# 	Val Target R2 Score: : 0.9806
# 	Val Source Mve Loss: : -0.1992
# 	Val Target Mve Loss: : -0.1890
# 	Val Source Nll Loss: : -2.1007
# 	Val Target Nll Loss: : -1.9935
#
# Epoch 73: 81.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0435
# 	Train Regression Loss: : 0.0053
# 	Train Mve Loss: : -0.1641
# 	Train R2 Score: : 0.9839
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0037
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9887
# 	Val Target R2 Score: : 0.9840
# 	Val Source Mve Loss: : -0.1727
# 	Val Target Mve Loss: : -0.1618
# 	Val Source Nll Loss: : -2.2575
# 	Val Target Nll Loss: : -2.1153
#
# Epoch 74: 74.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0428
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1605
# 	Train R2 Score: : 0.9847
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0039
# 	Val Target Regression Loss: : 0.0057
# 	Val Source R2 Score: : 0.9880
# 	Val Target R2 Score: : 0.9832
# 	Val Source Mve Loss: : -0.1990
# 	Val Target Mve Loss: : -0.1896
# 	Val Source Nll Loss: : -2.1515
# 	Val Target Nll Loss: : -2.0500
#
# Epoch 75: 80.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0436
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1677
# 	Train R2 Score: : 0.9845
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0048
# 	Val Target Regression Loss: : 0.0064
# 	Val Source R2 Score: : 0.9851
# 	Val Target R2 Score: : 0.9809
# 	Val Source Mve Loss: : -0.1541
# 	Val Target Mve Loss: : -0.1429
# 	Val Source Nll Loss: : -2.1703
# 	Val Target Nll Loss: : -2.0132
#
# Epoch 76: 95.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0053
# 	Train Mve Loss: : -0.1659
# 	Train R2 Score: : 0.9839
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0049
# 	Val Target Regression Loss: : 0.0066
# 	Val Source R2 Score: : 0.9849
# 	Val Target R2 Score: : 0.9804
# 	Val Source Mve Loss: : -0.1971
# 	Val Target Mve Loss: : -0.1887
# 	Val Source Nll Loss: : -2.0837
# 	Val Target Nll Loss: : -1.9950
#
# Epoch 77: 91.11s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0047
# 	Train Mve Loss: : -0.1606
# 	Train R2 Score: : 0.9857
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0056
# 	Val Target Regression Loss: : 0.0073
# 	Val Source R2 Score: : 0.9829
# 	Val Target R2 Score: : 0.9782
# 	Val Source Mve Loss: : -0.1268
# 	Val Target Mve Loss: : -0.1126
# 	Val Source Nll Loss: : -2.0632
# 	Val Target Nll Loss: : -1.8333
#
# Epoch 78: 68.12s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1676
# 	Train R2 Score: : 0.9849
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0044
# 	Val Target Regression Loss: : 0.0066
# 	Val Source R2 Score: : 0.9865
# 	Val Target R2 Score: : 0.9807
# 	Val Source Mve Loss: : -0.1134
# 	Val Target Mve Loss: : -0.0921
# 	Val Source Nll Loss: : -2.1617
# 	Val Target Nll Loss: : -1.7503
#
# Epoch 79: 87.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0428
# 	Train Regression Loss: : 0.0154
# 	Train Mve Loss: : -0.2485
# 	Train R2 Score: : 0.9530
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0111
# 	Val Target Regression Loss: : 0.0132
# 	Val Source R2 Score: : 0.9659
# 	Val Target R2 Score: : 0.9606
# 	Val Source Mve Loss: : -0.3458
# 	Val Target Mve Loss: : -0.3434
# 	Val Source Nll Loss: : -0.7575
# 	Val Target Nll Loss: : -0.7526
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 80: 70.60s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0424
# 	Train Regression Loss: : 0.0096
# 	Train Mve Loss: : -0.3448
# 	Train R2 Score: : 0.9711
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0055
# 	Val Target Regression Loss: : 0.0073
# 	Val Source R2 Score: : 0.9831
# 	Val Target R2 Score: : 0.9783
# 	Val Source Mve Loss: : -0.3197
# 	Val Target Mve Loss: : -0.3155
# 	Val Source Nll Loss: : -1.4625
# 	Val Target Nll Loss: : -1.4439
#
# Epoch 81: 81.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0432
# 	Train Regression Loss: : 0.0071
# 	Train Mve Loss: : -0.1996
# 	Train R2 Score: : 0.9784
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0143
# 	Val Target Regression Loss: : 0.0162
# 	Val Source R2 Score: : 0.9563
# 	Val Target R2 Score: : 0.9517
# 	Val Source Mve Loss: : -0.1285
# 	Val Target Mve Loss: : -0.1174
# 	Val Source Nll Loss: : -1.5503
# 	Val Target Nll Loss: : -1.4197
#
# Epoch 82: 79.53s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0428
# 	Train Regression Loss: : 0.0059
# 	Train Mve Loss: : -0.1655
# 	Train R2 Score: : 0.9821
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0040
# 	Val Target Regression Loss: : 0.0054
# 	Val Source R2 Score: : 0.9879
# 	Val Target R2 Score: : 0.9839
# 	Val Source Mve Loss: : -0.1817
# 	Val Target Mve Loss: : -0.1730
# 	Val Source Nll Loss: : -2.2079
# 	Val Target Nll Loss: : -2.1012
#
# Epoch 83: 88.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0055
# 	Train Mve Loss: : -0.1596
# 	Train R2 Score: : 0.9833
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0067
# 	Val Target Regression Loss: : 0.0086
# 	Val Source R2 Score: : 0.9794
# 	Val Target R2 Score: : 0.9744
# 	Val Source Mve Loss: : -0.1780
# 	Val Target Mve Loss: : -0.1675
# 	Val Source Nll Loss: : -1.9957
# 	Val Target Nll Loss: : -1.8770
#
# Epoch 84: 63.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0424
# 	Train Regression Loss: : 0.0054
# 	Train Mve Loss: : -0.1609
# 	Train R2 Score: : 0.9836
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0041
# 	Val Target Regression Loss: : 0.0057
# 	Val Source R2 Score: : 0.9875
# 	Val Target R2 Score: : 0.9830
# 	Val Source Mve Loss: : -0.1480
# 	Val Target Mve Loss: : -0.1361
# 	Val Source Nll Loss: : -2.2531
# 	Val Target Nll Loss: : -2.0725
#
# Epoch 85: 74.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0433
# 	Train Regression Loss: : 0.0054
# 	Train Mve Loss: : -0.1631
# 	Train R2 Score: : 0.9837
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0036
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9888
# 	Val Target R2 Score: : 0.9833
# 	Val Source Mve Loss: : -0.1387
# 	Val Target Mve Loss: : -0.1233
# 	Val Source Nll Loss: : -2.3117
# 	Val Target Nll Loss: : -2.0559
#
# Epoch 86: 61.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0428
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1576
# 	Train R2 Score: : 0.9849
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0073
# 	Val Target Regression Loss: : 0.0094
# 	Val Source R2 Score: : 0.9777
# 	Val Target R2 Score: : 0.9721
# 	Val Source Mve Loss: : -0.1247
# 	Val Target Mve Loss: : -0.1088
# 	Val Source Nll Loss: : -1.8888
# 	Val Target Nll Loss: : -1.6476
#
# Epoch 87: 86.07s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1583
# 	Train R2 Score: : 0.9847
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0038
# 	Val Target Regression Loss: : 0.0057
# 	Val Source R2 Score: : 0.9884
# 	Val Target R2 Score: : 0.9830
# 	Val Source Mve Loss: : -0.1234
# 	Val Target Mve Loss: : -0.1059
# 	Val Source Nll Loss: : -2.2748
# 	Val Target Nll Loss: : -1.9520
#
# Epoch 88: 77.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0053
# 	Train Mve Loss: : -0.1818
# 	Train R2 Score: : 0.9839
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0051
# 	Val Target Regression Loss: : 0.0066
# 	Val Source R2 Score: : 0.9841
# 	Val Target R2 Score: : 0.9804
# 	Val Source Mve Loss: : -0.1637
# 	Val Target Mve Loss: : -0.1545
# 	Val Source Nll Loss: : -2.1353
# 	Val Target Nll Loss: : -2.0154
#
# Epoch 89: 77.81s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0424
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1627
# 	Train R2 Score: : 0.9843
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0054
# 	Val Target Regression Loss: : 0.0072
# 	Val Source R2 Score: : 0.9834
# 	Val Target R2 Score: : 0.9786
# 	Val Source Mve Loss: : -0.1578
# 	Val Target Mve Loss: : -0.1460
# 	Val Source Nll Loss: : -2.1172
# 	Val Target Nll Loss: : -1.9586
#
# Epoch 90: 76.49s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0435
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1645
# 	Train R2 Score: : 0.9844
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0063
# 	Val Target Regression Loss: : 0.0081
# 	Val Source R2 Score: : 0.9807
# 	Val Target R2 Score: : 0.9758
# 	Val Source Mve Loss: : -0.1163
# 	Val Target Mve Loss: : -0.1018
# 	Val Source Nll Loss: : -1.9262
# 	Val Target Nll Loss: : -1.6852
#
# Epoch 91: 67.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0418
# 	Train Regression Loss: : 0.1816
# 	Train Mve Loss: : 0.0039
# 	Train R2 Score: : 0.4440
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0441
# 	Val Target Regression Loss: : 0.0501
# 	Val Source R2 Score: : 0.8647
# 	Val Target R2 Score: : 0.8460
# 	Val Source Mve Loss: : -0.2918
# 	Val Target Mve Loss: : -0.2864
# 	Val Source Nll Loss: : -0.5415
# 	Val Target Nll Loss: : -0.5323
#
# Epoch 92: 68.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0412
# 	Train Regression Loss: : 0.0278
# 	Train Mve Loss: : -0.3096
# 	Train R2 Score: : 0.9156
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0217
# 	Val Target Regression Loss: : 0.0215
# 	Val Source R2 Score: : 0.9327
# 	Val Target R2 Score: : 0.9363
# 	Val Source Mve Loss: : -0.3181
# 	Val Target Mve Loss: : -0.3186
# 	Val Source Nll Loss: : -0.6096
# 	Val Target Nll Loss: : -0.6115
#
# Epoch 93: 87.98s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0383
# 	Train Regression Loss: : 0.0181
# 	Train Mve Loss: : -0.3252
# 	Train R2 Score: : 0.9453
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0161
# 	Val Target Regression Loss: : 0.0178
# 	Val Source R2 Score: : 0.9505
# 	Val Target R2 Score: : 0.9472
# 	Val Source Mve Loss: : -0.3306
# 	Val Target Mve Loss: : -0.3290
# 	Val Source Nll Loss: : -0.6636
# 	Val Target Nll Loss: : -0.6613
#
# Epoch 94: 79.97s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0388
# 	Train Regression Loss: : 0.0161
# 	Train Mve Loss: : -0.3341
# 	Train R2 Score: : 0.9512
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0158
# 	Val Target Regression Loss: : 0.0166
# 	Val Source R2 Score: : 0.9517
# 	Val Target R2 Score: : 0.9504
# 	Val Source Mve Loss: : -0.3378
# 	Val Target Mve Loss: : -0.3370
# 	Val Source Nll Loss: : -0.7195
# 	Val Target Nll Loss: : -0.7182
#
# Epoch 95: 59.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0454
# 	Train Regression Loss: : 0.0157
# 	Train Mve Loss: : -0.3412
# 	Train R2 Score: : 0.9523
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0170
# 	Val Target Regression Loss: : 0.0184
# 	Val Source R2 Score: : 0.9477
# 	Val Target R2 Score: : 0.9449
# 	Val Source Mve Loss: : -0.3427
# 	Val Target Mve Loss: : -0.3412
# 	Val Source Nll Loss: : -0.7936
# 	Val Target Nll Loss: : -0.7903
#
# Epoch 96: 72.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0448
# 	Train Regression Loss: : 0.0146
# 	Train Mve Loss: : -0.3473
# 	Train R2 Score: : 0.9557
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0149
# 	Val Target Regression Loss: : 0.0163
# 	Val Source R2 Score: : 0.9545
# 	Val Target R2 Score: : 0.9516
# 	Val Source Mve Loss: : -0.3481
# 	Val Target Mve Loss: : -0.3463
# 	Val Source Nll Loss: : -0.9057
# 	Val Target Nll Loss: : -0.9013
#
# Epoch 97: 70.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0450
# 	Train Regression Loss: : 0.0136
# 	Train Mve Loss: : -0.3474
# 	Train R2 Score: : 0.9589
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0099
# 	Val Target Regression Loss: : 0.0110
# 	Val Source R2 Score: : 0.9698
# 	Val Target R2 Score: : 0.9673
# 	Val Source Mve Loss: : -0.3474
# 	Val Target Mve Loss: : -0.3455
# 	Val Source Nll Loss: : -1.1148
# 	Val Target Nll Loss: : -1.1090
#
# Epoch 98: 80.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0441
# 	Train Regression Loss: : 0.0119
# 	Train Mve Loss: : -0.3132
# 	Train R2 Score: : 0.9639
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0089
# 	Val Target Regression Loss: : 0.0108
# 	Val Source R2 Score: : 0.9727
# 	Val Target R2 Score: : 0.9677
# 	Val Source Mve Loss: : -0.2366
# 	Val Target Mve Loss: : -0.2298
# 	Val Source Nll Loss: : -1.7590
# 	Val Target Nll Loss: : -1.7079
#
# Epoch 99: 69.75s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0432
# 	Train Regression Loss: : 0.0100
# 	Train Mve Loss: : -0.1844
# 	Train R2 Score: : 0.9697
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0180
# 	Val Target Regression Loss: : 0.0199
# 	Val Source R2 Score: : 0.9452
# 	Val Target R2 Score: : 0.9409
# 	Val Source Mve Loss: : -0.1503
# 	Val Target Mve Loss: : -0.1412
# ...
# 	Val Target Regression Loss: : 0.0056
# 	Val Source R2 Score: : 0.9867
# 	Val Target R2 Score: : 0.9833
# 	Val Source Mve Loss: : -0.1302
# 	Val Target Mve Loss: : -0.1196
# 	Val Source Nll Loss: : -2.2080
# 	Val Target Nll Loss: : -2.0294
#
# Epoch 117: 70.77s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0059
# 	Train Mve Loss: : -0.1658
# 	Train R2 Score: : 0.9821
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0060
# 	Val Target Regression Loss: : 0.0078
# 	Val Source R2 Score: : 0.9815
# 	Val Target R2 Score: : 0.9771
# 	Val Source Mve Loss: : -0.1238
# 	Val Target Mve Loss: : -0.1095
# 	Val Source Nll Loss: : -2.0032
# 	Val Target Nll Loss: : -1.7730
#
# Epoch 118: 67.34s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0428
# 	Train Regression Loss: : 0.0057
# 	Train Mve Loss: : -0.1673
# 	Train R2 Score: : 0.9827
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0051
# 	Val Target Regression Loss: : 0.0068
# 	Val Source R2 Score: : 0.9844
# 	Val Target R2 Score: : 0.9798
# 	Val Source Mve Loss: : -0.1667
# 	Val Target Mve Loss: : -0.1558
# 	Val Source Nll Loss: : -2.1294
# 	Val Target Nll Loss: : -1.9904
#
# Epoch 119: 77.76s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0056
# 	Train Mve Loss: : -0.2161
# 	Train R2 Score: : 0.9831
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0047
# 	Val Target Regression Loss: : 0.0062
# 	Val Source R2 Score: : 0.9857
# 	Val Target R2 Score: : 0.9815
# 	Val Source Mve Loss: : -0.1596
# 	Val Target Mve Loss: : -0.1491
# 	Val Source Nll Loss: : -2.1781
# 	Val Target Nll Loss: : -2.0351
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 120: 67.88s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0437
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1587
# 	Train R2 Score: : 0.9843
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0044
# 	Val Target Regression Loss: : 0.0058
# 	Val Source R2 Score: : 0.9865
# 	Val Target R2 Score: : 0.9828
# 	Val Source Mve Loss: : -0.1671
# 	Val Target Mve Loss: : -0.1579
# 	Val Source Nll Loss: : -2.1948
# 	Val Target Nll Loss: : -2.0742
#
# Epoch 121: 75.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0429
# 	Train Regression Loss: : 0.0056
# 	Train Mve Loss: : -0.1651
# 	Train R2 Score: : 0.9829
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0052
# 	Val Target Regression Loss: : 0.0070
# 	Val Source R2 Score: : 0.9839
# 	Val Target R2 Score: : 0.9793
# 	Val Source Mve Loss: : -0.2022
# 	Val Target Mve Loss: : -0.1934
# 	Val Source Nll Loss: : -2.0479
# 	Val Target Nll Loss: : -1.9584
#
# Epoch 122: 75.82s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0437
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1642
# 	Train R2 Score: : 0.9845
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0050
# 	Val Target Regression Loss: : 0.0061
# 	Val Source R2 Score: : 0.9848
# 	Val Target R2 Score: : 0.9819
# 	Val Source Mve Loss: : -0.1633
# 	Val Target Mve Loss: : -0.1563
# 	Val Source Nll Loss: : -2.1442
# 	Val Target Nll Loss: : -2.0528
#
# Epoch 123: 72.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0437
# 	Train Regression Loss: : 0.0050
# 	Train Mve Loss: : -0.1577
# 	Train R2 Score: : 0.9850
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0048
# 	Val Target Regression Loss: : 0.0067
# 	Val Source R2 Score: : 0.9852
# 	Val Target R2 Score: : 0.9803
# 	Val Source Mve Loss: : -0.1860
# 	Val Target Mve Loss: : -0.1755
# 	Val Source Nll Loss: : -2.1199
# 	Val Target Nll Loss: : -1.9999
#
# Epoch 124: 75.92s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0441
# 	Train Regression Loss: : 0.0257
# 	Train Mve Loss: : -0.2478
# 	Train R2 Score: : 0.9216
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0096
# 	Val Target Regression Loss: : 0.0104
# 	Val Source R2 Score: : 0.9707
# 	Val Target R2 Score: : 0.9689
# 	Val Source Mve Loss: : -0.1810
# 	Val Target Mve Loss: : -0.1768
# 	Val Source Nll Loss: : -1.8231
# 	Val Target Nll Loss: : -1.7807
#
# Epoch 125: 52.38s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0443
# 	Train Regression Loss: : 0.0084
# 	Train Mve Loss: : -0.1786
# 	Train R2 Score: : 0.9746
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0077
# 	Val Target Regression Loss: : 0.0093
# 	Val Source R2 Score: : 0.9763
# 	Val Target R2 Score: : 0.9723
# 	Val Source Mve Loss: : -0.1514
# 	Val Target Mve Loss: : -0.1412
# 	Val Source Nll Loss: : -1.9239
# 	Val Target Nll Loss: : -1.7953
#
# Epoch 126: 84.68s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0443
# 	Train Regression Loss: : 0.0064
# 	Train Mve Loss: : -0.1692
# 	Train R2 Score: : 0.9805
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0047
# 	Val Target Regression Loss: : 0.0058
# 	Val Source R2 Score: : 0.9858
# 	Val Target R2 Score: : 0.9826
# 	Val Source Mve Loss: : -0.1748
# 	Val Target Mve Loss: : -0.1675
# 	Val Source Nll Loss: : -2.1587
# 	Val Target Nll Loss: : -2.0686
#
# Epoch 127: 94.45s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0447
# 	Train Regression Loss: : 0.0061
# 	Train Mve Loss: : -0.1688
# 	Train R2 Score: : 0.9815
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0046
# 	Val Target Regression Loss: : 0.0061
# 	Val Source R2 Score: : 0.9861
# 	Val Target R2 Score: : 0.9820
# 	Val Source Mve Loss: : -0.1709
# 	Val Target Mve Loss: : -0.1614
# 	Val Source Nll Loss: : -2.1747
# 	Val Target Nll Loss: : -2.0537
#
# Epoch 128: 80.64s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0438
# 	Train Regression Loss: : 0.0060
# 	Train Mve Loss: : -0.1688
# 	Train R2 Score: : 0.9820
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0065
# 	Val Target Regression Loss: : 0.0073
# 	Val Source R2 Score: : 0.9801
# 	Val Target R2 Score: : 0.9783
# 	Val Source Mve Loss: : -0.1548
# 	Val Target Mve Loss: : -0.1495
# 	Val Source Nll Loss: : -2.0167
# 	Val Target Nll Loss: : -1.9475
#
# Epoch 129: 74.67s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0055
# 	Train Mve Loss: : -0.1681
# 	Train R2 Score: : 0.9833
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0044
# 	Val Target Regression Loss: : 0.0057
# 	Val Source R2 Score: : 0.9864
# 	Val Target R2 Score: : 0.9830
# 	Val Source Mve Loss: : -0.1527
# 	Val Target Mve Loss: : -0.1433
# 	Val Source Nll Loss: : -2.2100
# 	Val Target Nll Loss: : -2.0754
#
# Epoch 130: 105.09s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0431
# 	Train Regression Loss: : 0.0056
# 	Train Mve Loss: : -0.1623
# 	Train R2 Score: : 0.9830
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0044
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9865
# 	Val Target R2 Score: : 0.9835
# 	Val Source Mve Loss: : -0.2240
# 	Val Target Mve Loss: : -0.2191
# 	Val Source Nll Loss: : -2.0200
# 	Val Target Nll Loss: : -1.9753
#
# Epoch 131: 94.84s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0055
# 	Train Mve Loss: : -0.1775
# 	Train R2 Score: : 0.9835
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0047
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9854
# 	Val Target R2 Score: : 0.9837
# 	Val Source Mve Loss: : -0.1664
# 	Val Target Mve Loss: : -0.1619
# 	Val Source Nll Loss: : -2.1648
# 	Val Target Nll Loss: : -2.1051
#
# Epoch 132: 88.71s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1682
# 	Train R2 Score: : 0.9844
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0056
# 	Val Target Regression Loss: : 0.0060
# 	Val Source R2 Score: : 0.9828
# 	Val Target R2 Score: : 0.9820
# 	Val Source Mve Loss: : -0.1958
# 	Val Target Mve Loss: : -0.1938
# 	Val Source Nll Loss: : -2.0365
# 	Val Target Nll Loss: : -2.0152
#
# Epoch 133: 81.39s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0438
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1678
# 	Train R2 Score: : 0.9845
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0042
# 	Val Target Regression Loss: : 0.0057
# 	Val Source R2 Score: : 0.9871
# 	Val Target R2 Score: : 0.9832
# 	Val Source Mve Loss: : -0.1799
# 	Val Target Mve Loss: : -0.1711
# 	Val Source Nll Loss: : -2.1864
# 	Val Target Nll Loss: : -2.0795
#
# Epoch 134: 85.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0431
# 	Train Regression Loss: : 0.0052
# 	Train Mve Loss: : -0.1835
# 	Train R2 Score: : 0.9842
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0041
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9872
# 	Val Target R2 Score: : 0.9837
# 	Val Source Mve Loss: : -0.1855
# 	Val Target Mve Loss: : -0.1777
# 	Val Source Nll Loss: : -2.1779
# 	Val Target Nll Loss: : -2.0858
#
# Epoch 135: 78.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0448
# 	Train Regression Loss: : 0.0051
# 	Train Mve Loss: : -0.1677
# 	Train R2 Score: : 0.9847
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0041
# 	Val Target Regression Loss: : 0.0055
# 	Val Source R2 Score: : 0.9876
# 	Val Target R2 Score: : 0.9836
# 	Val Source Mve Loss: : -0.2501
# 	Val Target Mve Loss: : -0.2445
# 	Val Source Nll Loss: : -1.9175
# 	Val Target Nll Loss: : -1.8753
#
# Epoch 136: 71.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0439
# 	Train Regression Loss: : 0.0048
# 	Train Mve Loss: : -0.1758
# 	Train R2 Score: : 0.9854
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0039
# 	Val Target Regression Loss: : 0.0052
# 	Val Source R2 Score: : 0.9881
# 	Val Target R2 Score: : 0.9846
# 	Val Source Mve Loss: : -0.1808
# 	Val Target Mve Loss: : -0.1729
# 	Val Source Nll Loss: : -2.2132
# 	Val Target Nll Loss: : -2.1163
#
# Epoch 137: 93.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0434
# 	Train Regression Loss: : 0.0047
# 	Train Mve Loss: : -0.1641
# 	Train R2 Score: : 0.9856
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0058
# 	Val Target Regression Loss: : 0.0075
# 	Val Source R2 Score: : 0.9823
# 	Val Target R2 Score: : 0.9775
# 	Val Source Mve Loss: : -0.2205
# 	Val Target Mve Loss: : -0.2128
# 	Val Source Nll Loss: : -1.9534
# 	Val Target Nll Loss: : -1.8855
#
# Epoch 138: 89.80s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0433
# 	Train Regression Loss: : 0.0054
# 	Train Mve Loss: : -0.1880
# 	Train R2 Score: : 0.9837
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0043
# 	Val Target Regression Loss: : 0.0058
# 	Val Source R2 Score: : 0.9866
# 	Val Target R2 Score: : 0.9828
# 	Val Source Mve Loss: : -0.2079
# 	Val Target Mve Loss: : -0.2007
# 	Val Source Nll Loss: : -2.0875
# 	Val Target Nll Loss: : -2.0146
#
# Epoch 139: 67.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0416
# 	Train Regression Loss: : 0.0047
# 	Train Mve Loss: : -0.1569
# 	Train R2 Score: : 0.9859
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0061
# 	Val Target Regression Loss: : 0.0075
# 	Val Source R2 Score: : 0.9814
# 	Val Target R2 Score: : 0.9779
# 	Val Source Mve Loss: : -0.1440
# 	Val Target Mve Loss: : -0.1343
# 	Val Source Nll Loss: : -2.0402
# 	Val Target Nll Loss: : -1.9024
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 140: 80.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0421
# 	Train Regression Loss: : 0.0049
# 	Train Mve Loss: : -0.1785
# 	Train R2 Score: : 0.9852
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0055
# 	Val Target Regression Loss: : 0.0075
# 	Val Source R2 Score: : 0.9831
# 	Val Target R2 Score: : 0.9778
# 	Val Source Mve Loss: : -0.1548
# 	Val Target Mve Loss: : -0.1414
# 	Val Source Nll Loss: : -2.1000
# 	Val Target Nll Loss: : -1.9185
#
# Epoch 141: 91.37s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0437
# 	Train Regression Loss: : 0.0210
# 	Train Mve Loss: : -0.1908
# 	Train R2 Score: : 0.9360
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0194
# 	Val Target Regression Loss: : 0.0222
# 	Val Source R2 Score: : 0.9402
# 	Val Target R2 Score: : 0.9342
# 	Val Source Mve Loss: : -0.3078
# 	Val Target Mve Loss: : -0.3054
# 	Val Source Nll Loss: : -0.5510
# 	Val Target Nll Loss: : -0.5466
#
# Epoch 142: 64.94s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0421
# 	Train Regression Loss: : 0.0121
# 	Train Mve Loss: : -0.3364
# 	Train R2 Score: : 0.9634
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0109
# 	Val Target Regression Loss: : 0.0135
# 	Val Source R2 Score: : 0.9666
# 	Val Target R2 Score: : 0.9599
# 	Val Source Mve Loss: : -0.3482
# 	Val Target Mve Loss: : -0.3452
# 	Val Source Nll Loss: : -0.7856
# 	Val Target Nll Loss: : -0.7790
#
# Epoch 143: 77.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0421
# 	Train Regression Loss: : 0.0093
# 	Train Mve Loss: : -0.3534
# 	Train R2 Score: : 0.9717
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0094
# 	Val Target Regression Loss: : 0.0114
# 	Val Source R2 Score: : 0.9713
# 	Val Target R2 Score: : 0.9659
# 	Val Source Mve Loss: : -0.3553
# 	Val Target Mve Loss: : -0.3527
# 	Val Source Nll Loss: : -0.9203
# 	Val Target Nll Loss: : -0.9138
# Saving Model MVE... Done.
#
# Epoch 144: 94.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0419
# 	Train Regression Loss: : 0.0090
# 	Train Mve Loss: : -0.3548
# 	Train R2 Score: : 0.9726
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0145
# 	Val Target Regression Loss: : 0.0160
# 	Val Source R2 Score: : 0.9556
# 	Val Target R2 Score: : 0.9522
# 	Val Source Mve Loss: : -0.3447
# 	Val Target Mve Loss: : -0.3424
# 	Val Source Nll Loss: : -1.0331
# 	Val Target Nll Loss: : -1.0265
#
# Epoch 145: 67.10s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0404
# 	Train Regression Loss: : 0.0086
# 	Train Mve Loss: : -0.3499
# 	Train R2 Score: : 0.9740
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0123
# 	Val Target Regression Loss: : 0.0141
# 	Val Source R2 Score: : 0.9621
# 	Val Target R2 Score: : 0.9581
# 	Val Source Mve Loss: : -0.3393
# 	Val Target Mve Loss: : -0.3364
# 	Val Source Nll Loss: : -1.1500
# 	Val Target Nll Loss: : -1.1412
#
# Epoch 146: 79.17s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0411
# 	Train Regression Loss: : 0.0080
# 	Train Mve Loss: : -0.3412
# 	Train R2 Score: : 0.9757
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0064
# 	Val Target Regression Loss: : 0.0077
# 	Val Source R2 Score: : 0.9805
# 	Val Target R2 Score: : 0.9772
# 	Val Source Mve Loss: : -0.3375
# 	Val Target Mve Loss: : -0.3350
# 	Val Source Nll Loss: : -1.2996
# 	Val Target Nll Loss: : -1.2901
#
# Epoch 147: 92.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0406
# 	Train Regression Loss: : 0.0079
# 	Train Mve Loss: : -0.3240
# 	Train R2 Score: : 0.9761
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0056
# 	Val Target Regression Loss: : 0.0068
# 	Val Source R2 Score: : 0.9828
# 	Val Target R2 Score: : 0.9796
# 	Val Source Mve Loss: : -0.3151
# 	Val Target Mve Loss: : -0.3120
# 	Val Source Nll Loss: : -1.4889
# 	Val Target Nll Loss: : -1.4755
#
# Epoch 148: 67.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0407
# 	Train Regression Loss: : 0.0068
# 	Train Mve Loss: : -0.2791
# 	Train R2 Score: : 0.9794
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0090
# 	Val Target Regression Loss: : 0.0099
# 	Val Source R2 Score: : 0.9725
# 	Val Target R2 Score: : 0.9705
# 	Val Source Mve Loss: : -0.2151
# 	Val Target Mve Loss: : -0.2104
# 	Val Source Nll Loss: : -1.7698
# 	Val Target Nll Loss: : -1.7271
#
# Epoch 149: 76.90s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0426
# 	Train Regression Loss: : 0.0060
# 	Train Mve Loss: : -0.1864
# 	Train R2 Score: : 0.9817
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0052
# 	Val Target Regression Loss: : 0.0068
# 	Val Source R2 Score: : 0.9840
# 	Val Target R2 Score: : 0.9796
# 	Val Source Mve Loss: : -0.1513
# 	Val Target Mve Loss: : -0.1388
# 	Val Source Nll Loss: : -2.0692
# 	Val Target Nll Loss: : -1.8799

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = save_mod_name#"models/papermve_v3_aug22_1315_C_mve" # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['val_source_nll_loss'], label = "Source Val NLL Loss")
plt.plot(eps, stats['val_target_nll_loss'], label = "Target Val NLL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-2, 1)
# Out:
# (-2.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.0))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9687

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.969')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | NLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | NLL: 131.683')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9579

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.958')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.273')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
