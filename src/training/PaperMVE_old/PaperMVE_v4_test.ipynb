# %%
# Imports we will use
import torch
import gc
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.autograd import Function
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import random
from pathlib import Path
from sklearn.metrics import r2_score
from astropy.visualization import make_lupton_rgb
from sklearn.manifold import Isomap
from train_utils import *
import time
import os
import json

# %matplotlib inline
plt.rcParams.update({'font.size': 12})

# Find if cuda is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#fix seed
seed = 13
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.enabled=False
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ## Load Data

# %%
# Specify paths, load in data, and subsample labels
head = Path.cwd().parents[1]
source_img_path = head / 'data/mb_paper_source_final/mb_paper_source_final.npy'
target_img_path = head / 'data/mb_paper_target_final/mb_paper_target_final.npy'
source_meta = head / 'data/mb_paper_source_final/mb_paper_source_final_metadata.csv'
target_meta = head / 'data/mb_paper_target_final/mb_paper_target_final_metadata.csv'
batch_size = 128
source_train_dataloader, source_test_dataloader, source_val_dataloader, source_data = create_dataloader(source_img_path, source_meta, batch_size)
target_train_dataloader, target_test_dataloader, target_val_dataloader, target_data = create_dataloader(target_img_path, target_meta, batch_size)
isomap_source_label_sample = pd.read_csv(source_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]
isomap_target_label_sample = pd.read_csv(target_meta)['PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g'].tolist()[:1000]

# %%
# Visualize source data
visualize_data(source_data)

# %%
# Visualize target data
visualize_data(target_data)

# %% [markdown]
# ## Model Setup

# %%
# Choose how you prefer to evolve beta and the DA Weight
def da_weight_function(epoch):
    """ Linear evolving DA weighting in loss function. """
    if epoch < evolv_epoch:
        da_weight = init_wt_da - ((init_wt_da - final_wt_da) * (epoch / n_epoch))
    else:
        da_weight = final_wt_da
    return da_weight

def beta_function(epoch):
    """ Linear evolving beta weighting in loss function until halfway through total epochs. """
    if epoch < evolv_epoch:
        beta_val = beta_init - (beta_init - beta_final) * (epoch / evolv_epoch)
    else:
        beta_val = beta_final
    return beta_val

# Initialize hyperparameters
learning_rate = 3e-5
n_epoch = 200

evolv_epoch = 150
init_wt_da = 1.4
final_wt_da = 1.0
beta_init = 1.0
beta_final = 0.5

# %%
from torch.optim.lr_scheduler import MultiStepLR
# Initialize model
model = NeuralNetworkMVE(npix=40).cuda()

# Loss Functions / Optimizers
regressor_loss_fn = nn.MSELoss().cuda()
da_loss_fn = MMD_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
#scheduler = MultiStepLR(optimizer, milestones=[100, 200, 250, 275], gamma=0.5)

# %%
# To continue training from a past model, enter path into load_mod_name
# Else, enter None, and you still have to run the function.
# Then, enter save_mod_name to save for the current run  

load_mod_name = None #"models/papermve_v1_aug20_1940_A" # "models/start_code_test_2"
stats, model, optimizer, best_target_R2, best_mve_loss = initialize_state(load_mod_name, model, optimizer)


#save_mod_name = load_mod_name # may overwrite loaded model
save_mod_name = "models/papermve_v4_test_aug23_2240"

# %% [markdown]
# ## Train

# %%
print("Beginning Training...")

#stats['lr'] = []
for curr_epoch in range(stats['epoch_no'], stats['epoch_no'] + n_epoch):

        # Generate isomaps every 20 epochs
        if (curr_epoch % 20 == 0):
            print("Generating Isomap...")
            source_iso, target_iso = generate_isomaps(source_data, target_data, model)
            show_isomaps(source_iso, 
                         target_iso, 
                         isomap_source_label_sample, 
                         isomap_target_label_sample, 
                         save_mod_name, 
                         name = stats["epoch_no"], 
                         axlim = 50, save = True)

        # Save best models
        if (len(stats['val_target_r2_score']) > 0):
            
            # Save and overwrite model every best target R2
            if (stats['val_target_r2_score'][-1] > best_target_R2):
                print("Saving Model...", end = ' ')
                save_model(save_mod_name, model, optimizer, stats)
                best_target_R2 = stats['val_target_r2_score'][-1]
                print("Done.")
                
            # Save and overwrite model every best target MVE Loss
            if (stats['val_target_mve_loss'][-1] < best_mve_loss):
                print("Saving Model MVE...", end = ' ')
                mve_name = save_mod_name + "_mve"
                save_model(mve_name, model, optimizer, stats)
                best_mve_loss = stats['val_target_mve_loss'][-1]
                print("Done.")

            if ((curr_epoch > 250) and (stats['val_target_r2_score'][-1] > 0.95) and (stats['val_target_mve_loss'][-1] < -1)):
                print("Saving Model Minima...", end = ' ')
                m_name = save_mod_name + f"_{curr_epoch}"
                save_model(m_name, model, optimizer, stats)
                print("Done.")

        
        start_time = time.time()

        beta = beta_function(curr_epoch)
        da_weight = da_weight_function(curr_epoch)

        # Train, backpropagate
        vals = train_loop_mve(source_train_dataloader, 
                              target_train_dataloader, 
                              model,
                              regressor_loss_fn, 
                              da_loss_fn, 
                              optimizer,
                              da_weight, 
                              beta)

        # Test, validate metrics
        vals_validate = test_loop_mve(source_val_dataloader, 
                                      target_val_dataloader,
                                      model, 
                                      regressor_loss_fn, 
                                      beta)

        #scheduler.step()

        # Training Metrics
        stats['train_DA_loss'].append(vals[0])
        stats['train_regression_loss'].append(vals[1])
        stats['train_mve_loss'].append(vals[2])
        stats['train_r2_score'].append(vals[3])

        # Validation Metrics
        stats['val_source_regression_loss'].append(vals_validate[0])
        stats['val_target_regression_loss'].append(vals_validate[1])
        stats['val_source_r2_score'].append(vals_validate[2])
        stats['val_target_r2_score'].append(vals_validate[3])
        stats['val_source_mve_loss'].append(vals_validate[4])
        stats['val_target_mve_loss'].append(vals_validate[5])
        
        # Other Parameters
        stats['da_weight'].append(da_weight)
        stats['beta'].append(beta)
        stats['epoch_no'] += 1
        #stats['lr'].append(scheduler.get_last_lr())
        print_epoch_scores(stats, curr_epoch, time.time() - start_time)
# Out:
# Beginning Training...
# Generating Isomap...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Epoch 0: 36.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.4657
# 	Train Regression Loss: : 2.0740
# 	Train Mve Loss: : 0.8835
# 	Train R2 Score: : -5.3215
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.7792
# 	Val Target Regression Loss: : 0.7237
# 	Val Source R2 Score: : -1.3843
# 	Val Target R2 Score: : -1.1479
# 	Val Source Mve Loss: : 0.2336
# 	Val Target Mve Loss: : 0.2026
# Saving Model MVE... Done.
#
# Epoch 1: 35.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.3153
# 	Train Regression Loss: : 0.4476
# 	Train Mve Loss: : 0.0647
# 	Train R2 Score: : -0.3531
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2847
# 	Val Target Regression Loss: : 0.2972
# 	Val Source R2 Score: : 0.1322
# 	Val Target R2 Score: : 0.1142
# 	Val Source Mve Loss: : -0.0216
# 	Val Target Mve Loss: : -0.0199
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 2: 34.42s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.2011
# 	Train Regression Loss: : 0.2445
# 	Train Mve Loss: : -0.0476
# 	Train R2 Score: : 0.2616
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.2012
# 	Val Target Regression Loss: : 0.2341
# 	Val Source R2 Score: : 0.3865
# 	Val Target R2 Score: : 0.3071
# 	Val Source Mve Loss: : -0.0715
# 	Val Target Mve Loss: : -0.0563
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 3: 34.74s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.1356
# 	Train Regression Loss: : 0.1689
# 	Train Mve Loss: : -0.0819
# 	Train R2 Score: : 0.4900
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.1335
# 	Val Target Regression Loss: : 0.1671
# 	Val Source R2 Score: : 0.5919
# 	Val Target R2 Score: : 0.5046
# 	Val Source Mve Loss: : -0.0881
# 	Val Target Mve Loss: : -0.0623
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 4: 35.11s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0964
# 	Train Regression Loss: : 0.1120
# 	Train Mve Loss: : -0.0872
# 	Train R2 Score: : 0.6622
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0929
# 	Val Target Regression Loss: : 0.1205
# 	Val Source R2 Score: : 0.7162
# 	Val Target R2 Score: : 0.6423
# 	Val Source Mve Loss: : -0.0788
# 	Val Target Mve Loss: : -0.0548
# Saving Model... Done.
#
# Epoch 5: 34.04s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0757
# 	Train Regression Loss: : 0.0830
# 	Train Mve Loss: : -0.0752
# 	Train R2 Score: : 0.7490
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0738
# 	Val Target Regression Loss: : 0.0950
# 	Val Source R2 Score: : 0.7751
# 	Val Target R2 Score: : 0.7166
# 	Val Source Mve Loss: : -0.0725
# 	Val Target Mve Loss: : -0.0508
# Saving Model... Done.
#
# Epoch 6: 35.15s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0628
# 	Train Regression Loss: : 0.0670
# 	Train Mve Loss: : -0.0689
# 	Train R2 Score: : 0.7972
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0600
# 	Val Target Regression Loss: : 0.0774
# 	Val Source R2 Score: : 0.8165
# 	Val Target R2 Score: : 0.7705
# 	Val Source Mve Loss: : -0.0619
# 	Val Target Mve Loss: : -0.0446
# Saving Model... Done.
#
# Epoch 7: 35.18s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0551
# 	Train Regression Loss: : 0.0552
# 	Train Mve Loss: : -0.0652
# 	Train R2 Score: : 0.8332
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0496
# 	Val Target Regression Loss: : 0.0638
# 	Val Source R2 Score: : 0.8483
# 	Val Target R2 Score: : 0.8109
# 	Val Source Mve Loss: : -0.0509
# 	Val Target Mve Loss: : -0.0390
# Saving Model... Done.
#
# Epoch 8: 34.58s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0498
# 	Train Regression Loss: : 0.0458
# 	Train Mve Loss: : -0.0702
# 	Train R2 Score: : 0.8615
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0421
# 	Val Target Regression Loss: : 0.0523
# 	Val Source R2 Score: : 0.8721
# 	Val Target R2 Score: : 0.8446
# 	Val Source Mve Loss: : -0.0677
# 	Val Target Mve Loss: : -0.0605
# Saving Model... Done.
#
# Epoch 9: 35.44s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0449
# 	Train Regression Loss: : 0.0385
# 	Train Mve Loss: : -0.0663
# 	Train R2 Score: : 0.8835
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0358
# 	Val Target Regression Loss: : 0.0436
# 	Val Source R2 Score: : 0.8906
# 	Val Target R2 Score: : 0.8701
# 	Val Source Mve Loss: : -0.0576
# 	Val Target Mve Loss: : -0.0500
# Saving Model... Done.
#
# Epoch 10: 34.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0414
# 	Train Regression Loss: : 0.0340
# 	Train Mve Loss: : -0.0779
# 	Train R2 Score: : 0.8969
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0326
# 	Val Target Regression Loss: : 0.0399
# 	Val Source R2 Score: : 0.8999
# 	Val Target R2 Score: : 0.8811
# 	Val Source Mve Loss: : -0.0505
# 	Val Target Mve Loss: : -0.0424
# Saving Model... Done.
#
# Epoch 11: 35.05s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0393
# 	Train Regression Loss: : 0.0310
# 	Train Mve Loss: : -0.0776
# 	Train R2 Score: : 0.9062
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0292
# 	Val Target Regression Loss: : 0.0361
# 	Val Source R2 Score: : 0.9096
# 	Val Target R2 Score: : 0.8917
# 	Val Source Mve Loss: : -0.0734
# 	Val Target Mve Loss: : -0.0712
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 12: 34.47s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0375
# 	Train Regression Loss: : 0.0282
# 	Train Mve Loss: : -0.1047
# 	Train R2 Score: : 0.9146
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0269
# 	Val Target Regression Loss: : 0.0329
# 	Val Source R2 Score: : 0.9174
# 	Val Target R2 Score: : 0.9023
# 	Val Source Mve Loss: : -0.0740
# 	Val Target Mve Loss: : -0.0706
# Saving Model... Done.
#
# Epoch 13: 33.87s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0363
# 	Train Regression Loss: : 0.0257
# 	Train Mve Loss: : -0.0573
# 	Train R2 Score: : 0.9222
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0244
# 	Val Target Regression Loss: : 0.0307
# 	Val Source R2 Score: : 0.9247
# 	Val Target R2 Score: : 0.9087
# 	Val Source Mve Loss: : -0.0509
# 	Val Target Mve Loss: : -0.0496
# Saving Model... Done.
#
# Epoch 14: 34.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0351
# 	Train Regression Loss: : 0.0238
# 	Train Mve Loss: : -0.0552
# 	Train R2 Score: : 0.9280
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0227
# 	Val Target Regression Loss: : 0.0279
# 	Val Source R2 Score: : 0.9309
# 	Val Target R2 Score: : 0.9167
# 	Val Source Mve Loss: : -0.0463
# 	Val Target Mve Loss: : -0.0461
# Saving Model... Done.
#
# Epoch 15: 34.52s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0337
# 	Train Regression Loss: : 0.0224
# 	Train Mve Loss: : -0.0918
# 	Train R2 Score: : 0.9321
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0219
# 	Val Target Regression Loss: : 0.0280
# 	Val Source R2 Score: : 0.9327
# 	Val Target R2 Score: : 0.9170
# 	Val Source Mve Loss: : -0.0712
# 	Val Target Mve Loss: : -0.0711
# Saving Model... Done.
#
# Epoch 16: 35.03s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0324
# 	Train Regression Loss: : 0.0213
# 	Train Mve Loss: : -0.0646
# 	Train R2 Score: : 0.9356
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0203
# 	Val Target Regression Loss: : 0.0262
# 	Val Source R2 Score: : 0.9377
# 	Val Target R2 Score: : 0.9211
# 	Val Source Mve Loss: : -0.1148
# 	Val Target Mve Loss: : -0.1142
# Saving Model... Done.
# Saving Model MVE... Done.
#
# Epoch 17: 34.95s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0319
# 	Train Regression Loss: : 0.0200
# 	Train Mve Loss: : -0.0589
# 	Train R2 Score: : 0.9393
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0200
# 	Val Target Regression Loss: : 0.0250
# 	Val Source R2 Score: : 0.9387
# 	Val Target R2 Score: : 0.9257
# 	Val Source Mve Loss: : -0.1084
# 	Val Target Mve Loss: : -0.1082
# Saving Model... Done.
#
# Epoch 18: 35.19s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0317
# 	Train Regression Loss: : 0.0193
# 	Train Mve Loss: : -0.0616
# 	Train R2 Score: : 0.9414
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0187
# 	Val Target Regression Loss: : 0.0249
# 	Val Source R2 Score: : 0.9424
# 	Val Target R2 Score: : 0.9259
# 	Val Source Mve Loss: : -0.0455
# 	Val Target Mve Loss: : -0.0456
# Saving Model... Done.
#
# Epoch 19: 35.61s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0309
# 	Train Regression Loss: : 0.0182
# 	Train Mve Loss: : -0.0449
# 	Train R2 Score: : 0.9449
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0181
# 	Val Target Regression Loss: : 0.0236
# 	Val Source R2 Score: : 0.9437
# 	Val Target R2 Score: : 0.9301
# 	Val Source Mve Loss: : -0.0365
# 	Val Target Mve Loss: : -0.0359
# Generating Isomap...
# Saving Model... Done.
#
# Epoch 20: 34.26s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0299
# 	Train Regression Loss: : 0.0174
# 	Train Mve Loss: : -0.0461
# 	Train R2 Score: : 0.9474
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0175
# 	Val Target Regression Loss: : 0.0227
# 	Val Source R2 Score: : 0.9464
# 	Val Target R2 Score: : 0.9320
# 	Val Source Mve Loss: : -0.0450
# 	Val Target Mve Loss: : -0.0438
# Saving Model... Done.
#
# Epoch 21: 34.32s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0286
# 	Train Regression Loss: : 0.0170
# 	Train Mve Loss: : -0.0925
# 	Train R2 Score: : 0.9484
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0167
# 	Val Target Regression Loss: : 0.0221
# 	Val Source R2 Score: : 0.9489
# 	Val Target R2 Score: : 0.9344
# 	Val Source Mve Loss: : -0.0717
# 	Val Target Mve Loss: : -0.0685
# Saving Model... Done.
#
# Epoch 22: 34.25s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0280
# 	Train Regression Loss: : 0.0164
# 	Train Mve Loss: : -0.0672
# 	Train R2 Score: : 0.9502
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0161
# 	Val Target Regression Loss: : 0.0218
# 	Val Source R2 Score: : 0.9504
# 	Val Target R2 Score: : 0.9353
# 	Val Source Mve Loss: : -0.0456
# 	Val Target Mve Loss: : -0.0454
# Saving Model... Done.
#
# Epoch 23: 34.41s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0279
# 	Train Regression Loss: : 0.0160
# 	Train Mve Loss: : -0.0603
# 	Train R2 Score: : 0.9514
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0158
# 	Val Target Regression Loss: : 0.0215
# 	Val Source R2 Score: : 0.9520
# 	Val Target R2 Score: : 0.9360
# 	Val Source Mve Loss: : -0.0469
# 	Val Target Mve Loss: : -0.0460
# Saving Model... Done.
#
# Epoch 24: 34.14s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0284
# 	Train Regression Loss: : 0.0156
# 	Train Mve Loss: : -0.0562
# 	Train R2 Score: : 0.9527
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0157
# 	Val Target Regression Loss: : 0.0210
# 	Val Source R2 Score: : 0.9516
# 	Val Target R2 Score: : 0.9373
# 	Val Source Mve Loss: : -0.0368
# 	Val Target Mve Loss: : -0.0366
# Saving Model... Done.
#
# Epoch 25: 34.35s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0263
# 	Train Regression Loss: : 0.0152
# 	Train Mve Loss: : -0.0570
# 	Train R2 Score: : 0.9541
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0150
# 	Val Target Regression Loss: : 0.0203
# 	Val Source R2 Score: : 0.9539
# 	Val Target R2 Score: : 0.9395
# 	Val Source Mve Loss: : -0.0443
# 	Val Target Mve Loss: : -0.0438
# Saving Model... Done.
#
# Epoch 26: 34.48s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0265
# 	Train Regression Loss: : 0.0148
# 	Train Mve Loss: : -0.0759
# 	Train R2 Score: : 0.9550
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0148
# 	Val Target Regression Loss: : 0.0195
# 	Val Source R2 Score: : 0.9547
# 	Val Target R2 Score: : 0.9418
# 	Val Source Mve Loss: : -0.0493
# 	Val Target Mve Loss: : -0.0479
# Saving Model... Done.
#
# Epoch 27: 34.02s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0251
# 	Train Regression Loss: : 0.0142
# 	Train Mve Loss: : -0.0432
# 	Train R2 Score: : 0.9569
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0147
# 	Val Target Regression Loss: : 0.0189
# 	Val Source R2 Score: : 0.9549
# 	Val Target R2 Score: : 0.9436
# 	Val Source Mve Loss: : -0.0493
# 	Val Target Mve Loss: : -0.0485
# Saving Model... Done.
#
# Epoch 28: 35.30s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0254
# 	Train Regression Loss: : 0.0141
# 	Train Mve Loss: : -0.0573
# 	Train R2 Score: : 0.9574
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0141
# 	Val Target Regression Loss: : 0.0188
# 	Val Source R2 Score: : 0.9568
# 	Val Target R2 Score: : 0.9438
# 	Val Source Mve Loss: : -0.0377
# 	Val Target Mve Loss: : -0.0361
# Saving Model... Done.
#
# Epoch 29: 33.56s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0243
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.0518
# 	Train R2 Score: : 0.9584
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0186
# 	Val Source R2 Score: : 0.9583
# 	Val Target R2 Score: : 0.9446
# 	Val Source Mve Loss: : -0.0795
# 	Val Target Mve Loss: : -0.0784
# Saving Model... Done.
#
# Epoch 30: 34.86s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0237
# 	Train Regression Loss: : 0.0134
# 	Train Mve Loss: : -0.0565
# 	Train R2 Score: : 0.9595
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0136
# 	Val Target Regression Loss: : 0.0177
# 	Val Source R2 Score: : 0.9583
# 	Val Target R2 Score: : 0.9473
# 	Val Source Mve Loss: : -0.0553
# 	Val Target Mve Loss: : -0.0537
# Saving Model... Done.
#
# Epoch 31: 33.83s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0223
# 	Train Regression Loss: : 0.0133
# 	Train Mve Loss: : -0.0866
# 	Train R2 Score: : 0.9597
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0137
# 	Val Target Regression Loss: : 0.0181
# 	Val Source R2 Score: : 0.9582
# 	Val Target R2 Score: : 0.9459
# 	Val Source Mve Loss: : -0.1077
# 	Val Target Mve Loss: : -0.1051
#
# Epoch 32: 33.85s
# -------------------------------
#  Training Statistics:
# 	Train Da Loss: : 0.0219
# 	Train Regression Loss: : 0.0137
# 	Train Mve Loss: : -0.1201
# 	Train R2 Score: : 0.9584
#  Validation Statistics:
# 	Val Source Regression Loss: : 0.0142
# 	Val Target Regression Loss: : 0.0183
# 	Val Source R2 Score: : 0.9564
# 	Val Target R2 Score: : 0.9454
# 	Val Source Mve Loss: : -0.1618
# 	Val Target Mve Loss: : -0.1592
# Saving Model MVE... Done.

# %%
# Saves the end result model after running for all stages, as well as the .json of stats

state = {
    'epoch': stats['epoch_no'],
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
}
final_mod_name = save_mod_name + "_final"
torch.save(state, final_mod_name)
json.dump(stats, open(final_mod_name+'.json', 'w'))

# %% [markdown]
# ## Visualize Results

# %%
# Loads a model for plotting/viz

viz_mod_name = "models/papermve_v3_aug22_1315_C_mve" # "models/start_code_test_4_final"
model.load_state_dict(torch.load(viz_mod_name)['state_dict'])
stats = json.load(open(viz_mod_name+'.json', 'r'))

# %%
# Visualize isomaps 
trained_source_iso, trained_target_iso = generate_isomaps(source_data, target_data, model)
show_isomaps(trained_source_iso, trained_target_iso, isomap_source_label_sample, isomap_target_label_sample, viz_mod_name, axlim = 50)
# Out:
# (<Figure size 1300x400 with 4 Axes>,
#  array([<Axes: title={'center': 'Source and Target'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Source Embedding'}, xlabel='Component 1', ylabel='Component 2'>,
#         <Axes: title={'center': 'Target Embedding'}, xlabel='Component 1', ylabel='Component 2'>],
#        dtype=object))

# %%
# DA Loss
fmt = lambda k: " ".join([i.capitalize() for i in k.split('_')])
eps = np.arange(stats["epoch_no"])
plt.title("DA Loss Error")
plt.plot(eps, stats['train_DA_loss'], label = "DA Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Estimator / Regression
plt.title("Estimator Error")
plt.plot(eps, stats['train_regression_loss'], label = "Training Regression Loss")
plt.plot(eps, stats['val_source_regression_loss'], label = "Source Val Regression Loss")
plt.plot(eps, stats['val_target_regression_loss'], label = "Target Val Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')

# %%
# BNLL for MVE
plt.title("BNLL Error")
plt.plot(eps, stats['train_mve_loss'], label = "Training MVE Loss")
plt.plot(eps, stats['val_source_mve_loss'], label = "Source Val MVE Loss")
plt.plot(eps, stats['val_target_mve_loss'], label = "Target Val MVE Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize = 'small')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
# R2 Scores
plt.title("R2 Scores")
plt.plot(eps, stats['train_r2_score'], label = "Training R2")
plt.plot(eps, stats['val_source_r2_score'], label = "Source Val R2")
plt.plot(eps, stats['val_target_r2_score'], label = "Target Val R2")
plt.xlabel("Epoch")
plt.ylabel("$R^2$")
plt.legend()
plt.ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
# Test Source
var_preds_source = np.array([])
preds_source = np.array([])
true_source = np.array([])
lbnll_source = np.array([])
score_list = np.array([])

with torch.no_grad():
    for X, y in source_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_source = np.append(preds_source, pred[:, 0].cpu())
        var_preds_source = np.append(var_preds_source, pred[:, 1].cpu())
        true_source = np.append(true_source, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_source = np.append(lbnll_source, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))

score = np.mean(score_list)
print(f'Source R2 Score is {score:.4f}')
# Out:
# Source R2 Score is 0.9613

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, preds_source,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Source | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Source | R2: 0.961')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_source, np.sqrt(var_preds_source),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Source | BNLL: {0:.3f}'.format(np.mean(lbnll_source)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Source | BNLL: -0.308')

# %%
# Test target
preds_target = np.array([])
var_preds_target = np.array([])
true_target = np.array([])
score_list = np.array([])
lbnll_target = np.array([])


with torch.no_grad():
    for X, y in target_test_dataloader:
        X = X.float()
        pred, _ = model(X.cuda())
        preds_target = np.append(preds_target, pred[:, 0].cpu())
        var_preds_target = np.append(var_preds_target, pred[:, 1].cpu())
        true_target = np.append(true_target, y.cpu())
        score = r2_score(y.cpu(), pred[:, 0].cpu())
        score_list = np.append(score_list, score)
        lbnll_target = np.append(lbnll_target, loss_bnll(pred[:, 0].cpu(), pred[:, 1].cpu(), y, beta = 0.5))


score = np.mean(score_list)
print(f'Target R2 Score is {score:.4f}')
# Out:
# Target R2 Score is 0.9382

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, preds_target,  color='black', alpha = 0.1)
line = np.linspace(1, 3, 100)
plt.plot(line, line)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.938')

# %%
plt.figure(figsize=(8,8))
idx = np.random.choice(np.arange(len(true_target)), 100)
plt.errorbar(true_target[idx], preds_target[idx], yerr = np.sqrt(var_preds_target[idx]), fmt = 'o', color='orange', ecolor = 'k', alpha = 1)
line = np.linspace(1, 3, 100)
plt.plot(line, line, lw = 3)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Predicted Theta E');
plt.rc('font', size=20)
plt.title('MMD | Target | R2: {0:.3f}'.format(np.mean(score_list)))
# Out:
# Text(0.5, 1.0, 'MMD | Target | R2: 0.938')

# %%
plt.figure(figsize=(8,8))
plt.scatter(true_target, np.sqrt(var_preds_target),  color='black', alpha = 0.1)
plt.rc('font', size=12)
plt.xlabel('True Theta E')
plt.ylabel('Error on Theta E');
plt.rc('font', size=20)
plt.title('Uncertainty | Target | BNLL: {0:.3f}'.format(np.mean(lbnll_target)))
# Out:
# Text(0.5, 1.0, 'Uncertainty | Target | BNLL: -0.291')

# %%
def sample_variance(obs, true):
    return np.std(obs - true) ** 2

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_source[rand_idx] - true_source[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_source[rand_idx])
sv = np.sqrt(sample_variance(preds_source, true_source))
mn = np.mean(resid_all)

# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=10, edgecolor='black', alpha=0.7)
ax_hist.set_title('Source Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 'x-small')

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()

# %%
n_points = 30
rand_idx = np.random.choice(np.arange(len(preds_source)), n_points)
residuals = preds_target[rand_idx] - true_target[rand_idx]
resid_all = preds_target - true_target
errors = np.sqrt(var_preds_target[rand_idx])
sv = np.sqrt(sample_variance(preds_target, true_target))
mn = np.mean(resid_all)
# Create the figure and axes
fig, (ax_hist, ax_resid) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [1, 3]}, figsize=(6, 8))



# Plot the histogram
ax_hist.hist(resid_all, bins=20, edgecolor='black', alpha=0.7)
ax_hist.set_title('Target Residuals')
ax_hist.set_ylabel('Frequency')

# Plot the residuals with error bars in the x-direction
ax_resid.errorbar(x=residuals, y=np.arange(n_points), xerr=errors, fmt='o', alpha=0.5, ecolor = 'k', color = 'k')
ax_resid.axvline(x=0, color='red', linestyle='--')
ax_resid.set_xlabel('Residuals (Predicted - True)')
ax_resid.set_ylabel('Data Point Index')
ax_resid.set_title('Sample Stdev: {0:.3f}'.format(sv))
ax_resid.axvspan(mn-sv, mn+sv, alpha = 0.5, label = "Sample Stdev")
ax_resid.axvline(mn, color = 'k', ls = '--', label = "Bias")
ax_resid.legend(loc = 'upper left', fontsize = 7)
ax_resid.sharex(ax_hist)

plt.xlim(-0.8, 0.8)

plt.tight_layout()
plt.show()
